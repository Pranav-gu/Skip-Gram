# %%
import torch
import numpy as np
import math
import torch.nn as nn
import pandas as pd
import re

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
skip_gram_embeddings = torch.load("skip-gram-word-vectors1.pt")
skip_gram_embeddings
# Out:
# {'Reuters': array([-0.485021  , -0.22831962,  0.37018558,  0.6738861 ,  0.02729357,
#         -0.24505594,  0.08561967, -0.28748474,  0.2091244 , -0.6306353 ,
#         -0.775046  ,  0.5930816 ,  0.23167622,  1.0884048 ,  0.1531802 ,
#         -1.0949636 ,  0.7206871 ,  0.31305924, -0.16668054,  0.33939946,
#          0.27809626, -0.15041062, -0.32272533, -0.13966677,  0.07866573,
#         -0.275185  , -0.45511195, -0.42056105,  0.77432925, -0.03655996,
#         -0.11016252,  0.21615253, -0.28735617, -0.01562322,  0.05912277,
#         -0.47739983, -0.59000796,  0.16255237, -0.51498735,  0.20325118,
#         -0.11311341,  0.35369092,  0.03094628,  0.01079833, -0.08045641,
#         -0.76955664, -0.537272  , -0.05266323,  0.18675391,  0.14749959],
#        dtype=float32),
#  '-': array([ 0.06046658,  0.11317125,  0.09143232, -0.05367319,  0.02383963,
#          0.06754354, -0.111431  ,  0.02517351,  0.1519315 ,  0.05162168,
#          0.14240478,  0.0061157 , -0.09423324,  0.10989027, -0.02062796,
#         -0.17302945,  0.00824061,  0.01760348,  0.11181966, -0.06086828,
#          0.09077251, -0.05447068,  0.1563073 ,  0.13257192,  0.0887022 ,
#          0.04878022, -0.02139307, -0.07067153, -0.01307219, -0.14716129,
#          0.04968451, -0.05875179, -0.01943431,  0.08910477, -0.10919197,
#          0.09378353, -0.10356253, -0.05208457,  0.07041235,  0.08666485,
#         -0.03301915,  0.10424332,  0.0988937 ,  0.08207797,  0.07887858,
#         -0.12010595, -0.2561348 , -0.0868926 , -0.13140833,  0.15011808],
#        dtype=float32),
#  'Short': array([-0.8699075 ,  0.4969765 , -0.30518365,  0.06820614, -0.7849748 ,
#          0.09913155, -1.0067071 , -0.25185558, -0.797895  ,  0.33315358,
#         -0.82801455,  0.57846385, -1.2024747 ,  0.8769716 , -0.18059093,
#         -0.39154267, -0.23106274, -0.16758646, -0.70695543, -1.3797946 ,
#          0.20886753,  0.61535746, -1.1173811 ,  0.66292465, -0.36691946,
#          1.030227  , -0.06546541, -0.30938378, -0.3302127 , -0.04429138,
#          0.24904552,  0.11410289,  0.5624242 , -0.46116996,  0.43709406,
#         -0.3050829 , -0.4157468 ,  0.8473337 ,  0.5727582 , -0.13815027,
#          0.24950428, -0.34621507, -1.1297544 ,  0.2248697 ,  0.6253655 ,
#         -0.8510845 , -1.6322823 , -1.0002662 ,  0.41022104,  0.29528677],
#        dtype=float32),
#  'sellers': array([ 1.3345814 ,  0.27725756,  1.096935  , -0.6289187 ,  1.3095982 ,
#          0.9126409 , -0.5720235 , -0.6934663 ,  1.1642978 , -0.23163718,
#         -1.3918478 , -0.16030836,  0.31116918, -0.8086196 , -0.56682324,
#         -0.27531734, -0.85387397, -0.418668  ,  0.07136396,  0.72327286,
#          0.50982416, -0.26195508, -1.0468104 , -0.73030764,  0.27678978,
#          0.5830022 ,  0.3015107 , -0.3358786 ,  0.36726844, -0.25098705,
#          1.0396827 ,  0.8001864 , -0.34711364,  0.42465273, -0.15099621,
#          0.02025679, -0.33088648,  1.1144052 , -0.30126137,  0.7605652 ,
#         -0.26909775,  0.5099736 , -1.2879957 , -0.05546594,  1.4633284 ,
#          0.6046392 , -0.8204095 , -0.4303917 , -0.20395523,  0.03081132],
#        dtype=float32),
#  ...}

# %%
class LSTM(nn.Module):
    def __init__(self, hidden_dim, output_dim, embedding_dim = 50, num_layers = 1):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True, bidirectional=False)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)
        
        # Initialize hidden state
        output, (hn, cn) = self.lstm(x, (h0, c0))
        
        # Take the output from the last time step

        output_last = output[:, -1]
        # Pass it through the fully connected layer
        output_fc = self.fc(output_last)
        
        return output_fc

        # output, (_, _) = self.lstm(x)
        # return self.fc(output)

# %%
skip_gram_embeddings['OOV'] = torch.randn(50, dtype = torch.float32)

# %%
data_train = pd.read_csv('train.csv')
length = []
for i in range(len(data_train['Description'])):
    sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][i])
    length.append(len(sentence))
length.sort()
max_len = length[int(0.95*len(length))]
max_len
# Out:
# 59

# %%
data = pd.read_csv('test.csv')
data
# Out:
#       Class Index                                        Description
# 0               3  Unions representing workers at Turner   Newall...
# 1               4  SPACE.com - TORONTO, Canada -- A second\team o...
# 2               4  AP - A company founded by a chemistry research...
# 3               4  AP - It's barely dawn when Mike Fitzpatrick st...
# 4               4  AP - Southern California's smog-fighting agenc...
# ...           ...                                                ...
# 7595            1  Ukrainian presidential candidate Viktor Yushch...
# 7596            2  With the supply of attractive pitching options...
# 7597            2  Like Roger Clemens did almost exactly eight ye...
# 7598            3  SINGAPORE : Doctors in the United States have ...
# 7599            3  EBay plans to buy the apartment and home renta...
#
# [7600 rows x 2 columns]

# %%
hidden_dim = 256
output_dim = data['Class Index'].unique().shape[0]

model = LSTM(hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
model
# Out:
# LSTM(
#   (lstm): LSTM(50, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in skip_gram_embeddings):
                    batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.24463333333333334	Loss = 0.01386810652911663
# Epoch = 1	Training Set Accuracy = 0.25096666666666667	Loss = 0.013823936693370342
# Epoch = 2	Training Set Accuracy = 0.299725	Loss = 0.013534355908632278
# Epoch = 3	Training Set Accuracy = 0.4957	Loss = 0.011000053957104683
# Epoch = 4	Training Set Accuracy = 0.7821	Loss = 0.005929304286837578
# Epoch = 5	Training Set Accuracy = 0.8516666666666667	Loss = 0.004233403597027063
# Epoch = 6	Training Set Accuracy = 0.8811083333333334	Loss = 0.0034833261743187904
# Epoch = 7	Training Set Accuracy = 0.9015666666666666	Loss = 0.00294856377877295
# Epoch = 8	Training Set Accuracy = 0.9170166666666667	Loss = 0.002536778338253498
# Epoch = 9	Training Set Accuracy = 0.928975	Loss = 0.0021996768191456795

# %%
batch_size = 100
model.eval()
correct = 0
test_loss = 0

for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in skip_gram_embeddings):
                batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()
print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Testing Set Accuracy = 0.8598684210526316	Loss = 0.004514516331255436

# %%
from sklearn.metrics import precision_score, f1_score, recall_score, confusion_matrix

# %%
torch.save(model, "skip-gram-classification-model.pt")

# %%
batch_size = 100
model.train()
precision = []
f1 = []
recall = []
correct = 0
train_loss = 0
import warnings
warnings.filterwarnings('ignore')


confusion = None
with torch.no_grad():
    for i in range(int(len(data_train['Description'])/batch_size)):
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in skip_gram_embeddings):
                    batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()

        pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
        true = y_true.cpu().numpy()
        precision.append(precision_score(pred, true, average='weighted'))
        f1.append(f1_score(pred, true, average='weighted'))
        recall.append(recall_score(pred, true, average='weighted'))
        confusion = confusion_matrix(pred, true)
        print(f"Confusion Matrix for Batch = {i} is {confusion}")

    print(f"Training Set Accuracy = {correct / len(data_train['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {train_loss/len(data_train['Description'])}\tConfusion Matrix = {confusion}")
# Out:
# Confusion Matrix for Batch = 0 is [[ 0  0  5  3]
#  [ 0  0  0  1]
#  [ 0  0 61  1]
#  [ 0  0 12 17]]
# Confusion Matrix for Batch = 1 is [[ 0  0 14]
#  [ 0  0  1]
#  [ 0  0 85]]
# Confusion Matrix for Batch = 2 is [[ 0  0  0  7]
#  [ 0  0  0  4]
#  [ 0  0  0  5]
#  [ 0  0  0 84]]
# Confusion Matrix for Batch = 3 is [[ 0  0  0  4]
#  [ 0  0  0  5]
#  [ 0  0  0  9]
#  [ 0  0  0 82]]
# Confusion Matrix for Batch = 4 is [[ 8  1  0  1]
#  [ 0 42  0  1]
#  [ 0  0  0  4]
#  [ 0  1  0 42]]
# Confusion Matrix for Batch = 5 is [[52  1  1  1]
#  [ 8 16  0  1]
#  [ 4  0  5  1]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 6 is [[31  0  1  0]
#  [ 6 41  0  0]
#  [ 2  0 14  0]
#  [ 2  0  0  3]]
# Confusion Matrix for Batch = 7 is [[36  0  2  1]
#  [ 1 25  0  0]
#  [ 2  0 13  3]
#  [ 0  0  4 13]]
# Confusion Matrix for Batch = 8 is [[24  0  0  0]
#  [ 1  8  0  1]
#  [ 1  0 34  1]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 9 is [[28  0  1  3]
#  [ 4  7  1  1]
#  [ 2  0 18  3]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 10 is [[27  1  1  3]
#  [ 3 19  0  1]
#  [ 3  0 15  3]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 11 is [[20  0  0  1]
#  [ 3 20  0  1]
#  [ 4  0 11  4]
#  [ 1  0  0 35]]
# Confusion Matrix for Batch = 12 is [[26  0  2  0]
#  [ 1 22  0  0]
#  [ 1  0 26  4]
#  [ 2  1  1 14]]
# Confusion Matrix for Batch = 13 is [[29  0  1  2]
#  [ 2 15  0  0]
#  [ 3  1 23  3]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 14 is [[18  0  0  2]
#  [ 4  5  0  0]
#  [ 4  0 41  3]
#  [ 1  0  0 22]]
# Confusion Matrix for Batch = 15 is [[23  0  0  3]
#  [ 2 22  0  1]
#  [ 2  0 12  4]
#  [ 1  0  0 30]]
# Confusion Matrix for Batch = 16 is [[12  0  0  1]
#  [ 1 21  0  0]
#  [ 1  0 35  6]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 17 is [[20  0  1  0]
#  [ 3 31  0  2]
#  [ 1  0 20  2]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 18 is [[17  0  0  2]
#  [ 1 22  0  1]
#  [ 2  0 19  4]
#  [ 1  0  0 31]]
# Confusion Matrix for Batch = 19 is [[19  1  0  1]
#  [ 5 15  0  0]
#  [ 0  0 25  6]
#  [ 2  0  0 26]]
# Confusion Matrix for Batch = 20 is [[19  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 25  4]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 21 is [[25  0  0  0]
#  [ 3 32  0  1]
#  [ 0  0 23  6]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 22 is [[17  2  2  1]
#  [ 0 44  0  0]
#  [ 0  0 22  3]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 23 is [[26  1  0  2]
#  [ 0 29  3  1]
#  [ 1  0 24  1]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 24 is [[33  0  0  0]
#  [ 2 30  0  0]
#  [ 3  0 22  2]
#  [ 0  0  1  7]]
# Confusion Matrix for Batch = 25 is [[34  0  0  1]
#  [ 0 15  0  0]
#  [ 2  0 28  5]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 26 is [[20  1  2  1]
#  [ 2 10  0  0]
#  [ 2  0 37  2]
#  [ 3  0  0 20]]
# Confusion Matrix for Batch = 27 is [[28  1  0  0]
#  [ 0 16  0  1]
#  [ 0  0 35  2]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 28 is [[15  1  2  1]
#  [ 0 14  0  0]
#  [ 0  0 34  2]
#  [ 0  0  4 27]]
# Confusion Matrix for Batch = 29 is [[18  1  0  0]
#  [ 0 23  0  0]
#  [ 2  0 29  3]
#  [ 0  0  2 22]]
# Confusion Matrix for Batch = 30 is [[27  0  0  0]
#  [ 3 21  0  0]
#  [ 3  0 10  1]
#  [ 2  0  0 33]]
# Confusion Matrix for Batch = 31 is [[19  1  1  0]
#  [ 1 12  0  0]
#  [ 0  0 33  1]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 32 is [[27  0  0  0]
#  [ 1 22  0  1]
#  [ 2  0 20  2]
#  [ 1  0  0 24]]
# Confusion Matrix for Batch = 33 is [[29  0  1  0]
#  [ 0 23  0  1]
#  [ 0  0 18  1]
#  [ 1  0  2 24]]
# Confusion Matrix for Batch = 34 is [[25  1  0  0]
#  [ 3 27  0  0]
#  [ 4  0 23  0]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 35 is [[26  0  0  1]
#  [ 3 24  0  0]
#  [ 2  0 33  0]
#  [ 1  0  0 10]]
# Confusion Matrix for Batch = 36 is [[23  0  0  1]
#  [ 1 32  0  0]
#  [ 1  0 30  2]
#  [ 2  0  0  8]]
# Confusion Matrix for Batch = 37 is [[23  1  0  1]
#  [ 0 25  1  0]
#  [ 0  0 18  3]
#  [ 0  0  1 27]]
# Confusion Matrix for Batch = 38 is [[23  0  0  2]
#  [ 1 19  1  1]
#  [ 2  0 33  3]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 39 is [[ 8  0  0  1]
#  [ 0  9  0  0]
#  [ 0  0 54  3]
#  [ 0  0  5 20]]
# Confusion Matrix for Batch = 40 is [[18  0  0  5]
#  [ 3 15  0  1]
#  [ 2  0  2 10]
#  [ 0  0  0 44]]
# Confusion Matrix for Batch = 41 is [[23  0  1  1]
#  [ 0 10  0  0]
#  [ 2  0 35  5]
#  [ 0  0  3 20]]
# Confusion Matrix for Batch = 42 is [[16  0  0  1]
#  [ 1 22  0  0]
#  [ 0  0 13 10]
#  [ 0  0  0 37]]
# Confusion Matrix for Batch = 43 is [[16  0  0  1]
#  [ 0 27  0  1]
#  [ 0  0 22  3]
#  [ 1  0  0 29]]
# Confusion Matrix for Batch = 44 is [[12  1  0  2]
#  [ 1 29  1  0]
#  [ 1  0 33  5]
#  [ 1  1  2 11]]
# Confusion Matrix for Batch = 45 is [[16  0  0  1]
#  [ 2 28  0  0]
#  [ 0  1 31  3]
#  [ 0  0  3 15]]
# Confusion Matrix for Batch = 46 is [[20  1  1  1]
#  [ 3 19  0  1]
#  [ 0  0 37  1]
#  [ 0  0  2 14]]
# Confusion Matrix for Batch = 47 is [[29  1  1  0]
#  [ 0 33  0  0]
#  [ 0  0 18  3]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 48 is [[35  0  0  1]
#  [ 2 18  0  1]
#  [ 4  0 16  2]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 49 is [[25  2  1  0]
#  [ 1 26  0  0]
#  [ 1  1 22  1]
#  [ 2  0  1 17]]
# Confusion Matrix for Batch = 50 is [[20  0  0  0]
#  [ 3 15  0  0]
#  [ 2  0 29  2]
#  [ 1  0  2 26]]
# Confusion Matrix for Batch = 51 is [[20  0  0  2]
#  [ 2 25  1  1]
#  [ 2  0 23  0]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 52 is [[22  0  1  2]
#  [ 0 17  0  0]
#  [ 4  0 28  5]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 53 is [[25  0  0  0]
#  [ 2 18  1  0]
#  [ 4  0 16  4]
#  [ 1  0  0 29]]
# Confusion Matrix for Batch = 54 is [[26  0  0  1]
#  [ 1 37  0  0]
#  [ 1  0 24  1]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 55 is [[37  2  1  1]
#  [ 2 32  0  1]
#  [ 1  0  8  2]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 56 is [[22  0  1  2]
#  [ 4 25  0  0]
#  [ 0  0 20  5]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 57 is [[33  0  1  0]
#  [ 2 28  1  1]
#  [ 1  0 21  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 58 is [[32  0  1  0]
#  [ 6 43  1  0]
#  [ 0  0  9  1]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 59 is [[29  0  1  0]
#  [ 4 28  0  1]
#  [ 3  0 19  1]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 60 is [[33  1  0  2]
#  [ 0 38  0  0]
#  [ 0  0 19  1]
#  [ 0  0  1  5]]
# Confusion Matrix for Batch = 61 is [[19  0  0  0]
#  [ 2 52  1  0]
#  [ 0  0 16  2]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 62 is [[28  0  2  1]
#  [ 0 31  0  1]
#  [ 0  0 20  2]
#  [ 1  0  2 12]]
# Confusion Matrix for Batch = 63 is [[29  0  2  0]
#  [ 1 38  1  0]
#  [ 1  0 19  1]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 64 is [[43  1  0  0]
#  [ 4 30  0  0]
#  [ 0  0 13  3]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 65 is [[26  0  2  1]
#  [ 3 34  0  0]
#  [ 0  0 16  1]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 66 is [[35  2  2  0]
#  [ 6 41  0  0]
#  [ 0  0  7  2]
#  [ 0  0  2  3]]
# Confusion Matrix for Batch = 67 is [[24  0  1  1]
#  [ 2 43  1  0]
#  [ 2  0  7  4]
#  [ 1  0  1 13]]
# Confusion Matrix for Batch = 68 is [[29  0  3  2]
#  [ 2 39  0  1]
#  [ 0  0 23  0]
#  [ 0  0  0  1]]
# Confusion Matrix for Batch = 69 is [[21  0  2  1]
#  [ 1 31  1  1]
#  [ 1  0 22  4]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 70 is [[23  0  0  2]
#  [ 0 37  0  0]
#  [ 1  0 26  3]
#  [ 1  0  0  7]]
# Confusion Matrix for Batch = 71 is [[19  0  2  0]
#  [ 1 34  0  1]
#  [ 0  0 30  0]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 72 is [[20  0  1  2]
#  [ 1 41  0  0]
#  [ 2  0 18  1]
#  [ 1  0  0 13]]
# Confusion Matrix for Batch = 73 is [[23  1  3  1]
#  [ 2 25  0  0]
#  [ 0  0 25  5]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 74 is [[25  1  1  0]
#  [ 1 15  1  0]
#  [ 1  0 34  0]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 75 is [[21  0  0  3]
#  [ 1 12  0  1]
#  [ 2  0 35  4]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 76 is [[28  1  2  1]
#  [ 1 19  2  0]
#  [ 2  0 19  4]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 77 is [[18  1  2  0]
#  [ 1 24  0  0]
#  [ 1  0 23  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 78 is [[19  0  1  1]
#  [ 1 15  0  0]
#  [ 1  0 30  0]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 79 is [[17  1  0  2]
#  [ 0 12  0  0]
#  [ 0  0 30  4]
#  [ 0  0  1 33]]
# Confusion Matrix for Batch = 80 is [[15  0  1  0]
#  [ 2 24  0  2]
#  [ 2  0 24  2]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 81 is [[22  0  0  1]
#  [ 1 27  0  2]
#  [ 3  0 27  0]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 82 is [[25  0  1  0]
#  [ 3 33  0  0]
#  [ 0  0 19  3]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 83 is [[16  0  2  0]
#  [ 2 29  1  0]
#  [ 0  0 30  4]
#  [ 0  0  4 12]]
# Confusion Matrix for Batch = 84 is [[23  0  3  2]
#  [ 0 22  0  0]
#  [ 1  0 34  6]
#  [ 0  0  2  7]]
# Confusion Matrix for Batch = 85 is [[20  0  1  2]
#  [ 0 29  0  0]
#  [ 0  0 27  6]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 86 is [[28  0  1  0]
#  [ 4 15  1  2]
#  [ 2  1 23  2]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 87 is [[21  0  1  3]
#  [ 2 16  0  1]
#  [ 1  0 28  3]
#  [ 1  0  1 22]]
# Confusion Matrix for Batch = 88 is [[21  0  1  4]
#  [ 0 19  1  0]
#  [ 0  0 30  4]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 89 is [[16  0  2  2]
#  [ 1 21  0  0]
#  [ 1  0 25  6]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 90 is [[14  0  1  2]
#  [ 2 16  0  0]
#  [ 0  0 38  5]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 91 is [[14  1  3  2]
#  [ 1 17  0  0]
#  [ 0  0 24  5]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 92 is [[13  0  3  0]
#  [ 0 21  1  0]
#  [ 1  0 27  2]
#  [ 1  0  1 30]]
# Confusion Matrix for Batch = 93 is [[28  0  0  2]
#  [ 3 26  0  1]
#  [ 0  0  7  5]
#  [ 3  0  3 22]]
# Confusion Matrix for Batch = 94 is [[16  0  0  3]
#  [ 1 14  0  1]
#  [ 0  0 24  7]
#  [ 1  0  1 32]]
# Confusion Matrix for Batch = 95 is [[15  0  2  1]
#  [ 1 19  0  0]
#  [ 0  0 19  4]
#  [ 0  0  1 38]]
# Confusion Matrix for Batch = 96 is [[27  1  0  1]
#  [ 0 15  1  0]
#  [ 1  0 20  4]
#  [ 0  1  1 28]]
# Confusion Matrix for Batch = 97 is [[22  0  2  2]
#  [ 0 17  0  2]
#  [ 1  0 20  5]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 98 is [[10  1  1  2]
#  [ 1 13  1  1]
#  [ 0  0 26  8]
#  [ 2  0  1 33]]
# Confusion Matrix for Batch = 99 is [[14  0  1  0]
#  [ 0 18  0  0]
#  [ 2  0 25  8]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 100 is [[20  0  0  1]
#  [ 0 19  0  0]
#  [ 1  0 30  4]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 101 is [[23  0  0  3]
#  [ 1 22  0  2]
#  [ 2  0 26  4]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 102 is [[20  1  0  0]
#  [ 2 30  0  0]
#  [ 1  0 28  3]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 103 is [[33  0  1  1]
#  [ 1 26  0  0]
#  [ 0  0 20  3]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 104 is [[27  0  0  1]
#  [ 0 28  2  0]
#  [ 1  0 31  2]
#  [ 0  0  2  6]]
# Confusion Matrix for Batch = 105 is [[18  1  0  0]
#  [ 2 14  0  1]
#  [ 1  0 20  7]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 106 is [[14  1  0  1]
#  [ 0 20  0  1]
#  [ 0  0 35  4]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 107 is [[20  0  2  2]
#  [ 4 13  0  1]
#  [ 2  0 27  0]
#  [ 2  0  0 27]]
# Confusion Matrix for Batch = 108 is [[19  0  0  0]
#  [ 0 17  1  0]
#  [ 1  0 31  3]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 109 is [[17  1  1  0]
#  [ 0 14  0  0]
#  [ 1  0 32  4]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 110 is [[16  0  0  1]
#  [ 1  7  0  2]
#  [ 1  0 28 11]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 111 is [[16  0  2  0]
#  [ 2 27  0  0]
#  [ 4  0 20 10]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 112 is [[24  0  0  0]
#  [ 1 29  0  1]
#  [ 0  0 28  0]
#  [ 0  1  0 16]]
# Confusion Matrix for Batch = 113 is [[21  0  0  1]
#  [ 0 27  0  0]
#  [ 0  1 29  5]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 114 is [[22  0  1  0]
#  [ 0 27  0  0]
#  [ 0  0 34  3]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 115 is [[23  0  1  1]
#  [ 0 27  0  2]
#  [ 0  0 21  5]
#  [ 0  0  4 16]]
# Confusion Matrix for Batch = 116 is [[27  0  1  1]
#  [ 1 31  0  1]
#  [ 0  0 18  2]
#  [ 1  0  0 17]]
# Confusion Matrix for Batch = 117 is [[14  2  1  2]
#  [ 1 31  0  1]
#  [ 0  0 22  3]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 118 is [[26  0  0  3]
#  [ 2 17  0  0]
#  [ 0  0 23  8]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 119 is [[15  0  1  2]
#  [ 0 17  0  1]
#  [ 0  0 29  1]
#  [ 1  0  1 32]]
# Confusion Matrix for Batch = 120 is [[16  1  1  1]
#  [ 1 21  0  0]
#  [ 3  0 28  3]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 121 is [[22  0  0  1]
#  [ 1 19  0  0]
#  [ 2  0 21  5]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 122 is [[17  0  2  2]
#  [ 0 24  0  1]
#  [ 4  0 19  5]
#  [ 0  0  3 23]]
# Confusion Matrix for Batch = 123 is [[21  0  0  0]
#  [ 1 27  0  0]
#  [ 1  0 14  3]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 124 is [[24  1  1  0]
#  [ 2 21  0  0]
#  [ 1  0 16  8]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 125 is [[15  0  0  0]
#  [ 1 30  0  0]
#  [ 0  0 17  4]
#  [ 0  0  3 30]]
# Confusion Matrix for Batch = 126 is [[18  0  2  0]
#  [ 2 34  1  0]
#  [ 0  0 18  4]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 127 is [[26  2  4  2]
#  [ 1 41  0  0]
#  [ 1  0 14  1]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 128 is [[29  2  0  1]
#  [ 0 41  0  0]
#  [ 0  0 13  4]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 129 is [[27  1  2  1]
#  [ 2 40  0  0]
#  [ 1  0 16  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 130 is [[35  2  0  0]
#  [ 1 33  0  0]
#  [ 0  0 15  1]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 131 is [[42  2  0  2]
#  [ 1 33  0  0]
#  [ 0  0  8  4]
#  [ 0  0  1  7]]
# Confusion Matrix for Batch = 132 is [[32  3  0  0]
#  [ 4 47  0  0]
#  [ 0  0  5  1]
#  [ 0  0  1  7]]
# Confusion Matrix for Batch = 133 is [[28  1  0  0]
#  [ 1 46  2  0]
#  [ 2  0 12  1]
#  [ 1  1  0  5]]
# Confusion Matrix for Batch = 134 is [[35  1  2  0]
#  [ 0 49  0  0]
#  [ 0  0  3  0]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 135 is [[37  1  1  1]
#  [ 1 26  0  0]
#  [ 2  0 14  3]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 136 is [[32  0  0  0]
#  [ 0 36  0  0]
#  [ 0  2 19  1]
#  [ 1  0  1  8]]
# Confusion Matrix for Batch = 137 is [[44  1  0  2]
#  [ 1 24  0  0]
#  [ 2  0 12  1]
#  [ 2  0  0 11]]
# Confusion Matrix for Batch = 138 is [[39  0  2  0]
#  [ 0 41  0  0]
#  [ 0  0  8  3]
#  [ 0  1  1  5]]
# Confusion Matrix for Batch = 139 is [[42  2  1  0]
#  [ 1 35  0  0]
#  [ 0  0  7  4]
#  [ 0  0  1  7]]
# Confusion Matrix for Batch = 140 is [[34  0  0  0]
#  [ 1 44  0  1]
#  [ 1  0  6  2]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 141 is [[32  1  3  3]
#  [ 1 29  0  0]
#  [ 1  0 19  2]
#  [ 1  0  1  7]]
# Confusion Matrix for Batch = 142 is [[26  0  2  0]
#  [ 0 30  0  1]
#  [ 0  0 21  4]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 143 is [[25  0  3  0]
#  [ 1 40  0  0]
#  [ 0  0 17  3]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 144 is [[34  1  0  2]
#  [ 2 23  0  1]
#  [ 2  0 14  2]
#  [ 0  1  7 11]]
# Confusion Matrix for Batch = 145 is [[22  0  2  2]
#  [ 1 23  0  0]
#  [ 3  0 23  2]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 146 is [[26  0  0  1]
#  [ 0 10  1  0]
#  [ 2  0 30  4]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 147 is [[25  0  1  1]
#  [ 2 15  0  0]
#  [ 1  0 25  0]
#  [ 0  1  2 27]]
# Confusion Matrix for Batch = 148 is [[26  0  1  1]
#  [ 0 13  0  2]
#  [ 4  0 24  4]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 149 is [[23  0  0  1]
#  [ 1 22  0  0]
#  [ 1  0 27  1]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 150 is [[15  0  0  1]
#  [ 0 22  1  1]
#  [ 1  0 19  4]
#  [ 0  0  2 34]]
# Confusion Matrix for Batch = 151 is [[14  0  1  6]
#  [ 1  9  0  0]
#  [ 4  0 19  4]
#  [ 1  0  1 40]]
# Confusion Matrix for Batch = 152 is [[26  0  0  1]
#  [ 1 30  1  1]
#  [ 1  0 20  5]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 153 is [[17  0  0  2]
#  [ 0 25  1  1]
#  [ 0  0 25  4]
#  [ 1  0  1 23]]
# Confusion Matrix for Batch = 154 is [[25  0  1  1]
#  [ 1 24  2  1]
#  [ 0  0 16  5]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 155 is [[21  0  0  3]
#  [ 2 15  1  0]
#  [ 2  0 31  3]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 156 is [[17  1  1  3]
#  [ 0 13  1  1]
#  [ 2  0 22  3]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 157 is [[17  0  0  0]
#  [ 0 13  0  0]
#  [ 1  0 32  7]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 158 is [[22  0  1  1]
#  [ 2 19  0  0]
#  [ 0  0 30  1]
#  [ 1  0  2 21]]
# Confusion Matrix for Batch = 159 is [[12  0  1  4]
#  [ 0 12  0  1]
#  [ 2  0 20  7]
#  [ 1  0  1 39]]
# Confusion Matrix for Batch = 160 is [[25  1  1  4]
#  [ 0 37  0  0]
#  [ 0  0 17  3]
#  [ 1  0  0 11]]
# Confusion Matrix for Batch = 161 is [[21  1  0  3]
#  [ 0 19  0  0]
#  [ 1  0 20  3]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 162 is [[32  1  3  2]
#  [ 3 18  0  0]
#  [ 3  0 17  2]
#  [ 1  0  2 16]]
# Confusion Matrix for Batch = 163 is [[14  0  1  0]
#  [ 0  8  1  0]
#  [ 1  0 28  6]
#  [ 1  0  2 38]]
# Confusion Matrix for Batch = 164 is [[28  2  0  0]
#  [ 0 24  0  0]
#  [ 1  0 27  1]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 165 is [[13  0  0  1]
#  [ 0 10  0  0]
#  [ 2  0 14  7]
#  [ 0  0  0 53]]
# Confusion Matrix for Batch = 166 is [[12  0  1  4]
#  [ 0 22  0  0]
#  [ 1  0 18  2]
#  [ 0  0  0 40]]
# Confusion Matrix for Batch = 167 is [[27  0  0  0]
#  [ 0 22  0  1]
#  [ 3  1 11  2]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 168 is [[23  1  0  1]
#  [ 2 32  0  0]
#  [ 0  1 22  1]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 169 is [[29  1  0  0]
#  [ 0 28  0  0]
#  [ 1  0 16  3]
#  [ 1  0  3 18]]
# Confusion Matrix for Batch = 170 is [[24  0  0  4]
#  [ 0 27  1  2]
#  [ 1  0  9  3]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 171 is [[31  0  3  0]
#  [ 1 10  0  0]
#  [ 4  0 32  3]
#  [ 0  0  2 14]]
# Confusion Matrix for Batch = 172 is [[16  1  0  4]
#  [ 0 14  0  0]
#  [ 0  0 15  5]
#  [ 0  0  3 42]]
# Confusion Matrix for Batch = 173 is [[19  0  1  1]
#  [ 0 26  0  0]
#  [ 0  0 18  4]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 174 is [[18  0  4  0]
#  [ 3 35  0  0]
#  [ 0  0 32  0]
#  [ 1  0  1  6]]
# Confusion Matrix for Batch = 175 is [[11  0  1  2]
#  [ 1 11  0  0]
#  [ 0  0 14 12]
#  [ 0  0  0 48]]
# Confusion Matrix for Batch = 176 is [[37  0  1  1]
#  [ 1 10  0  0]
#  [ 0  0 24  5]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 177 is [[17  1  0  2]
#  [ 0 19  0  0]
#  [ 0  0 29  6]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 178 is [[28  0  2  1]
#  [ 0 19  1  0]
#  [ 5  0 18  1]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 179 is [[24  0  0  4]
#  [ 0 14  0  1]
#  [ 0  0 10  3]
#  [ 0  0  0 44]]
# Confusion Matrix for Batch = 180 is [[25  0  2  0]
#  [ 1 31  0  1]
#  [ 0  0 18  4]
#  [ 1  0  1 16]]
# Confusion Matrix for Batch = 181 is [[24  0  0  0]
#  [ 2 39  0  0]
#  [ 2  0 15  2]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 182 is [[34  0  2  1]
#  [ 1 33  0  0]
#  [ 0  0 17  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 183 is [[26  1  1  3]
#  [ 2 40  0  0]
#  [ 0  0 13  1]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 184 is [[44  0  1  1]
#  [ 0 23  1  1]
#  [ 2  0 15  1]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 185 is [[30  0  0  0]
#  [ 3 40  0  1]
#  [ 1  0 12  0]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 186 is [[26  0  1  0]
#  [ 2 41  0  0]
#  [ 1  0 19  2]
#  [ 1  0  4  3]]
# Confusion Matrix for Batch = 187 is [[35  0  2  1]
#  [ 1 29  0  0]
#  [ 1  0 22  1]
#  [ 1  0  0  7]]
# Confusion Matrix for Batch = 188 is [[21  0  1  0]
#  [ 0 56  0  1]
#  [ 0  0 13  1]
#  [ 1  0  0  6]]
# Confusion Matrix for Batch = 189 is [[34  0  1  1]
#  [ 0 28  1  0]
#  [ 0  0 16  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 190 is [[40  0  0  0]
#  [ 1 27  0  0]
#  [ 2  0 19  2]
#  [ 1  0  0  8]]
# Confusion Matrix for Batch = 191 is [[24  0  0  1]
#  [ 1 36  0  3]
#  [ 0  0 20  3]
#  [ 1  0  1 10]]
# Confusion Matrix for Batch = 192 is [[25  0  2  1]
#  [ 0 40  1  0]
#  [ 0  0 17  2]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 193 is [[26  0  2  0]
#  [ 0 39  1  0]
#  [ 0  0 16  2]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 194 is [[34  0  1  0]
#  [ 0 32  1  1]
#  [ 0  0 19  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 195 is [[28  0  2  2]
#  [ 2 27  1  0]
#  [ 1  0 18  0]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 196 is [[25  0  1  4]
#  [ 2 16  0  0]
#  [ 1  0 22  4]
#  [ 1  0  0 24]]
# Confusion Matrix for Batch = 197 is [[28  0  5  2]
#  [ 0 18  0  1]
#  [ 1  0 25  4]
#  [ 1  0  0 15]]
# Confusion Matrix for Batch = 198 is [[25  0  2  4]
#  [ 0 23  0  0]
#  [ 2  0 17  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 199 is [[30  0  1  0]
#  [ 1 30  0  0]
#  [ 2  0 15  2]
#  [ 2  0  0 17]]
# Confusion Matrix for Batch = 200 is [[30  0  4  1]
#  [ 4 32  0  3]
#  [ 0  0 12  1]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 201 is [[29  0  0  1]
#  [ 2 36  0  0]
#  [ 0  0 16  0]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 202 is [[26  2  1  0]
#  [ 1 37  0  2]
#  [ 0  0 19  3]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 203 is [[27  0  0  1]
#  [ 2 30  0  0]
#  [ 0  0 22  0]
#  [ 0  1  1 16]]
# Confusion Matrix for Batch = 204 is [[25  0  2  2]
#  [ 1 27  0  0]
#  [ 1  0 28  3]
#  [ 0  0  2  9]]
# Confusion Matrix for Batch = 205 is [[25  0  2  1]
#  [ 2 13  0  0]
#  [ 0  0 25  8]
#  [ 1  0  1 22]]
# Confusion Matrix for Batch = 206 is [[15  2  2  2]
#  [ 0 12  0  0]
#  [ 0  0 15  7]
#  [ 0  0  0 45]]
# Confusion Matrix for Batch = 207 is [[14  0  0  1]
#  [ 0 17  0  1]
#  [ 1  0 29  2]
#  [ 0  0  1 34]]
# Confusion Matrix for Batch = 208 is [[25  0  0  3]
#  [ 1 11  0  2]
#  [ 2  0 15  7]
#  [ 0  0  2 32]]
# Confusion Matrix for Batch = 209 is [[24  0  1  1]
#  [ 0 10  0  1]
#  [ 0  0 30  2]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 210 is [[29  0  0  4]
#  [ 2 24  0  0]
#  [ 1  0 14  3]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 211 is [[11  0  0  1]
#  [ 0 20  0  0]
#  [ 1  1 15  5]
#  [ 0  0  0 46]]
# Confusion Matrix for Batch = 212 is [[19  0  0  2]
#  [ 0 31  2  0]
#  [ 0  0 24  4]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 213 is [[24  0  0  1]
#  [ 2 21  0  0]
#  [ 1  0 23  3]
#  [ 1  0  0 24]]
# Confusion Matrix for Batch = 214 is [[23  0  2  1]
#  [ 1 19  0  1]
#  [ 0  0 32  2]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 215 is [[25  0  0  1]
#  [ 1 26  0  2]
#  [ 0  0 20  3]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 216 is [[20  0  1  2]
#  [ 0 19  0  1]
#  [ 0  0 27  3]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 217 is [[20  0  0  2]
#  [ 3 12  2  1]
#  [ 6  0 26  2]
#  [ 3  0  0 23]]
# Confusion Matrix for Batch = 218 is [[13  0  1  3]
#  [ 0 17  0  0]
#  [ 1  0 18  2]
#  [ 0  0  1 44]]
# Confusion Matrix for Batch = 219 is [[25  0  0  2]
#  [ 0 13  0  0]
#  [ 2  0 25  1]
#  [ 2  0  1 29]]
# Confusion Matrix for Batch = 220 is [[19  0  0  0]
#  [ 0 20  0  0]
#  [ 0  0 16  4]
#  [ 1  0  0 40]]
# Confusion Matrix for Batch = 221 is [[25  0  0  0]
#  [ 2 25  0  0]
#  [ 1  0 22  2]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 222 is [[19  0  0  2]
#  [ 1 19  0  2]
#  [ 0  0 27  5]
#  [ 1  0  0 24]]
# Confusion Matrix for Batch = 223 is [[26  0  0  1]
#  [ 0 32  1  1]
#  [ 3  0 18  2]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 224 is [[22  0  0  0]
#  [ 1 30  0  0]
#  [ 1  0 22  3]
#  [ 1  0  0 20]]
# Confusion Matrix for Batch = 225 is [[21  0  1  0]
#  [ 1 25  0  0]
#  [ 0  0 27  1]
#  [ 1  0  4 19]]
# Confusion Matrix for Batch = 226 is [[14  0  0  1]
#  [ 1 21  0  1]
#  [ 1  0 35  2]
#  [ 1  0  0 23]]
# Confusion Matrix for Batch = 227 is [[24  0  1  6]
#  [ 0  2  0  1]
#  [ 4  0 16  5]
#  [ 1  0  0 40]]
# Confusion Matrix for Batch = 228 is [[22  1  0  0]
#  [ 1 23  1  1]
#  [ 1  0 22  0]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 229 is [[24  0  0  2]
#  [ 0 18  0  1]
#  [ 1  0 25  3]
#  [ 1  0  0 25]]
# Confusion Matrix for Batch = 230 is [[19  0  0  3]
#  [ 1 22  0  0]
#  [ 1  0 21  5]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 231 is [[34  0  0  0]
#  [ 2 19  0  1]
#  [ 1  0 16  3]
#  [ 0  1  1 22]]
# Confusion Matrix for Batch = 232 is [[11  0  0  3]
#  [ 0 22  0  0]
#  [ 1  0 16  6]
#  [ 0  0  0 41]]
# Confusion Matrix for Batch = 233 is [[16  0  1  0]
#  [ 4 33  0  0]
#  [ 2  0 22  2]
#  [ 2  0  1 17]]
# Confusion Matrix for Batch = 234 is [[21  1  0  1]
#  [ 0 35  0  0]
#  [ 2  1 19  4]
#  [ 2  0  0 14]]
# Confusion Matrix for Batch = 235 is [[16  0  0  2]
#  [ 1 18  0  1]
#  [ 3  0 31  3]
#  [ 0  1  1 23]]
# Confusion Matrix for Batch = 236 is [[19  1  1  2]
#  [ 2 25  0  0]
#  [ 1  0 21  1]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 237 is [[18  0  0  0]
#  [ 0 11  1  0]
#  [ 2  0 24  1]
#  [ 0  0  1 42]]
# Confusion Matrix for Batch = 238 is [[17  0  2  0]
#  [ 0 26  0  1]
#  [ 1  0 27  4]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 239 is [[29  0  0  4]
#  [ 0  9  0  0]
#  [ 3  0 21  5]
#  [ 1  0  2 26]]
# Confusion Matrix for Batch = 240 is [[13  0  1  3]
#  [ 0 25  0  0]
#  [ 0  0 21  4]
#  [ 0  0  1 32]]
# Confusion Matrix for Batch = 241 is [[21  1  0  2]
#  [ 2 19  1  1]
#  [ 0  0 15  3]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 242 is [[23  0  0  0]
#  [ 2 36  0  0]
#  [ 1  0 19  1]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 243 is [[28  0  0  0]
#  [ 1 40  0  2]
#  [ 1  0 14  1]
#  [ 1  0  2 10]]
# Confusion Matrix for Batch = 244 is [[39  0  1  1]
#  [ 0 29  0  1]
#  [ 1  0 16  0]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 245 is [[36  0  0  0]
#  [ 1 39  0  0]
#  [ 0  0 11  0]
#  [ 1  0  1 11]]
# Confusion Matrix for Batch = 246 is [[30  0  0  1]
#  [ 3 40  0  0]
#  [ 1  0 18  1]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 247 is [[25  2  2  1]
#  [ 0 36  0  0]
#  [ 0  0 10  4]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 248 is [[44  1  1  0]
#  [ 0 28  0  1]
#  [ 0  0 18  2]
#  [ 1  1  1  2]]
# Confusion Matrix for Batch = 249 is [[22  0  2  0]
#  [ 1 57  1  0]
#  [ 0  0 10  0]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 250 is [[35  0  1  0]
#  [ 2 41  0  0]
#  [ 0  0 11  0]
#  [ 0  0  2  8]]
# Confusion Matrix for Batch = 251 is [[42  0  0  1]
#  [ 1 28  1  0]
#  [ 1  0 12  2]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 252 is [[38  2  0  0]
#  [ 1 28  0  0]
#  [ 0  0 10  2]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 253 is [[30  0  0  0]
#  [ 2 38  0  0]
#  [ 4  0 20  0]
#  [ 1  0  1  4]]
# Confusion Matrix for Batch = 254 is [[27  0  0  0]
#  [ 1 35  0  0]
#  [ 0  0 19  1]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 255 is [[16  0  1  0]
#  [ 0 24  1  0]
#  [ 0  0 36  3]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 256 is [[39  0  0  0]
#  [ 1 20  0  0]
#  [ 3  0  9  5]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 257 is [[17  1  1  0]
#  [ 0 24  0  1]
#  [ 0  0 21  3]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 258 is [[41  1  0  0]
#  [ 1 10  0  0]
#  [ 2  0 22  0]
#  [ 2  0  2 19]]
# Confusion Matrix for Batch = 259 is [[10  0  3  2]
#  [ 0 10  0  2]
#  [ 3  0 23  2]
#  [ 1  0  3 41]]
# Confusion Matrix for Batch = 260 is [[24  0  0  0]
#  [ 2 15  0  0]
#  [ 2  0 24  4]
#  [ 0  0  2 27]]
# Confusion Matrix for Batch = 261 is [[19  0  0  2]
#  [ 1 19  0  1]
#  [ 0  1 18  3]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 262 is [[27  1  1  0]
#  [ 2 15  0  0]
#  [ 2  0 13  4]
#  [ 0  0  2 33]]
# Confusion Matrix for Batch = 263 is [[19  0  0  0]
#  [ 1 20  0  0]
#  [ 1  0 29  1]
#  [ 2  0  2 25]]
# Confusion Matrix for Batch = 264 is [[25  1  0  1]
#  [ 0 25  0  0]
#  [ 1  0 20  0]
#  [ 2  0  1 24]]
# Confusion Matrix for Batch = 265 is [[30  0  0  0]
#  [ 0 26  1  0]
#  [ 0  0 27  1]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 266 is [[25  0  0  0]
#  [ 2 27  0  0]
#  [ 2  0 29  0]
#  [ 1  0  1 13]]
# Confusion Matrix for Batch = 267 is [[31  0  0  3]
#  [ 0 24  0  0]
#  [ 0  0 21  4]
#  [ 0  1  0 16]]
# Confusion Matrix for Batch = 268 is [[25  0  1  2]
#  [ 1  9  0  0]
#  [ 0  0 20  5]
#  [ 2  1  1 33]]
# Confusion Matrix for Batch = 269 is [[17  0  2  3]
#  [ 0 14  0  1]
#  [ 0  0 42  4]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 270 is [[29  0  0  1]
#  [ 1 17  0  1]
#  [ 2  0 27  2]
#  [ 1  0  0 19]]
# Confusion Matrix for Batch = 271 is [[29  0  0  1]
#  [ 1 14  0  0]
#  [ 3  0 18  6]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 272 is [[15  0  1  1]
#  [ 0 22  0  0]
#  [ 1  0 22  5]
#  [ 1  0  1 31]]
# Confusion Matrix for Batch = 273 is [[26  0  0  3]
#  [ 0 16  0  0]
#  [ 2  0 26  2]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 274 is [[16  0  0  0]
#  [ 2 24  0  1]
#  [ 1  0 25  1]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 275 is [[27  1  1  0]
#  [ 2 20  0  0]
#  [ 1  1 18  3]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 276 is [[16  0  0  4]
#  [ 0 28  0  1]
#  [ 2  0 21  2]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 277 is [[32  0  0  1]
#  [ 0 19  0  0]
#  [ 0  0 30  1]
#  [ 1  0  1 15]]
# Confusion Matrix for Batch = 278 is [[15  0  1  2]
#  [ 1 32  0  0]
#  [ 1  0 29  2]
#  [ 1  0  1 15]]
# Confusion Matrix for Batch = 279 is [[28  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 33  2]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 280 is [[23  0  0  0]
#  [ 0 34  1  2]
#  [ 1  0 20  0]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 281 is [[28  0  2  0]
#  [ 0 18  0  0]
#  [ 0  0 32  0]
#  [ 0  0  3 17]]
# Confusion Matrix for Batch = 282 is [[16  0  0  2]
#  [ 1 23  0  1]
#  [ 0  0 30  2]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 283 is [[23  0  1  5]
#  [ 1 11  0  2]
#  [ 0  0 29  3]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 284 is [[20  0  0  2]
#  [ 0 19  0  0]
#  [ 0  0 31  0]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 285 is [[17  0  1  1]
#  [ 0 25  0  0]
#  [ 1  0 33  3]
#  [ 1  0  0 18]]
# Confusion Matrix for Batch = 286 is [[16  0  1  2]
#  [ 0 22  0  1]
#  [ 1  0 29  4]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 287 is [[25  1  0  1]
#  [ 1 19  0  0]
#  [ 2  0 25  2]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 288 is [[20  1  0  2]
#  [ 0 17  0  0]
#  [ 1  1 24  2]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 289 is [[23  2  0  2]
#  [ 1 24  1  0]
#  [ 2  0 14  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 290 is [[15  1  1  0]
#  [ 1 23  0  0]
#  [ 0  0 28  3]
#  [ 0  0  1 27]]
# Confusion Matrix for Batch = 291 is [[26  0  1  0]
#  [ 1 33  1  1]
#  [ 0  1 25  1]
#  [ 1  0  1  8]]
# Confusion Matrix for Batch = 292 is [[27  0  0  0]
#  [ 1 33  0  0]
#  [ 1  0 29  1]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 293 is [[28  0  0  1]
#  [ 0 32  0  0]
#  [ 0  0 25  2]
#  [ 0  0  2 10]]
# Confusion Matrix for Batch = 294 is [[28  0  1  1]
#  [ 0 32  0  0]
#  [ 1  0 18  1]
#  [ 1  0  1 16]]
# Confusion Matrix for Batch = 295 is [[22  0  1  1]
#  [ 0 13  0  1]
#  [ 2  0 26  3]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 296 is [[17  0  0  0]
#  [ 0 16  0  0]
#  [ 1  0 34  0]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 297 is [[24  0  0  0]
#  [ 0 24  0  0]
#  [ 1  0 24  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 298 is [[16  0  0  1]
#  [ 2 20  0  0]
#  [ 2  0 28  7]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 299 is [[20  0  2  1]
#  [ 0 18  0  1]
#  [ 0  1 20  3]
#  [ 1  0  0 33]]
# Confusion Matrix for Batch = 300 is [[12  1  1  1]
#  [ 1 21  0  2]
#  [ 1  0 27  2]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 301 is [[23  1  0  0]
#  [ 0 19  0  0]
#  [ 2  0 21  5]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 302 is [[28  0  0  1]
#  [ 1 19  0  0]
#  [ 5  0 22  4]
#  [ 0  0  1 19]]
# Confusion Matrix for Batch = 303 is [[24  0  0  0]
#  [ 1 32  0  0]
#  [ 0  0 20  5]
#  [ 1  0  1 16]]
# Confusion Matrix for Batch = 304 is [[22  0  2  1]
#  [ 3 26  0  2]
#  [ 1  0 26  1]
#  [ 1  0  2 13]]
# Confusion Matrix for Batch = 305 is [[23  0  1  1]
#  [ 0 39  0  0]
#  [ 1  0 20  1]
#  [ 1  0  2 11]]
# Confusion Matrix for Batch = 306 is [[28  1  1  1]
#  [ 1 20  0  1]
#  [ 3  0 25  1]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 307 is [[18  0  0  1]
#  [ 0 14  1  1]
#  [ 2  0 23  8]
#  [ 0  0  3 29]]
# Confusion Matrix for Batch = 308 is [[17  0  1  1]
#  [ 1 15  1  1]
#  [ 0  0 32  5]
#  [ 0  1  1 24]]
# Confusion Matrix for Batch = 309 is [[20  0  2  0]
#  [ 0 19  1  1]
#  [ 1  0 21  2]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 310 is [[23  0  0  1]
#  [ 2 22  1  0]
#  [ 0  0 27  0]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 311 is [[24  0  2  2]
#  [ 0 27  0  1]
#  [ 1  0 25  3]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 312 is [[28  0  1  1]
#  [ 2 12  0  0]
#  [ 0  1 20  3]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 313 is [[28  0  0  4]
#  [ 2 26  1  0]
#  [ 0  0 16  1]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 314 is [[28  0  1  2]
#  [ 0 37  1  0]
#  [ 0  0 12  3]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 315 is [[24  1  1  2]
#  [ 2 35  0  0]
#  [ 0  1 22  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 316 is [[31  0  1  1]
#  [ 2 34  0  0]
#  [ 1  1 12  1]
#  [ 0  0  2 14]]
# Confusion Matrix for Batch = 317 is [[18  0  0  0]
#  [ 1 49  0  0]
#  [ 0  0 18  0]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 318 is [[40  1  1  2]
#  [ 2 22  0  0]
#  [ 0  0 14  0]
#  [ 1  0  0 17]]
# Confusion Matrix for Batch = 319 is [[40  1  1  2]
#  [ 2 33  0  0]
#  [ 1  0 10  0]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 320 is [[32  1  0  0]
#  [ 2 44  0  0]
#  [ 0  0 11  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 321 is [[37  0  0  0]
#  [ 1 42  0  0]
#  [ 2  0  9  2]
#  [ 2  0  0  5]]
# Confusion Matrix for Batch = 322 is [[26  0  0  1]
#  [ 0 47  0  0]
#  [ 0  0 13  1]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 323 is [[42  0  0  2]
#  [ 0 32  0  0]
#  [ 0  0 13  2]
#  [ 0  0  2  7]]
# Confusion Matrix for Batch = 324 is [[42  1  0  2]
#  [ 2 35  0  0]
#  [ 0  0 12  1]
#  [ 0  0  0  5]]
# Confusion Matrix for Batch = 325 is [[47  0  0  1]
#  [ 2 27  1  0]
#  [ 2  0  9  0]
#  [ 1  0  0 10]]
# Confusion Matrix for Batch = 326 is [[38  0  0  0]
#  [ 4 39  0  0]
#  [ 0  0 10  0]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 327 is [[34  0  1  1]
#  [ 1 27  0  1]
#  [ 0  0 14  0]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 328 is [[32  0  0  1]
#  [ 1 32  0  0]
#  [ 3  0 19  1]
#  [ 1  0  1  9]]
# Confusion Matrix for Batch = 329 is [[29  0  1  3]
#  [ 0 27  1  0]
#  [ 0  0 20  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 330 is [[25  0  0  0]
#  [ 1 21  0  1]
#  [ 3  0 29  2]
#  [ 1  0  2 15]]
# Confusion Matrix for Batch = 331 is [[31  0  2  0]
#  [ 0 16  1  0]
#  [ 0  0 25  0]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 332 is [[19  0  0  0]
#  [ 1 29  0  0]
#  [ 1  0 26  2]
#  [ 1  0  4 17]]
# Confusion Matrix for Batch = 333 is [[19  0  0  1]
#  [ 0 14  0  0]
#  [ 1  0 26  3]
#  [ 1  0  2 33]]
# Confusion Matrix for Batch = 334 is [[21  0  2  0]
#  [ 1 14  0  0]
#  [ 0  0 37  2]
#  [ 1  0  0 22]]
# Confusion Matrix for Batch = 335 is [[20  0  0  1]
#  [ 0 18  1  1]
#  [ 1  0 22  2]
#  [ 1  0  3 30]]
# Confusion Matrix for Batch = 336 is [[30  0  0  3]
#  [ 0  9  0  0]
#  [ 0  0 28  1]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 337 is [[21  0  0  1]
#  [ 1 25  1  1]
#  [ 0  0 25  3]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 338 is [[20  0  1  1]
#  [ 1 23  0  0]
#  [ 1  0 27  1]
#  [ 0  0  4 21]]
# Confusion Matrix for Batch = 339 is [[19  0  1  4]
#  [ 2 15  0  0]
#  [ 1  0 13  4]
#  [ 1  0  1 39]]
# Confusion Matrix for Batch = 340 is [[25  0  1  1]
#  [ 0 20  0  0]
#  [ 1  0 21  5]
#  [ 0  0  3 23]]
# Confusion Matrix for Batch = 341 is [[28  0  0  1]
#  [ 2 29  0  0]
#  [ 2  0 20  2]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 342 is [[18  0  2  0]
#  [ 1 31  0  0]
#  [ 0  0 25  4]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 343 is [[16  0  2  3]
#  [ 0 35  0  0]
#  [ 0  0 16  5]
#  [ 1  0  0 22]]
# Confusion Matrix for Batch = 344 is [[31  0  0  0]
#  [ 0 23  0  1]
#  [ 1  0 24  1]
#  [ 0  0  3 16]]
# Confusion Matrix for Batch = 345 is [[15  0  0  2]
#  [ 0 17  0  0]
#  [ 4  0 12  2]
#  [ 0  0  3 45]]
# Confusion Matrix for Batch = 346 is [[15  0  1  1]
#  [ 1 24  0  0]
#  [ 2  0 29  6]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 347 is [[17  0  1  3]
#  [ 0 10  0  0]
#  [ 1  0 22 12]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 348 is [[23  1  0  2]
#  [ 1 14  1  0]
#  [ 0  0 24  7]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 349 is [[19  0  0  2]
#  [ 0 23  1  0]
#  [ 3  0 23  2]
#  [ 0  0  3 24]]
# Confusion Matrix for Batch = 350 is [[19  1  1  0]
#  [ 0 23  0  0]
#  [ 2  0 15  6]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 351 is [[25  1  0  0]
#  [ 1 35  0  0]
#  [ 2  0 12  6]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 352 is [[21  0  0  0]
#  [ 2 29  0  1]
#  [ 2  0 28  2]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 353 is [[28  0  1  1]
#  [ 1 15  0  0]
#  [ 2  0 30  4]
#  [ 2  0  1 15]]
# Confusion Matrix for Batch = 354 is [[23  0  0  1]
#  [ 0 28  0  0]
#  [ 1  0 21  5]
#  [ 1  0  5 15]]
# Confusion Matrix for Batch = 355 is [[27  0  0  1]
#  [ 3 15  0  0]
#  [ 0  0 27  5]
#  [ 1  0  1 20]]
# Confusion Matrix for Batch = 356 is [[22  1  0  0]
#  [ 3  6  0  0]
#  [ 2  0 38  5]
#  [ 1  0  1 21]]
# Confusion Matrix for Batch = 357 is [[21  0  1  0]
#  [ 1 17  1  1]
#  [ 1  0 39  4]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 358 is [[29  0  0  0]
#  [ 2 16  1  0]
#  [ 1  0 24  5]
#  [ 0  1  2 19]]
# Confusion Matrix for Batch = 359 is [[23  0  0  1]
#  [ 1 19  0  0]
#  [ 1  0 30  0]
#  [ 1  0  3 21]]
# Confusion Matrix for Batch = 360 is [[22  0  0  1]
#  [ 0  9  0  0]
#  [ 1  0 38  2]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 361 is [[21  0  0  0]
#  [ 2 19  0  1]
#  [ 2  0 33  1]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 362 is [[16  0  0  0]
#  [ 0 16  1  0]
#  [ 1  0 25  4]
#  [ 0  0  0 37]]
# Confusion Matrix for Batch = 363 is [[29  0  1  0]
#  [ 0 26  0  0]
#  [ 1  0 18  2]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 364 is [[25  0  1  1]
#  [ 3 20  0  0]
#  [ 2  0 15  1]
#  [ 1  0  3 28]]
# Confusion Matrix for Batch = 365 is [[28  0  1  0]
#  [ 2 32  0  0]
#  [ 0  0 19  2]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 366 is [[21  0  0  0]
#  [ 0 26  1  0]
#  [ 1  0 31  3]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 367 is [[27  0  1  2]
#  [ 1 16  1  0]
#  [ 0  0 20  4]
#  [ 0  0  4 24]]
# Confusion Matrix for Batch = 368 is [[28  1  0  1]
#  [ 1 28  0  1]
#  [ 0  0 18  2]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 369 is [[25  0  2  2]
#  [ 1 12  0  0]
#  [ 1  0 25  1]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 370 is [[22  0  0  1]
#  [ 1  9  0  0]
#  [ 2  1 34  2]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 371 is [[23  0  0  0]
#  [ 0 18  0  0]
#  [ 3  0 28  3]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 372 is [[26  0  2  3]
#  [ 0 13  0  0]
#  [ 1  0 21  5]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 373 is [[17  1  0  2]
#  [ 2 22  0  0]
#  [ 1  0 26  0]
#  [ 1  0  0 28]]
# Confusion Matrix for Batch = 374 is [[16  0  0  4]
#  [ 1 11  1  1]
#  [ 2  0 22  5]
#  [ 0  0  2 35]]
# Confusion Matrix for Batch = 375 is [[24  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 15  5]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 376 is [[18  0  1  4]
#  [ 2 16  0  0]
#  [ 1  0 16  6]
#  [ 3  0  0 33]]
# Confusion Matrix for Batch = 377 is [[23  0  0  0]
#  [ 3 27  0  1]
#  [ 3  0 24  2]
#  [ 1  0  1 15]]
# Confusion Matrix for Batch = 378 is [[25  0  0  3]
#  [ 0 26  1  0]
#  [ 1  0 34  3]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 379 is [[25  1  2  3]
#  [ 1 26  0  0]
#  [ 1  0 24  2]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 380 is [[17  1  0  2]
#  [ 0 36  0  0]
#  [ 1  0 28  0]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 381 is [[16  0  0  1]
#  [ 2 19  1  1]
#  [ 2  1 30  5]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 382 is [[19  0  0  2]
#  [ 0 15  0  1]
#  [ 1  0 40  4]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 383 is [[18  0  0  1]
#  [ 0 14  0  0]
#  [ 1  0 36  3]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 384 is [[28  0  0  1]
#  [ 0 19  0  0]
#  [ 1  0 24  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 385 is [[24  0  0  0]
#  [ 0 26  0  1]
#  [ 1  0 25  3]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 386 is [[19  2  2  1]
#  [ 0 15  1  2]
#  [ 2  0 23  0]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 387 is [[21  0  0  0]
#  [ 0 26  0  1]
#  [ 2  0 11  2]
#  [ 0  0  1 36]]
# Confusion Matrix for Batch = 388 is [[33  0  0  1]
#  [ 1 23  0  0]
#  [ 1  0 14  0]
#  [ 0  0  2 25]]
# Confusion Matrix for Batch = 389 is [[27  0  2  0]
#  [ 2 36  1  0]
#  [ 0  0 19  2]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 390 is [[27  1  1  1]
#  [ 2 29  0  0]
#  [ 1  0 18  5]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 391 is [[25  0  1  0]
#  [ 1 47  0  1]
#  [ 0  0 12  1]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 392 is [[29  0  1  2]
#  [ 0 42  0  1]
#  [ 0  0 18  0]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 393 is [[34  0  0  1]
#  [ 1 40  0  0]
#  [ 1  1  5  1]
#  [ 1  0  1 14]]
# Confusion Matrix for Batch = 394 is [[36  0  1  2]
#  [ 2 44  1  0]
#  [ 0  0 10  0]
#  [ 0  0  0  4]]
# Confusion Matrix for Batch = 395 is [[28  1  0  1]
#  [ 0 44  1  0]
#  [ 2  0 10  2]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 396 is [[30  0  0  0]
#  [ 3 38  1  0]
#  [ 0  0 14  0]
#  [ 0  1  0 13]]
# Confusion Matrix for Batch = 397 is [[25  0  2  2]
#  [ 0 34  1  0]
#  [ 0  0 21  0]
#  [ 0  0  5 10]]
# Confusion Matrix for Batch = 398 is [[47  0  2  0]
#  [ 1 28  0  0]
#  [ 2  0 10  2]
#  [ 1  0  1  6]]
# Confusion Matrix for Batch = 399 is [[30  0  1  0]
#  [ 2 48  0  0]
#  [ 0  0 10  2]
#  [ 1  0  1  5]]
# Confusion Matrix for Batch = 400 is [[53  0  1  0]
#  [ 1 26  0  0]
#  [ 1  0  8  1]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 401 is [[32  0  0  0]
#  [ 1 37  0  0]
#  [ 0  0 19  1]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 402 is [[30  0  0  2]
#  [ 1 40  1  0]
#  [ 1  0 14  2]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 403 is [[24  0  1  1]
#  [ 3 47  0  0]
#  [ 3  0 15  0]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 404 is [[26  0  1  1]
#  [ 1 28  0  0]
#  [ 1  0 22  1]
#  [ 0  0  3 16]]
# Confusion Matrix for Batch = 405 is [[22  0  1  2]
#  [ 2 33  0  0]
#  [ 1  0 22  0]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 406 is [[32  0  0  1]
#  [ 0 30  1  0]
#  [ 1  0 23  2]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 407 is [[26  0  0  0]
#  [ 1 10  0  0]
#  [ 1  0 27  3]
#  [ 1  0  3 28]]
# Confusion Matrix for Batch = 408 is [[23  1  0  1]
#  [ 1 17  1  0]
#  [ 0  0 31  1]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 409 is [[20  0  0  2]
#  [ 0  9  2  0]
#  [ 2  0 28  1]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 410 is [[28  0  0  3]
#  [ 0 13  1  0]
#  [ 1  0 23  4]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 411 is [[22  0  0  1]
#  [ 0 22  0  0]
#  [ 2  0 26  4]
#  [ 0  0  3 20]]
# Confusion Matrix for Batch = 412 is [[20  1  0  0]
#  [ 0 17  0  1]
#  [ 0  0 17  4]
#  [ 0  0  0 40]]
# Confusion Matrix for Batch = 413 is [[18  1  0  0]
#  [ 0 19  1  0]
#  [ 2  0 31  1]
#  [ 0  0  3 24]]
# Confusion Matrix for Batch = 414 is [[18  0  0  0]
#  [ 1 27  1  1]
#  [ 1  0 22  4]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 415 is [[21  0  0  2]
#  [ 0 17  0  0]
#  [ 0  0 17  5]
#  [ 0  0  1 37]]
# Confusion Matrix for Batch = 416 is [[22  0  0  1]
#  [ 0 23  0  3]
#  [ 1  0 12  5]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 417 is [[13  1  2  3]
#  [ 0 33  1  0]
#  [ 3  0 26  3]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 418 is [[23  0  0  3]
#  [ 0 31  0  0]
#  [ 0  0 29  2]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 419 is [[12  1  1  2]
#  [ 0 29  0  0]
#  [ 0  0 30  3]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 420 is [[25  0  1  0]
#  [ 0 32  0  0]
#  [ 0  0 26  1]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 421 is [[22  0  0  0]
#  [ 0 25  1  0]
#  [ 3  0 25  2]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 422 is [[17  1  0  1]
#  [ 0 17  0  0]
#  [ 0  0 24  4]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 423 is [[24  0  0  3]
#  [ 1 15  0  1]
#  [ 0  0 26  1]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 424 is [[16  0  0  1]
#  [ 0 13  0  1]
#  [ 0  0 47  5]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 425 is [[31  0  0  0]
#  [ 0 14  2  0]
#  [ 2  0 19  2]
#  [ 0  0  2 28]]
# Confusion Matrix for Batch = 426 is [[12  0  1  0]
#  [ 0 22  0  0]
#  [ 0  0 33  3]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 427 is [[19  0  0  3]
#  [ 0 20  0  0]
#  [ 1  0 20  3]
#  [ 1  0  4 29]]
# Confusion Matrix for Batch = 428 is [[23  0  0  1]
#  [ 1 28  0  0]
#  [ 1  0 15  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 429 is [[18  0  0  1]
#  [ 0 20  0  0]
#  [ 0  0 27  4]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 430 is [[25  1  1  2]
#  [ 0 19  0  0]
#  [ 3  0 14  6]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 431 is [[22  1  0  1]
#  [ 2 14  2  0]
#  [ 1  0 20  2]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 432 is [[26  0  0  0]
#  [ 0 29  0  0]
#  [ 1  0 32  2]
#  [ 1  0  0  9]]
# Confusion Matrix for Batch = 433 is [[16  0  0  2]
#  [ 1 27  0  0]
#  [ 1  0 34  2]
#  [ 0  1  0 16]]
# Confusion Matrix for Batch = 434 is [[32  0  0  1]
#  [ 1 23  0  1]
#  [ 0  0 28  0]
#  [ 1  0  1 12]]
# Confusion Matrix for Batch = 435 is [[25  0  0  0]
#  [ 0 15  0  0]
#  [ 1  0 35  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 436 is [[16  0  1  0]
#  [ 1 16  0  1]
#  [ 1  0 26  7]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 437 is [[22  0  0  2]
#  [ 4 12  0  0]
#  [ 0  0 29  2]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 438 is [[19  0  0  1]
#  [ 2 11  0  0]
#  [ 2  0 34  3]
#  [ 0  0  2 26]]
# Confusion Matrix for Batch = 439 is [[16  0  0  2]
#  [ 0 13  0  1]
#  [ 3  0 27  2]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 440 is [[13  1  1  1]
#  [ 0 22  1  0]
#  [ 0  0 22  2]
#  [ 0  0  2 35]]
# Confusion Matrix for Batch = 441 is [[17  0  0  1]
#  [ 0 18  0  0]
#  [ 0  0 30  5]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 442 is [[23  0  1  0]
#  [ 3 19  0  0]
#  [ 1  0 29  3]
#  [ 1  0  0 20]]
# Confusion Matrix for Batch = 443 is [[21  0  0  0]
#  [ 0 24  0  0]
#  [ 2  0 18  4]
#  [ 0  0  2 29]]
# Confusion Matrix for Batch = 444 is [[14  2  1  0]
#  [ 0 26  1  2]
#  [ 0  0 24  1]
#  [ 1  0  0 28]]
# Confusion Matrix for Batch = 445 is [[24  1  0  0]
#  [ 3 26  0  0]
#  [ 0  0 22  2]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 446 is [[23  0  0  2]
#  [ 0 24  0  2]
#  [ 0  0 33  2]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 447 is [[32  0  0  2]
#  [ 0 14  1  0]
#  [ 0  0 36  1]
#  [ 1  0  0 13]]
# Confusion Matrix for Batch = 448 is [[28  0  0  2]
#  [ 0 28  0  0]
#  [ 0  0 27  1]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 449 is [[24  2  1  0]
#  [ 0 10  0  0]
#  [ 0  0 29  1]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 450 is [[20  0  0  1]
#  [ 1 18  2  1]
#  [ 1  0 26  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 451 is [[29  0  0  1]
#  [ 0  6  0  0]
#  [ 0  0 32  1]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 452 is [[13  0  0  1]
#  [ 0 21  0  1]
#  [ 0  0 32  2]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 453 is [[12  0  1  0]
#  [ 0 15  0  1]
#  [ 3  0 30  6]
#  [ 0  0  3 29]]
# Confusion Matrix for Batch = 454 is [[17  1  0  5]
#  [ 1 18  0  1]
#  [ 2  0 20  6]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 455 is [[20  1  1  1]
#  [ 0 17  0  1]
#  [ 1  0 31  2]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 456 is [[17  0  0  2]
#  [ 2 16  0  0]
#  [ 2  0 24 10]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 457 is [[22  2  2  0]
#  [ 0 18  0  0]
#  [ 2  0 18  4]
#  [ 0  1  0 31]]
# Confusion Matrix for Batch = 458 is [[25  0  1  0]
#  [ 0 27  0  1]
#  [ 3  0 21  2]
#  [ 0  0  2 18]]
# Confusion Matrix for Batch = 459 is [[26  0  0  0]
#  [ 1 30  0  1]
#  [ 1  0 21  4]
#  [ 0  0  2 14]]
# Confusion Matrix for Batch = 460 is [[14  0  0  1]
#  [ 0 30  0  1]
#  [ 2  0 28  4]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 461 is [[20  1  0  0]
#  [ 0 34  0  1]
#  [ 0  0 25  2]
#  [ 1  1  1 14]]
# Confusion Matrix for Batch = 462 is [[30  1  0  1]
#  [ 0 16  0  0]
#  [ 0  0 20  5]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 463 is [[13  0  1  3]
#  [ 0 22  1  0]
#  [ 1  0 24  5]
#  [ 1  0  3 26]]
# Confusion Matrix for Batch = 464 is [[29  0  0  0]
#  [ 0 18  0  0]
#  [ 2  0 31  3]
#  [ 0  0  2 15]]
# Confusion Matrix for Batch = 465 is [[11  0  0  3]
#  [ 0 21  0  0]
#  [ 2  0 15  6]
#  [ 1  0  1 40]]
# Confusion Matrix for Batch = 466 is [[20  1  1  1]
#  [ 1 11  0  1]
#  [ 0  0 32  0]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 467 is [[16  0  0  0]
#  [ 1 22  0  0]
#  [ 2  0 35  1]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 468 is [[18  0  0  2]
#  [ 0 22  0  2]
#  [ 0  0 30  4]
#  [ 1  0  1 20]]
# Confusion Matrix for Batch = 469 is [[17  0  2  2]
#  [ 0 21  0  0]
#  [ 1  0 29  4]
#  [ 0  0  2 22]]
# Confusion Matrix for Batch = 470 is [[22  0  0  1]
#  [ 1 24  0  0]
#  [ 2  0 24  1]
#  [ 2  0  1 22]]
# Confusion Matrix for Batch = 471 is [[12  0  1  3]
#  [ 0 33  0  1]
#  [ 2  0 16  2]
#  [ 1  0  2 27]]
# Confusion Matrix for Batch = 472 is [[23  0  0  0]
#  [ 2 40  1  0]
#  [ 0  0 22  2]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 473 is [[27  0  1  2]
#  [ 1 37  0  1]
#  [ 0  0 21  0]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 474 is [[29  0  0  2]
#  [ 2 39  1  0]
#  [ 1  0  9  0]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 475 is [[38  0  0  2]
#  [ 1 29  0  1]
#  [ 0  1 14  1]
#  [ 1  0  2 10]]
# Confusion Matrix for Batch = 476 is [[31  0  2  1]
#  [ 2 25  1  0]
#  [ 2  0  7  3]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 477 is [[35  0  1  0]
#  [ 1 41  0  1]
#  [ 0  0 12  0]
#  [ 1  0  0  8]]
# Confusion Matrix for Batch = 478 is [[21  0  1  3]
#  [ 1 53  0  0]
#  [ 2  0  8  1]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 479 is [[26  0  0  2]
#  [ 2 47  0  0]
#  [ 0  1 13  0]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 480 is [[24  1  1  1]
#  [ 1 36  5  0]
#  [ 0  0 15  1]
#  [ 0  1  1 13]]
# Confusion Matrix for Batch = 481 is [[30  0  1  0]
#  [ 1 41  0  1]
#  [ 2  0 11  1]
#  [ 0  1  2  9]]
# Confusion Matrix for Batch = 482 is [[49  0  0  0]
#  [ 1 21  1  0]
#  [ 2  0 13  0]
#  [ 1  0  1 11]]
# Confusion Matrix for Batch = 483 is [[37  0  2  0]
#  [ 3 32  0  0]
#  [ 0  0 12  1]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 484 is [[19  0  1  0]
#  [ 3 35  0  1]
#  [ 0  0 21  2]
#  [ 1  0  3 14]]
# Confusion Matrix for Batch = 485 is [[28  0  1  0]
#  [ 3 40  1  0]
#  [ 2  0 13  1]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 486 is [[21  0  2  0]
#  [ 0 32  0  0]
#  [ 0  0 27  1]
#  [ 0  0  2 15]]
# Confusion Matrix for Batch = 487 is [[31  0  1  2]
#  [ 2 20  1  1]
#  [ 2  0 25  0]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 488 is [[41  0  0  0]
#  [ 0 24  1  0]
#  [ 0  0 17  2]
#  [ 0  0  4 11]]
# Confusion Matrix for Batch = 489 is [[16  0  0  1]
#  [ 1 18  1  2]
#  [ 0  0 21  1]
#  [ 0  0  7 32]]
# Confusion Matrix for Batch = 490 is [[24  0  0  2]
#  [ 0 13  0  1]
#  [ 2  0 25  2]
#  [ 0  0  4 27]]
# Confusion Matrix for Batch = 491 is [[14  0  2  2]
#  [ 0 10  0  2]
#  [ 0  0 26  0]
#  [ 1  0  5 38]]
# Confusion Matrix for Batch = 492 is [[16  0  0  4]
#  [ 0 22  0  0]
#  [ 2  0 24  4]
#  [ 1  0  1 26]]
# Confusion Matrix for Batch = 493 is [[18  0  0  0]
#  [ 0  9  1  0]
#  [ 2  0 27  3]
#  [ 1  0  3 36]]
# Confusion Matrix for Batch = 494 is [[11  0  1  2]
#  [ 1 19  0  0]
#  [ 1  0 37  4]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 495 is [[20  0  0  4]
#  [ 0 16  0  0]
#  [ 1  0 27  1]
#  [ 0  0  1 30]]
# ...
#  [ 0 14  0  0]
#  [ 1  0 25  4]
#  [ 1  0  0 28]]
# Confusion Matrix for Batch = 1040 is [[15  0  1  1]
#  [ 0 18  0  0]
#  [ 1  0 28  4]
#  [ 1  0  0 31]]
# Confusion Matrix for Batch = 1041 is [[16  0  0  1]
#  [ 1 19  0  0]
#  [ 1  0 24  2]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 1042 is [[10  1  0  3]
#  [ 0 17  0  0]
#  [ 0  0 32  0]
#  [ 0  0  2 35]]
# Confusion Matrix for Batch = 1043 is [[16  0  2  1]
#  [ 0 31  0  0]
#  [ 0  0 21  0]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 1044 is [[17  0  0  0]
#  [ 0 17  0  0]
#  [ 3  0 34  1]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1045 is [[27  0  1  1]
#  [ 0 26  0  2]
#  [ 0  0 21  0]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 1046 is [[21  0  1  2]
#  [ 1 27  0  0]
#  [ 0  0 18  1]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1047 is [[24  0  1  0]
#  [ 1 24  0  1]
#  [ 0  0 31  0]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 1048 is [[28  0  0  1]
#  [ 0 20  0  0]
#  [ 1  0 32  2]
#  [ 0  0  3 13]]
# Confusion Matrix for Batch = 1049 is [[31  0  2  1]
#  [ 0 26  0  1]
#  [ 0  0 23  0]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 1050 is [[17  0  0  0]
#  [ 0 15  0  0]
#  [ 0  0 32  5]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 1051 is [[19  0  0  2]
#  [ 0 18  0  0]
#  [ 0  0 35  2]
#  [ 1  0  1 22]]
# Confusion Matrix for Batch = 1052 is [[34  0  0  0]
#  [ 0 21  0  0]
#  [ 1  0 29  1]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 1053 is [[23  0  0  1]
#  [ 1 22  0  0]
#  [ 1  0 22  2]
#  [ 0  0  1 27]]
# Confusion Matrix for Batch = 1054 is [[13  0  0  2]
#  [ 0 15  0  0]
#  [ 0  0 32  1]
#  [ 0  0  3 34]]
# Confusion Matrix for Batch = 1055 is [[19  0  0  0]
#  [ 0 23  0  0]
#  [ 0  0 31  2]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 1056 is [[18  0  0  0]
#  [ 2 17  0  0]
#  [ 1  0 32  3]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 1057 is [[17  1  1  0]
#  [ 0 24  0  0]
#  [ 0  0 15  2]
#  [ 1  0  0 39]]
# Confusion Matrix for Batch = 1058 is [[26  0  0  0]
#  [ 0 33  0  0]
#  [ 0  0 22  1]
#  [ 1  0  0 17]]
# Confusion Matrix for Batch = 1059 is [[21  0  0  0]
#  [ 0 28  0  0]
#  [ 0  0 25  1]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 1060 is [[18  0  0  0]
#  [ 1 33  0  0]
#  [ 0  0 38  0]
#  [ 1  0  0  9]]
# Confusion Matrix for Batch = 1061 is [[25  0  0  1]
#  [ 0 17  0  0]
#  [ 0  0 41  2]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1062 is [[26  1  1  0]
#  [ 0 16  0  0]
#  [ 0  0 21  2]
#  [ 0  0  1 32]]
# Confusion Matrix for Batch = 1063 is [[18  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 34  0]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1064 is [[23  0  1  0]
#  [ 1 16  0  0]
#  [ 0  0 21  2]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 1065 is [[18  0  0  1]
#  [ 0 22  0  0]
#  [ 0  0 27  0]
#  [ 0  0  3 29]]
# Confusion Matrix for Batch = 1066 is [[29  0  0  1]
#  [ 0 18  1  0]
#  [ 1  0 21  1]
#  [ 0  0  4 24]]
# Confusion Matrix for Batch = 1067 is [[30  1  0  0]
#  [ 0 33  0  1]
#  [ 0  0 17  2]
#  [ 1  1  1 13]]
# Confusion Matrix for Batch = 1068 is [[ 9  0  0  2]
#  [ 0 22  0  0]
#  [ 0  0 20  0]
#  [ 0  0  1 46]]
# Confusion Matrix for Batch = 1069 is [[11  0  1  3]
#  [ 1 16  0  0]
#  [ 0  0 19  3]
#  [ 2  0  2 42]]
# Confusion Matrix for Batch = 1070 is [[26  1  1  0]
#  [ 0 30  0  0]
#  [ 1  0 25  1]
#  [ 1  0  0 14]]
# Confusion Matrix for Batch = 1071 is [[29  0  0  0]
#  [ 0 20  1  0]
#  [ 0  0 29  0]
#  [ 1  1  2 17]]
# Confusion Matrix for Batch = 1072 is [[19  0  0  2]
#  [ 0 18  0  0]
#  [ 1  0 17  1]
#  [ 0  0  0 42]]
# Confusion Matrix for Batch = 1073 is [[16  0  1  1]
#  [ 1 27  0  0]
#  [ 0  0 30  1]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1074 is [[22  0  0  1]
#  [ 0 26  2  0]
#  [ 0  0 37  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 1075 is [[17  0  0  1]
#  [ 0 20  0  0]
#  [ 1  0 26  3]
#  [ 0  1  1 30]]
# Confusion Matrix for Batch = 1076 is [[21  1  0  1]
#  [ 0 21  0  0]
#  [ 0  0 16  3]
#  [ 1  0  0 36]]
# Confusion Matrix for Batch = 1077 is [[19  0  0  0]
#  [ 0 24  1  0]
#  [ 0  0 37  0]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 1078 is [[24  0  0  0]
#  [ 0 28  0  0]
#  [ 1  0 25  0]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 1079 is [[35  1  1  0]
#  [ 1 31  0  0]
#  [ 1  0 26  0]
#  [ 0  0  1  3]]
# Confusion Matrix for Batch = 1080 is [[21  0  1  1]
#  [ 0 17  0  0]
#  [ 0  0 28  3]
#  [ 1  0  1 27]]
# Confusion Matrix for Batch = 1081 is [[22  0  0  0]
#  [ 0 21  0  1]
#  [ 0  0 33  0]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 1082 is [[21  0  0  0]
#  [ 0 18  0  1]
#  [ 0  0 33  1]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1083 is [[17  0  0  0]
#  [ 0 21  0  1]
#  [ 1  0 40  1]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1084 is [[22  0  0  1]
#  [ 0 16  0  0]
#  [ 0  0 27  1]
#  [ 1  0  2 30]]
# Confusion Matrix for Batch = 1085 is [[21  0  0  0]
#  [ 0 24  1  0]
#  [ 0  0 25  1]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1086 is [[12  0  0  1]
#  [ 0 29  1  0]
#  [ 0  0 16  5]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 1087 is [[21  0  0  0]
#  [ 0 46  0  1]
#  [ 0  0 20  0]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 1088 is [[28  0  0  1]
#  [ 0 41  1  0]
#  [ 0  0 19  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 1089 is [[31  0  0  0]
#  [ 0 32  0  1]
#  [ 2  0 17  1]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 1090 is [[27  1  0  1]
#  [ 0 17  0  1]
#  [ 0  0 14  4]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 1091 is [[21  0  0  0]
#  [ 0 25  0  0]
#  [ 0  0 31  1]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 1092 is [[26  1  1  0]
#  [ 1 18  0  0]
#  [ 1  0 23  2]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 1093 is [[21  0  1  0]
#  [ 0 31  0  0]
#  [ 0  0 13  1]
#  [ 0  0  1 32]]
# Confusion Matrix for Batch = 1094 is [[15  1  0  0]
#  [ 2 27  0  0]
#  [ 0  0 29  0]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 1095 is [[21  0  0  1]
#  [ 0 44  0  0]
#  [ 1  0 19  0]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1096 is [[26  0  0  0]
#  [ 0 30  0  0]
#  [ 1  0 26  1]
#  [ 1  0  1 14]]
# Confusion Matrix for Batch = 1097 is [[22  0  0  0]
#  [ 1 30  0  0]
#  [ 1  0 35  2]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 1098 is [[24  0  0  1]
#  [ 0 27  0  1]
#  [ 0  0 20  2]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 1099 is [[22  0  0  1]
#  [ 0 23  0  0]
#  [ 0  0 31  0]
#  [ 0  0  3 20]]
# Confusion Matrix for Batch = 1100 is [[28  0  0  2]
#  [ 0 23  0  0]
#  [ 0  0 24  1]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 1101 is [[22  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 35  0]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 1102 is [[15  0  0  3]
#  [ 0 21  0  0]
#  [ 1  0 18  1]
#  [ 0  0  3 38]]
# Confusion Matrix for Batch = 1103 is [[14  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 27  3]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 1104 is [[17  0  1  0]
#  [ 0 26  0  0]
#  [ 0  0 36  1]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 1105 is [[30  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 18  1]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 1106 is [[18  0  1  0]
#  [ 0 31  0  0]
#  [ 0  0 16  0]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 1107 is [[18  0  0  2]
#  [ 1 23  0  0]
#  [ 0  0 20  1]
#  [ 1  0  1 33]]
# Confusion Matrix for Batch = 1108 is [[27  0  0  2]
#  [ 0 14  0  0]
#  [ 2  0 29  0]
#  [ 1  1  0 24]]
# Confusion Matrix for Batch = 1109 is [[30  0  1  2]
#  [ 0 14  0  0]
#  [ 1  0 34  0]
#  [ 0  0  2 16]]
# Confusion Matrix for Batch = 1110 is [[22  0  1  0]
#  [ 0 24  0  1]
#  [ 0  0 31  2]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 1111 is [[20  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0 40  2]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 1112 is [[21  0  0  1]
#  [ 0 21  0  0]
#  [ 0  0 34  1]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 1113 is [[23  0  0  2]
#  [ 0 17  0  1]
#  [ 0  0 13  2]
#  [ 0  0  0 42]]
# Confusion Matrix for Batch = 1114 is [[17  0  0  1]
#  [ 0 22  1  1]
#  [ 0  0 28  1]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1115 is [[19  0  0  3]
#  [ 0 13  0  1]
#  [ 0  0 28  2]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 1116 is [[14  1  0  0]
#  [ 0 22  0  0]
#  [ 0  0 28  2]
#  [ 0  0  1 32]]
# Confusion Matrix for Batch = 1117 is [[25  0  0  2]
#  [ 0 26  0  0]
#  [ 0  0 28  0]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 1118 is [[14  0  2  0]
#  [ 1 38  1  1]
#  [ 0  0 32  2]
#  [ 1  0  0  8]]
# Confusion Matrix for Batch = 1119 is [[20  0  0  1]
#  [ 0 28  0  0]
#  [ 2  0 25  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 1120 is [[22  0  0  0]
#  [ 0 35  0  0]
#  [ 2  0 26  0]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 1121 is [[16  0  0  0]
#  [ 0 22  0  0]
#  [ 1  0 21  3]
#  [ 1  0  2 34]]
# Confusion Matrix for Batch = 1122 is [[18  0  2  0]
#  [ 0 16  1  0]
#  [ 0  0 31  1]
#  [ 1  0  0 30]]
# Confusion Matrix for Batch = 1123 is [[23  0  0  1]
#  [ 0 24  0  0]
#  [ 0  0 26  2]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 1124 is [[26  0  0  2]
#  [ 0 18  0  0]
#  [ 0  0 27  1]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1125 is [[22  0  0  0]
#  [ 0 28  0  0]
#  [ 0  0 28  0]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 1126 is [[26  0  2  0]
#  [ 0 22  0  0]
#  [ 0  0 27  0]
#  [ 4  0  3 16]]
# Confusion Matrix for Batch = 1127 is [[14  0  1  1]
#  [ 0 20  0  1]
#  [ 1  0 16  5]
#  [ 1  0  2 38]]
# Confusion Matrix for Batch = 1128 is [[20  0  0  0]
#  [ 0 31  1  0]
#  [ 1  0 28  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1129 is [[28  0  1  0]
#  [ 0 35  0  0]
#  [ 0  0 23  3]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 1130 is [[34  0  0  0]
#  [ 0 24  0  0]
#  [ 0  0 24  1]
#  [ 1  0  1 15]]
# Confusion Matrix for Batch = 1131 is [[33  0  0  0]
#  [ 1 44  0  0]
#  [ 0  0 14  1]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 1132 is [[28  0  1  0]
#  [ 2 48  0  0]
#  [ 0  0 10  0]
#  [ 1  0  0 10]]
# Confusion Matrix for Batch = 1133 is [[34  0  0  1]
#  [ 0 42  0  0]
#  [ 1  0 16  0]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 1134 is [[22  0  1  0]
#  [ 0 48  0  0]
#  [ 0  0 16  0]
#  [ 1  0  2 10]]
# Confusion Matrix for Batch = 1135 is [[43  0  1  1]
#  [ 1 40  0  0]
#  [ 0  0  6  1]
#  [ 0  0  1  6]]
# Confusion Matrix for Batch = 1136 is [[48  0  1  0]
#  [ 0 20  0  0]
#  [ 0  0 15  1]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 1137 is [[31  0  0  0]
#  [ 1 34  0  0]
#  [ 0  0 15  0]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 1138 is [[30  0  0  2]
#  [ 0 36  1  2]
#  [ 1  0 10  0]
#  [ 2  0  1 15]]
# Confusion Matrix for Batch = 1139 is [[25  0  0  0]
#  [ 1 31  0  0]
#  [ 0  0 26  3]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 1140 is [[22  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 16  1]
#  [ 2  0  6 26]]
# Confusion Matrix for Batch = 1141 is [[26  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 24  0]
#  [ 1  0  1 18]]
# Confusion Matrix for Batch = 1142 is [[17  0  0  2]
#  [ 1 21  0  2]
#  [ 2  0 24  3]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 1143 is [[20  0  0  0]
#  [ 1 17  0  0]
#  [ 1  0 40  0]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 1144 is [[16  0  0  1]
#  [ 0 13  0  0]
#  [ 0  0 34  4]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 1145 is [[29  0  0  0]
#  [ 0 15  0  0]
#  [ 1  0 41  1]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 1146 is [[21  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 29  0]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1147 is [[20  0  0  1]
#  [ 0 28  0  0]
#  [ 0  0 21  1]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1148 is [[21  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 24  0]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1149 is [[11  0  0  2]
#  [ 0 20  0  1]
#  [ 0  0 16  5]
#  [ 0  0  0 45]]
# Confusion Matrix for Batch = 1150 is [[24  0  1  0]
#  [ 0 25  1  0]
#  [ 0  0 30  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1151 is [[16  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 25  0]
#  [ 0  0  1 27]]
# Confusion Matrix for Batch = 1152 is [[27  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 22  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 1153 is [[29  0  0  0]
#  [ 0 22  0  1]
#  [ 1  0 28  2]
#  [ 0  0  3 14]]
# Confusion Matrix for Batch = 1154 is [[24  0  0  4]
#  [ 0 16  0  0]
#  [ 0  0 25  1]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 1155 is [[25  0  0  3]
#  [ 0  9  0  0]
#  [ 0  0 21  1]
#  [ 2  0  0 39]]
# Confusion Matrix for Batch = 1156 is [[23  0  0  1]
#  [ 0  6  0  0]
#  [ 1  0 36  3]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 1157 is [[14  0  0  1]
#  [ 0 16  0  0]
#  [ 2  0 28  2]
#  [ 0  0  2 35]]
# Confusion Matrix for Batch = 1158 is [[20  0  0  1]
#  [ 0 13  0  0]
#  [ 0  0 27  4]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 1159 is [[25  0  0  4]
#  [ 1 17  0  0]
#  [ 0  0 20  3]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 1160 is [[22  0  0  0]
#  [ 0 35  0  0]
#  [ 0  0 22  2]
#  [ 1  0  0 18]]
# Confusion Matrix for Batch = 1161 is [[24  0  1  0]
#  [ 1 28  0  0]
#  [ 0  0 25  2]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 1162 is [[26  0  0  0]
#  [ 0 26  0  1]
#  [ 0  0 16  1]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 1163 is [[21  0  0  0]
#  [ 0 32  0  0]
#  [ 2  0 34  0]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 1164 is [[30  0  0  2]
#  [ 1 30  0  0]
#  [ 0  0 24  1]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 1165 is [[33  0  0  0]
#  [ 1 18  0  0]
#  [ 0  0 29  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 1166 is [[18  0  0  0]
#  [ 0 10  0  0]
#  [ 1  0 45  0]
#  [ 0  0  2 24]]
# Confusion Matrix for Batch = 1167 is [[21  0  0  0]
#  [ 0 21  1  0]
#  [ 0  0 34  0]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1168 is [[24  0  1  0]
#  [ 0 21  0  0]
#  [ 0  0 38  1]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 1169 is [[30  0  0  0]
#  [ 1 22  0  0]
#  [ 0  0 26  0]
#  [ 0  0  2 19]]
# Confusion Matrix for Batch = 1170 is [[14  0  0  1]
#  [ 1 17  0  0]
#  [ 0  0 17  6]
#  [ 0  0  1 43]]
# Confusion Matrix for Batch = 1171 is [[13  0  0  0]
#  [ 1 22  0  0]
#  [ 1  0 28  3]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 1172 is [[28  1  0  0]
#  [ 0 22  0  1]
#  [ 0  1 23  0]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 1173 is [[28  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 21  1]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 1174 is [[12  0  0  1]
#  [ 0 31  1  0]
#  [ 0  0 26  2]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 1175 is [[15  0  0  1]
#  [ 0 26  0  1]
#  [ 0  0 26  1]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 1176 is [[19  0  0  1]
#  [ 0 35  4  0]
#  [ 0  0 31  0]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 1177 is [[32  0  0  0]
#  [ 1 30  0  0]
#  [ 1  0 20  0]
#  [ 0  1  1 14]]
# Confusion Matrix for Batch = 1178 is [[26  0  0  0]
#  [ 1 10  0  0]
#  [ 0  0 34  1]
#  [ 0  1  2 25]]
# Confusion Matrix for Batch = 1179 is [[26  0  0  0]
#  [ 1 20  0  1]
#  [ 0  0 36  0]
#  [ 1  0  0 15]]
# Confusion Matrix for Batch = 1180 is [[18  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0 39  0]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 1181 is [[35  0  0  0]
#  [ 1 24  0  0]
#  [ 0  0 32  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 1182 is [[15  1  0  0]
#  [ 0 21  0  0]
#  [ 0  0 43  1]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 1183 is [[ 9  0  0  1]
#  [ 0 38  1  1]
#  [ 0  0 20  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1184 is [[27  0  0  1]
#  [ 0 22  0  0]
#  [ 0  0 14  2]
#  [ 1  0  1 32]]
# Confusion Matrix for Batch = 1185 is [[29  0  0  0]
#  [ 0 36  0  0]
#  [ 0  0 22  0]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 1186 is [[30  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 24  2]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 1187 is [[19  0  1  0]
#  [ 0 21  0  0]
#  [ 1  0 26  3]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 1188 is [[22  0  1  0]
#  [ 0 38  0  0]
#  [ 0  0 26  1]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 1189 is [[35  0  0  1]
#  [ 0 13  0  0]
#  [ 1  0 22  2]
#  [ 1  0  0 25]]
# Confusion Matrix for Batch = 1190 is [[23  0  1  0]
#  [ 1  9  0  1]
#  [ 0  0 22  1]
#  [ 0  0  0 42]]
# Confusion Matrix for Batch = 1191 is [[20  0  0  0]
#  [ 0 19  0  0]
#  [ 0  0 29  0]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 1192 is [[17  0  0  1]
#  [ 0 20  0  0]
#  [ 1  0 28  3]
#  [ 1  0  0 29]]
# Confusion Matrix for Batch = 1193 is [[11  0  0  1]
#  [ 0 22  0  0]
#  [ 1  0 39  0]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1194 is [[15  0  0  0]
#  [ 0 31  0  0]
#  [ 1  0 29  0]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 1195 is [[25  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 21  1]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 1196 is [[29  1  0  1]
#  [ 0 32  0  0]
#  [ 2  0 21  0]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1197 is [[29  0  0  1]
#  [ 0 35  0  0]
#  [ 0  0 19  1]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 1198 is [[31  0  1  0]
#  [ 0 34  0  0]
#  [ 0  0 22  1]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 1199 is [[31  0  1  1]
#  [ 0 27  0  0]
#  [ 0  0 21  2]
#  [ 2  0  1 14]]
# Training Set Accuracy = 0.9291833333333334	Recall = 0.9291833333333334	Precision = 0.9343379087297012	F1-Score = 0.9291042257423574	Loss = 0.0021735006012022495	Confusion Matrix = [[31  0  1  1]
#  [ 0 27  0  0]
#  [ 0  0 21  2]
#  [ 2  0  1 14]]

# %%
batch_size = len(data['Description'])
model.eval()
correct = 0
test_loss = 0
precision = []
f1 = []
recall = []


for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in skip_gram_embeddings):
                batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()

    pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
    true = y_true.cpu().numpy()
    precision.append(precision_score(pred, true, average='weighted'))
    f1.append(f1_score(pred, true, average='weighted'))
    recall.append(recall_score(pred, true, average='weighted'))
    confusion = confusion_matrix(pred, true)
    print(f"Confusion Matrix for Batch = {i} is {confusion}")

print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Confusion Matrix for Batch = 0 is [[1656   53   90  130]
#  [  84 1808   46   65]
#  [ 106   24 1633  267]
#  [  54   15  131 1438]]
# Testing Set Accuracy = 0.8598684210526316	Recall = 0.8598684210526316	Precision = 0.8647009695290859	F1-Score = 0.8608927130970534	Loss = 5.9401521866675466e-05

# %% [markdown]
# # Context Window = 1 Ends

# %%
skip_gram_embeddings = torch.load("skip-gram-word-vectors2.pt")
skip_gram_embeddings
# Out:
# {'Reuters': array([ 0.7636274 , -0.01760704,  0.10106981,  1.1672716 , -0.12675798,
#         -0.23597664,  0.02369807, -0.4138495 ,  0.5162099 ,  0.14314738,
#         -0.06102663, -0.45349666, -0.44845033,  0.26092783,  0.19941507,
#          0.10213922,  0.18474385,  0.96512777,  0.3281345 , -0.29805392,
#          0.22238177, -0.05911426, -0.08121579, -0.32284373, -0.06514688,
#          0.03500207, -0.37231332, -0.2370133 , -0.56966174, -0.05508831,
#          0.449918  , -0.02793967, -0.16277455, -0.29195547,  1.0260798 ,
#          0.72269547,  0.36685672, -0.1694271 , -0.16824317, -0.17533356,
#         -0.02780384,  0.00672828, -0.48418033, -0.8101055 , -0.74108505,
#          0.09441836,  0.23502359, -0.64683944, -0.07770781, -0.23833114],
#        dtype=float32),
#  '-': array([-0.02509637, -0.28923526, -0.00323538,  0.32122934, -0.12708332,
#         -0.10712501,  0.0173927 , -0.24429137,  0.03293813, -0.09965374,
#          0.04424008, -0.2287708 ,  0.11736935,  0.2804739 ,  0.42755574,
#         -0.11973572, -0.00500698,  0.31373635,  0.09433911,  0.0485448 ,
#          0.04231192, -0.33122215, -0.04685227,  0.1812591 , -0.04244477,
#          0.07319474, -0.06975285, -0.03447091, -0.13138413,  0.06393205,
#          0.06786557,  0.2506903 ,  0.00487149, -0.09335567,  0.3466593 ,
#          0.27088732,  0.10853482,  0.2787981 ,  0.02901363,  0.011599  ,
#          0.03547051,  0.18969424, -0.1779718 , -0.27243426,  0.2364954 ,
#          0.0725618 , -0.28762966,  0.10975837, -0.13323112, -0.2151568 ],
#        dtype=float32),
#  'Short': array([ 0.6598089 ,  1.0091542 , -0.78272545, -2.0228167 , -0.06367025,
#         -0.42817155,  0.7626421 , -1.2828928 ,  0.23355518, -0.7426397 ,
#          0.13951488, -0.07041474, -0.01664663, -0.09325993,  0.07548986,
#          0.070305  ,  0.3001844 , -0.02769918, -0.01496737,  0.25642806,
#          0.15464714,  0.04832778,  0.23498574,  0.09807761,  0.03638738,
#         -0.00797207,  0.16369545, -0.12521571, -0.24684587,  0.2343795 ,
#          0.0847899 , -0.20907295,  0.17792204, -0.13363749, -0.1512432 ],
#        dtype=float32),
#  'making': array([ 0.423064  , -0.23766407, -0.4369077 ,  0.17119634, -0.37497854,
#         -0.30620798,  0.01253521,  0.9129014 , -1.1948005 ,  0.2830044 ,
#          0.5818085 , -0.2640102 ,  0.3330427 , -0.16323918,  0.6554112 ,
#          0.7760337 , -0.2218292 , -0.38325238, -0.7594942 , -1.1905531 ,
#          1.5412879 , -0.00335519, -0.25705433,  0.90444374,  0.5875664 ,
#         -0.15808707,  0.620873  ,  0.3716758 , -0.14986685,  0.0948279 ,
#         -0.38608733,  0.7245481 , -0.3855268 ,  0.4180403 ,  0.73176813,
#          1.268792  , -0.63964665, -0.79544806, -0.6352267 , -0.50964105,
#          0.43461332, -0.31491148,  0.48248884, -0.20646313,  0.55387634,
#         -1.0292487 , -0.08296019, -0.11550412,  0.20716193,  0.70527595],
#        dtype=float32),
#  'well': array([ 0.92859834,  0.6990247 , -0.22440487,  0.3871201 , -0.18356447,
#         -0.49675208, -0.084596  ,  0.01605335,  0.06975868,  1.0526308 ,
#         -0.57879895,  0.10107991,  0.99176025, -0.30687457,  0.20690742,
#          0.24722685, -0.15929478, -0.7373005 ,  0.17335689, -0.31964904,
#          0.68825865, -0.64209735,  0.5668745 ,  0.2557373 , -0.92083764,
#         -0.75710434,  0.5921806 ,  0.11855544, -0.54303557, -0.4814859 ,
#          0.04127013,  0.896639  , -0.30958107, -0.15232974, -0.25896373,
#          0.24735712,  0.75938404,  0.60957557, -0.8195003 ,  0.58821994,
#         -0.10173243, -0.03797591,  0.04934618,  0.74435973,  0.73916626,
#          1.2275404 , -0.69324636, -0.61388344, -0.5192381 ,  0.15810962],
#        dtype=float32),
#  'timed': array([ 0.7762847 ,  1.3574038 ,  0.02956057,  0.62775224,  0.48461097,
#          0.31137076,  0.08226874,  0.3020168 ,  0.41710433, -0.6920135 ,
#         -0.23060858,  0.08997589, -0.10345207, -0.11210358, -1.3023643 ,
#          0.05411492, -2.0401428 ,  0.60319155,  0.09171271,  1.541148  ,
#         -0.2285724 , -1.0657412 , -0.129542  ,  0.36213243,  0.1996583 ,
#         -0.30512437, -0.02973738,  1.4740646 ,  0.9305012 ,  0.00598733,
#          0.6739259 , -0.9136525 , -1.5808648 , -1.2134383 , -0.26505238,
#         -0.28596655,  0.37713858,  0.65318906,  0.06873578,  0.19395447,
#          0.5253475 ,  0.48108032,  0.18505774, -0.1585986 , -0.65651274,
#         -0.34887633, -0.31318197, -1.1023332 ,  1.3655732 ,  0.44693628],
#        dtype=float32),
#  'and': array([ 0.01624498, -0.26133892,  0.03102993,  0.18718348, -0.14362645,
#         -0.02186864, -0.01177773, -0.15987583, -0.04504536, -0.12179877,
#          0.06445494,  0.8324258 ,  1.1475953 ,  0.58801806, -0.18183953,
#          1.0254858 , -0.48018405, -0.22021894, -0.5929464 , -0.07620209,
#          0.24678604, -1.1127466 , -0.38446957, -1.3789501 , -0.53893363,
#          0.3353878 , -0.3205911 , -0.1569581 ,  0.06012379,  0.01163715,
#         -0.7573275 , -0.36435378,  0.20659542,  0.42758864,  0.13686982,
#          0.5846583 ,  0.04387132, -0.4673208 , -0.3924675 ,  0.5677954 ,
#         -0.45257846, -0.08376378,  0.18251793,  1.5969224 ,  0.14739522],
#        dtype=float32),
#  'market': array([ 0.0262422 , -0.12158642, -0.25466087, -0.12906554,  0.01029964,
#          0.0057846 , -0.47748232,  0.357947  , -0.0792751 ,  0.22464576,
#         -0.38791627, -0.27867627,  1.1438718 , -0.09093901,  1.0933768 ,
#         -0.27123117, -0.3697993 ,  1.1640818 , -0.9999742 ,  0.82309157,
#         -0.3289818 ,  0.1235473 , -0.49418077,  0.6394675 ,  0.09434724,
#          0.15448199, -0.61389303, -0.00742413,  0.31747222,  0.23280306,
#          0.5753851 , -0.05171016,  0.24572814, -0.2716931 ,  1.0503818 ,
#          0.56873167,  0.4383736 ,  0.2892478 , -0.16038796, -0.10891782,
#          0.48202652, -0.24461578,  0.5032939 ,  0.09278695,  0.38641956,
#          0.1366032 ,  0.11517613,  0.16256584,  0.20875102, -0.87783027],
#        dtype=float32),
#  'Soaring': array([ 0.5389349 , -0.5237794 ,  0.13022316, -0.7223066 ,  0.09892843,
#          0.7274464 , -0.04022411, -0.4556725 , -0.19758803,  0.73486376,
#          0.96902037, -1.2101338 , -0.48897356, -0.48117146,  0.39509177,
#          1.3986107 , -0.7597973 ,  0.36026525, -0.08165818, -1.6060197 ,
#          0.80568206,  0.6806219 ,  0.4071713 , -0.62973857, -0.2467896 ,
#         -0.699392  , -0.10597044, -0.18722323,  1.2763057 , -1.6256485 ,
#          0.40614155,  0.01169867, -0.8463115 ,  1.4080666 , -0.4130897 ,
#          0.5947324 , -0.6326284 , -0.0474647 ,  0.46620542, -0.06951271,
#         -0.34407002,  0.28516918,  0.94432366,  0.01515165,  0.44729212,
#         -0.13314128,  0.47258925,  0.25719568, -1.1401193 ,  1.382382  ],
#        dtype=float32),
#  'crude': array([-0.07537717, -0.35276806, -0.8508337 ,  0.5933672 ,  0.576965  ,
#         -0.36168557, -0.33397633,  1.0169394 , -0.2719258 , -0.4585002 ,
#          0.00419126, -0.53541034, -0.6513979 , -0.26376688, -0.30133355,
#          0.42485937, -1.155714  ,  0.4534323 ,  0.6272    , -0.2393711 ,
#          1.0648365 , -1.2363588 ,  0.20972824, -0.9405862 , -0.8446628 ,
#          0.32621723, -1.2003915 , -0.9479627 , -0.92115676, -0.3081749 ,
#          0.30367115,  0.39653397, -0.27388918,  0.07186015, -0.8367981 ,
#          0.2838794 , -0.47267738, -0.20541504, -0.12483022, -0.59898317,
#          0.6030939 , -0.64898956, -0.52309877, -0.11967598, -0.22594547,
#          0.16157717,  1.8216    ,  0.99809265, -0.20107895, -0.44401273],
#          0.14184532, -0.48142412, -0.47021565,  0.71258897, -1.6490128 ,
#          1.7384083 ,  0.8771845 , -0.96419877, -0.9591029 , -0.39132863],
#        dtype=float32),
#  'Asian': array([-0.34618098,  0.35938933, -0.14058998, -0.69545877,  1.247042  ,
#          1.0427855 ,  0.7660655 ,  0.67877036,  0.3011642 , -0.25705153,
#          0.26770252, -1.1105309 , -0.8247708 , -0.33589083, -0.09866259,
#         -0.67268026, -0.5034479 ,  0.18331358, -0.45126927,  0.11617351,
#          0.65966547, -0.23598415, -0.30644637,  0.50489247,  0.7555878 ,
#          0.06163668, -0.06707573, -0.53404814,  0.44393837,  1.0754758 ,
#          0.610173  ,  1.7668514 , -0.50623894, -0.5512739 ,  0.0146862 ,
#         -1.3555573 ,  0.05324332,  0.2528876 , -0.44033164, -0.5437456 ,
#         -0.9049361 ,  0.5548829 , -0.6182742 ,  0.11560869,  0.41077495,
#          0.2940763 , -0.06964985, -0.96250975, -0.33456674, -0.03635892],
#        dtype=float32),
#  'tourism': array([-0.37774974,  0.7004593 ,  1.5926986 ,  0.83125323,  0.8688723 ,
#         -0.02479779,  0.5201485 , -0.349056  ,  0.3543409 ,  0.16696863,
#          0.214567  , -0.6997955 ,  0.1235978 ,  0.22982928,  0.88335675,
#         -0.7700876 ,  0.1455781 , -0.4709741 ,  0.1088683 ,  0.5602176 ,
#         -0.8486167 ,  0.5007384 ,  0.4509285 ,  0.36489612, -1.1400013 ,
#          1.0635891 ,  0.12890457, -0.51909757, -0.70267504,  0.02885181,
#          1.2643768 ,  0.17447922, -0.47159803,  0.92090106, -0.5685217 ,
#         -0.25023454, -0.27855164,  0.73186344,  0.06633466,  0.4742886 ,
#          1.0763549 ,  0.3383528 , -0.62470084,  0.03011495, -1.2136892 ,
#         -1.0505732 , -0.41892725,  0.28438234, -0.94238836,  0.60467446],
#        dtype=float32),
#  'destinations': array([ 0.7898027 , -0.7117229 , -0.07520178, -0.9200473 ,  1.7834239 ,
#         -0.08332819, -0.8209276 , -0.22121768, -0.16092277, -0.16379151,
#         -0.03759718,  0.5043686 ,  0.31635457,  0.02872524, -0.6429141 ,
#          0.08432375,  0.04978667, -0.5300527 , -0.00967694,  0.33962193,
#         -0.12353224, -1.4886203 , -0.9842544 , -0.48025995,  0.7567685 ,
#          1.3374153 ,  0.15327436, -0.69474554, -0.77666044,  1.0981166 ,
#          0.83287555,  0.11717147, -0.88275707,  1.2349654 , -0.0784772 ,
#          0.9369045 ,  1.1372073 ,  0.11361325, -0.6578222 ,  0.8613336 ,
#          0.5973808 , -0.23599741, -1.8542025 , -0.25340065,  0.7104044 ,
#         -0.5017194 , -0.45027936, -0.24128172, -0.32419395,  0.18673117],
#        dtype=float32),
#  'just': array([ 0.05491298, -0.04941352,  0.51817656, -0.09330443, -0.5830092 ,
#          0.217025  ,  0.3846593 ,  0.63828707,  0.19423276,  0.7540847 ,
#          1.6207011 ,  0.22893602, -0.23874736,  0.7019024 ,  0.49102503,
#          0.09118172, -0.2177939 ,  0.47391427, -1.108002  ,  0.15350123,
#          0.53266114, -0.877331  ,  0.39386207,  0.90129304,  0.53205395,
#          0.6569092 ,  0.6460775 ,  0.31470892,  0.6292073 , -0.43670213,
#         -0.00783613,  0.35970464, -0.5531409 ,  0.14137924,  0.04334965,
#          0.31697905, -0.6704979 ,  0.30692133,  0.2629079 , -0.13410063,
#          0.37222397, -0.21390255,  0.13971503, -0.3349761 , -0.41067523,
#          0.2422558 , -0.36173803, -0.677083  , -0.27465785, -0.31627625],
#        dtype=float32),
#  'kicked': array([ 0.20527269, -0.5689168 , -0.5151659 ,  2.0340922 ,  0.41074228,
#         -0.63155115, -0.04321036, -0.4665783 ,  0.14231831,  0.58964026,
#         -0.67034894,  1.1090814 , -0.8204332 , -0.23532718, -0.55807185,
#         -0.45254478,  0.15915358, -0.81666625, -1.4161503 ,  0.49803215,
#          0.49876493,  1.5940228 ,  0.6893081 , -0.39733008,  0.9865339 ,
#         -0.07686605, -0.16580118,  0.19844075, -0.48320025, -0.29721516,
#          0.59437287, -0.37751806, -0.46789038,  0.57514447,  0.98957217,
#         -0.25897253,  0.02694082, -0.4647783 ,  0.7455456 ,  0.97320336,
#          0.20145957, -0.48571202, -1.066627  ,  0.446904  , -0.4519236 ,
#          0.13900441,  0.70374066, -0.14816049, -0.22638573,  0.52106035],
#        dtype=float32),
#  ...}

# %%
skip_gram_embeddings['OOV'] = torch.randn(50, dtype = torch.float32)

# %%
hidden_dim = 256
output_dim = data['Class Index'].unique().shape[0]

model = LSTM(hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
model
# Out:
# LSTM(
#   (lstm): LSTM(50, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in skip_gram_embeddings):
                    batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.245625	Loss = 0.013868843205273151
# Epoch = 1	Training Set Accuracy = 0.2529666666666667	Loss = 0.013833113946020603
# Epoch = 2	Training Set Accuracy = 0.30345833333333333	Loss = 0.013598411343991756
# Epoch = 3	Training Set Accuracy = 0.575175	Loss = 0.009768212214112282
# Epoch = 4	Training Set Accuracy = 0.81475	Loss = 0.0050962818786501884
# Epoch = 5	Training Set Accuracy = 0.8668833333333333	Loss = 0.003797404235228896
# Epoch = 6	Training Set Accuracy = 0.8927333333333334	Loss = 0.0031310743652284145
# Epoch = 7	Training Set Accuracy = 0.9114333333333333	Loss = 0.0026386405806988478
# Epoch = 8	Training Set Accuracy = 0.9247083333333334	Loss = 0.00226288172416389
# Epoch = 9	Training Set Accuracy = 0.9377833333333333	Loss = 0.0019142128294333816

# %%
batch_size = 100
model.eval()
correct = 0
test_loss = 0

for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in skip_gram_embeddings):
                batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()
print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Testing Set Accuracy = 0.8568421052631578	Loss = 0.005296119023114443

# %%
batch_size = 100
model.train()
precision = []
f1 = []
recall = []
correct = 0
train_loss = 0
import warnings
warnings.filterwarnings('ignore')


confusion = None
with torch.no_grad():
    for i in range(int(len(data_train['Description'])/batch_size)):
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in skip_gram_embeddings):
                    batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()

        pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
        true = y_true.cpu().numpy()
        precision.append(precision_score(pred, true, average='weighted'))
        f1.append(f1_score(pred, true, average='weighted'))
        recall.append(recall_score(pred, true, average='weighted'))
        confusion = confusion_matrix(pred, true)
        print(f"Confusion Matrix for Batch = {i} is {confusion}")

    print(f"Training Set Accuracy = {correct / len(data_train['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {train_loss/len(data_train['Description'])}\tConfusion Matrix = {confusion}")
# Out:
# Confusion Matrix for Batch = 0 is [[ 0  0  5  0]
#  [ 0  0  0  1]
#  [ 0  0 65  0]
#  [ 0  0  8 21]]
# Confusion Matrix for Batch = 1 is [[ 0  0  0 15]
#  [ 0  0  0  3]
#  [ 0  0  0  2]
#  [ 0  0  0 80]]
# Confusion Matrix for Batch = 2 is [[ 0  0  0  5]
#  [ 0  0  0  9]
#  [ 0  0  0  5]
#  [ 0  0  0 81]]
# Confusion Matrix for Batch = 3 is [[ 0  0  0  7]
#  [ 0  0  0  6]
#  [ 0  0  0  8]
#  [ 0  0  0 79]]
# Confusion Matrix for Batch = 4 is [[ 8  1  0  2]
#  [ 0 43  0  4]
#  [ 0  0  0  3]
#  [ 0  0  0 39]]
# Confusion Matrix for Batch = 5 is [[53  1  0  0]
#  [ 7 16  0  2]
#  [ 4  0  6  0]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 6 is [[29  0  0  0]
#  [ 8 41  0  1]
#  [ 3  0 15  0]
#  [ 1  0  0  2]]
# Confusion Matrix for Batch = 7 is [[35  0  1  0]
#  [ 1 25  1  2]
#  [ 3  0 14  4]
#  [ 0  0  3 11]]
# Confusion Matrix for Batch = 8 is [[23  0  0  1]
#  [ 2  8  0  1]
#  [ 1  0 35  0]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 9 is [[28  0  0  4]
#  [ 4  7  0  2]
#  [ 2  0 18  3]
#  [ 0  0  3 29]]
# Confusion Matrix for Batch = 10 is [[29  0  0  1]
#  [ 3 20  0  1]
#  [ 1  0 16  3]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 11 is [[21  0  0  3]
#  [ 4 20  1  0]
#  [ 2  0 10  7]
#  [ 1  0  0 31]]
# Confusion Matrix for Batch = 12 is [[26  0  2  1]
#  [ 2 23  0  0]
#  [ 2  0 26  6]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 13 is [[26  1  1  1]
#  [ 5 15  0  0]
#  [ 3  0 23  7]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 14 is [[20  0  0  0]
#  [ 4  5  0  1]
#  [ 3  0 41  5]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 15 is [[27  0  0  1]
#  [ 1 22  0  0]
#  [ 0  0 12  7]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 16 is [[12  0  0  0]
#  [ 1 21  0  1]
#  [ 0  0 35  6]
#  [ 1  0  0 23]]
# Confusion Matrix for Batch = 17 is [[20  0  0  0]
#  [ 3 30  0  0]
#  [ 1  0 21  3]
#  [ 0  1  0 21]]
# Confusion Matrix for Batch = 18 is [[17  0  0  0]
#  [ 2 22  0  2]
#  [ 1  0 19  1]
#  [ 1  0  0 35]]
# Confusion Matrix for Batch = 19 is [[22  1  1  1]
#  [ 4 15  0  0]
#  [ 0  0 23  2]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 20 is [[18  0  0  1]
#  [ 1 22  0  1]
#  [ 0  0 25  4]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 21 is [[23  0  0  0]
#  [ 4 32  0  1]
#  [ 1  0 23  2]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 22 is [[17  0  0  0]
#  [ 0 46  2  0]
#  [ 0  0 22  0]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 23 is [[23  0  0  2]
#  [ 1 30  0  1]
#  [ 2  0 26  2]
#  [ 1  0  1 11]]
# Confusion Matrix for Batch = 24 is [[35  0  0  1]
#  [ 1 30  0  0]
#  [ 2  0 22  0]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 25 is [[34  0  1  0]
#  [ 0 15  0  0]
#  [ 1  0 26  4]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 26 is [[20  0  1  3]
#  [ 2 11  0  0]
#  [ 2  0 38  1]
#  [ 3  0  0 19]]
# Confusion Matrix for Batch = 27 is [[28  0  1  1]
#  [ 0 17  0  0]
#  [ 1  0 34  2]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 28 is [[14  2  1  2]
#  [ 0 13  0  0]
#  [ 1  0 36  2]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 29 is [[19  0  0  3]
#  [ 0 23  1  0]
#  [ 1  0 30  2]
#  [ 0  1  0 20]]
# Confusion Matrix for Batch = 30 is [[28  0  0  1]
#  [ 2 21  0  0]
#  [ 3  0 10  5]
#  [ 2  0  0 28]]
# Confusion Matrix for Batch = 31 is [[18  0  2  2]
#  [ 1 13  1  1]
#  [ 1  0 31  1]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 32 is [[27  0  0  1]
#  [ 2 22  0  1]
#  [ 2  0 20  3]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 33 is [[30  0  0  0]
#  [ 0 23  0  2]
#  [ 0  0 20  1]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 34 is [[26  1  0  0]
#  [ 2 27  0  0]
#  [ 4  0 22  3]
#  [ 1  0  1 13]]
# Confusion Matrix for Batch = 35 is [[27  0  3  2]
#  [ 3 24  0  0]
#  [ 2  0 30  0]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 36 is [[22  0  0  2]
#  [ 3 32  1  1]
#  [ 0  0 29  0]
#  [ 2  0  0  8]]
# Confusion Matrix for Batch = 37 is [[23  0  0  1]
#  [ 0 26  0  2]
#  [ 0  0 20  4]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 38 is [[20  0  0  2]
#  [ 3 19  0  1]
#  [ 2  0 34  1]
#  [ 1  0  0 17]]
# Confusion Matrix for Batch = 39 is [[ 8  0  1  2]
#  [ 0  9  0  2]
#  [ 0  0 52  3]
#  [ 0  0  6 17]]
# Confusion Matrix for Batch = 40 is [[20  1  0  3]
#  [ 1 14  0  3]
#  [ 2  0  2  7]
#  [ 0  0  0 47]]
# Confusion Matrix for Batch = 41 is [[23  0  2  0]
#  [ 0 10  0  0]
#  [ 2  0 34  4]
#  [ 0  0  3 22]]
# Confusion Matrix for Batch = 42 is [[17  0  0  1]
#  [ 0 22  0  1]
#  [ 0  0 13 10]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 43 is [[15  0  0  0]
#  [ 0 27  0  2]
#  [ 1  0 22  5]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 44 is [[13  0  0  0]
#  [ 1 31  1  1]
#  [ 0  0 33  1]
#  [ 1  0  2 16]]
# Confusion Matrix for Batch = 45 is [[14  0  0  2]
#  [ 2 29  1  1]
#  [ 2  0 31  1]
#  [ 0  0  2 15]]
# Confusion Matrix for Batch = 46 is [[21  1  0  0]
#  [ 1 19  1  2]
#  [ 1  0 38  2]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 47 is [[29  0  1  1]
#  [ 0 34  0  0]
#  [ 0  0 19  2]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 48 is [[34  0  0  1]
#  [ 2 18  0  0]
#  [ 5  0 16  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 49 is [[26  1  0  0]
#  [ 1 26  0  0]
#  [ 1  0 24  2]
#  [ 1  2  0 16]]
# Confusion Matrix for Batch = 50 is [[20  0  1  0]
#  [ 3 15  0  0]
#  [ 2  0 29  2]
#  [ 1  0  1 26]]
# Confusion Matrix for Batch = 51 is [[21  0  0  2]
#  [ 2 25  1  2]
#  [ 1  0 22  4]
#  [ 0  0  1 19]]
# Confusion Matrix for Batch = 52 is [[23  0  1  1]
#  [ 1 17  0  0]
#  [ 2  0 28  2]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 53 is [[23  0  0  1]
#  [ 6 18  1  0]
#  [ 3  0 16  4]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 54 is [[26  0  0  0]
#  [ 1 37  1  0]
#  [ 0  0 23  1]
#  [ 1  0  1  9]]
# Confusion Matrix for Batch = 55 is [[36  0  0  1]
#  [ 2 33  1  3]
#  [ 2  1  8  2]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 56 is [[23  0  0  4]
#  [ 3 25  1  0]
#  [ 0  0 20  3]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 57 is [[31  0  1  2]
#  [ 4 28  2  1]
#  [ 1  0 18  2]
#  [ 0  0  2  8]]
# Confusion Matrix for Batch = 58 is [[32  0  0  0]
#  [ 6 43  2  1]
#  [ 0  0  9  1]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 59 is [[29  0  2  0]
#  [ 5 28  0  2]
#  [ 2  0 20  1]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 60 is [[32  0  2  0]
#  [ 0 39  0  2]
#  [ 1  0 18  1]
#  [ 0  0  0  5]]
# Confusion Matrix for Batch = 61 is [[17  0  1  1]
#  [ 2 52  1  0]
#  [ 2  0 15  2]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 62 is [[26  0  3  3]
#  [ 3 31  0  3]
#  [ 0  0 20  2]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 63 is [[30  0  2  1]
#  [ 1 38  2  0]
#  [ 0  0 18  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 64 is [[44  0  0  1]
#  [ 3 31  2  0]
#  [ 0  0 11  1]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 65 is [[26  0  1  1]
#  [ 1 34  0  0]
#  [ 0  0 17  3]
#  [ 2  0  0 15]]
# Confusion Matrix for Batch = 66 is [[36  0  0  0]
#  [ 5 43  0  0]
#  [ 0  0 10  2]
#  [ 0  0  1  3]]
# Confusion Matrix for Batch = 67 is [[27  0  0  1]
#  [ 1 43  0  2]
#  [ 1  0  9  5]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 68 is [[29  0  0  1]
#  [ 2 39  1  2]
#  [ 0  0 25  0]
#  [ 0  0  0  1]]
# Confusion Matrix for Batch = 69 is [[20  0  0  1]
#  [ 1 31  0  1]
#  [ 2  0 25  3]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 70 is [[21  1  3  1]
#  [ 0 36  0  1]
#  [ 2  0 23  4]
#  [ 2  0  0  6]]
# Confusion Matrix for Batch = 71 is [[19  0  1  0]
#  [ 0 34  0  1]
#  [ 1  0 29  0]
#  [ 0  0  3 12]]
# Confusion Matrix for Batch = 72 is [[22  0  0  2]
#  [ 0 41  0  1]
#  [ 2  0 19  1]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 73 is [[22  0  0  1]
#  [ 3 26  3  1]
#  [ 0  0 26  4]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 74 is [[24  0  0  0]
#  [ 2 16  1  0]
#  [ 1  0 35  3]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 75 is [[20  0  0  1]
#  [ 2 12  0  0]
#  [ 2  0 35  5]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 76 is [[29  0  2  0]
#  [ 1 20  1  0]
#  [ 1  0 21  9]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 77 is [[18  1  2  1]
#  [ 1 24  1  0]
#  [ 1  0 21  4]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 78 is [[20  0  0  3]
#  [ 0 15  0  0]
#  [ 1  0 31  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 79 is [[16  1  0  3]
#  [ 1 12  0  0]
#  [ 0  0 29  5]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 80 is [[15  0  0  0]
#  [ 1 24  0  1]
#  [ 3  0 25  5]
#  [ 1  0  0 25]]
# Confusion Matrix for Batch = 81 is [[23  0  0  0]
#  [ 1 27  0  3]
#  [ 2  0 28  0]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 82 is [[26  0  0  0]
#  [ 2 33  0  0]
#  [ 0  0 19  4]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 83 is [[16  0  1  0]
#  [ 2 29  2  0]
#  [ 0  0 31  3]
#  [ 0  0  3 13]]
# Confusion Matrix for Batch = 84 is [[23  0  1  0]
#  [ 0 22  1  3]
#  [ 1  0 35  3]
#  [ 0  0  2  9]]
# Confusion Matrix for Batch = 85 is [[19  0  3  0]
#  [ 1 29  0  4]
#  [ 0  0 24  6]
#  [ 0  0  3 11]]
# Confusion Matrix for Batch = 86 is [[28  1  0  1]
#  [ 4 15  0  1]
#  [ 2  0 23  1]
#  [ 0  0  2 22]]
# Confusion Matrix for Batch = 87 is [[21  0  1  1]
#  [ 2 16  0  1]
#  [ 2  0 28  4]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 88 is [[21  0  0  3]
#  [ 0 19  2  3]
#  [ 0  0 30  4]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 89 is [[14  0  1  3]
#  [ 1 21  1  1]
#  [ 2  0 25  5]
#  [ 1  0  0 25]]
# Confusion Matrix for Batch = 90 is [[13  0  0  0]
#  [ 3 16  0  0]
#  [ 0  0 39  7]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 91 is [[14  1  2  1]
#  [ 1 17  0  1]
#  [ 0  0 25  5]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 92 is [[13  0  1  1]
#  [ 1 21  1  0]
#  [ 1  0 28  2]
#  [ 0  0  2 29]]
# Confusion Matrix for Batch = 93 is [[29  0  0  2]
#  [ 4 26  0  2]
#  [ 0  0  8  5]
#  [ 1  0  2 21]]
# Confusion Matrix for Batch = 94 is [[17  0  0  0]
#  [ 1 14  0  1]
#  [ 0  0 24  9]
#  [ 0  0  1 33]]
# Confusion Matrix for Batch = 95 is [[16  0  2  2]
#  [ 0 19  0  1]
#  [ 0  0 18  6]
#  [ 0  0  2 34]]
# Confusion Matrix for Batch = 96 is [[25  0  3  2]
#  [ 0 17  1  0]
#  [ 3  0 17  2]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 97 is [[22  0  1  2]
#  [ 0 17  0  0]
#  [ 1  0 21  4]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 98 is [[12  0  0  0]
#  [ 1 14  0  1]
#  [ 0  0 29  7]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 99 is [[15  0  1  1]
#  [ 0 18  0  1]
#  [ 0  0 26  9]
#  [ 1  0  0 28]]
# Confusion Matrix for Batch = 100 is [[18  0  0  1]
#  [ 2 19  0  0]
#  [ 1  0 30  5]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 101 is [[25  0  2  3]
#  [ 1 22  2  1]
#  [ 0  0 23  5]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 102 is [[23  0  0  1]
#  [ 0 31  1  0]
#  [ 0  0 28  6]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 103 is [[32  0  0  0]
#  [ 2 26  0  0]
#  [ 0  0 21  4]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 104 is [[25  0  2  0]
#  [ 2 28  1  0]
#  [ 1  0 30  2]
#  [ 0  0  2  7]]
# Confusion Matrix for Batch = 105 is [[19  0  0  4]
#  [ 1 15  0  1]
#  [ 1  0 20  3]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 106 is [[13  0  0  2]
#  [ 0 21  0  1]
#  [ 1  0 35  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 107 is [[23  0  1  0]
#  [ 3 13  0  0]
#  [ 1  0 27  2]
#  [ 1  0  1 28]]
# Confusion Matrix for Batch = 108 is [[21  0  0  3]
#  [ 0 17  0  0]
#  [ 0  0 32  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 109 is [[18  0  1  3]
#  [ 0 15  0  1]
#  [ 0  0 32  5]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 110 is [[16  0  0  0]
#  [ 1  7  0  0]
#  [ 1  0 29  8]
#  [ 0  0  1 37]]
# Confusion Matrix for Batch = 111 is [[17  0  2  2]
#  [ 1 27  0  0]
#  [ 4  0 20  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 112 is [[23  0  0  0]
#  [ 1 29  1  0]
#  [ 1  0 27  1]
#  [ 0  1  0 16]]
# Confusion Matrix for Batch = 113 is [[18  0  0  1]
#  [ 1 28  0  0]
#  [ 1  0 28  3]
#  [ 1  0  1 18]]
# Confusion Matrix for Batch = 114 is [[19  0  1  1]
#  [ 1 26  0  0]
#  [ 1  0 33  4]
#  [ 1  1  2 10]]
# Confusion Matrix for Batch = 115 is [[23  0  0  1]
#  [ 0 27  1  3]
#  [ 0  0 22  3]
#  [ 0  0  3 17]]
# Confusion Matrix for Batch = 116 is [[29  0  0  1]
#  [ 0 31  0  0]
#  [ 0  0 19  3]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 117 is [[12  0  1  1]
#  [ 1 33  2  0]
#  [ 2  0 22  4]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 118 is [[23  0  0  1]
#  [ 3 17  0  1]
#  [ 1  0 23  6]
#  [ 1  0  0 24]]
# Confusion Matrix for Batch = 119 is [[15  0  1  1]
#  [ 1 17  1  0]
#  [ 0  0 29  4]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 120 is [[16  1  1  0]
#  [ 1 21  0  0]
#  [ 3  0 28  2]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 121 is [[22  0  0  1]
#  [ 2 19  0  1]
#  [ 1  0 20  8]
#  [ 0  0  2 24]]
# Confusion Matrix for Batch = 122 is [[19  0  1  3]
#  [ 0 24  2  0]
#  [ 2  0 19  2]
#  [ 0  0  2 26]]
# Confusion Matrix for Batch = 123 is [[20  1  0  3]
#  [ 2 26  0  1]
#  [ 1  0 14  4]
#  [ 0  0  2 26]]
# Confusion Matrix for Batch = 124 is [[23  0  1  0]
#  [ 2 22  0  0]
#  [ 1  0 15  6]
#  [ 1  0  1 28]]
# Confusion Matrix for Batch = 125 is [[14  0  1  2]
#  [ 2 30  0  0]
#  [ 0  0 16  4]
#  [ 0  0  3 28]]
# Confusion Matrix for Batch = 126 is [[19  0  0  1]
#  [ 1 34  0  0]
#  [ 0  0 21  3]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 127 is [[25  0  2  1]
#  [ 2 43  2  0]
#  [ 1  0 14  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 128 is [[28  2  0  0]
#  [ 1 41  0  0]
#  [ 0  0 13  7]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 129 is [[29  0  0  1]
#  [ 0 41  0  0]
#  [ 1  0 18  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 130 is [[35  0  0  0]
#  [ 1 35  0  0]
#  [ 0  0 15  1]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 131 is [[42  1  2  3]
#  [ 1 34  0  0]
#  [ 0  0  7  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 132 is [[32  0  0  0]
#  [ 4 50  1  0]
#  [ 0  0  5  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 133 is [[30  2  1  0]
#  [ 1 46  0  0]
#  [ 0  0 13  0]
#  [ 1  0  0  6]]
# Confusion Matrix for Batch = 134 is [[33  0  0  2]
#  [ 1 50  0  0]
#  [ 1  0  5  1]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 135 is [[35  0  0  3]
#  [ 2 27  0  0]
#  [ 2  0 17  1]
#  [ 1  0  0 12]]
# Confusion Matrix for Batch = 136 is [[31  0  1  1]
#  [ 0 38  1  1]
#  [ 1  0 17  2]
#  [ 1  0  1  5]]
# Confusion Matrix for Batch = 137 is [[46  0  0  1]
#  [ 2 25  0  0]
#  [ 1  0 12  3]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 138 is [[38  0  1  0]
#  [ 0 42  0  1]
#  [ 1  0 10  2]
#  [ 0  0  0  5]]
# Confusion Matrix for Batch = 139 is [[39  1  2  0]
#  [ 3 36  0  0]
#  [ 1  0  7  3]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 140 is [[32  0  0  0]
#  [ 3 44  0  0]
#  [ 1  0  6  3]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 141 is [[34  0  3  1]
#  [ 1 30  0  0]
#  [ 0  0 19  4]
#  [ 0  0  1  7]]
# Confusion Matrix for Batch = 142 is [[24  0  5  0]
#  [ 2 30  0  0]
#  [ 0  0 19  2]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 143 is [[23  0  3  0]
#  [ 1 40  0  0]
#  [ 1  0 15  2]
#  [ 1  0  3 11]]
# Confusion Matrix for Batch = 144 is [[36  0  1  3]
#  [ 0 25  0  0]
#  [ 1  0 16  3]
#  [ 1  0  4 10]]
# Confusion Matrix for Batch = 145 is [[23  0  2  2]
#  [ 2 23  0  0]
#  [ 1  0 22  4]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 146 is [[26  0  1  2]
#  [ 0 10  0  1]
#  [ 2  0 30  4]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 147 is [[26  0  0  1]
#  [ 1 16  0  0]
#  [ 1  0 26  2]
#  [ 0  0  2 25]]
# Confusion Matrix for Batch = 148 is [[28  0  0  1]
#  [ 0 13  1  0]
#  [ 2  0 24  6]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 149 is [[22  0  0  2]
#  [ 1 22  0  0]
#  [ 2  0 27  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 150 is [[16  0  0  1]
#  [ 0 22  1  2]
#  [ 0  0 19  7]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 151 is [[12  0  0  2]
#  [ 4  9  2  2]
#  [ 4  0 18  4]
#  [ 0  0  1 42]]
# Confusion Matrix for Batch = 152 is [[25  0  0  0]
#  [ 1 30  0  1]
#  [ 2  0 21  1]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 153 is [[16  0  1  0]
#  [ 1 25  0  0]
#  [ 0  0 25  4]
#  [ 1  0  1 26]]
# Confusion Matrix for Batch = 154 is [[25  1  0  3]
#  [ 1 23  0  1]
#  [ 0  0 19  2]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 155 is [[21  0  0  3]
#  [ 2 15  1  0]
#  [ 2  0 31  4]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 156 is [[16  1  1  1]
#  [ 1 13  1  2]
#  [ 2  0 22  5]
#  [ 0  0  1 34]]
# Confusion Matrix for Batch = 157 is [[17  0  1  0]
#  [ 0 13  0  0]
#  [ 1  0 31  9]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 158 is [[20  0  4  1]
#  [ 2 19  0  0]
#  [ 3  0 29  0]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 159 is [[11  0  0  3]
#  [ 1 12  0  1]
#  [ 2  0 22 10]
#  [ 1  0  0 37]]
# Confusion Matrix for Batch = 160 is [[26  0  1  2]
#  [ 0 37  1  0]
#  [ 0  1 16  3]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 161 is [[22  0  0  0]
#  [ 0 20  0  0]
#  [ 0  0 20  4]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 162 is [[35  0  0  3]
#  [ 2 19  1  1]
#  [ 2  0 21  1]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 163 is [[14  0  1  0]
#  [ 0  8  0  0]
#  [ 2  0 28 11]
#  [ 0  0  3 33]]
# Confusion Matrix for Batch = 164 is [[26  1  1  1]
#  [ 1 25  0  0]
#  [ 2  0 27  1]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 165 is [[12  0  0  3]
#  [ 0 10  0  1]
#  [ 3  0 14  8]
#  [ 0  0  0 49]]
# Confusion Matrix for Batch = 166 is [[12  0  0  4]
#  [ 0 22  0  1]
#  [ 1  0 19  3]
#  [ 0  0  0 38]]
# Confusion Matrix for Batch = 167 is [[29  1  0  0]
#  [ 1 21  0  0]
#  [ 0  1 11  3]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 168 is [[22  0  1  1]
#  [ 2 34  0  1]
#  [ 1  0 21  1]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 169 is [[28  0  0  4]
#  [ 1 29  1  0]
#  [ 2  0 16  5]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 170 is [[23  0  1  2]
#  [ 0 27  0  0]
#  [ 2  0  9  7]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 171 is [[31  0  1  1]
#  [ 0 10  2  1]
#  [ 5  0 33  4]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 172 is [[16  0  0  2]
#  [ 0 15  0  1]
#  [ 0  0 16  5]
#  [ 0  0  2 43]]
# Confusion Matrix for Batch = 173 is [[19  0  0  5]
#  [ 0 26  0  0]
#  [ 0  0 20  7]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 174 is [[19  0  3  0]
#  [ 2 35  0  1]
#  [ 0  0 32  0]
#  [ 1  0  2  5]]
# Confusion Matrix for Batch = 175 is [[12  0  2  2]
#  [ 0 11  0  1]
#  [ 0  0 13 15]
#  [ 0  0  0 44]]
# Confusion Matrix for Batch = 176 is [[35  0  1  0]
#  [ 3 10  1  2]
#  [ 0  0 23  6]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 177 is [[16  0  1  1]
#  [ 1 20  0  0]
#  [ 0  0 25  5]
#  [ 0  0  3 28]]
# Confusion Matrix for Batch = 178 is [[23  1  1  0]
#  [ 4 18  0  0]
#  [ 4  0 20  2]
#  [ 2  0  0 25]]
# Confusion Matrix for Batch = 179 is [[23  0  0  3]
#  [ 0 14  1  1]
#  [ 1  0  9  8]
#  [ 0  0  0 40]]
# Confusion Matrix for Batch = 180 is [[25  0  1  0]
#  [ 1 31  2  1]
#  [ 0  0 18  2]
#  [ 1  0  0 18]]
# Confusion Matrix for Batch = 181 is [[24  0  0  2]
#  [ 1 39  0  1]
#  [ 2  0 16  1]
#  [ 1  0  0 13]]
# Confusion Matrix for Batch = 182 is [[32  0  2  1]
#  [ 3 33  0  0]
#  [ 0  0 17  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 183 is [[26  0  0  0]
#  [ 1 41  1  0]
#  [ 1  0 13  1]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 184 is [[44  0  1  2]
#  [ 1 23  0  0]
#  [ 1  0 16  3]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 185 is [[27  0  0  1]
#  [ 4 40  0  1]
#  [ 3  0 12  0]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 186 is [[28  0  1  0]
#  [ 1 40  0  0]
#  [ 1  1 20  0]
#  [ 0  0  3  5]]
# Confusion Matrix for Batch = 187 is [[36  0  3  0]
#  [ 0 29  0  0]
#  [ 1  0 20  1]
#  [ 1  0  1  8]]
# Confusion Matrix for Batch = 188 is [[21  0  0  0]
#  [ 0 56  1  0]
#  [ 1  0 13  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 189 is [[34  0  3  1]
#  [ 0 28  0  0]
#  [ 0  0 14  2]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 190 is [[40  0  0  1]
#  [ 2 27  0  0]
#  [ 2  0 19  1]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 191 is [[26  0  2  3]
#  [ 0 36  0  1]
#  [ 0  0 19  3]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 192 is [[24  0  1  1]
#  [ 0 40  1  1]
#  [ 0  0 18  0]
#  [ 1  0  0 13]]
# Confusion Matrix for Batch = 193 is [[25  0  3  0]
#  [ 1 39  1  0]
#  [ 0  0 16  0]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 194 is [[34  0  0  0]
#  [ 0 32  0  1]
#  [ 0  0 21  1]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 195 is [[31  0  2  3]
#  [ 0 27  1  0]
#  [ 1  0 17  1]
#  [ 0  0  2 15]]
# Confusion Matrix for Batch = 196 is [[26  0  1  3]
#  [ 2 16  0  0]
#  [ 0  0 22  3]
#  [ 1  0  0 26]]
# Confusion Matrix for Batch = 197 is [[29  0  2  2]
#  [ 1 18  0  1]
#  [ 0  0 28  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 198 is [[26  0  1  3]
#  [ 0 23  1  1]
#  [ 1  0 17  2]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 199 is [[31  0  2  2]
#  [ 1 30  0  0]
#  [ 2  0 14  1]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 200 is [[31  0  3  3]
#  [ 3 32  0  1]
#  [ 0  0 13  1]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 201 is [[30  0  0  0]
#  [ 1 36  0  0]
#  [ 0  0 16  3]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 202 is [[26  1  1  3]
#  [ 1 38  0  0]
#  [ 0  0 19  3]
#  [ 0  0  1  7]]
# Confusion Matrix for Batch = 203 is [[27  0  0  0]
#  [ 1 31  1  2]
#  [ 1  0 22  5]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 204 is [[24  0  2  3]
#  [ 1 27  0  0]
#  [ 2  0 29  5]
#  [ 0  0  1  6]]
# Confusion Matrix for Batch = 205 is [[25  0  3  2]
#  [ 3 13  0  0]
#  [ 0  0 25  5]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 206 is [[15  0  1  3]
#  [ 0 14  0  0]
#  [ 0  0 16  9]
#  [ 0  0  0 42]]
# Confusion Matrix for Batch = 207 is [[13  0  0  4]
#  [ 0 17  1  1]
#  [ 1  0 29  2]
#  [ 1  0  0 31]]
# Confusion Matrix for Batch = 208 is [[23  0  0  1]
#  [ 2 11  0  3]
#  [ 3  0 14  4]
#  [ 0  0  3 36]]
# Confusion Matrix for Batch = 209 is [[22  0  1  1]
#  [ 1 10  0  0]
#  [ 1  0 30  6]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 210 is [[28  0  0  3]
#  [ 2 24  0  0]
#  [ 2  0 14  2]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 211 is [[11  1  0  3]
#  [ 0 20  0  0]
#  [ 1  0 15  6]
#  [ 0  0  0 43]]
# Confusion Matrix for Batch = 212 is [[19  0  0  1]
#  [ 0 31  1  0]
#  [ 0  0 25  7]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 213 is [[24  0  0  2]
#  [ 2 21  0  0]
#  [ 1  0 23  4]
#  [ 1  0  0 22]]
# Confusion Matrix for Batch = 214 is [[24  0  0  1]
#  [ 0 19  0  0]
#  [ 0  0 34  5]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 215 is [[25  0  0  2]
#  [ 0 26  0  1]
#  [ 1  0 20  6]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 216 is [[20  0  1  1]
#  [ 0 19  0  0]
#  [ 0  0 27  5]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 217 is [[22  0  0  1]
#  [ 4 12  0  0]
#  [ 4  0 28  5]
#  [ 2  0  0 22]]
# Confusion Matrix for Batch = 218 is [[14  0  0  1]
#  [ 0 17  0  0]
#  [ 0  0 20  9]
#  [ 0  0  0 39]]
# Confusion Matrix for Batch = 219 is [[24  0  1  4]
#  [ 3 13  0  1]
#  [ 0  0 25  2]
#  [ 2  0  0 25]]
# Confusion Matrix for Batch = 220 is [[20  0  0  0]
#  [ 0 20  0  1]
#  [ 0  0 16  8]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 221 is [[26  0  0  2]
#  [ 2 25  0  0]
#  [ 0  0 22  0]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 222 is [[20  0  1  1]
#  [ 0 19  1  0]
#  [ 1  0 25  8]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 223 is [[27  0  0  0]
#  [ 2 32  0  0]
#  [ 0  0 19  2]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 224 is [[21  0  1  0]
#  [ 2 30  0  0]
#  [ 1  0 21  2]
#  [ 1  0  0 21]]
# Confusion Matrix for Batch = 225 is [[22  0  0  1]
#  [ 1 25  0  0]
#  [ 0  0 30  3]
#  [ 0  0  2 16]]
# Confusion Matrix for Batch = 226 is [[16  0  0  0]
#  [ 0 21  0  1]
#  [ 0  0 34  2]
#  [ 1  0  1 24]]
# Confusion Matrix for Batch = 227 is [[24  0  0  8]
#  [ 1  2  0  0]
#  [ 4  0 17  4]
#  [ 0  0  0 40]]
# Confusion Matrix for Batch = 228 is [[22  0  2  0]
#  [ 2 24  0  0]
#  [ 0  0 21  4]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 229 is [[24  1  1  1]
#  [ 0 17  0  1]
#  [ 1  0 24  2]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 230 is [[19  0  0  3]
#  [ 1 22  1  0]
#  [ 1  0 20  5]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 231 is [[33  0  0  0]
#  [ 2 20  1  0]
#  [ 0  0 15  6]
#  [ 2  0  1 20]]
# Confusion Matrix for Batch = 232 is [[11  0  0  3]
#  [ 0 22  0  0]
#  [ 1  0 16  6]
#  [ 0  0  0 41]]
# Confusion Matrix for Batch = 233 is [[15  0  1  1]
#  [ 4 33  1  1]
#  [ 2  0 22  5]
#  [ 3  0  0 12]]
# Confusion Matrix for Batch = 234 is [[25  0  0  1]
#  [ 0 37  0  0]
#  [ 0  0 19  4]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 235 is [[18  0  0  1]
#  [ 1 19  0  2]
#  [ 1  0 32  5]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 236 is [[21  0  0  1]
#  [ 0 26  0  1]
#  [ 1  0 23  2]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 237 is [[17  0  0  1]
#  [ 0 10  1  0]
#  [ 3  1 23  4]
#  [ 0  0  2 38]]
# Confusion Matrix for Batch = 238 is [[18  0  2  0]
#  [ 0 26  0  0]
#  [ 0  0 27  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 239 is [[26  1  0  0]
#  [ 1  8  0  1]
#  [ 4  0 22  5]
#  [ 2  0  1 29]]
# Confusion Matrix for Batch = 240 is [[13  0  0  5]
#  [ 0 25  0  2]
#  [ 0  0 22  3]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 241 is [[20  0  0  2]
#  [ 3 20  1  0]
#  [ 0  0 15  7]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 242 is [[21  0  0  0]
#  [ 3 36  0  0]
#  [ 2  0 19  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 243 is [[30  0  0  2]
#  [ 1 40  0  0]
#  [ 0  0 15  1]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 244 is [[39  0  0  1]
#  [ 1 29  0  0]
#  [ 0  0 17  1]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 245 is [[37  0  0  0]
#  [ 0 39  1  0]
#  [ 1  0 11  2]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 246 is [[29  0  0  2]
#  [ 3 40  0  0]
#  [ 2  0 18  1]
#  [ 0  0  0  5]]
# Confusion Matrix for Batch = 247 is [[24  1  3  1]
#  [ 0 37  1  0]
#  [ 1  0  8  4]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 248 is [[43  0  0  0]
#  [ 0 30  1  1]
#  [ 2  0 19  1]
#  [ 0  0  0  3]]
# Confusion Matrix for Batch = 249 is [[22  1  2  0]
#  [ 0 56  0  0]
#  [ 1  0 11  0]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 250 is [[32  0  0  0]
#  [ 1 41  1  0]
#  [ 4  0 11  0]
#  [ 0  0  2  8]]
# Confusion Matrix for Batch = 251 is [[41  0  0  2]
#  [ 2 28  0  1]
#  [ 1  0 13  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 252 is [[33  1  0  2]
#  [ 3 29  0  0]
#  [ 3  0 10  1]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 253 is [[30  1  0  1]
#  [ 6 37  0  0]
#  [ 1  0 20  0]
#  [ 0  0  1  3]]
# Confusion Matrix for Batch = 254 is [[25  0  0  1]
#  [ 2 35  0  0]
#  [ 1  0 19  1]
#  [ 1  0  0 15]]
# Confusion Matrix for Batch = 255 is [[16  0  0  1]
#  [ 0 24  0  2]
#  [ 0  0 38  0]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 256 is [[36  1  0  0]
#  [ 3 19  0  0]
#  [ 4  0 10  2]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 257 is [[16  0  0  1]
#  [ 1 25  1  1]
#  [ 0  0 20  4]
#  [ 0  0  3 28]]
# Confusion Matrix for Batch = 258 is [[40  0  0  1]
#  [ 1 11  0  0]
#  [ 3  0 21  2]
#  [ 2  0  3 16]]
# Confusion Matrix for Batch = 259 is [[13  0  1  2]
#  [ 0 10  0  0]
#  [ 1  0 26  4]
#  [ 0  0  2 41]]
# Confusion Matrix for Batch = 260 is [[26  0  0  0]
#  [ 1 15  0  1]
#  [ 1  0 25  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 261 is [[19  0  0  0]
#  [ 0 19  0  0]
#  [ 1  1 19  0]
#  [ 0  0  0 41]]
# Confusion Matrix for Batch = 262 is [[29  0  1  0]
#  [ 1 16  0  1]
#  [ 1  0 12  2]
#  [ 0  0  3 34]]
# Confusion Matrix for Batch = 263 is [[20  1  0  0]
#  [ 1 19  0  0]
#  [ 2  0 30  3]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 264 is [[25  0  0  0]
#  [ 1 26  0  1]
#  [ 1  0 21  1]
#  [ 1  0  0 23]]
# Confusion Matrix for Batch = 265 is [[30  0  1  0]
#  [ 0 25  0  0]
#  [ 0  1 28  1]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 266 is [[26  0  0  0]
#  [ 2 26  1  0]
#  [ 2  1 28  0]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 267 is [[29  1  0  0]
#  [ 1 24  0  2]
#  [ 1  0 21  6]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 268 is [[23  0  0  3]
#  [ 2 10  0  1]
#  [ 1  0 21  7]
#  [ 2  0  1 29]]
# Confusion Matrix for Batch = 269 is [[17  0  0  5]
#  [ 0 14  0  1]
#  [ 0  0 44  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 270 is [[30  0  0  0]
#  [ 2 17  0  2]
#  [ 1  0 25  1]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 271 is [[28  0  0  2]
#  [ 1 14  0  0]
#  [ 4  0 17  3]
#  [ 1  0  3 27]]
# Confusion Matrix for Batch = 272 is [[15  0  0  3]
#  [ 1 22  0  0]
#  [ 1  0 22  1]
#  [ 0  0  2 33]]
# Confusion Matrix for Batch = 273 is [[22  1  1  2]
#  [ 1 14  0  1]
#  [ 3  0 26  0]
#  [ 2  1  0 26]]
# Confusion Matrix for Batch = 274 is [[16  0  1  0]
#  [ 2 24  0  1]
#  [ 1  0 23  1]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 275 is [[28  0  0  1]
#  [ 1 22  0  1]
#  [ 1  0 19  1]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 276 is [[16  0  0  1]
#  [ 0 28  1  1]
#  [ 2  0 18  4]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 277 is [[33  1  0  0]
#  [ 0 18  0  0]
#  [ 0  0 31  2]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 278 is [[13  2  0  0]
#  [ 1 30  0  0]
#  [ 3  0 30  2]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 279 is [[27  0  0  0]
#  [ 1 31  0  1]
#  [ 0  0 32  2]
#  [ 0  0  1  5]]
# Confusion Matrix for Batch = 280 is [[23  0  0  0]
#  [ 0 34  0  1]
#  [ 0  0 21  3]
#  [ 2  0  1 15]]
# Confusion Matrix for Batch = 281 is [[28  0  0  0]
#  [ 0 18  0  0]
#  [ 0  0 37  0]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 282 is [[17  0  1  2]
#  [ 0 23  0  2]
#  [ 0  0 30  2]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 283 is [[23  0  0  2]
#  [ 1 11  1  2]
#  [ 0  0 29  1]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 284 is [[20  0  0  1]
#  [ 0 19  0  0]
#  [ 0  0 32  1]
#  [ 1  0  1 25]]
# Confusion Matrix for Batch = 285 is [[19  1  0  0]
#  [ 0 23  0  0]
#  [ 0  0 33  2]
#  [ 0  1  1 20]]
# Confusion Matrix for Batch = 286 is [[17  1  0  2]
#  [ 0 21  2  1]
#  [ 0  0 28  4]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 287 is [[24  0  0  3]
#  [ 1 20  3  0]
#  [ 3  0 22  2]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 288 is [[20  0  0  2]
#  [ 0 19  0  2]
#  [ 1  0 25  1]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 289 is [[21  0  0  3]
#  [ 1 26  0  0]
#  [ 3  0 15  4]
#  [ 1  0  1 25]]
# Confusion Matrix for Batch = 290 is [[15  0  0  0]
#  [ 1 24  0  1]
#  [ 0  0 29  4]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 291 is [[26  1  0  1]
#  [ 2 33  0  0]
#  [ 0  0 26  2]
#  [ 0  0  2  7]]
# Confusion Matrix for Batch = 292 is [[26  0  1  2]
#  [ 0 33  1  0]
#  [ 1  0 27  1]
#  [ 2  0  0  6]]
# Confusion Matrix for Batch = 293 is [[28  0  0  2]
#  [ 0 32  0  0]
#  [ 0  0 26  2]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 294 is [[27  0  0  1]
#  [ 0 32  0  1]
#  [ 2  0 20  3]
#  [ 1  0  0 13]]
# Confusion Matrix for Batch = 295 is [[23  0  2  1]
#  [ 0 13  0  3]
#  [ 1  0 24  4]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 296 is [[16  0  0  2]
#  [ 0 16  1  0]
#  [ 2  0 33  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 297 is [[24  0  0  1]
#  [ 0 24  0  0]
#  [ 1  0 24  4]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 298 is [[17  0  2  1]
#  [ 2 19  0  0]
#  [ 1  1 26  4]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 299 is [[20  0  0  2]
#  [ 0 19  1  1]
#  [ 0  0 21  5]
#  [ 1  0  0 30]]
# Confusion Matrix for Batch = 300 is [[11  1  1  2]
#  [ 0 21  1  1]
#  [ 2  0 27  4]
#  [ 1  0  0 28]]
# Confusion Matrix for Batch = 301 is [[21  0  0  0]
#  [ 1 20  0  0]
#  [ 3  0 21  6]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 302 is [[32  0  1  1]
#  [ 0 19  0  0]
#  [ 2  0 21  4]
#  [ 0  0  1 19]]
# Confusion Matrix for Batch = 303 is [[21  0  0  1]
#  [ 1 32  0  1]
#  [ 2  0 21  3]
#  [ 2  0  0 16]]
# Confusion Matrix for Batch = 304 is [[24  0  2  2]
#  [ 2 26  1  1]
#  [ 1  0 26  1]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 305 is [[23  0  0  1]
#  [ 1 39  0  0]
#  [ 0  0 23  1]
#  [ 1  0  0 11]]
# Confusion Matrix for Batch = 306 is [[30  0  0  3]
#  [ 0 21  0  1]
#  [ 2  0 27  2]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 307 is [[20  0  0  2]
#  [ 0 14  0  0]
#  [ 0  0 23  6]
#  [ 0  0  4 31]]
# Confusion Matrix for Batch = 308 is [[17  0  0  1]
#  [ 1 16  0  0]
#  [ 0  0 35  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 309 is [[18  0  3  0]
#  [ 1 19  0  1]
#  [ 1  0 20  4]
#  [ 1  0  1 31]]
# Confusion Matrix for Batch = 310 is [[24  0  0  3]
#  [ 1 22  0  0]
#  [ 0  0 28  3]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 311 is [[24  0  0  2]
#  [ 0 27  0  0]
#  [ 1  0 26  2]
#  [ 0  0  3 15]]
# Confusion Matrix for Batch = 312 is [[27  0  0  1]
#  [ 2 12  0  1]
#  [ 1  1 20  2]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 313 is [[28  0  0  2]
#  [ 2 26  1  1]
#  [ 0  0 17  1]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 314 is [[27  0  0  1]
#  [ 0 37  2  0]
#  [ 1  0 12  1]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 315 is [[23  0  0  2]
#  [ 2 36  0  0]
#  [ 1  1 23  1]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 316 is [[32  0  0  0]
#  [ 1 35  2  1]
#  [ 1  0 12  3]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 317 is [[18  1  0  0]
#  [ 1 48  1  0]
#  [ 0  0 16  1]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 318 is [[41  1  0  0]
#  [ 1 22  1  1]
#  [ 1  0 14  1]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 319 is [[39  0  0  1]
#  [ 3 34  0  1]
#  [ 0  0 12  0]
#  [ 1  0  0  9]]
# Confusion Matrix for Batch = 320 is [[31  0  0  1]
#  [ 3 45  0  0]
#  [ 0  0 11  2]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 321 is [[39  0  0  0]
#  [ 2 42  0  0]
#  [ 1  0  9  1]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 322 is [[23  0  0  0]
#  [ 3 47  2  0]
#  [ 0  0 12  3]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 323 is [[41  0  0  2]
#  [ 0 32  0  1]
#  [ 0  0 14  2]
#  [ 1  0  1  6]]
# Confusion Matrix for Batch = 324 is [[43  0  0  0]
#  [ 1 36  0  3]
#  [ 0  0 12  0]
#  [ 0  0  0  5]]
# Confusion Matrix for Batch = 325 is [[45  0  0  0]
#  [ 5 27  0  0]
#  [ 2  0 10  2]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 326 is [[39  1  0  1]
#  [ 3 38  0  0]
#  [ 0  0 10  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 327 is [[34  1  0  2]
#  [ 0 26  0  1]
#  [ 1  0 16  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 328 is [[33  0  0  0]
#  [ 1 32  0  1]
#  [ 2  0 19  1]
#  [ 1  0  1  9]]
# Confusion Matrix for Batch = 329 is [[28  0  0  3]
#  [ 0 27  0  0]
#  [ 1  0 22  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 330 is [[26  0  0  0]
#  [ 3 21  0  1]
#  [ 1  0 30  3]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 331 is [[31  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0 29  1]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 332 is [[19  0  0  2]
#  [ 1 29  2  2]
#  [ 1  0 24  6]
#  [ 1  0  4  9]]
# Confusion Matrix for Batch = 333 is [[20  0  0  0]
#  [ 1 14  0  0]
#  [ 0  0 26  4]
#  [ 0  0  2 33]]
# Confusion Matrix for Batch = 334 is [[21  0  2  0]
#  [ 1 14  0  1]
#  [ 0  0 35  1]
#  [ 1  0  2 22]]
# Confusion Matrix for Batch = 335 is [[20  0  0  0]
#  [ 1 18  0  0]
#  [ 1  0 25  3]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 336 is [[30  0  1  2]
#  [ 0  8  0  0]
#  [ 0  0 28  3]
#  [ 0  1  0 27]]
# Confusion Matrix for Batch = 337 is [[20  0  2  0]
#  [ 1 24  1  0]
#  [ 1  0 24  7]
#  [ 0  1  1 18]]
# Confusion Matrix for Batch = 338 is [[20  0  1  1]
#  [ 1 23  0  0]
#  [ 1  0 27  2]
#  [ 0  0  4 20]]
# Confusion Matrix for Batch = 339 is [[20  0  0  3]
#  [ 3 15  0  0]
#  [ 0  0 14  7]
#  [ 0  0  1 37]]
# Confusion Matrix for Batch = 340 is [[25  0  0  0]
#  [ 1 20  0  0]
#  [ 0  0 21  3]
#  [ 0  0  4 26]]
# Confusion Matrix for Batch = 341 is [[30  0  0  1]
#  [ 1 29  0  0]
#  [ 0  0 20  4]
#  [ 1  0  0 14]]
# Confusion Matrix for Batch = 342 is [[18  0  0  0]
#  [ 1 31  0  0]
#  [ 1  0 27  5]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 343 is [[16  1  0  3]
#  [ 0 34  0  0]
#  [ 0  0 18  7]
#  [ 1  0  0 20]]
# Confusion Matrix for Batch = 344 is [[31  2  0  2]
#  [ 0 21  0  0]
#  [ 1  0 26  2]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 345 is [[15  0  0  3]
#  [ 1 17  0  0]
#  [ 3  0 12  6]
#  [ 0  0  3 40]]
# Confusion Matrix for Batch = 346 is [[14  0  0  2]
#  [ 2 24  0  0]
#  [ 2  0 29  3]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 347 is [[18  0  0  1]
#  [ 0 10  0  0]
#  [ 0  0 22 11]
#  [ 0  0  1 37]]
# Confusion Matrix for Batch = 348 is [[22  0  0  0]
#  [ 1 15  0  0]
#  [ 1  0 25  4]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 349 is [[18  0  0  1]
#  [ 2 23  0  1]
#  [ 2  0 24  3]
#  [ 0  0  3 23]]
# Confusion Matrix for Batch = 350 is [[19  0  0  1]
#  [ 0 24  0  0]
#  [ 2  0 16  4]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 351 is [[26  0  0  2]
#  [ 1 36  0  0]
#  [ 1  0 12  3]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 352 is [[24  0  1  1]
#  [ 1 29  0  0]
#  [ 0  0 25  5]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 353 is [[31  0  0  0]
#  [ 1 15  0  0]
#  [ 1  0 31  3]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 354 is [[23  0  0  1]
#  [ 0 28  1  0]
#  [ 1  0 23  2]
#  [ 1  0  2 18]]
# Confusion Matrix for Batch = 355 is [[30  0  0  2]
#  [ 0 15  0  2]
#  [ 0  0 28  2]
#  [ 1  0  0 20]]
# Confusion Matrix for Batch = 356 is [[23  0  1  0]
#  [ 1  6  0  1]
#  [ 3  1 37  4]
#  [ 1  0  1 21]]
# Confusion Matrix for Batch = 357 is [[22  0  0  0]
#  [ 1 17  1  0]
#  [ 0  0 41  0]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 358 is [[30  0  0  1]
#  [ 0 17  0  1]
#  [ 1  0 26  2]
#  [ 1  0  1 20]]
# Confusion Matrix for Batch = 359 is [[23  0  0  0]
#  [ 0 19  0  0]
#  [ 2  0 33  1]
#  [ 1  0  0 21]]
# Confusion Matrix for Batch = 360 is [[22  0  1  0]
#  [ 0  9  0  1]
#  [ 1  0 37  4]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 361 is [[20  0  0  0]
#  [ 1 19  0  2]
#  [ 3  0 32  1]
#  [ 1  0  2 19]]
# Confusion Matrix for Batch = 362 is [[16  0  0  0]
#  [ 0 16  0  0]
#  [ 1  0 26  5]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 363 is [[29  0  0  1]
#  [ 1 26  0  0]
#  [ 0  0 17  0]
#  [ 0  0  2 24]]
# Confusion Matrix for Batch = 364 is [[28  0  0  1]
#  [ 2 20  0  0]
#  [ 1  0 17  3]
#  [ 0  0  2 26]]
# Confusion Matrix for Batch = 365 is [[29  0  0  0]
#  [ 1 32  0  0]
#  [ 0  0 20  3]
#  [ 0  0  0 15]]
# Confusion Matrix for Batch = 366 is [[20  0  0  0]
#  [ 0 26  0  0]
#  [ 2  0 29  2]
#  [ 0  0  3 18]]
# Confusion Matrix for Batch = 367 is [[27  0  2  1]
#  [ 1 16  1  1]
#  [ 0  0 21  3]
#  [ 0  0  2 25]]
# Confusion Matrix for Batch = 368 is [[28  0  1  0]
#  [ 1 29  0  0]
#  [ 0  0 17  1]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 369 is [[24  0  0  1]
#  [ 1 12  0  0]
#  [ 2  0 26  3]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 370 is [[21  0  1  1]
#  [ 2 10  0  0]
#  [ 2  0 33  0]
#  [ 1  0  0 29]]
# Confusion Matrix for Batch = 371 is [[25  0  0  1]
#  [ 0 18  0  0]
#  [ 1  0 28  6]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 372 is [[26  0  0  3]
#  [ 0 13  0  1]
#  [ 1  0 23  4]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 373 is [[18  1  0  0]
#  [ 2 22  0  0]
#  [ 1  0 25  1]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 374 is [[17  1  1  3]
#  [ 1 10  0  0]
#  [ 1  0 23  5]
#  [ 0  0  1 37]]
# Confusion Matrix for Batch = 375 is [[24  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 15  9]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 376 is [[19  0  0  3]
#  [ 1 16  0  1]
#  [ 2  0 17 10]
#  [ 2  0  0 29]]
# Confusion Matrix for Batch = 377 is [[28  0  0  0]
#  [ 0 27  0  0]
#  [ 2  0 24  1]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 378 is [[23  1  0  1]
#  [ 2 25  0  1]
#  [ 1  0 35  2]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 379 is [[26  1  1  2]
#  [ 1 26  0  0]
#  [ 0  0 25  1]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 380 is [[17  0  0  0]
#  [ 0 37  1  0]
#  [ 1  0 27  1]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 381 is [[17  0  0  1]
#  [ 2 20  0  1]
#  [ 1  0 29  6]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 382 is [[19  1  1  1]
#  [ 0 14  0  0]
#  [ 1  0 38  5]
#  [ 0  0  1 19]]
# Confusion Matrix for Batch = 383 is [[17  0  1  2]
#  [ 1 14  0  2]
#  [ 1  0 34  3]
#  [ 0  0  2 23]]
# Confusion Matrix for Batch = 384 is [[28  0  1  0]
#  [ 0 19  0  1]
#  [ 1  0 23  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 385 is [[23  0  0  1]
#  [ 0 26  0  0]
#  [ 2  0 24  2]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 386 is [[19  0  0  2]
#  [ 0 17  0  0]
#  [ 2  0 26  0]
#  [ 0  0  2 32]]
# Confusion Matrix for Batch = 387 is [[23  0  0  0]
#  [ 0 26  0  1]
#  [ 0  0 12  2]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 388 is [[33  0  2  0]
#  [ 1 23  0  0]
#  [ 1  0 13  0]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 389 is [[27  0  0  0]
#  [ 2 36  1  0]
#  [ 0  0 22  0]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 390 is [[27  0  0  1]
#  [ 1 30  0  0]
#  [ 2  0 19  3]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 391 is [[24  0  0  0]
#  [ 2 47  0  2]
#  [ 0  0 12  0]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 392 is [[29  0  1  1]
#  [ 0 42  0  0]
#  [ 0  0 17  0]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 393 is [[35  0  0  1]
#  [ 1 41  0  1]
#  [ 1  0  6  0]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 394 is [[33  0  0  1]
#  [ 3 44  0  0]
#  [ 1  0 12  0]
#  [ 1  0  0  5]]
# Confusion Matrix for Batch = 395 is [[28  0  1  2]
#  [ 0 45  0  1]
#  [ 2  0 10  1]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 396 is [[31  0  1  1]
#  [ 2 39  0  0]
#  [ 0  0 14  0]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 397 is [[25  0  0  2]
#  [ 0 34  3  1]
#  [ 0  0 25  1]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 398 is [[49  0  0  0]
#  [ 1 28  0  0]
#  [ 1  0 13  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 399 is [[31  0  0  1]
#  [ 1 48  1  0]
#  [ 1  0 10  0]
#  [ 0  0  1  6]]
# Confusion Matrix for Batch = 400 is [[52  0  0  2]
#  [ 1 26  0  0]
#  [ 1  0  9  2]
#  [ 1  0  1  5]]
# Confusion Matrix for Batch = 401 is [[31  0  1  0]
#  [ 1 37  0  1]
#  [ 1  0 18  1]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 402 is [[28  0  0  1]
#  [ 3 40  1  0]
#  [ 1  0 14  0]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 403 is [[25  0  1  1]
#  [ 2 47  0  0]
#  [ 3  0 15  0]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 404 is [[27  0  1  0]
#  [ 1 28  1  0]
#  [ 0  0 24  2]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 405 is [[22  0  1  0]
#  [ 1 33  0  1]
#  [ 1  0 22  2]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 406 is [[31  0  0  0]
#  [ 1 30  1  0]
#  [ 1  0 24  2]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 407 is [[25  0  1  1]
#  [ 1 10  1  1]
#  [ 2  0 28  1]
#  [ 1  0  0 28]]
# Confusion Matrix for Batch = 408 is [[22  0  1  0]
#  [ 1 17  0  0]
#  [ 0  1 30  3]
#  [ 1  0  1 23]]
# Confusion Matrix for Batch = 409 is [[19  0  0  1]
#  [ 0  9  1  1]
#  [ 2  0 29  2]
#  [ 1  0  1 34]]
# Confusion Matrix for Batch = 410 is [[28  0  0  4]
#  [ 0 13  0  1]
#  [ 1  0 24  6]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 411 is [[23  0  0  0]
#  [ 0 22  1  0]
#  [ 1  0 25  2]
#  [ 0  0  3 23]]
# Confusion Matrix for Batch = 412 is [[19  1  0  0]
#  [ 1 17  0  1]
#  [ 0  0 17  4]
#  [ 0  0  0 40]]
# Confusion Matrix for Batch = 413 is [[18  0  0  0]
#  [ 0 20  0  1]
#  [ 2  0 32  3]
#  [ 0  0  3 21]]
# Confusion Matrix for Batch = 414 is [[19  0  0  1]
#  [ 0 27  0  1]
#  [ 1  0 23  1]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 415 is [[21  0  0  0]
#  [ 0 17  0  1]
#  [ 0  0 18  5]
#  [ 0  0  0 38]]
# Confusion Matrix for Batch = 416 is [[21  0  0  1]
#  [ 0 23  0  2]
#  [ 2  0 13  3]
#  [ 0  0  1 34]]
# Confusion Matrix for Batch = 417 is [[13  0  2  0]
#  [ 1 34  1  1]
#  [ 2  0 26  1]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 418 is [[22  0  1  0]
#  [ 0 31  0  0]
#  [ 1  0 27  3]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 419 is [[ 9  0  1  0]
#  [ 2 30  0  0]
#  [ 1  0 29  5]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 420 is [[24  0  0  0]
#  [ 1 32  1  1]
#  [ 0  0 25  2]
#  [ 0  0  3 11]]
# Confusion Matrix for Batch = 421 is [[21  0  0  0]
#  [ 0 25  0  1]
#  [ 4  0 27  4]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 422 is [[17  0  0  1]
#  [ 0 18  0  0]
#  [ 0  0 24  4]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 423 is [[25  0  0  2]
#  [ 0 15  0  2]
#  [ 0  0 26  5]
#  [ 0  0  1 24]]
# Confusion Matrix for Batch = 424 is [[16  0  0  0]
#  [ 1 13  0  0]
#  [ 0  0 46  4]
#  [ 0  0  1 19]]
# Confusion Matrix for Batch = 425 is [[31  0  0  0]
#  [ 0 14  0  1]
#  [ 2  0 22  4]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 426 is [[12  0  1  1]
#  [ 0 21  0  1]
#  [ 0  1 33  4]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 427 is [[19  0  0  1]
#  [ 0 20  0  1]
#  [ 2  0 22  3]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 428 is [[23  0  0  0]
#  [ 1 28  0  0]
#  [ 1  0 16  3]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 429 is [[17  0  0  1]
#  [ 0 20  0  1]
#  [ 1  0 27  3]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 430 is [[26  0  1  3]
#  [ 0 20  0  1]
#  [ 2  0 14  4]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 431 is [[23  0  0  2]
#  [ 1 14  0  0]
#  [ 1  1 22  3]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 432 is [[26  0  0  0]
#  [ 1 29  0  0]
#  [ 0  0 31  3]
#  [ 1  0  1  8]]
# Confusion Matrix for Batch = 433 is [[16  0  1  1]
#  [ 2 28  1  1]
#  [ 0  0 31  2]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 434 is [[32  0  0  0]
#  [ 1 23  0  1]
#  [ 1  0 27  1]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 435 is [[26  0  1  0]
#  [ 0 15  0  0]
#  [ 0  0 34  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 436 is [[18  0  1  1]
#  [ 0 16  0  1]
#  [ 0  0 25  7]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 437 is [[22  0  1  1]
#  [ 1 12  1  0]
#  [ 2  0 29  2]
#  [ 1  0  1 27]]
# Confusion Matrix for Batch = 438 is [[19  0  0  0]
#  [ 3 11  0  0]
#  [ 1  0 33  4]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 439 is [[15  0  0  2]
#  [ 1 13  0  2]
#  [ 3  0 26  1]
#  [ 0  0  2 35]]
# Confusion Matrix for Batch = 440 is [[13  0  0  0]
#  [ 0 23  0  1]
#  [ 0  0 26  1]
#  [ 0  0  0 36]]
# Confusion Matrix for Batch = 441 is [[17  0  0  2]
#  [ 0 18  0  2]
#  [ 0  0 31  3]
#  [ 0  0  2 25]]
# Confusion Matrix for Batch = 442 is [[23  0  1  0]
#  [ 2 19  0  0]
#  [ 1  0 28  2]
#  [ 2  0  1 21]]
# Confusion Matrix for Batch = 443 is [[21  0  0  1]
#  [ 0 24  0  1]
#  [ 2  0 19  2]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 444 is [[13  0  0  1]
#  [ 0 28  0  1]
#  [ 1  0 26  0]
#  [ 1  0  0 29]]
# Confusion Matrix for Batch = 445 is [[24  0  0  1]
#  [ 3 27  0  1]
#  [ 0  0 23  3]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 446 is [[23  0  0  1]
#  [ 0 24  0  1]
#  [ 0  0 32  0]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 447 is [[31  0  0  1]
#  [ 1 14  1  1]
#  [ 1  0 34  0]
#  [ 0  0  2 14]]
# Confusion Matrix for Batch = 448 is [[28  1  1  1]
#  [ 0 27  0  0]
#  [ 0  0 26  2]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 449 is [[24  2  1  2]
#  [ 0 10  1  2]
#  [ 0  0 27  1]
#  [ 0  0  3 27]]
# Confusion Matrix for Batch = 450 is [[21  0  0  1]
#  [ 0 17  0  4]
#  [ 1  1 28  2]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 451 is [[27  0  0  2]
#  [ 0  6  0  0]
#  [ 2  0 32  1]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 452 is [[13  0  1  1]
#  [ 0 21  1  1]
#  [ 0  0 30  4]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 453 is [[11  0  0  1]
#  [ 1 14  0  1]
#  [ 3  1 31  4]
#  [ 0  0  3 30]]
# Confusion Matrix for Batch = 454 is [[17  0  0  2]
#  [ 2 19  0  0]
#  [ 1  0 21  3]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 455 is [[18  0  1  0]
#  [ 0 18  0  1]
#  [ 3  0 30  2]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 456 is [[19  0  0  1]
#  [ 1 16  0  2]
#  [ 1  0 23  5]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 457 is [[21  1  1  1]
#  [ 1 20  3  0]
#  [ 2  0 15  6]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 458 is [[24  0  0  2]
#  [ 1 27  0  0]
#  [ 3  0 23  1]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 459 is [[25  1  0  0]
#  [ 2 29  0  0]
#  [ 1  0 21  2]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 460 is [[14  1  0  1]
#  [ 1 29  0  0]
#  [ 1  0 28  4]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 461 is [[21  0  0  2]
#  [ 0 35  0  0]
#  [ 0  0 25  3]
#  [ 0  1  1 12]]
# Confusion Matrix for Batch = 462 is [[30  0  0  1]
#  [ 0 17  0  1]
#  [ 0  0 21  6]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 463 is [[14  0  0  2]
#  [ 0 22  1  0]
#  [ 1  0 26  2]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 464 is [[29  0  0  2]
#  [ 1 18  0  1]
#  [ 1  0 31  3]
#  [ 0  0  2 12]]
# Confusion Matrix for Batch = 465 is [[10  0  0  5]
#  [ 1 21  0  1]
#  [ 2  0 15  8]
#  [ 1  0  1 35]]
# Confusion Matrix for Batch = 466 is [[19  0  1  2]
#  [ 2 12  0  0]
#  [ 0  0 32  1]
#  [ 0  0  2 29]]
# Confusion Matrix for Batch = 467 is [[17  0  0  0]
#  [ 1 22  0  0]
#  [ 1  0 35  5]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 468 is [[17  0  0  2]
#  [ 0 22  0  1]
#  [ 1  0 29  6]
#  [ 1  0  2 19]]
# Confusion Matrix for Batch = 469 is [[18  0  0  2]
#  [ 0 21  0  3]
#  [ 0  0 31  5]
#  [ 0  0  2 18]]
# Confusion Matrix for Batch = 470 is [[22  0  0  0]
#  [ 2 24  1  1]
#  [ 2  0 23  0]
#  [ 1  0  1 23]]
# Confusion Matrix for Batch = 471 is [[13  0  0  3]
#  [ 0 33  1  0]
#  [ 2  0 17  4]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 472 is [[24  0  1  0]
#  [ 1 40  1  0]
#  [ 0  0 21  3]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 473 is [[27  0  1  1]
#  [ 0 37  1  1]
#  [ 1  0 20  1]
#  [ 0  0  1  9]]
# Confusion Matrix for Batch = 474 is [[30  0  0  0]
#  [ 1 39  0  0]
#  [ 1  0 10  0]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 475 is [[36  0  0  0]
#  [ 2 30  0  1]
#  [ 1  0 13  0]
#  [ 1  0  3 13]]
# Confusion Matrix for Batch = 476 is [[31  0  1  0]
#  [ 2 25  0  0]
#  [ 2  0  9  3]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 477 is [[33  0  0  1]
#  [ 3 41  0  1]
#  [ 1  0 13  0]
#  [ 0  0  0  7]]
# Confusion Matrix for Batch = 478 is [[21  0  0  0]
#  [ 2 53  0  1]
#  [ 1  0 10  0]
#  [ 0  0  0 12]]
# Confusion Matrix for Batch = 479 is [[26  0  0  1]
#  [ 2 48  0  1]
#  [ 0  0 14  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 480 is [[25  0  0  1]
#  [ 0 38  1  1]
#  [ 0  0 20  0]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 481 is [[31  0  0  0]
#  [ 0 42  1  1]
#  [ 2  0 12  0]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 482 is [[51  0  1  1]
#  [ 0 21  0  0]
#  [ 1  0 13  1]
#  [ 1  0  1  9]]
# Confusion Matrix for Batch = 483 is [[38  0  2  0]
#  [ 2 32  0  0]
#  [ 0  0 12  0]
#  [ 0  0  1 13]]
# Confusion Matrix for Batch = 484 is [[20  0  0  0]
#  [ 3 35  0  0]
#  [ 0  0 23  1]
#  [ 0  0  2 16]]
# Confusion Matrix for Batch = 485 is [[30  0  0  0]
#  [ 2 40  0  0]
#  [ 1  0 15  0]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 486 is [[20  0  2  0]
#  [ 1 32  0  0]
#  [ 0  0 28  2]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 487 is [[33  0  1  1]
#  [ 1 20  0  1]
#  [ 1  0 25  0]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 488 is [[40  0  2  0]
#  [ 0 24  2  1]
#  [ 0  0 17  1]
#  [ 1  0  1 11]]
# Confusion Matrix for Batch = 489 is [[16  0  0  2]
#  [ 1 18  0  1]
#  [ 0  0 24  2]
#  [ 0  0  5 31]]
# Confusion Matrix for Batch = 490 is [[23  0  0  0]
#  [ 1 13  0  1]
#  [ 2  0 27  2]
#  [ 0  0  2 29]]
# Confusion Matrix for Batch = 491 is [[15  0  0  2]
#  [ 0 10  0  5]
#  [ 0  0 29  0]
#  [ 0  0  4 35]]
# Confusion Matrix for Batch = 492 is [[16  0  0  0]
#  [ 1 22  0  4]
#  [ 2  0 24  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 493 is [[20  0  1  0]
#  [ 0  9  1  1]
#  [ 0  0 29  3]
#  [ 1  0  0 35]]
# Confusion Matrix for Batch = 494 is [[11  0  0  2]
#  [ 1 19  0  2]
#  [ 1  0 39  4]
#  [ 0  0  0 21]]
# Confusion Matrix for Batch = 495 is [[19  0  0  3]
#  [ 0 16  0  0]
#  [ 2  0 27  2]
# ...
#  [ 0 14  0  0]
#  [ 0  0 23  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1040 is [[17  0  1  1]
#  [ 0 18  0  0]
#  [ 0  0 28  1]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 1041 is [[18  0  0  0]
#  [ 0 19  0  0]
#  [ 0  0 24  2]
#  [ 0  0  0 37]]
# Confusion Matrix for Batch = 1042 is [[10  0  2  2]
#  [ 0 18  0  1]
#  [ 0  0 31  1]
#  [ 0  0  1 34]]
# Confusion Matrix for Batch = 1043 is [[16  0  3  1]
#  [ 0 31  0  0]
#  [ 0  0 21  2]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1044 is [[19  0  1  0]
#  [ 1 17  0  0]
#  [ 0  0 33  1]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1045 is [[27  0  2  0]
#  [ 0 26  0  1]
#  [ 0  0 20  1]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1046 is [[21  0  2  2]
#  [ 1 27  0  0]
#  [ 0  0 17  4]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1047 is [[24  0  1  0]
#  [ 1 24  1  1]
#  [ 0  0 31  1]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 1048 is [[29  0  2  0]
#  [ 0 20  0  0]
#  [ 0  0 31  1]
#  [ 0  0  2 15]]
# Confusion Matrix for Batch = 1049 is [[31  0  0  1]
#  [ 0 26  0  2]
#  [ 0  0 25  1]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1050 is [[16  0  2  0]
#  [ 0 15  0  1]
#  [ 1  0 30  3]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 1051 is [[18  0  1  1]
#  [ 0 18  0  0]
#  [ 1  0 34  3]
#  [ 1  0  1 22]]
# Confusion Matrix for Batch = 1052 is [[34  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 29  0]
#  [ 1  0  1 14]]
# Confusion Matrix for Batch = 1053 is [[25  0  1  0]
#  [ 0 22  0  0]
#  [ 0  0 21  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 1054 is [[13  0  1  1]
#  [ 0 15  0  0]
#  [ 0  0 31  0]
#  [ 0  0  3 36]]
# Confusion Matrix for Batch = 1055 is [[19  0  0  0]
#  [ 0 23  0  0]
#  [ 0  0 32  1]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 1056 is [[18  0  0  1]
#  [ 1 17  2  0]
#  [ 1  0 30  2]
#  [ 1  0  0 27]]
# Confusion Matrix for Batch = 1057 is [[18  0  0  1]
#  [ 0 25  0  1]
#  [ 0  0 16  2]
#  [ 0  0  0 37]]
# Confusion Matrix for Batch = 1058 is [[25  0  0  1]
#  [ 0 33  0  0]
#  [ 1  0 22  1]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 1059 is [[21  0  0  1]
#  [ 0 28  0  1]
#  [ 0  0 25  0]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 1060 is [[19  0  0  0]
#  [ 0 33  0  1]
#  [ 0  0 37  0]
#  [ 1  0  1  8]]
# Confusion Matrix for Batch = 1061 is [[25  0  0  0]
#  [ 0 17  0  0]
#  [ 0  0 41  1]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 1062 is [[26  0  0  0]
#  [ 0 17  0  0]
#  [ 0  0 22  3]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 1063 is [[18  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 34  0]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1064 is [[22  0  0  0]
#  [ 1 16  0  0]
#  [ 1  0 23  3]
#  [ 0  0  0 34]]
# Confusion Matrix for Batch = 1065 is [[17  0  1  0]
#  [ 0 22  0  0]
#  [ 0  0 26  0]
#  [ 1  0  3 30]]
# Confusion Matrix for Batch = 1066 is [[29  0  0  0]
#  [ 0 18  0  0]
#  [ 1  0 24  1]
#  [ 0  0  2 25]]
# Confusion Matrix for Batch = 1067 is [[31  0  0  0]
#  [ 0 35  0  0]
#  [ 0  0 18  0]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 1068 is [[ 9  0  0  2]
#  [ 0 22  0  0]
#  [ 0  0 21  3]
#  [ 0  0  0 43]]
# Confusion Matrix for Batch = 1069 is [[12  0  0  1]
#  [ 1 16  0  0]
#  [ 0  0 20  4]
#  [ 1  0  2 43]]
# Confusion Matrix for Batch = 1070 is [[27  0  0  0]
#  [ 0 31  0  0]
#  [ 1  0 26  2]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 1071 is [[28  0  0  2]
#  [ 0 21  0  0]
#  [ 0  0 31  1]
#  [ 2  0  1 14]]
# Confusion Matrix for Batch = 1072 is [[19  0  0  0]
#  [ 0 18  0  0]
#  [ 1  0 17  5]
#  [ 0  0  0 40]]
# Confusion Matrix for Batch = 1073 is [[17  0  0  0]
#  [ 0 27  0  1]
#  [ 0  0 31  2]
#  [ 0  0  0 22]]
# Confusion Matrix for Batch = 1074 is [[22  1  1  0]
#  [ 0 25  0  0]
#  [ 0  0 38  2]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 1075 is [[17  0  1  1]
#  [ 0 21  0  0]
#  [ 1  0 26  4]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1076 is [[21  0  0  1]
#  [ 0 22  0  1]
#  [ 0  0 15  4]
#  [ 1  0  1 34]]
# Confusion Matrix for Batch = 1077 is [[20  0  0  0]
#  [ 0 24  1  0]
#  [ 0  0 37  0]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 1078 is [[24  0  0  1]
#  [ 0 28  0  0]
#  [ 1  0 27  2]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 1079 is [[34  0  1  0]
#  [ 2 32  0  0]
#  [ 1  0 27  0]
#  [ 0  0  0  3]]
# Confusion Matrix for Batch = 1080 is [[21  0  0  1]
#  [ 0 17  0  0]
#  [ 1  0 29  3]
#  [ 0  0  1 27]]
# Confusion Matrix for Batch = 1081 is [[22  0  0  1]
#  [ 0 21  0  0]
#  [ 0  0 33  1]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 1082 is [[21  0  0  1]
#  [ 0 18  1  0]
#  [ 0  0 32  4]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1083 is [[17  0  0  0]
#  [ 0 21  0  0]
#  [ 1  0 39  0]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 1084 is [[22  0  0  3]
#  [ 0 16  0  0]
#  [ 0  0 28  1]
#  [ 1  0  1 28]]
# Confusion Matrix for Batch = 1085 is [[21  0  0  0]
#  [ 0 24  0  0]
#  [ 0  0 24  1]
#  [ 0  0  2 28]]
# Confusion Matrix for Batch = 1086 is [[12  0  1  0]
#  [ 0 29  2  0]
#  [ 0  0 14  5]
#  [ 0  0  1 36]]
# Confusion Matrix for Batch = 1087 is [[21  0  0  0]
#  [ 0 46  0  0]
#  [ 0  0 19  1]
#  [ 0  0  2 11]]
# Confusion Matrix for Batch = 1088 is [[28  0  0  0]
#  [ 0 41  0  0]
#  [ 0  0 20  0]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 1089 is [[32  0  0  0]
#  [ 0 32  0  0]
#  [ 1  0 17  1]
#  [ 0  0  0 17]]
# Confusion Matrix for Batch = 1090 is [[27  0  0  0]
#  [ 0 18  0  2]
#  [ 0  0 14  1]
#  [ 0  0  0 38]]
# Confusion Matrix for Batch = 1091 is [[21  0  0  1]
#  [ 0 25  0  0]
#  [ 0  0 30  2]
#  [ 0  0  2 19]]
# Confusion Matrix for Batch = 1092 is [[25  0  1  0]
#  [ 2 19  0  0]
#  [ 1  0 23  1]
#  [ 0  0  1 27]]
# Confusion Matrix for Batch = 1093 is [[21  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 14  1]
#  [ 0  0  1 32]]
# Confusion Matrix for Batch = 1094 is [[14  0  1  1]
#  [ 1 28  0  0]
#  [ 2  0 28  1]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 1095 is [[21  0  0  1]
#  [ 0 44  0  0]
#  [ 1  0 19  0]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1096 is [[25  0  0  0]
#  [ 0 30  0  0]
#  [ 2  0 27  1]
#  [ 1  0  0 14]]
# Confusion Matrix for Batch = 1097 is [[22  0  1  1]
#  [ 1 30  0  0]
#  [ 0  0 34  0]
#  [ 1  0  0 10]]
# Confusion Matrix for Batch = 1098 is [[24  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 19  1]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 1099 is [[22  1  0  0]
#  [ 0 22  0  0]
#  [ 0  0 32  0]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 1100 is [[28  0  1  2]
#  [ 0 23  0  0]
#  [ 0  0 24  2]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 1101 is [[22  0  0  1]
#  [ 0 21  0  0]
#  [ 0  0 36  1]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 1102 is [[15  2  0  2]
#  [ 0 19  0  0]
#  [ 1  0 19  1]
#  [ 0  0  2 39]]
# Confusion Matrix for Batch = 1103 is [[14  0  0  3]
#  [ 0 22  0  1]
#  [ 0  0 27  2]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 1104 is [[17  0  0  0]
#  [ 0 26  0  0]
#  [ 0  0 36  2]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 1105 is [[30  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 18  1]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 1106 is [[18  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 17  3]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 1107 is [[19  0  0  1]
#  [ 0 23  0  2]
#  [ 0  0 21  2]
#  [ 1  0  0 31]]
# Confusion Matrix for Batch = 1108 is [[28  0  0  1]
#  [ 0 15  0  0]
#  [ 2  0 29  1]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 1109 is [[30  0  0  2]
#  [ 0 14  0  0]
#  [ 0  0 37  1]
#  [ 1  0  0 15]]
# Confusion Matrix for Batch = 1110 is [[22  0  1  0]
#  [ 0 24  0  0]
#  [ 0  0 32  3]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 1111 is [[19  0  0  0]
#  [ 0 16  0  0]
#  [ 1  0 40  1]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1112 is [[21  0  1  0]
#  [ 0 21  0  0]
#  [ 0  0 34  0]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1113 is [[23  0  0  1]
#  [ 0 17  0  0]
#  [ 0  0 13  5]
#  [ 0  0  0 41]]
# Confusion Matrix for Batch = 1114 is [[17  0  0  1]
#  [ 0 22  0  1]
#  [ 0  0 28  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 1115 is [[19  0  0  2]
#  [ 0 13  0  0]
#  [ 0  0 27  0]
#  [ 0  0  1 38]]
# Confusion Matrix for Batch = 1116 is [[14  0  0  0]
#  [ 0 23  0  1]
#  [ 0  0 29  2]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 1117 is [[25  0  0  1]
#  [ 0 26  0  0]
#  [ 1  0 29  0]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 1118 is [[15  0  0  1]
#  [ 0 38  0  0]
#  [ 0  0 34  1]
#  [ 1  0  1  9]]
# Confusion Matrix for Batch = 1119 is [[20  0  0  1]
#  [ 0 28  0  0]
#  [ 2  0 26  0]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1120 is [[23  0  0  0]
#  [ 1 34  0  0]
#  [ 0  1 26  0]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 1121 is [[16  0  0  0]
#  [ 0 22  0  0]
#  [ 2  0 23  0]
#  [ 0  0  0 37]]
# Confusion Matrix for Batch = 1122 is [[18  0  1  0]
#  [ 0 16  0  0]
#  [ 0  0 33  1]
#  [ 1  0  0 30]]
# Confusion Matrix for Batch = 1123 is [[23  0  1  0]
#  [ 0 24  1  0]
#  [ 0  0 24  1]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1124 is [[26  0  0  2]
#  [ 0 18  0  0]
#  [ 0  0 27  0]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 1125 is [[22  0  0  0]
#  [ 0 28  0  0]
#  [ 0  0 29  1]
#  [ 0  0  1 19]]
# Confusion Matrix for Batch = 1126 is [[29  0  1  0]
#  [ 0 22  0  0]
#  [ 0  0 30  0]
#  [ 1  0  1 16]]
# Confusion Matrix for Batch = 1127 is [[14  0  1  2]
#  [ 0 20  0  1]
#  [ 1  0 18  4]
#  [ 1  0  0 38]]
# Confusion Matrix for Batch = 1128 is [[21  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 29  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1129 is [[28  0  0  0]
#  [ 0 35  0  1]
#  [ 0  0 24  1]
#  [ 0  0  0 11]]
# Confusion Matrix for Batch = 1130 is [[34  0  0  0]
#  [ 0 24  0  0]
#  [ 0  0 25  0]
#  [ 1  0  0 16]]
# Confusion Matrix for Batch = 1131 is [[33  1  0  0]
#  [ 0 43  0  0]
#  [ 1  0 14  2]
#  [ 0  0  0  6]]
# Confusion Matrix for Batch = 1132 is [[30  0  0  0]
#  [ 1 48  0  0]
#  [ 0  0 11  0]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 1133 is [[35  0  0  2]
#  [ 0 41  0  0]
#  [ 0  1 16  0]
#  [ 0  0  0  5]]
# Confusion Matrix for Batch = 1134 is [[21  0  0  1]
#  [ 2 48  0  0]
#  [ 0  0 19  0]
#  [ 0  0  0  9]]
# Confusion Matrix for Batch = 1135 is [[42  0  1  0]
#  [ 0 40  0  0]
#  [ 2  0  6  0]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 1136 is [[48  0  1  0]
#  [ 0 20  0  1]
#  [ 0  0 15  1]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1137 is [[32  0  0  0]
#  [ 0 34  0  0]
#  [ 0  0 15  0]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 1138 is [[28  0  0  1]
#  [ 3 36  0  0]
#  [ 1  0 12  1]
#  [ 1  0  0 17]]
# Confusion Matrix for Batch = 1139 is [[23  0  0  0]
#  [ 1 31  0  0]
#  [ 0  0 26  3]
#  [ 2  0  1 13]]
# Confusion Matrix for Batch = 1140 is [[20  0  0  0]
#  [ 2 27  0  0]
#  [ 0  0 18  0]
#  [ 2  0  4 27]]
# Confusion Matrix for Batch = 1141 is [[26  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 25  0]
#  [ 1  0  0 18]]
# Confusion Matrix for Batch = 1142 is [[18  0  0  0]
#  [ 2 21  0  0]
#  [ 1  0 24  2]
#  [ 0  0  0 32]]
# Confusion Matrix for Batch = 1143 is [[20  0  0  0]
#  [ 1 17  0  2]
#  [ 1  0 39  1]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 1144 is [[16  0  0  0]
#  [ 0 13  0  1]
#  [ 0  0 34  1]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 1145 is [[29  0  0  1]
#  [ 0 15  0  0]
#  [ 0  0 41  0]
#  [ 1  0  1 12]]
# Confusion Matrix for Batch = 1146 is [[21  0  0  1]
#  [ 0 21  0  0]
#  [ 0  0 29  1]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 1147 is [[20  0  1  0]
#  [ 0 28  0  2]
#  [ 0  0 20  0]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1148 is [[20  0  0  0]
#  [ 1 27  0  1]
#  [ 0  0 23  1]
#  [ 0  0  1 26]]
# Confusion Matrix for Batch = 1149 is [[11  0  0  0]
#  [ 0 20  0  2]
#  [ 0  0 15  4]
#  [ 0  0  1 47]]
# Confusion Matrix for Batch = 1150 is [[23  0  0  0]
#  [ 1 25  0  0]
#  [ 0  0 32  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1151 is [[16  0  1  0]
#  [ 0 31  0  1]
#  [ 0  0 25  0]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1152 is [[26  0  0  0]
#  [ 1 27  0  0]
#  [ 0  0 23  0]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1153 is [[30  0  0  1]
#  [ 0 22  1  2]
#  [ 0  0 28  1]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 1154 is [[24  0  0  4]
#  [ 0 16  0  0]
#  [ 0  0 24  1]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 1155 is [[27  0  0  4]
#  [ 0  9  0  0]
#  [ 0  0 21  0]
#  [ 0  0  0 39]]
# Confusion Matrix for Batch = 1156 is [[23  0  0  2]
#  [ 0  6  0  0]
#  [ 1  0 36  2]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 1157 is [[14  0  0  1]
#  [ 0 16  0  1]
#  [ 2  0 29  0]
#  [ 0  0  1 36]]
# Confusion Matrix for Batch = 1158 is [[20  0  0  2]
#  [ 0 13  0  0]
#  [ 0  0 27  1]
#  [ 0  0  0 37]]
# Confusion Matrix for Batch = 1159 is [[25  0  0  2]
#  [ 1 17  0  1]
#  [ 0  0 20  4]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 1160 is [[22  1  0  0]
#  [ 0 34  0  0]
#  [ 1  0 22  1]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1161 is [[25  0  0  0]
#  [ 0 28  0  0]
#  [ 0  0 27  2]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 1162 is [[26  0  0  1]
#  [ 0 26  0  1]
#  [ 0  0 16  1]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 1163 is [[21  0  0  0]
#  [ 1 32  0  0]
#  [ 1  0 35  0]
#  [ 0  0  0 10]]
# Confusion Matrix for Batch = 1164 is [[30  0  0  0]
#  [ 1 30  0  0]
#  [ 0  0 24  2]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 1165 is [[33  0  0  0]
#  [ 1 18  0  0]
#  [ 0  0 29  1]
#  [ 0  0  0 18]]
# Confusion Matrix for Batch = 1166 is [[18  0  0  0]
#  [ 1 10  0  0]
#  [ 0  0 47  0]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 1167 is [[20  0  0  0]
#  [ 1 21  0  1]
#  [ 0  0 35  2]
#  [ 0  0  0 20]]
# Confusion Matrix for Batch = 1168 is [[24  0  0  0]
#  [ 0 21  0  1]
#  [ 0  0 38  0]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 1169 is [[29  0  0  0]
#  [ 1 22  0  0]
#  [ 0  0 27  0]
#  [ 1  0  1 19]]
# Confusion Matrix for Batch = 1170 is [[14  0  1  0]
#  [ 0 17  0  0]
#  [ 0  0 17  6]
#  [ 1  0  0 44]]
# Confusion Matrix for Batch = 1171 is [[13  0  0  0]
#  [ 1 22  0  0]
#  [ 1  0 27  4]
#  [ 0  0  2 30]]
# Confusion Matrix for Batch = 1172 is [[28  0  0  0]
#  [ 0 23  1  0]
#  [ 0  1 22  1]
#  [ 0  0  0 24]]
# Confusion Matrix for Batch = 1173 is [[28  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 20  3]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 1174 is [[12  0  0  0]
#  [ 0 31  0  0]
#  [ 0  0 28  0]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1175 is [[15  0  0  0]
#  [ 0 26  0  0]
#  [ 0  0 27  2]
#  [ 0  0  0 30]]
# Confusion Matrix for Batch = 1176 is [[19  0  1  0]
#  [ 0 35  0  0]
#  [ 0  0 33  0]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 1177 is [[32  0  0  1]
#  [ 1 31  0  0]
#  [ 1  0 21  0]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 1178 is [[25  0  0  1]
#  [ 0 11  0  0]
#  [ 1  0 34  0]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 1179 is [[28  0  1  0]
#  [ 0 20  0  0]
#  [ 0  0 35  0]
#  [ 0  0  0 16]]
# Confusion Matrix for Batch = 1180 is [[18  0  0  1]
#  [ 0 16  0  0]
#  [ 0  0 39  1]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 1181 is [[35  0  0  0]
#  [ 0 24  0  0]
#  [ 1  0 32  0]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 1182 is [[14  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 45  0]
#  [ 1  0  0 18]]
# Confusion Matrix for Batch = 1183 is [[ 9  0  0  0]
#  [ 0 38  0  2]
#  [ 0  0 21  1]
#  [ 0  0  0 29]]
# Confusion Matrix for Batch = 1184 is [[27  0  0  0]
#  [ 0 22  0  1]
#  [ 0  0 14  1]
#  [ 1  0  1 33]]
# Confusion Matrix for Batch = 1185 is [[29  0  0  0]
#  [ 0 36  0  1]
#  [ 0  0 22  0]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 1186 is [[30  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 25  1]
#  [ 0  0  0 14]]
# Confusion Matrix for Batch = 1187 is [[19  0  0  1]
#  [ 0 21  0  0]
#  [ 1  0 28  2]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1188 is [[22  0  0  0]
#  [ 0 38  0  0]
#  [ 0  0 26  1]
#  [ 0  0  1 12]]
# Confusion Matrix for Batch = 1189 is [[35  0  0  1]
#  [ 0 13  0  1]
#  [ 1  0 22  0]
#  [ 1  0  0 26]]
# Confusion Matrix for Batch = 1190 is [[24  0  0  0]
#  [ 0  9  0  2]
#  [ 0  0 23  1]
#  [ 0  0  0 41]]
# Confusion Matrix for Batch = 1191 is [[20  0  0  0]
#  [ 0 19  1  0]
#  [ 0  0 29  0]
#  [ 0  0  0 31]]
# Confusion Matrix for Batch = 1192 is [[18  0  0  0]
#  [ 0 20  0  0]
#  [ 1  0 28  0]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 1193 is [[12  0  0  0]
#  [ 0 22  0  1]
#  [ 0  0 39  0]
#  [ 0  0  0 26]]
# Confusion Matrix for Batch = 1194 is [[15  0  0  0]
#  [ 0 31  0  0]
#  [ 1  0 30  0]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1195 is [[24  0  0  0]
#  [ 0 31  1  0]
#  [ 0  0 21  1]
#  [ 1  0  1 20]]
# Confusion Matrix for Batch = 1196 is [[29  0  0  0]
#  [ 0 33  0  0]
#  [ 1  0 21  0]
#  [ 1  0  0 15]]
# Confusion Matrix for Batch = 1197 is [[28  0  0  1]
#  [ 0 35  0  0]
#  [ 1  0 19  1]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 1198 is [[30  0  0  0]
#  [ 0 34  0  0]
#  [ 0  0 23  1]
#  [ 1  0  0 11]]
# Confusion Matrix for Batch = 1199 is [[33  0  1  1]
#  [ 0 27  0  0]
#  [ 0  0 21  2]
#  [ 0  0  1 14]]
# Training Set Accuracy = 0.9300333333333334	Recall = 0.9300333333333333	Precision = 0.936421206606781	F1-Score = 0.9301234429207267	Loss = 0.0021732973400503397	Confusion Matrix = [[33  0  1  1]
#  [ 0 27  0  0]
#  [ 0  0 21  2]
#  [ 0  0  1 14]]

# %%
batch_size = len(data['Description'])
model.eval()
correct = 0
test_loss = 0
precision = []
f1 = []
recall = []


for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in skip_gram_embeddings):
                batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()

    pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
    true = y_true.cpu().numpy()
    precision.append(precision_score(pred, true, average='weighted'))
    f1.append(f1_score(pred, true, average='weighted'))
    recall.append(recall_score(pred, true, average='weighted'))
    confusion = confusion_matrix(pred, true)
    print(f"Confusion Matrix for Batch = {i} is {confusion}")

print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Confusion Matrix for Batch = 0 is [[1640   33   89  127]
#  [ 103 1822   59   88]
#  [ 108   36 1636  271]
#  [  49    9  116 1414]]
# Testing Set Accuracy = 0.8568421052631578	Recall = 0.8568421052631578	Precision = 0.8638512465373962	F1-Score = 0.8581816337286763	Loss = 6.968576781218871e-05

# %% [markdown]
# # Context Window = 2 Ends

# %%
skip_gram_embeddings = torch.load("skip-gram-word-vectors3.pt")
skip_gram_embeddings
# Out:
# {'Reuters': array([ 0.12625949, -0.20541026,  0.06544121, -0.06943685, -0.26494062,
#         -0.27261248,  0.21818571, -0.03563495, -0.35193318, -0.11749578,
#         -0.01266543, -0.05049492, -0.25902155, -0.21637039, -0.22595885,
#         -0.39755803, -0.4934507 , -0.18278563, -0.15559642,  0.00743056,
#         -0.1800574 , -0.05788817, -0.04657734,  0.15675008, -0.33874685,
#         -0.09521841, -0.42909387,  0.567192  , -0.08897841, -0.20097724,
#          0.41537738, -0.3775598 , -0.48451504, -0.26029035,  0.13610536,
#         -0.27856705,  0.44605678, -0.29937077,  0.1553495 ,  0.48205084,
#          0.00084167,  0.05268196, -0.10904583,  0.58368266, -0.06759404,
#          0.16011265,  0.01210472, -0.31068686, -0.35882956,  0.21053262],
#        dtype=float32),
#  '-': array([ 0.26248774, -0.17456482,  0.11316085, -0.03484554, -0.18866777,
#         -0.19673875,  0.23122594, -0.08101395,  0.03163633, -0.24538067,
#         -0.03245716, -0.12655213, -0.07073623, -0.31168276, -0.19963509,
#         -0.14614238, -0.40861887, -0.07250774, -0.16212213, -0.17366903,
#         -0.29221252, -0.1325728 , -0.01040552,  0.2722858 , -0.2904663 ,
#          0.02566475, -0.46218675,  0.434902  , -0.0204672 , -0.34552503,
#          0.26544958, -0.36052147, -0.20635149, -0.04531394,  0.01560956,
#         -0.16651018,  0.4098368 , -0.17917348,  0.41341704,  0.32912678,
#         -0.21366563,  0.18938175, -0.16686404,  0.2133827 , -0.03515286,
#         -0.01334075,  0.06450404, -0.00554032, -0.38220543,  0.1855379 ],
#        dtype=float32),
#  'Short': array([-5.74508369e-01, -1.60825104e-01, -9.39154446e-01, -1.10030144e-01,
#         -3.57878953e-02,  3.11547935e-01,  1.26382661e+00, -7.35265851e-01,
#         -7.45237842e-02, -9.10287201e-01,  4.78820562e-01,  9.62026358e-01,
#         -2.19568038e+00, -8.52835327e-02, -1.19704090e-01,  1.40761900e+00,
#         -9.12099004e-01, -7.92178273e-01, -2.04133391e-01,  2.52362281e-01,
#          0.2189452 , -0.33148456, -0.14479065, -0.03210212,  0.01122454,
#         -0.17628056,  0.34197325, -0.15741846,  0.43461043,  0.31687698,
#         -0.22293836,  0.2513544 , -0.12510496,  0.2594034 , -0.00096335,
#          0.00337102,  0.12492092,  0.02394034, -0.29895645,  0.1998727 ],
#        dtype=float32),
#  'ultra': array([ 0.49550357, -0.4401121 , -0.7151606 ,  0.86416936,  0.02213281,
#          0.07193041,  0.35186765,  0.45674843,  0.07567445, -1.3563969 ,
#          0.03762291,  0.74242425,  0.06534915, -0.17045255,  0.26006934,
#          0.1565783 ,  0.4481135 , -0.23720671,  0.5766125 ,  0.0458422 ,
#          0.589775  ,  0.3147918 , -0.49534974, -0.20155236,  0.05965334,
#         -0.82819647,  0.11165243,  0.4716834 ,  0.66734165, -0.09268233,
#         -0.03277097,  0.53731537,  0.35494468,  1.2155771 ,  0.00527511,
#         -0.7671056 ,  0.43551788, -1.0202163 , -0.38640925, -0.26052576,
#          0.7307794 , -1.0978811 ,  1.4915304 ,  0.47714788, -0.01686373,
#          1.8046333 , -0.4803915 , -1.6788096 , -0.45875454, -0.36701086],
#        dtype=float32),
#  'cynics': array([ 1.0690529 ,  0.3289125 , -0.31633145,  0.1338361 , -0.15639643,
#          0.4819338 ,  0.23913652,  0.11673003,  0.33767125,  0.3569733 ,
#         -0.3232025 ,  0.36538398,  0.08397689,  1.4135613 , -0.8628496 ,
#         -0.22311461, -1.1405782 ,  0.45564693, -0.30886865, -0.52096456,
#         -0.25743616,  0.37494582,  0.9070358 , -0.0236339 , -1.3492572 ,
#          1.1331434 , -1.6602659 , -0.01672575,  0.22045955,  0.49275997,
#         -0.5121431 , -0.2944405 ,  0.27278978, -0.9047071 , -1.3931499 ,
#          0.23874703,  1.2950221 ,  0.30568275, -0.32892337,  1.0824487 ,
#          0.52209616,  0.20091176, -0.06771593,  0.97336924,  0.33685198,
#          0.40814433,  0.2591631 , -0.05540657,  0.21211419, -1.280494  ],
#        dtype=float32),
#  'are': array([ 0.38350418, -0.39837283,  0.05546756,  0.0533577 , -0.33037192,
#         -0.36860543,  0.23810706,  0.00306452,  0.07145019, -0.2844188 ,
#         -0.32773867, -0.12525061, -0.00515978, -0.08258106, -0.26586854,
#         -0.19180451, -0.3330305 , -0.13109446, -0.24770397,  0.15518026,
#          0.06808451, -0.29962274,  0.13550678,  0.32993296, -0.3282174 ,
#         -0.02927019, -0.4244023 ,  0.24409826, -0.03114386, -0.2919383 ,
#          0.38893008, -0.5025681 , -0.10105897,  0.06647638,  0.05235177,
#         -0.07210097,  0.5220196 , -0.25365156,  0.38342452,  0.4720369 ,
#         -0.30479723,  0.09436254,  0.0522429 ,  0.17936738, -0.20044087,
#          0.04280847,  0.21411031, -0.07831281, -0.03628048,  0.20783485],
#        dtype=float32),
#  'seeing': array([ 0.5124594 ,  0.00333849, -0.7551595 , -0.40851182, -0.192426  ,
#         -0.9928665 , -0.21135214, -0.71282023, -0.62267363,  0.3848349 ,
#         -1.8865943e-01, -5.2779868e-02,  1.6705366e-04, -1.7461105e-01,
#          3.5199195e-01, -1.5832579e-01,  4.2255265e-01,  3.5801065e-01,
#         -2.4691799e-01,  2.6219177e-01, -1.4457592e-01,  2.3085117e-01,
#          2.9216504e-03, -4.9684152e-02,  8.6884297e-02, -1.3132711e-02,
#         -3.2148492e-01,  2.4829587e-01], dtype=float32),
#  'Private': array([-1.3169537 ,  0.47126403, -1.119154  ,  0.03472537,  0.00276291,
#          0.4985547 , -0.22676037,  0.28233874,  0.26316622, -0.07014787,
#          1.4016111 ,  0.5326064 , -0.8853595 ,  0.06619704, -0.5232863 ,
#         -0.8060157 ,  0.58143175,  0.5450482 ,  1.3823197 ,  1.0108205 ,
#          0.02643918, -1.2203774 ,  1.346897  , -0.74530774,  0.26264596,
#          0.22398247,  0.5825476 , -1.4780781 , -0.2854577 , -0.62427   ,
#         -0.86751115,  0.35487103, -0.02867809, -0.50177354,  2.4489124 ,
#          0.68579316,  0.3578183 , -0.05829766,  0.39901263,  0.5188337 ,
#          0.36614698, -0.7503495 ,  0.69074225, -0.38601172, -1.0349056 ,
#         -0.6208995 , -0.0112235 , -1.0400587 , -0.82982546, -0.24054003],
#        dtype=float32),
#  'investment': array([ 1.3413315 , -0.31387717, -0.766582  ,  0.58086276, -0.02418539,
#          0.21915346, -0.9373644 ,  0.6386337 ,  1.2618594 , -0.29844385,
#          0.01411999,  0.01728743, -0.43207657, -0.13697754, -0.38364065,
#          0.0391221 ,  0.03442474, -0.12101066, -0.19562924,  0.10800353,
#          0.00171146, -0.63900876, -0.7810078 ,  0.5477387 , -1.7104836 ,
#          0.18471126,  0.15752439,  0.11106527,  0.30422175,  0.44551736,
#         -0.24860343, -0.60395473,  0.75283897, -0.28797674, -0.936952  ,
#         -0.15088281,  0.01173005,  0.12939247, -0.3319465 , -0.31621248,
#         -0.27060524,  0.60074854,  0.0540863 , -0.65478754, -0.28453302,
#          0.94038606,  0.6738408 , -0.37519178, -0.60095227, -0.03907669],
#        dtype=float32),
#  'firm': array([-0.3393469 ,  0.3757509 ,  0.43821096,  0.65411264,  0.72620565,
#         -0.55418205,  0.12484325,  0.5806713 ,  0.09548002,  0.7164194 ,
#          0.39370978, -0.14332561,  0.2557961 ,  0.09159306, -0.82976174,
#         -0.90387046,  0.95935166, -0.7912366 ,  0.30344018,  0.63069355,
#         -0.14799522, -0.6077417 ,  0.20568724, -0.5564742 , -1.4823369 ,
#         -0.5374683 ,  0.54006416,  0.59419465,  0.16720814, -0.7241005 ,
#         -0.53963035, -0.34363294,  0.3360261 ,  0.8493855 , -0.1918821 ,
#         -0.4096583 , -0.20681658, -0.04413435,  0.3200759 ,  1.1053817 ,
#         -0.10230897, -0.68527734,  0.21639389, -1.482146  , -0.68697137,
#          0.6027298 , -0.14574388, -0.6232067 ,  0.1929372 ,  0.6991351 ],
#        dtype=float32),
#  'Carlyle': array([ 1.0012867 ,  0.00344642,  1.0028671 , -0.58813196,  1.3390396 ,
#          0.22061273, -0.32002565, -0.13247834, -0.03972164,  0.01080012,
#         -0.1592754 ,  0.34718338, -0.14794388,  0.35975656,  0.2868902 ,
#         -0.20071423,  0.21115327, -0.14045832,  0.20680071, -0.02144552,
#         -0.02174839,  0.0891846 , -0.01094387, -0.29999653,  0.21762913],
#        dtype=float32),
#  'occasionally': array([-0.19048245, -0.14730658, -0.06780267, -0.514132  , -0.16014093,
#         -0.3287193 , -0.28855526, -0.66353583,  0.49078855,  0.9407313 ,
#         -0.16254559,  1.3455206 , -0.34316814,  0.5240008 , -0.10243851,
#          0.36170977, -0.1536834 , -1.095277  , -0.4972378 ,  1.1301756 ,
#          0.11892399,  0.22436458,  0.01303339, -0.33488166,  0.82238543,
#         -1.0331607 , -0.47328693, -0.13478127,  1.1403421 ,  0.65587544,
#          0.58169365, -0.5457707 ,  0.9884132 ,  0.22560671,  0.18839821,
#          0.02147785,  0.7280728 ,  0.61010593,  0.8059584 , -0.39482704,
#          0.65399724,  0.71831495, -0.23060513, -0.34953368, -0.9873875 ,
#          0.262828  ,  0.6719708 ,  0.19020167,  0.3457537 ,  0.1245725 ],
#        dtype=float32),
#  'controversial': array([ 0.5779754 , -1.1544788 ,  0.4991367 , -0.58533585, -0.8348689 ,
#          0.1970376 , -0.73180413,  0.43334728, -0.18676686, -0.26669446,
#          0.91851676,  1.0484998 ,  0.35468534,  0.3503423 ,  0.60062295,
#          0.84162545,  0.7774451 , -0.63537043,  0.6517492 , -0.2880415 ,
#          0.40038157, -0.64276004, -0.03495586,  0.17078406,  0.06301701,
#          0.66918564, -0.09743063,  0.03454377, -0.42200676, -0.4899705 ,
#          1.0615091 ,  0.54425496,  0.15925965,  0.06700797, -0.0619798 ,
#         -0.35572505,  0.18120709,  0.01739462,  0.19106779,  0.0068115 ,
#         -0.21792558, -0.5977962 , -0.43120116,  0.3007434 , -0.09022876,
#          1.4113609 ,  0.5526413 ,  0.04530263, -0.24307218,  0.5071458 ],
#        dtype=float32),
#  'plays': array([ 0.40271324, -1.6970246 , -0.14451367,  0.5319398 , -0.9340075 ,
#         -0.7837143 ,  0.53599536, -0.1570214 , -0.9309622 ,  0.48066863,
#          0.25178757,  0.31806436, -1.2115339 , -0.38125193,  0.04864915,
#         -1.0810543 , -1.538194  , -0.59020865, -0.03265488,  1.3117595 ,
#         -0.44629607, -1.028021  ,  0.50162995, -0.2259515 , -1.4617958 ,
#          1.0306426 ,  0.07974239,  0.22567365,  1.2603624 , -0.1774776 ,
#         -0.3337857 ,  0.56825125,  0.49370003, -0.13420546,  0.74452496,
#         -0.16424324, -0.2948989 , -0.18954097,  0.3509158 , -0.6807054 ,
#          0.4439236 , -0.67067873,  0.10492375, -0.5339661 ,  0.45834762,
#         -0.02801317,  0.05363409, -1.6847383 , -0.02934849,  0.09588915],
#        dtype=float32),
#  'in': array([ 0.29391542, -0.18307897,  0.10056775,  0.00884519, -0.2087591 ,
#         -0.22484015,  0.20934218, -0.05494262,  0.08321971, -0.3016647 ,
#          0.25155234, -0.05784699, -1.2678618 ,  0.37165102,  0.6697247 ],
#        dtype=float32),
#  'quietly': array([-0.03642349, -0.75825775,  0.48283422, -0.5493884 , -0.75872844,
#         -0.23294087, -0.31153828, -0.07548391, -0.24363858, -0.08565657,
#         -0.685655  , -0.01428187, -0.9086906 , -0.81735796, -0.06057562,
#          0.36775336,  0.43949723,  0.09473661, -0.6491382 ,  0.0597592 ,
#          0.13685395,  1.338875  ,  0.45259058,  0.20901746,  0.18166098,
#         -1.1206976 , -1.0219989 , -0.21663645,  0.841186  ,  0.41401842,
#         -1.3969883 ,  0.63413805,  0.6916737 , -0.71247125, -1.0672454 ,
#         -0.8815468 ,  0.8691342 ,  0.4714065 , -0.48566037,  0.0753397 ,
#          0.28484112, -0.8651078 ,  0.09397888, -0.5583903 , -0.55612916,
#         -0.20825522,  0.5906594 ,  0.37409598, -0.3372121 ,  0.44911826],
#        dtype=float32),
#  'placed': array([-0.5496814 , -0.49674392,  0.18190551,  0.35692984, -0.69919795,
#         -0.3109438 ,  0.19007924,  1.1740968 , -0.54386795, -0.38892174,
#          0.06039903, -0.5250697 , -1.1962372 , -0.5852373 ,  0.91882956,
#          1.3159652 , -0.8885761 , -0.42545244,  0.31576937,  0.35575038,
#          0.32287696, -0.5105176 , -0.7607296 ,  1.7206304 , -0.47057098,
#         -1.1139915 ,  0.37094918, -0.6015255 ,  0.4176427 ,  0.66636467,
#          0.12271431,  0.40497985,  0.09504233, -0.34986886,  0.35263425,
#         -0.6010822 ,  0.58935475, -0.8184831 ,  1.0282067 ,  0.41727126,
#          0.39137998,  1.0381213 , -0.04505167,  0.4469115 , -0.21321693,
#         -0.36228353, -1.3104985 , -0.30015373,  0.6430328 , -1.2922964 ],
#        dtype=float32),
#  'its': array([ 0.23758082, -0.11507401,  0.11573285,  0.02039901, -0.15606262,
#         -0.24083668,  0.21236664, -0.00290138,  0.07845454, -0.33113718,
#         -0.01288746, -0.14171132, -0.05566048, -0.30785242, -0.16731334,
#         -0.10256758, -0.4364403 , -0.11973883, -0.18953595, -0.18122774,
#         -0.19743107, -0.13602929,  0.04187969,  0.21811613, -0.31259882,
#          0.09649412, -0.49931583,  0.3537639 , -0.03408061, -0.3653895 ,
#          0.1779401 , -0.33246562, -0.1346524 , -0.05082424,  0.02326001,
#         -0.22197655,  0.33652782, -0.17179576,  0.40014747,  0.31446174,
#         -0.22956155,  0.17094363, -0.15096982,  0.23733711, -0.01305997,
#         -0.01869468,  0.07787616,  0.03623641, -0.30850732,  0.24442148],
#        dtype=float32),
#  'bets': array([ 0.7929472 , -0.70991206,  0.14543326, -1.0506403 ,  0.5514016 ,
#          0.3931845 , -0.14233941,  0.13784051, -0.736053  ,  0.14593112,
#         -0.4009288 ,  0.75847006,  0.1268298 , -0.55899024, -0.9942495 ,
#         -0.04568121,  0.29673538,  0.3920108 ,  0.7753998 , -0.10894863,
#         -0.5096668 ,  0.7144112 , -1.4002738 , -0.7779948 ,  0.5257529 ,
#         -0.7538121 ,  0.5521306 ,  2.0435119 ,  0.12631577,  1.6581956 ,
#          0.29808152,  0.01007301,  0.19503179,  0.31123796,  0.06828626],
#        dtype=float32),
#  'plus': array([ 0.4294133 ,  0.16551504,  0.01084568, -0.30341485, -0.2585894 ,
#          0.516577  , -0.15099587,  0.16633463, -0.10967878, -0.9975824 ,
#          0.53686315,  0.09811738, -0.5352647 ,  0.319269  , -0.48754025,
#          1.0086627 , -0.28105772, -0.3954268 , -0.4936395 , -0.36233446,
#          0.6499777 ,  0.5678942 ,  0.06018341, -0.246508  ,  0.44032532,
#         -1.1612892 , -0.4751623 ,  1.3839942 , -0.33395517, -0.29747763,
#          0.1969066 , -0.5051944 , -0.5409861 , -0.2586461 , -0.04185557,
#         -1.1915984 , -0.63892484,  0.5061865 ,  2.2041693 ,  0.05136025,
#         -0.9725346 , -1.3867698 ,  0.6077241 ,  0.36502695,  1.0068772 ,
#          0.42496672,  1.1667366 ,  0.8246869 ,  0.37831736,  0.4755721 ],
#        dtype=float32),
#  'worries': array([-0.98863804, -0.74174833,  0.6045385 ,  0.40506017, -0.4885255 ,
#         -0.14658472, -0.35063738,  0.43771696, -0.5676209 , -0.18431282,
#          0.65813303, -0.07484323, -0.16912833, -0.07377641,  0.2370728 ,
#         -0.20637962, -0.05429067, -1.5820496 , -0.8533992 ,  1.0807251 ,
#         -0.18160394,  0.72631264, -0.24520445, -0.05278972,  0.16032144,
#         -0.04792266, -1.7069898 , -0.5377168 , -0.48227528, -0.15232158,
#         -0.81332505, -1.1821107 ,  0.9347142 , -0.12436683, -1.2400753 ,
#         -0.8082165 ,  0.5013034 , -0.8459358 , -0.09145997, -0.40865493,
#          1.0629424 , -0.26468423,  0.60293734,  0.4725264 ,  0.2980414 ,
#         -0.06681781,  0.01000509, -0.15057524,  0.56291497,  0.6130887 ],
#        dtype=float32),
#  'about': array([ 0.49211583, -0.36550447,  0.32754794, -0.09608229, -0.28533167,
#         -0.29306597,  0.7019899 ,  0.04850687,  0.0488516 , -1.0737028 ,
#         -0.04207616,  0.14068832, -0.29560247, -0.8031155 , -0.09754525,
#         -0.43265155, -0.15680426,  0.03995618, -0.71392214, -0.49546117,
#         -0.3925692 , -0.04715146, -0.08255734, -0.23458982, -0.09076571,
#         -0.25501707, -0.19110042, -0.07130043,  0.24589337, -0.46594357,
#          0.3460153 , -0.5606239 ,  0.28475907,  0.3497732 , -0.13861495,
#          0.39507383,  0.41990414,  0.20676893,  0.6144341 ,  0.46006986,
#         -0.16033792, -0.00922894,  0.02854555,  0.19461864, -0.06355652,
#         -0.10984161, -0.00633626,  0.24294001, -0.195891  ,  0.5769004 ],
#        dtype=float32),
#  'economy': array([ 0.35622853, -0.47812936,  0.4894486 , -0.2173934 , -0.44239542,
#          0.05668232,  0.6318784 , -0.2338508 ,  0.78149676,  0.15501434,
#         -0.04310301,  0.16381738, -0.08666667, -0.5988682 , -0.13475038,
#         -0.44726673, -0.5133932 ,  0.7554996 , -0.54948115, -0.41365993,
#         -0.2823931 , -0.8623817 , -0.1145801 , -0.9009444 , -0.9576947 ,
#        dtype=float32),
#  'stock': array([-0.29550022,  0.39278367,  0.7643069 , -0.01298371,  0.88446426,
#          0.04471447,  0.25289997,  0.24768685,  0.36250252,  0.34251752,
#         -0.8499877 ,  1.0726345 , -0.26851574,  0.07455921,  0.34226385,
#          0.6537247 ,  0.70571274,  0.02055994,  0.68862146, -0.3446539 ,
#         -0.13559061, -0.28975222, -0.59804475, -0.28054088, -1.0913241 ,
#          0.21051842, -0.56130236, -0.24620192,  0.04386193, -1.6570295 ,
#          0.9152628 , -0.51167387,  1.0505143 , -1.2456744 , -0.23798758,
#         -0.08993307,  0.15051296, -0.56281114,  0.24148166,  0.5429397 ,
#         -0.89183176, -0.08362526, -0.22354794,  0.17843719,  0.7962669 ,
#          0.00614664, -0.2032452 ,  0.38733023, -0.71794754, -0.47274217],
#        dtype=float32),
#  'next': array([ 0.5965613 , -0.53551966,  0.45243394,  0.3546639 ,  0.46376836,
#         -0.33540884,  0.32916653, -0.4085819 ,  0.4742123 , -0.99726593,
#         -0.48548317, -0.15954465, -0.38352823, -0.37285525, -0.6190218 ,
#         -0.6828835 , -1.1229174 ,  0.05135897, -0.24020115,  0.19581537,
#          0.05990505,  0.01807081, -0.33713698,  0.14373443,  0.08336327,
#          0.6986202 , -0.6458513 , -0.07056879,  0.16300009, -0.39544   ,
#         -0.06794554, -0.63122743,  0.4398335 ,  0.907131  , -0.21755354,
#          0.06161863,  0.895087  ,  0.38907066,  0.7315384 ,  0.00312021,
#         -0.35319513, -0.3350975 , -0.17976469,  0.62930673, -0.07924461,
#          0.37222043, -0.19536969, -0.06534269, -0.31095207, -0.21581554],
#        dtype=float32),
# ...
#         -0.4131209 , -0.7507324 ,  0.52390456,  1.797587  ,  0.43537304,
#         -0.15123948, -0.27238217,  0.53207254,  0.41374108, -0.8147454 ,
#         -0.71754205, -1.5050292 ,  0.30258742,  0.5468662 ,  0.17046249,
#         -0.12261628, -1.0277879 , -0.36282343, -0.947358  ,  0.28579098],
#        dtype=float32),
#  'Globalization': array([-0.8693567 ,  0.3924988 ,  1.1045752 ,  0.27575973, -1.2288034 ,
#          0.77924967,  1.2760777 , -0.22262517, -0.78316516, -0.27277064,
#          0.29012132, -1.0342646 ,  0.25236604,  0.7804419 , -0.6644418 ,
#          0.31047446,  0.47700256,  0.14486837,  0.49469164, -1.3162638 ,
#         -0.5863948 , -0.56357193, -0.7242456 , -0.26913977, -0.4822826 ,
#          0.6212893 ,  0.6212284 ,  0.28673396,  0.5024706 ,  0.42033923,
#          1.1899263 ,  0.31846488,  0.31148773,  0.83729064, -0.4582013 ,
#         -0.18327895,  0.28358668, -0.50312644, -0.70549357, -1.2379607 ,
#          0.23977965, -0.487296  ,  1.6734065 ,  0.11877269, -0.16568777,
#         -1.8319409 ,  0.31836915,  0.4203247 , -0.04149735, -0.672119  ],
#        dtype=float32),
#  'does': array([ 1.2551397 , -0.5207342 , -0.70477194, -0.19419521, -0.59293777,
#         -0.5322075 ,  0.5851405 ,  1.0173678 , -0.78866076,  0.6733114 ,
#          0.5686162 , -0.42905003,  1.4890294 , -0.05643392, -0.1847634 ,
#         -0.2578813 ,  0.19904059, -0.04286958, -0.13296461, -0.21246596,
#          0.326087  ,  1.1358731 ,  0.33033386, -1.3469774 , -0.40316257,
#         -0.37632895, -0.86079955,  0.15044951, -2.2571223 , -0.09193479,
#         -0.57420087,  0.6455628 , -0.07261825,  2.009015  ,  0.55826175,
#         -0.373784  ,  0.08342433,  0.5284916 , -0.38106853, -0.35230213],
#        dtype=float32),
#  'same': array([-0.26371786,  0.8046902 ,  1.633709  , -0.4294937 ,  1.290476  ,
#         -0.41068476,  1.046137  ,  1.2954609 ,  0.87083536,  0.13104174,
#          0.54371834, -0.15036432,  1.1623955 , -0.23345666,  0.3414876 ,
#          0.39663166, -0.2209242 , -0.07768996,  0.4114827 , -0.5947056 ,
#         -0.1147536 ,  0.8887247 , -0.5415206 ,  0.85054255, -0.04924127,
#          0.83296704, -0.863958  ,  0.6609458 ,  0.04303706,  0.30688953,
#         -0.20453042, -0.28245318,  0.34675318, -0.18918747, -0.5712883 ,
#         -0.17996804, -0.25028282, -0.6152296 ,  1.1496828 ,  0.8130529 ,
#          0.00557429,  0.89392835, -0.9465986 , -0.7580228 ,  0.46868452,
#         -0.3110405 ,  0.7371333 ,  0.70166945, -0.53245854,  0.0190151 ],
#        dtype=float32),
#  'page': array([-1.0814409 , -0.6675904 ,  0.9988236 ,  0.61642325, -0.13624552,
#         -0.30228317, -0.8995241 ,  0.2849648 ,  0.78193045, -0.4035572 ,
#          0.7700824 , -0.99086595, -0.20014432, -0.2707634 ,  1.6003923 ,
#         -0.420287  ,  0.11916529, -0.6225926 ,  0.5032023 ,  0.2945779 ,
#         -1.0300128 ,  0.50739044,  0.6648279 , -0.29503924, -0.44979382,
#          0.03981413, -0.2948947 ,  1.0081421 ,  0.14075327, -0.11065823,
#         -0.98052585,  1.0547582 , -0.89942133, -0.52069783,  0.13195735,
#         -0.43015563,  1.1815411 , -0.16708294, -0.6816125 ,  0.2359954 ,
#         -1.7894293 , -0.10952211, -0.12330833,  0.20784453, -0.12775928,
#         -0.54273146,  1.3395025 ,  0.27202147,  0.78588194, -0.08018367],
#        dtype=float32),
#  'APMF': array([ 0.5579268 , -0.08132084,  0.68412435, -0.34860232,  0.4936627 ,
#          0.18031895,  0.28001264, -0.01865524, -0.06545499,  0.4211555 ,
#          1.0952023 , -0.6960635 ,  0.26377216, -0.06067916,  0.19818777,
#         -0.02182238, -0.06847498,  0.36151934, -1.1330547 , -0.2854959 ,
#          0.343349  ,  0.3822325 ,  0.86370194, -0.01944852,  0.47332004,
#         -0.51720583, -0.16315168, -0.7247701 , -0.28909263,  0.29033273,
#         -0.5417732 , -1.1556753 , -0.35022932,  1.1532823 ,  0.9195578 ,
#          0.11549899,  0.5497801 , -1.1347826 , -0.13384587,  0.38701418,
#          0.32819095, -2.3003967 , -0.3440191 , -0.8094221 ,  0.0810449 ,
#         -0.20411125, -0.6384625 ,  1.128518  , -1.391046  , -0.134937  ],
#        dtype=float32),
#  'Asian': array([ 1.1036266 ,  1.0503125 ,  0.41583192,  0.53475124, -0.14914803,
#         -0.5445184 , -0.30767652, -1.1048763 , -0.93461996,  1.0877714 ,
#          0.16230112,  0.06431916, -0.3125645 , -0.19900613, -0.3949162 ,
#          0.00524597,  0.05907554, -0.26639113, -0.15554446,  0.08022314,
#          0.48478484,  0.78246385, -0.10827477, -0.28080904, -0.46076775,
#          1.1561353 ,  0.4478926 , -0.06419552, -0.09359068, -0.7456913 ,
#          0.3439896 , -0.5364481 ,  0.7631961 ,  0.7404161 , -0.1732003 ,
#          0.17815137,  0.26748106,  0.50459284,  0.42897815, -0.23151614,
#          0.28698006,  0.59293115, -0.31033272, -0.8587208 , -0.45635015,
#          0.33576515,  0.6525513 ,  0.1366168 ,  1.0221902 ,  0.5507601 ],
#        dtype=float32),
#  'tourism': array([ 0.62586814,  0.84238344,  1.2857034 , -0.12581116, -0.94136316,
#         -0.74884284,  0.8330357 , -0.11732332,  0.19722185,  0.32615378,
#          0.97253346, -0.7932359 ,  0.52746457, -0.04077366,  0.60185164,
#         -0.07164727,  0.8236872 , -0.5987526 , -1.0744087 ,  0.21991722,
#         -0.5680317 ,  0.32798326,  0.92795527, -0.85292095,  0.37967923,
#          0.71161115, -0.45220184,  0.2547277 ,  0.12337458,  0.1875892 ,
#         -0.4806906 , -0.2798857 , -1.286333  , -0.11516058, -0.20584625,
#          0.91191304, -1.1293898 , -0.96432   ,  1.0238107 , -0.5322008 ,
#          0.6521958 ,  1.0002334 , -0.472914  ,  1.09266   , -0.85930896,
#          0.06307833, -0.6837274 , -0.9915023 ,  0.01860484, -0.6714359 ],
#        dtype=float32),
#  'destinations': array([-0.2755373 ,  1.7989205 ,  0.42525262, -1.0341645 ,  0.33876204,
#         -0.03122154,  0.36507952, -0.34872648,  0.24800426, -0.8748307 ,
#          0.4352058 ,  0.38933063, -1.2738361 ,  0.20309854,  0.17674904,
#          1.0258832 ,  0.0438363 ,  0.5691019 , -1.5757642 , -0.7148015 ,
#          0.11101604, -1.2286334 , -0.38225383, -0.4425372 ,  0.34667763,
#         -0.05423785,  0.4598689 , -0.28814402, -0.79256225,  0.31349617,
#         -0.38758218,  0.2928427 , -0.02642402, -0.49632645,  0.89682865,
#         -0.33287627,  0.09227622,  0.6911156 , -0.26168936,  0.04101548,
#         -0.80838645,  0.1195889 , -0.7334815 ,  0.39557004,  0.44369465,
#         -0.3811543 , -0.42676574, -0.4936759 , -0.85405695,  0.7208069 ],
#        dtype=float32),
#  'just': array([-0.03531133,  0.3593467 , -0.34107962,  0.56656796,  0.75337523,
#         -0.33153036,  0.01737829,  0.79066646, -0.40473688,  0.1445092 ,
#          0.17890818, -0.12663104,  0.5517609 , -0.13613126, -0.33079413,
#         -0.23668966, -0.9360968 , -0.358788  ,  0.06828618, -0.15200064,
#          0.37143093, -0.1794652 ,  0.06023902,  0.10985827, -0.53612745,
#          0.4818071 , -0.6856669 ,  0.4525973 , -0.10118531, -0.00796585,
#          0.12031797, -0.25945997,  0.9271311 ,  0.23456414, -0.2981125 ,
#         -0.48770168,  0.13123158, -1.0456142 ,  0.04930094,  0.7855972 ,
#         -0.32367024, -0.00716581, -0.08027002,  0.711742  , -0.43900323,
#          0.3441856 , -0.2380602 , -0.08124356, -0.21381465,  0.86542296],
#        dtype=float32),
#  'kicked': array([-0.01992472,  0.4350764 , -1.0824306 ,  0.6985339 , -0.09086564,
#          0.21004993, -1.057805  , -0.1429314 , -0.04799676,  1.1360736 ,
#         -0.7158574 , -1.0625122 , -0.46031797, -0.27315694, -0.08316809,
#         -0.3676148 ,  0.26289305,  0.33116913, -2.0016365 , -0.37756848,
#         -0.3864631 ,  0.24249156,  0.3886242 , -0.7362281 ,  0.7982875 ,
#         -0.96396714, -0.1947494 , -1.5568388 , -0.7092823 , -0.16945367,
#         -0.48978537,  0.06415978, -0.5330726 ,  0.8079452 ,  0.63205314,
#          0.18524095,  0.39041072,  0.47961542,  0.09088379, -0.8489461 ,
#          0.1303874 ,  0.21916747,  0.9987641 , -0.6858517 , -1.0691574 ,
#         -0.16273753, -1.3345156 , -0.05592987, -0.22336805, -0.09926891],
#        dtype=float32),
#  ...}

# %%
skip_gram_embeddings['OOV'] = torch.randn(50, dtype = torch.float32)

# %%
hidden_dim = 256
output_dim = data['Class Index'].unique().shape[0]

model = LSTM(hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
model
# Out:
# LSTM(
#   (lstm): LSTM(50, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in skip_gram_embeddings):
                    batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.2434	Loss = 0.013869629241526127
# Epoch = 1	Training Set Accuracy = 0.2528	Loss = 0.013832208700478077
# Epoch = 2	Training Set Accuracy = 0.26056666666666667	Loss = 0.013784845359623432
# Epoch = 3	Training Set Accuracy = 0.2645416666666667	Loss = 0.013666863553225994
# Epoch = 4	Training Set Accuracy = 0.27468333333333333	Loss = 0.013592998497188091
# Epoch = 5	Training Set Accuracy = 0.4104083333333333	Loss = 0.012112616561353207
# Epoch = 6	Training Set Accuracy = 0.6701166666666667	Loss = 0.007833418436348438
# Epoch = 7	Training Set Accuracy = 0.8117833333333333	Loss = 0.005126394331455231
# Epoch = 8	Training Set Accuracy = 0.8618916666666666	Loss = 0.003965793177485466
# Epoch = 9	Training Set Accuracy = 0.8882333333333333	Loss = 0.003299793228507042

# %%
batch_size = 100
model.eval()
correct = 0
test_loss = 0

for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in skip_gram_embeddings):
                batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()
print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Testing Set Accuracy = 0.8581578947368421	Loss = 0.004256037995219231

# %%
batch_size = 100
model.train()
precision = []
f1 = []
recall = []
correct = 0
train_loss = 0
import warnings
warnings.filterwarnings('ignore')


confusion = None
with torch.no_grad():
    for i in range(int(len(data_train['Description'])/batch_size)):
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in skip_gram_embeddings):
                    batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()

        pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
        true = y_true.cpu().numpy()
        precision.append(precision_score(pred, true, average='weighted'))
        f1.append(f1_score(pred, true, average='weighted'))
        recall.append(recall_score(pred, true, average='weighted'))
        confusion = confusion_matrix(pred, true)
        print(f"Confusion Matrix for Batch = {i} is {confusion}")

    print(f"Training Set Accuracy = {correct / len(data_train['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {train_loss/len(data_train['Description'])}\tConfusion Matrix = {confusion}")
# Out:
# Confusion Matrix for Batch = 0 is [[ 0  0  8  2]
#  [ 0  0  2  1]
#  [ 0  0 36  0]
#  [ 0  0 32 19]]
# Confusion Matrix for Batch = 1 is [[ 0  0  0 12]
#  [ 0  0  0  1]
#  [ 0  0  0  1]
#  [ 0  0  0 86]]
# Confusion Matrix for Batch = 2 is [[ 0  0  0  3]
#  [ 0  0  0  3]
#  [ 0  0  0  3]
#  [ 0  0  0 91]]
# Confusion Matrix for Batch = 3 is [[ 0  0  0  5]
#  [ 0  0  0  3]
#  [ 0  0  0  3]
#  [ 0  0  0 89]]
# Confusion Matrix for Batch = 4 is [[ 8  1  0  1]
#  [ 0 41  0  0]
#  [ 0  0  0  1]
#  [ 0  2  0 46]]
# Confusion Matrix for Batch = 5 is [[49  1  2  1]
#  [ 6 16  0  1]
#  [ 4  0  4  0]
#  [ 5  0  0 11]]
# Confusion Matrix for Batch = 6 is [[32  0  1  1]
#  [ 6 40  0  0]
#  [ 1  1 13  0]
#  [ 2  0  1  2]]
# Confusion Matrix for Batch = 7 is [[35  0  3  0]
#  [ 1 25  1  1]
#  [ 3  0 10  2]
#  [ 0  0  5 14]]
# Confusion Matrix for Batch = 8 is [[22  0  1  0]
#  [ 3  8  0  1]
#  [ 1  0 33  0]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 9 is [[28  0  0  2]
#  [ 2  7  0  0]
#  [ 3  0 13  3]
#  [ 1  0  8 33]]
# Confusion Matrix for Batch = 10 is [[27  0  2  1]
#  [ 3 20  0  0]
#  [ 3  0 13  3]
#  [ 0  0  2 26]]
# Confusion Matrix for Batch = 11 is [[19  0  1  1]
#  [ 3 20  1  0]
#  [ 1  0  9  3]
#  [ 5  0  0 37]]
# Confusion Matrix for Batch = 12 is [[25  0  1  0]
#  [ 3 23  0  0]
#  [ 1  0 23  1]
#  [ 1  0  5 17]]
# Confusion Matrix for Batch = 13 is [[25  2  2  0]
#  [ 2 14  0  0]
#  [ 3  0 21  3]
#  [ 4  0  1 23]]
# Confusion Matrix for Batch = 14 is [[16  0  0  0]
#  [ 4  4  0  0]
#  [ 3  1 40  2]
#  [ 4  0  1 25]]
# Confusion Matrix for Batch = 15 is [[24  0  0  3]
#  [ 2 21  0  0]
#  [ 1  1 11  3]
#  [ 1  0  1 32]]
# Confusion Matrix for Batch = 16 is [[ 7  1  0  0]
#  [ 1 20  0  1]
#  [ 2  0 34  5]
#  [ 4  0  1 24]]
# Confusion Matrix for Batch = 17 is [[18  1  0  0]
#  [ 3 29  0  0]
#  [ 3  0 17  2]
#  [ 0  1  4 22]]
# Confusion Matrix for Batch = 18 is [[17  0  1  2]
#  [ 1 22  0  0]
#  [ 3  0 18  1]
#  [ 0  0  0 35]]
# Confusion Matrix for Batch = 19 is [[19  1  1  0]
#  [ 4 15  0  0]
#  [ 0  0 22  1]
#  [ 3  0  2 32]]
# Confusion Matrix for Batch = 20 is [[18  0  0  3]
#  [ 1 20  0  1]
#  [ 0  0 23  2]
#  [ 0  2  2 28]]
# Confusion Matrix for Batch = 21 is [[25  0  1  0]
#  [ 2 32  0  1]
#  [ 1  0 22  0]
#  [ 0  0  1 15]]
# Confusion Matrix for Batch = 22 is [[16  3  1  2]
#  [ 1 42  0  0]
#  [ 0  0 20  0]
#  [ 0  1  3 11]]
# Confusion Matrix for Batch = 23 is [[23  0  3  1]
#  [ 1 30  2  0]
#  [ 2  0 20  3]
#  [ 1  0  2 12]]
# Confusion Matrix for Batch = 24 is [[33  1  2  0]
#  [ 3 29  0  0]
#  [ 2  0 17  1]
#  [ 0  0  4  8]]
# Confusion Matrix for Batch = 25 is [[34  0  3  1]
#  [ 0 15  0  0]
#  [ 1  0 21  2]
#  [ 1  0  4 18]]
# Confusion Matrix for Batch = 26 is [[19  0  0  0]
#  [ 2 11  0  0]
#  [ 0  0 34  2]
#  [ 6  0  5 21]]
# Confusion Matrix for Batch = 27 is [[28  0  1  0]
#  [ 0 17  0  0]
#  [ 1  0 33  2]
#  [ 0  0  1 17]]
# Confusion Matrix for Batch = 28 is [[14  0  3  0]
#  [ 0 14  0  1]
#  [ 1  1 31  1]
#  [ 0  0  6 28]]
# Confusion Matrix for Batch = 29 is [[19  1  0  0]
#  [ 0 21  0  0]
#  [ 1  0 24  2]
#  [ 0  2  7 23]]
# Confusion Matrix for Batch = 30 is [[24  0  0  2]
#  [ 3 20  0  0]
#  [ 3  1  8  3]
#  [ 5  0  2 29]]
# Confusion Matrix for Batch = 31 is [[18  0  2  0]
#  [ 2 13  0  0]
#  [ 0  0 29  1]
#  [ 0  0  3 32]]
# Confusion Matrix for Batch = 32 is [[26  0  0  0]
#  [ 1 22  0  0]
#  [ 2  0 18  3]
#  [ 2  0  2 24]]
# Confusion Matrix for Batch = 33 is [[26  0  0  0]
#  [ 0 23  0  1]
#  [ 3  0 17  0]
#  [ 1  0  4 25]]
# Confusion Matrix for Batch = 34 is [[24  1  0  0]
#  [ 2 26  0  0]
#  [ 3  0 22  1]
#  [ 4  1  1 15]]
# Confusion Matrix for Batch = 35 is [[26  0  0  1]
#  [ 2 24  0  0]
#  [ 3  0 28  1]
#  [ 1  0  5  9]]
# Confusion Matrix for Batch = 36 is [[22  1  0  1]
#  [ 1 31  2  0]
#  [ 0  0 27  2]
#  [ 4  0  1  8]]
# Confusion Matrix for Batch = 37 is [[22  0  0  1]
#  [ 0 26  0  0]
#  [ 1  0 18  2]
#  [ 0  0  2 28]]
# Confusion Matrix for Batch = 38 is [[21  0  0  1]
#  [ 1 19  1  0]
#  [ 1  0 31  2]
#  [ 3  0  2 18]]
# Confusion Matrix for Batch = 39 is [[ 7  0  0  0]
#  [ 1  9  0  1]
#  [ 0  0 47  1]
#  [ 0  0 12 22]]
# Confusion Matrix for Batch = 40 is [[18  1  0  3]
#  [ 1 14  0  0]
#  [ 1  0  2  6]
#  [ 3  0  0 51]]
# Confusion Matrix for Batch = 41 is [[19  0  0  2]
#  [ 1 10  0  0]
#  [ 3  0 28  2]
#  [ 2  0 11 22]]
# Confusion Matrix for Batch = 42 is [[16  0  0  1]
#  [ 0 21  0  3]
#  [ 0  1 12  6]
#  [ 1  0  1 38]]
# Confusion Matrix for Batch = 43 is [[15  0  0  1]
#  [ 0 27  0  1]
#  [ 0  0 16  2]
#  [ 2  0  6 30]]
# Confusion Matrix for Batch = 44 is [[12  1  1  0]
#  [ 2 30  0  1]
#  [ 0  0 30  1]
#  [ 1  0  5 16]]
# Confusion Matrix for Batch = 45 is [[15  0  0  0]
#  [ 1 28  0  1]
#  [ 1  0 30  0]
#  [ 1  1  4 18]]
# Confusion Matrix for Batch = 46 is [[20  2  0  1]
#  [ 2 18  0  0]
#  [ 1  0 36  2]
#  [ 0  0  4 14]]
# Confusion Matrix for Batch = 47 is [[28  1  2  0]
#  [ 0 33  0  0]
#  [ 1  0 16  1]
#  [ 0  0  3 15]]
# Confusion Matrix for Batch = 48 is [[34  2  1  0]
#  [ 4 16  0  0]
#  [ 3  0 14  0]
#  [ 0  0  2 24]]
# Confusion Matrix for Batch = 49 is [[23  0  0  0]
#  [ 0 28  0  0]
#  [ 2  0 21  1]
#  [ 4  1  3 17]]
# Confusion Matrix for Batch = 50 is [[20  0  1  0]
#  [ 3 14  0  0]
#  [ 2  0 24  3]
#  [ 1  1  6 25]]
# Confusion Matrix for Batch = 51 is [[18  0  0  0]
#  [ 2 25  0  2]
#  [ 4  0 20  0]
#  [ 0  0  4 25]]
# Confusion Matrix for Batch = 52 is [[21  0  3  2]
#  [ 1 17  0  2]
#  [ 2  0 22  0]
#  [ 2  0  5 23]]
# Confusion Matrix for Batch = 53 is [[24  0  0  0]
#  [ 3 17  0  0]
#  [ 5  1 15  1]
#  [ 0  0  2 32]]
# Confusion Matrix for Batch = 54 is [[24  1  0  0]
#  [ 2 36  0  0]
#  [ 0  0 22  0]
#  [ 2  0  3 10]]
# Confusion Matrix for Batch = 55 is [[36  1  0  0]
#  [ 2 30  0  1]
#  [ 0  3  8  1]
#  [ 2  0  1 15]]
# Confusion Matrix for Batch = 56 is [[21  1  0  2]
#  [ 4 24  0  2]
#  [ 1  0 18  1]
#  [ 0  0  3 23]]
# Confusion Matrix for Batch = 57 is [[28  0  4  0]
#  [ 4 28  2  1]
#  [ 2  0 14  2]
#  [ 2  0  3 10]]
# Confusion Matrix for Batch = 58 is [[27  0  1  0]
#  [ 8 43  0  0]
#  [ 1  0  9  0]
#  [ 2  0  1  8]]
# Confusion Matrix for Batch = 59 is [[31  0  1  0]
#  [ 3 28  0  0]
#  [ 2  0 16  2]
#  [ 0  0  5 12]]
# Confusion Matrix for Batch = 60 is [[31  1  3  0]
#  [ 1 38  1  0]
#  [ 0  0 15  1]
#  [ 1  0  1  7]]
# Confusion Matrix for Batch = 61 is [[19  0  1  0]
#  [ 2 50  1  1]
#  [ 0  0 12  1]
#  [ 0  2  3  8]]
# Confusion Matrix for Batch = 62 is [[25  0  3  1]
#  [ 1 30  1  1]
#  [ 0  0 17  0]
#  [ 3  1  3 14]]
# Confusion Matrix for Batch = 63 is [[29  0  2  0]
#  [ 1 38  0  0]
#  [ 1  0 16  0]
#  [ 0  0  4  9]]
# Confusion Matrix for Batch = 64 is [[42  0  1  0]
#  [ 3 30  0  1]
#  [ 0  0 10  1]
#  [ 2  1  2  7]]
# Confusion Matrix for Batch = 65 is [[27  1  5  0]
#  [ 1 33  0  1]
#  [ 0  0 11  1]
#  [ 1  0  2 17]]
# Confusion Matrix for Batch = 66 is [[30  0  1  0]
#  [ 7 42  1  0]
#  [ 3  0  6  0]
#  [ 1  1  3  5]]
# Confusion Matrix for Batch = 67 is [[27  0  3  1]
#  [ 1 43  0  0]
#  [ 0  0  5  2]
#  [ 1  0  2 15]]
# Confusion Matrix for Batch = 68 is [[26  1  3  1]
#  [ 3 37  0  1]
#  [ 1  0 21  0]
#  [ 1  1  2  2]]
# Confusion Matrix for Batch = 69 is [[21  0  2  1]
#  [ 0 31  0  0]
#  [ 1  0 21  0]
#  [ 1  0  3 19]]
# Confusion Matrix for Batch = 70 is [[21  0  2  2]
#  [ 0 36  0  0]
#  [ 1  0 18  1]
#  [ 3  1  6  9]]
# Confusion Matrix for Batch = 71 is [[19  0  1  0]
#  [ 0 33  0  1]
#  [ 1  0 25  0]
#  [ 0  1  7 12]]
# Confusion Matrix for Batch = 72 is [[19  0  0  1]
#  [ 0 41  1  1]
#  [ 1  0 16  1]
#  [ 4  0  2 13]]
# Confusion Matrix for Batch = 73 is [[23  0  3  0]
#  [ 1 26  0  0]
#  [ 0  0 22  1]
#  [ 1  0  5 18]]
# Confusion Matrix for Batch = 74 is [[25  0  2  0]
#  [ 1 16  1  0]
#  [ 1  0 31  2]
#  [ 0  0  2 19]]
# Confusion Matrix for Batch = 75 is [[18  0  1  0]
#  [ 2 12  0  0]
#  [ 2  0 30  3]
#  [ 2  0  4 26]]
# Confusion Matrix for Batch = 76 is [[26  0  2  0]
#  [ 1 19  1  0]
#  [ 3  1 17  4]
#  [ 1  0  4 21]]
# Confusion Matrix for Batch = 77 is [[15  0  2  0]
#  [ 2 25  1  0]
#  [ 3  0 19  1]
#  [ 0  0  3 29]]
# Confusion Matrix for Batch = 78 is [[16  2  2  1]
#  [ 2 13  0  0]
#  [ 2  0 23  1]
#  [ 1  0  6 31]]
# Confusion Matrix for Batch = 79 is [[13  1  3  2]
#  [ 1 12  0  0]
#  [ 0  0 25  3]
#  [ 3  0  3 34]]
# Confusion Matrix for Batch = 80 is [[15  0  2  0]
#  [ 2 24  0  0]
#  [ 2  0 20  1]
#  [ 1  0  3 30]]
# Confusion Matrix for Batch = 81 is [[22  0  0  0]
#  [ 2 27  0  0]
#  [ 2  0 26  0]
#  [ 0  0  2 19]]
# Confusion Matrix for Batch = 82 is [[27  2  3  0]
#  [ 1 31  1  0]
#  [ 0  0 15  1]
#  [ 0  0  1 18]]
# Confusion Matrix for Batch = 83 is [[14  0  1  0]
#  [ 3 29  2  0]
#  [ 1  0 25  1]
#  [ 0  0  9 15]]
# Confusion Matrix for Batch = 84 is [[21  0  2  1]
#  [ 1 22  1  1]
#  [ 1  0 31  1]
#  [ 1  0  5 12]]
# Confusion Matrix for Batch = 85 is [[20  0  2  2]
#  [ 0 29  0  0]
#  [ 0  0 22  1]
#  [ 0  0  6 18]]
# Confusion Matrix for Batch = 86 is [[27  0  1  0]
#  [ 4 15  0  1]
#  [ 3  0 22  1]
#  [ 0  1  2 23]]
# Confusion Matrix for Batch = 87 is [[19  0  2  1]
#  [ 2 16  0  0]
#  [ 2  0 26  3]
#  [ 2  0  2 25]]
# Confusion Matrix for Batch = 88 is [[19  0  1  3]
#  [ 0 18  1  0]
#  [ 2  0 30  1]
#  [ 0  1  0 24]]
# Confusion Matrix for Batch = 89 is [[14  1  1  0]
#  [ 2 20  1  0]
#  [ 2  0 24  4]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 90 is [[14  0  3  2]
#  [ 2 16  1  0]
#  [ 0  0 34  4]
#  [ 0  0  1 23]]
# Confusion Matrix for Batch = 91 is [[14  0  3  1]
#  [ 1 17  0  1]
#  [ 0  0 25  2]
#  [ 0  1  1 34]]
# Confusion Matrix for Batch = 92 is [[14  1  3  1]
#  [ 0 20  0  0]
#  [ 1  0 25  0]
#  [ 0  0  4 31]]
# Confusion Matrix for Batch = 93 is [[28  1  0  1]
#  [ 1 24  0  1]
#  [ 0  1  6  1]
#  [ 5  0  4 27]]
# Confusion Matrix for Batch = 94 is [[14  0  0  1]
#  [ 2 14  0  2]
#  [ 2  0 24  2]
#  [ 0  0  1 38]]
# Confusion Matrix for Batch = 95 is [[15  0  3  0]
#  [ 0 19  0  1]
#  [ 0  0 16  1]
#  [ 1  0  3 41]]
# Confusion Matrix for Batch = 96 is [[24  0  2  1]
#  [ 0 17  0  0]
#  [ 4  0 15  1]
#  [ 0  0  5 31]]
# Confusion Matrix for Batch = 97 is [[18  0  1  1]
#  [ 1 17  0  0]
#  [ 2  0 20  1]
#  [ 2  0  2 35]]
# Confusion Matrix for Batch = 98 is [[10  0  1  0]
#  [ 1 14  0  0]
#  [ 0  0 26  1]
#  [ 2  0  2 43]]
# Confusion Matrix for Batch = 99 is [[15  0  3  1]
#  [ 0 18  0  0]
#  [ 1  0 19  5]
#  [ 0  0  5 33]]
# Confusion Matrix for Batch = 100 is [[17  0  1  0]
#  [ 0 18  0  1]
#  [ 2  0 27  2]
#  [ 2  1  2 27]]
# Confusion Matrix for Batch = 101 is [[25  0  1  2]
#  [ 1 21  0  0]
#  [ 0  1 20  1]
#  [ 0  0  6 22]]
# Confusion Matrix for Batch = 102 is [[21  0  3  2]
#  [ 0 31  0  0]
#  [ 1  0 25  1]
#  [ 1  0  1 14]]
# Confusion Matrix for Batch = 103 is [[30  0  1  1]
#  [ 2 26  0  0]
#  [ 0  0 19  0]
#  [ 2  0  1 18]]
# Confusion Matrix for Batch = 104 is [[25  0  1  0]
#  [ 0 28  2  0]
#  [ 1  0 24  0]
#  [ 2  0  8  9]]
# Confusion Matrix for Batch = 105 is [[17  0  0  0]
#  [ 2 15  0  0]
#  [ 1  0 19  1]
#  [ 1  0  2 42]]
# Confusion Matrix for Batch = 106 is [[13  0  1  1]
#  [ 0 21  0  0]
#  [ 1  0 33  1]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 107 is [[20  0  0  4]
#  [ 4 12  1  1]
#  [ 1  0 23  0]
#  [ 3  1  5 25]]
# Confusion Matrix for Batch = 108 is [[21  1  1  0]
#  [ 0 16  0  0]
#  [ 0  0 30  0]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 109 is [[12  0  2  0]
#  [ 1 15  0  1]
#  [ 3  0 30  3]
#  [ 2  0  2 29]]
# Confusion Matrix for Batch = 110 is [[16  0  1  3]
#  [ 2  7  0  0]
#  [ 0  0 25  4]
#  [ 0  0  4 38]]
# Confusion Matrix for Batch = 111 is [[16  0  2  0]
#  [ 2 27  0  1]
#  [ 2  0 16  2]
#  [ 2  0  4 26]]
# Confusion Matrix for Batch = 112 is [[23  0  2  0]
#  [ 1 29  0  0]
#  [ 0  0 24  0]
#  [ 1  1  2 17]]
# Confusion Matrix for Batch = 113 is [[21  0  0  2]
#  [ 0 28  0  0]
#  [ 0  0 26  3]
#  [ 0  0  3 17]]
# Confusion Matrix for Batch = 114 is [[21  0  3  1]
#  [ 0 26  0  1]
#  [ 0  0 29  2]
#  [ 1  1  4 11]]
# Confusion Matrix for Batch = 115 is [[22  0  3  2]
#  [ 0 27  0  1]
#  [ 0  0 13  3]
#  [ 1  0 10 18]]
# Confusion Matrix for Batch = 116 is [[26  0  1  1]
#  [ 1 31  0  1]
#  [ 1  0 17  0]
#  [ 1  0  1 19]]
# Confusion Matrix for Batch = 117 is [[12  0  2  1]
#  [ 0 33  0  1]
#  [ 0  0 17  3]
#  [ 3  0  6 22]]
# Confusion Matrix for Batch = 118 is [[23  0  3  1]
#  [ 2 17  0  0]
#  [ 1  0 19  3]
#  [ 2  0  1 28]]
# Confusion Matrix for Batch = 119 is [[13  0  1  3]
#  [ 1 17  0  1]
#  [ 0  0 26  0]
#  [ 2  0  4 32]]
# Confusion Matrix for Batch = 120 is [[14  1  1  1]
#  [ 1 20  0  0]
#  [ 2  0 26  2]
#  [ 3  1  3 25]]
# Confusion Matrix for Batch = 121 is [[21  0  1  1]
#  [ 1 18  0  0]
#  [ 1  0 18  1]
#  [ 2  1  3 32]]
# Confusion Matrix for Batch = 122 is [[20  0  1  0]
#  [ 0 24  0  2]
#  [ 1  0 20  1]
#  [ 0  0  3 28]]
# Confusion Matrix for Batch = 123 is [[21  2  0  1]
#  [ 1 25  0  0]
#  [ 1  0 12  2]
#  [ 0  0  4 31]]
# Confusion Matrix for Batch = 124 is [[23  2  2  0]
#  [ 3 20  0  0]
#  [ 1  0 13  3]
#  [ 0  0  2 31]]
# Confusion Matrix for Batch = 125 is [[13  0  1  0]
#  [ 1 30  1  0]
#  [ 1  0 15  4]
#  [ 1  0  3 30]]
# Confusion Matrix for Batch = 126 is [[17  0  2  2]
#  [ 1 33  1  0]
#  [ 0  0 17  2]
#  [ 2  1  1 21]]
# Confusion Matrix for Batch = 127 is [[26  0  5  0]
#  [ 1 42  0  0]
#  [ 0  0 11  1]
#  [ 1  1  2 10]]
# Confusion Matrix for Batch = 128 is [[27  4  0  0]
#  [ 2 38  0  0]
#  [ 0  1 13  2]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 129 is [[25  1  0  1]
#  [ 3 40  0  0]
#  [ 2  0 13  0]
#  [ 0  0  5 10]]
# Confusion Matrix for Batch = 130 is [[33  2  0  0]
#  [ 2 33  0  0]
#  [ 0  0 14  0]
#  [ 1  0  1 14]]
# Confusion Matrix for Batch = 131 is [[40  0  0  3]
#  [ 1 35  0  0]
#  [ 0  0  8  2]
#  [ 2  0  1  8]]
# Confusion Matrix for Batch = 132 is [[32  2  0  0]
#  [ 2 47  0  0]
#  [ 0  1  6  0]
#  [ 2  0  0  8]]
# Confusion Matrix for Batch = 133 is [[29  1  0  0]
#  [ 1 46  0  0]
#  [ 1  1 11  0]
#  [ 1  0  3  6]]
# Confusion Matrix for Batch = 134 is [[33  0  1  0]
#  [ 1 49  0  0]
#  [ 0  0  2  0]
#  [ 1  1  2 10]]
# Confusion Matrix for Batch = 135 is [[36  1  0  1]
#  [ 1 26  0  1]
#  [ 0  0 12  1]
#  [ 3  0  5 13]]
# Confusion Matrix for Batch = 136 is [[31  0  2  1]
#  [ 0 38  1  0]
#  [ 0  0 12  1]
#  [ 2  0  5  7]]
# Confusion Matrix for Batch = 137 is [[42  0  0  2]
#  [ 2 25  0  0]
#  [ 3  0 10  1]
#  [ 2  0  2 11]]
# Confusion Matrix for Batch = 138 is [[38  0  3  1]
#  [ 0 41  0  0]
#  [ 1  0  5  0]
#  [ 0  1  3  7]]
# Confusion Matrix for Batch = 139 is [[38  0  2  2]
#  [ 3 36  0  0]
#  [ 0  1  7  0]
#  [ 2  0  0  9]]
# Confusion Matrix for Batch = 140 is [[29  1  0  0]
#  [ 4 43  0  0]
#  [ 2  0  5  1]
#  [ 1  0  1 13]]
# Confusion Matrix for Batch = 141 is [[31  0  4  2]
#  [ 1 30  0  0]
#  [ 1  0 17  1]
#  [ 2  0  2  9]]
# Confusion Matrix for Batch = 142 is [[23  0  5  0]
#  [ 2 29  0  0]
#  [ 1  1 13  0]
#  [ 0  0  6 20]]
# Confusion Matrix for Batch = 143 is [[24  1  3  0]
#  [ 1 39  0  0]
#  [ 0  0 12  0]
#  [ 1  0  6 13]]
# Confusion Matrix for Batch = 144 is [[34  0  1  2]
#  [ 0 25  0  0]
#  [ 1  0  8  0]
#  [ 3  0 12 14]]
# Confusion Matrix for Batch = 145 is [[21  0  4  1]
#  [ 1 22  0  0]
#  [ 4  0 20  0]
#  [ 0  1  1 25]]
# Confusion Matrix for Batch = 146 is [[25  0  0  2]
#  [ 0 10  1  0]
#  [ 2  0 28  1]
#  [ 1  0  2 28]]
# Confusion Matrix for Batch = 147 is [[25  0  1  0]
#  [ 2 16  1  0]
#  [ 1  0 24  3]
#  [ 0  0  2 25]]
# Confusion Matrix for Batch = 148 is [[24  0  2  1]
#  [ 1 13  0  0]
#  [ 3  0 22  6]
#  [ 2  0  1 25]]
# Confusion Matrix for Batch = 149 is [[21  0  0  1]
#  [ 2 22  0  1]
#  [ 2  0 23  1]
#  [ 0  0  5 22]]
# Confusion Matrix for Batch = 150 is [[14  0  0  1]
#  [ 1 22  1  0]
#  [ 0  0 19  4]
#  [ 1  0  2 35]]
# Confusion Matrix for Batch = 151 is [[11  0  0  2]
#  [ 1  9  1  0]
#  [ 5  0 16  3]
#  [ 3  0  4 45]]
# Confusion Matrix for Batch = 152 is [[20  0  0  2]
#  [ 1 30  0  1]
#  [ 4  0 22  1]
#  [ 3  0  0 16]]
# Confusion Matrix for Batch = 153 is [[17  0  1  1]
#  [ 0 25  0  0]
#  [ 0  0 25  3]
#  [ 1  0  1 26]]
# Confusion Matrix for Batch = 154 is [[22  0  2  5]
#  [ 2 23  0  0]
#  [ 1  0 16  2]
#  [ 1  1  2 23]]
# Confusion Matrix for Batch = 155 is [[20  1  3  1]
#  [ 2 14  1  0]
#  [ 2  0 26  2]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 156 is [[14  0  2  0]
#  [ 1 12  0  0]
#  [ 1  0 17  1]
#  [ 3  2  6 41]]
# Confusion Matrix for Batch = 157 is [[18  0  1  0]
#  [ 0 13  0  0]
#  [ 0  0 29  3]
#  [ 0  0  2 34]]
# Confusion Matrix for Batch = 158 is [[21  0  6  1]
#  [ 2 19  0  0]
#  [ 0  0 25  0]
#  [ 2  0  2 22]]
# Confusion Matrix for Batch = 159 is [[12  0  0  5]
#  [ 0 12  0  2]
#  [ 2  0 21  4]
#  [ 1  0  1 40]]
# Confusion Matrix for Batch = 160 is [[24  0  2  1]
#  [ 0 36  0  3]
#  [ 0  2 15  2]
#  [ 2  0  1 12]]
# Confusion Matrix for Batch = 161 is [[21  0  2  1]
#  [ 0 20  0  1]
#  [ 1  0 18  3]
#  [ 0  0  0 33]]
# Confusion Matrix for Batch = 162 is [[31  0  3  2]
#  [ 2 18  1  0]
#  [ 1  0 16  0]
#  [ 5  1  2 18]]
# Confusion Matrix for Batch = 163 is [[14  0  1  0]
#  [ 0  8  0  0]
#  [ 1  0 27  2]
#  [ 1  0  4 42]]
# Confusion Matrix for Batch = 164 is [[27  1  1  0]
#  [ 0 25  0  0]
#  [ 2  0 26  1]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 165 is [[13  0  0  1]
#  [ 0 10  0  1]
#  [ 2  0 12  4]
#  [ 0  0  2 55]]
# Confusion Matrix for Batch = 166 is [[12  0  0  3]
#  [ 0 22  1  0]
#  [ 1  0 18  1]
#  [ 0  0  0 42]]
# Confusion Matrix for Batch = 167 is [[26  0  0  0]
#  [ 0 20  0  0]
#  [ 2  2  9  2]
#  [ 2  1  2 34]]
# Confusion Matrix for Batch = 168 is [[18  0  1  0]
#  [ 2 31  0  0]
#  [ 3  0 21  1]
#  [ 2  3  1 17]]
# Confusion Matrix for Batch = 169 is [[24  0  0  0]
#  [ 1 26  1  0]
#  [ 3  1 14  2]
#  [ 3  2  4 19]]
# Confusion Matrix for Batch = 170 is [[22  0  2  1]
#  [ 0 27  0  0]
#  [ 2  0  8  5]
#  [ 1  0  1 31]]
# Confusion Matrix for Batch = 171 is [[32  0  2  0]
#  [ 0 10  0  0]
#  [ 3  0 30  1]
#  [ 1  0  5 16]]
# Confusion Matrix for Batch = 172 is [[14  0  0  2]
#  [ 0 15  0  0]
#  [ 0  0 11  4]
#  [ 2  0  7 45]]
# Confusion Matrix for Batch = 173 is [[19  1  0  2]
#  [ 0 24  0  0]
#  [ 0  0 20  3]
#  [ 0  1  0 30]]
# Confusion Matrix for Batch = 174 is [[19  1  3  0]
#  [ 2 34  0  0]
#  [ 1  0 27  0]
#  [ 0  0  7  6]]
# Confusion Matrix for Batch = 175 is [[11  0  2  0]
#  [ 0 11  0  1]
#  [ 0  0 12  3]
#  [ 1  0  1 58]]
# Confusion Matrix for Batch = 176 is [[34  0  1  0]
#  [ 1  9  1  0]
#  [ 0  0 22  4]
#  [ 3  1  1 23]]
# Confusion Matrix for Batch = 177 is [[16  0  1  0]
#  [ 1 20  0  0]
#  [ 0  0 24  0]
#  [ 0  0  4 34]]
# Confusion Matrix for Batch = 178 is [[23  0  0  0]
#  [ 1 18  3  0]
#  [ 6  0 16  0]
#  [ 3  1  2 27]]
# Confusion Matrix for Batch = 179 is [[23  1  1  3]
#  [ 1 13  0  2]
#  [ 0  0  9  2]
#  [ 0  0  0 45]]
# Confusion Matrix for Batch = 180 is [[25  1  2  0]
#  [ 1 29  0  0]
#  [ 0  0 15  1]
#  [ 1  1  4 20]]
# Confusion Matrix for Batch = 181 is [[20  0  1  1]
#  [ 5 39  0  2]
#  [ 2  0 13  0]
#  [ 1  0  2 14]]
# Confusion Matrix for Batch = 182 is [[33  0  3  0]
#  [ 1 32  0  0]
#  [ 0  1 16  0]
#  [ 1  0  0 13]]
# Confusion Matrix for Batch = 183 is [[27  0  2  0]
#  [ 1 39  0  0]
#  [ 0  0  9  1]
#  [ 0  2  4 15]]
# Confusion Matrix for Batch = 184 is [[44  0  1  1]
#  [ 0 23  0  0]
#  [ 2  0 15  2]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 185 is [[29  1  0  1]
#  [ 4 39  0  0]
#  [ 1  0 12  0]
#  [ 0  0  0 13]]
# Confusion Matrix for Batch = 186 is [[25  1  1  0]
#  [ 1 40  1  0]
#  [ 1  0 14  1]
#  [ 3  0  8  4]]
# Confusion Matrix for Batch = 187 is [[36  0  4  0]
#  [ 1 29  0  0]
#  [ 0  0 18  0]
#  [ 1  0  2  9]]
# Confusion Matrix for Batch = 188 is [[21  0  0  0]
#  [ 0 54  2  1]
#  [ 0  0 11  0]
#  [ 1  2  1  7]]
# Confusion Matrix for Batch = 189 is [[32  0  2  1]
#  [ 1 27  0  0]
#  [ 1  0 13  3]
#  [ 0  1  3 16]]
# Confusion Matrix for Batch = 190 is [[39  1  3  0]
#  [ 2 26  0  0]
#  [ 2  0 16  1]
#  [ 1  0  0  9]]
# Confusion Matrix for Batch = 191 is [[21  0  0  2]
#  [ 2 36  0  2]
#  [ 0  0 20  0]
#  [ 3  0  1 13]]
# Confusion Matrix for Batch = 192 is [[23  0  1  1]
#  [ 1 39  2  1]
#  [ 0  0 15  0]
#  [ 1  1  2 13]]
# Confusion Matrix for Batch = 193 is [[24  0  4  1]
#  [ 1 39  1  0]
#  [ 0  0 14  1]
#  [ 1  0  2 12]]
# Confusion Matrix for Batch = 194 is [[34  0  1  0]
#  [ 0 31  0  0]
#  [ 0  0 18  1]
#  [ 0  1  2 12]]
# Confusion Matrix for Batch = 195 is [[26  0  2  0]
#  [ 3 26  1  0]
#  [ 2  0 13  0]
#  [ 1  1  6 19]]
# Confusion Matrix for Batch = 196 is [[22  0  1  2]
#  [ 3 16  0  0]
#  [ 1  0 22  3]
#  [ 3  0  0 27]]
# Confusion Matrix for Batch = 197 is [[25  0  4  4]
#  [ 0 18  0  1]
#  [ 2  0 25  0]
#  [ 3  0  1 17]]
# Confusion Matrix for Batch = 198 is [[26  1  2  4]
#  [ 0 22  0  0]
#  [ 0  0 16  1]
#  [ 1  0  1 26]]
# Confusion Matrix for Batch = 199 is [[28  0  2  2]
#  [ 1 30  0  0]
#  [ 2  0 13  0]
#  [ 4  0  1 17]]
# Confusion Matrix for Batch = 200 is [[26  0  1  2]
#  [ 4 32  0  0]
#  [ 3  0 13  0]
#  [ 1  0  3 15]]
# Confusion Matrix for Batch = 201 is [[29  0  0  2]
#  [ 2 36  0  1]
#  [ 0  0 15  0]
#  [ 0  0  1 14]]
# Confusion Matrix for Batch = 202 is [[26  0  2  3]
#  [ 1 39  0  0]
#  [ 0  0 17  1]
#  [ 0  0  2  9]]
# Confusion Matrix for Batch = 203 is [[27  0  4  1]
#  [ 1 31  0  0]
#  [ 1  0 17  5]
#  [ 0  0  2 11]]
# Confusion Matrix for Batch = 204 is [[26  0  2  3]
#  [ 0 27  0  0]
#  [ 1  0 25  0]
#  [ 0  0  5 11]]
# Confusion Matrix for Batch = 205 is [[23  0  3  0]
#  [ 2 13  0  1]
#  [ 2  0 22  0]
#  [ 1  0  3 30]]
# Confusion Matrix for Batch = 206 is [[15  0  2  1]
#  [ 0 14  0  1]
#  [ 0  0 14  2]
#  [ 0  0  1 50]]
# Confusion Matrix for Batch = 207 is [[13  0  0  1]
#  [ 0 17  0  0]
#  [ 2  0 27  2]
#  [ 0  0  3 35]]
# Confusion Matrix for Batch = 208 is [[23  0  2  4]
#  [ 1 11  0  0]
#  [ 3  0 11  2]
#  [ 1  0  4 38]]
# Confusion Matrix for Batch = 209 is [[24  0  1  1]
#  [ 0 10  0  0]
#  [ 0  0 28  2]
#  [ 0  0  2 32]]
# Confusion Matrix for Batch = 210 is [[27  0  1  4]
#  [ 2 24  0  1]
#  [ 2  0 13  2]
#  [ 1  0  0 23]]
# Confusion Matrix for Batch = 211 is [[11  0  0  0]
#  [ 0 20  0  1]
#  [ 1  1 15  4]
#  [ 0  0  0 47]]
# Confusion Matrix for Batch = 212 is [[18  0  1  2]
#  [ 1 31  0  0]
#  [ 0  0 21  1]
#  [ 0  0  4 21]]
# Confusion Matrix for Batch = 213 is [[22  0  3  1]
#  [ 3 21  0  0]
#  [ 1  0 19  2]
#  [ 2  0  1 25]]
# Confusion Matrix for Batch = 214 is [[24  0  3  2]
#  [ 0 18  0  0]
#  [ 0  0 28  1]
#  [ 0  1  3 20]]
# Confusion Matrix for Batch = 215 is [[22  0  1  0]
#  [ 2 25  0  1]
#  [ 1  0 18  2]
#  [ 1  1  2 24]]
# Confusion Matrix for Batch = 216 is [[19  0  1  1]
#  [ 0 18  0  1]
#  [ 1  0 26  3]
#  [ 0  1  1 28]]
# Confusion Matrix for Batch = 217 is [[21  0  1  1]
#  [ 3 12  0  0]
#  [ 5  0 26  1]
#  [ 3  0  1 26]]
# Confusion Matrix for Batch = 218 is [[11  0  0  2]
#  [ 0 17  0  0]
#  [ 0  0 17  4]
#  [ 3  0  3 43]]
# Confusion Matrix for Batch = 219 is [[25  0  0  1]
#  [ 0 13  0  0]
#  [ 1  0 25  2]
#  [ 3  0  1 29]]
# Confusion Matrix for Batch = 220 is [[17  0  1  1]
#  [ 0 20  0  1]
#  [ 1  0 13  3]
#  [ 2  0  2 39]]
# Confusion Matrix for Batch = 221 is [[25  0  0  0]
#  [ 1 25  0  0]
#  [ 1  0 22  1]
#  [ 1  0  1 23]]
# Confusion Matrix for Batch = 222 is [[17  0  1  1]
#  [ 0 19  0  1]
#  [ 2  0 26  4]
#  [ 2  0  0 27]]
# Confusion Matrix for Batch = 223 is [[25  0  2  0]
#  [ 2 31  0  0]
#  [ 0  0 17  0]
#  [ 2  1  0 20]]
# Confusion Matrix for Batch = 224 is [[20  0  0  1]
#  [ 1 30  0  0]
#  [ 2  0 22  5]
#  [ 2  0  0 17]]
# Confusion Matrix for Batch = 225 is [[20  0  1  0]
#  [ 1 24  1  0]
#  [ 0  1 23  1]
#  [ 2  0  7 19]]
# Confusion Matrix for Batch = 226 is [[15  0  0  1]
#  [ 0 21  0  0]
#  [ 0  0 33  1]
#  [ 2  0  2 25]]
# Confusion Matrix for Batch = 227 is [[22  0  0  7]
#  [ 1  2  0  0]
#  [ 3  0 14  4]
#  [ 3  0  3 41]]
# Confusion Matrix for Batch = 228 is [[23  0  1  1]
#  [ 1 24  0  0]
#  [ 0  0 22  1]
#  [ 0  0  0 27]]
# Confusion Matrix for Batch = 229 is [[24  0  0  2]
#  [ 0 17  0  0]
#  [ 0  0 23  0]
#  [ 2  1  2 29]]
# Confusion Matrix for Batch = 230 is [[19  0  0  1]
#  [ 1 21  0  0]
#  [ 1  1 19  2]
#  [ 0  0  2 33]]
# Confusion Matrix for Batch = 231 is [[35  0  0  1]
#  [ 0 19  0  1]
#  [ 1  0 14  1]
#  [ 1  1  3 23]]
# Confusion Matrix for Batch = 232 is [[11  0  1  1]
#  [ 0 22  0  1]
#  [ 1  0 15  4]
#  [ 0  0  0 44]]
# Confusion Matrix for Batch = 233 is [[16  0  1  0]
#  [ 4 32  0  0]
#  [ 2  1 20  1]
#  [ 2  0  3 18]]
# Confusion Matrix for Batch = 234 is [[21  0  1  0]
#  [ 0 37  0  0]
#  [ 1  0 15  0]
#  [ 3  0  3 19]]
# Confusion Matrix for Batch = 235 is [[17  0  1  0]
#  [ 0 19  0  1]
#  [ 1  0 30  3]
#  [ 2  0  1 25]]
# Confusion Matrix for Batch = 236 is [[18  0  0  0]
#  [ 0 26  0  0]
#  [ 1  0 22  1]
#  [ 3  0  1 28]]
# Confusion Matrix for Batch = 237 is [[17  0  1  3]
#  [ 0 10  1  0]
#  [ 2  0 21  3]
#  [ 1  1  3 37]]
# Confusion Matrix for Batch = 238 is [[16  0  2  0]
#  [ 0 25  0  0]
#  [ 0  0 25  0]
#  [ 2  1  2 27]]
# Confusion Matrix for Batch = 239 is [[28  0  0  2]
#  [ 0  8  0  0]
#  [ 3  0 18  1]
#  [ 2  1  5 32]]
# Confusion Matrix for Batch = 240 is [[12  1  2  3]
#  [ 0 24  0  0]
#  [ 0  0 17  2]
#  [ 1  0  4 34]]
# Confusion Matrix for Batch = 241 is [[18  0  0  1]
#  [ 2 20  0  0]
#  [ 3  0 14  2]
#  [ 0  0  2 38]]
# Confusion Matrix for Batch = 242 is [[19  0  1  0]
#  [ 3 36  0  0]
#  [ 3  0 17  0]
#  [ 1  0  1 19]]
# Confusion Matrix for Batch = 243 is [[28  0  0  0]
#  [ 3 38  1  0]
#  [ 0  0 14  0]
#  [ 0  2  1 13]]
# Confusion Matrix for Batch = 244 is [[38  0  1  0]
#  [ 0 29  0  0]
#  [ 0  0 15  0]
#  [ 2  0  1 14]]
# Confusion Matrix for Batch = 245 is [[36  0  1  0]
#  [ 1 39  1  0]
#  [ 0  0 10  0]
#  [ 1  0  0 11]]
# Confusion Matrix for Batch = 246 is [[28  0  0  1]
#  [ 3 40  0  0]
#  [ 0  0 18  0]
#  [ 3  0  0  7]]
# Confusion Matrix for Batch = 247 is [[24  1  4  0]
#  [ 0 37  0  0]
#  [ 1  0  5  0]
#  [ 0  0  3 25]]
# Confusion Matrix for Batch = 248 is [[43  0  1  0]
#  [ 0 30  0  0]
#  [ 1  0 17  0]
#  [ 1  0  2  5]]
# Confusion Matrix for Batch = 249 is [[21  0  3  0]
#  [ 0 57  1  0]
#  [ 0  0  6  0]
#  [ 2  0  3  7]]
# Confusion Matrix for Batch = 250 is [[32  0  1  0]
#  [ 1 41  0  0]
#  [ 3  0  8  0]
#  [ 1  0  5  8]]
# Confusion Matrix for Batch = 251 is [[41  0  0  0]
#  [ 1 28  0  1]
#  [ 1  0 13  0]
#  [ 1  0  0 14]]
# Confusion Matrix for Batch = 252 is [[35  1  1  1]
#  [ 1 29  1  0]
#  [ 2  0  8  1]
#  [ 1  0  0 19]]
# Confusion Matrix for Batch = 253 is [[29  1  1  0]
#  [ 2 37  0  0]
#  [ 3  0 16  0]
#  [ 3  0  4  4]]
# Confusion Matrix for Batch = 254 is [[26  0  1  0]
#  [ 1 33  0  0]
#  [ 1  1 17  1]
#  [ 1  1  1 16]]
# Confusion Matrix for Batch = 255 is [[16  0  3  0]
#  [ 0 22  0  0]
#  [ 0  0 33  1]
#  [ 0  2  4 19]]
# Confusion Matrix for Batch = 256 is [[36  0  0  0]
#  [ 2 20  0  0]
#  [ 5  0  8  2]
#  [ 0  0  3 24]]
# Confusion Matrix for Batch = 257 is [[15  0  1  1]
#  [ 1 25  1  2]
#  [ 0  0 16  1]
#  [ 1  0  6 30]]
# Confusion Matrix for Batch = 258 is [[41  0  0  0]
#  [ 1 11  0  0]
#  [ 3  0 20  0]
#  [ 1  0  4 19]]
# Confusion Matrix for Batch = 259 is [[11  0  4  2]
#  [ 0 10  0  0]
#  [ 1  0 20  2]
#  [ 2  0  5 43]]
# Confusion Matrix for Batch = 260 is [[22  0  2  0]
#  [ 2 15  0  0]
#  [ 1  0 21  0]
#  [ 3  0  3 31]]
# Confusion Matrix for Batch = 261 is [[19  0  0  0]
#  [ 0 19  0  0]
#  [ 0  0 15  1]
#  [ 1  1  4 40]]
# Confusion Matrix for Batch = 262 is [[26  0  1  0]
#  [ 1 15  0  0]
#  [ 2  0 12  3]
#  [ 2  1  3 34]]
# Confusion Matrix for Batch = 263 is [[19  0  0  0]
#  [ 1 20  0  0]
#  [ 1  0 25  2]
#  [ 2  0  6 24]]
# Confusion Matrix for Batch = 264 is [[22  0  0  0]
#  [ 1 26  0  0]
#  [ 1  0 19  0]
#  [ 4  0  2 25]]
# Confusion Matrix for Batch = 265 is [[29  0  1  0]
#  [ 0 26  0  0]
#  [ 0  0 26  1]
#  [ 1  0  2 14]]
# Confusion Matrix for Batch = 266 is [[24  0  4  0]
#  [ 3 27  0  0]
#  [ 2  0 24  0]
#  [ 1  0  2 13]]
# Confusion Matrix for Batch = 267 is [[30  0  0  1]
#  [ 0 25  1  1]
#  [ 1  0 18  4]
#  [ 0  0  2 17]]
# Confusion Matrix for Batch = 268 is [[20  0  1  4]
#  [ 2  9  0  0]
#  [ 1  0 19  6]
#  [ 5  1  2 30]]
# Confusion Matrix for Batch = 269 is [[14  0  1  2]
#  [ 0 14  0  1]
#  [ 1  0 40  4]
#  [ 2  0  3 18]]
# Confusion Matrix for Batch = 270 is [[25  0  0  0]
#  [ 3 17  0  0]
#  [ 2  0 25  1]
#  [ 3  0  2 22]]
# Confusion Matrix for Batch = 271 is [[26  0  0  1]
#  [ 2 14  0  0]
#  [ 2  0 15  0]
#  [ 4  0  5 31]]
# Confusion Matrix for Batch = 272 is [[14  0  0  1]
#  [ 0 22  0  0]
#  [ 1  0 17  0]
#  [ 2  0  7 36]]
# Confusion Matrix for Batch = 273 is [[24  0  2  1]
#  [ 0 16  0  0]
#  [ 1  0 22  1]
#  [ 3  0  3 27]]
# Confusion Matrix for Batch = 274 is [[16  0  0  0]
#  [ 0 24  0  0]
#  [ 2  0 23  1]
#  [ 1  0  2 31]]
# Confusion Matrix for Batch = 275 is [[25  1  1  0]
#  [ 1 21  0  0]
#  [ 1  0 16  1]
#  [ 3  0  3 27]]
# Confusion Matrix for Batch = 276 is [[14  0  0  1]
#  [ 1 28  0  0]
#  [ 0  0 16  0]
#  [ 3  0  6 31]]
# Confusion Matrix for Batch = 277 is [[28  0  1  0]
#  [ 1 19  0  0]
#  [ 2  0 29  0]
#  [ 2  0  1 17]]
# Confusion Matrix for Batch = 278 is [[16  0  2  0]
#  [ 0 30  1  0]
#  [ 0  0 26  0]
#  [ 2  2  2 19]]
# Confusion Matrix for Batch = 279 is [[25  1  0  1]
#  [ 1 30  0  0]
#  [ 0  0 32  0]
#  [ 2  0  1  7]]
# Confusion Matrix for Batch = 280 is [[20  1  3  1]
#  [ 1 33  0  0]
#  [ 2  0 18  1]
#  [ 2  0  1 17]]
# Confusion Matrix for Batch = 281 is [[27  0  2  0]
#  [ 0 18  0  0]
#  [ 0  0 30  0]
#  [ 1  0  5 17]]
# Confusion Matrix for Batch = 282 is [[16  1  3  2]
#  [ 0 22  0  1]
#  [ 1  0 25  0]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 283 is [[21  0  2  2]
#  [ 2 11  1  1]
#  [ 1  0 26  3]
#  [ 0  0  1 29]]
# Confusion Matrix for Batch = 284 is [[20  0  0  2]
#  [ 0 19  0  0]
#  [ 1  0 30  1]
#  [ 0  0  3 24]]
# Confusion Matrix for Batch = 285 is [[16  0  0  1]
#  [ 0 25  0  0]
#  [ 2  0 32  4]
#  [ 1  0  2 17]]
# Confusion Matrix for Batch = 286 is [[15  0  2  1]
#  [ 0 21  0  0]
#  [ 0  0 25  4]
#  [ 2  1  3 26]]
# Confusion Matrix for Batch = 287 is [[23  1  0  2]
#  [ 1 19  0  0]
#  [ 2  0 19  4]
#  [ 2  0  7 20]]
# Confusion Matrix for Batch = 288 is [[20  1  0  6]
#  [ 0 18  0  1]
#  [ 1  0 23  1]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 289 is [[23  0  1  1]
#  [ 0 26  0  1]
#  [ 2  0 13  1]
#  [ 1  0  2 29]]
# Confusion Matrix for Batch = 290 is [[15  1  1  0]
#  [ 1 23  0  0]
#  [ 0  0 28  2]
#  [ 0  0  1 28]]
# Confusion Matrix for Batch = 291 is [[25  0  1  0]
#  [ 1 32  0  0]
#  [ 0  0 25  0]
#  [ 2  2  2 10]]
# Confusion Matrix for Batch = 292 is [[26  0  3  1]
#  [ 1 33  0  0]
#  [ 2  0 25  0]
#  [ 0  0  1  8]]
# Confusion Matrix for Batch = 293 is [[27  0  1  1]
#  [ 0 32  0  0]
#  [ 0  0 23  0]
#  [ 1  0  3 12]]
# Confusion Matrix for Batch = 294 is [[26  0  1  0]
#  [ 0 32  0  0]
#  [ 2  0 17  0]
#  [ 2  0  2 18]]
# Confusion Matrix for Batch = 295 is [[21  0  1  1]
#  [ 0 13  0  1]
#  [ 1  0 24  1]
#  [ 2  0  2 33]]
# Confusion Matrix for Batch = 296 is [[17  0  1  0]
#  [ 0 16  0  0]
#  [ 1  0 32  0]
#  [ 0  0  1 32]]
# Confusion Matrix for Batch = 297 is [[23  0  0  0]
#  [ 0 23  0  1]
#  [ 2  0 22  0]
#  [ 0  1  2 26]]
# Confusion Matrix for Batch = 298 is [[16  0  2  0]
#  [ 2 19  0  1]
#  [ 1  0 24  1]
#  [ 1  1  3 29]]
# Confusion Matrix for Batch = 299 is [[19  0  0  2]
#  [ 1 19  0  0]
#  [ 0  0 18  2]
#  [ 1  0  4 34]]
# Confusion Matrix for Batch = 300 is [[12  0  2  0]
#  [ 0 21  0  2]
#  [ 0  0 23  3]
#  [ 2  1  4 30]]
# Confusion Matrix for Batch = 301 is [[23  0  0  0]
#  [ 0 20  0  0]
#  [ 1  0 21  4]
#  [ 1  0  0 30]]
# Confusion Matrix for Batch = 302 is [[29  0  1  1]
#  [ 0 19  0  0]
#  [ 4  0 20  0]
#  [ 1  0  2 23]]
# Confusion Matrix for Batch = 303 is [[21  0  0  0]
#  [ 1 31  2  0]
#  [ 2  0 18  1]
#  [ 2  1  1 20]]
# Confusion Matrix for Batch = 304 is [[22  0  5  0]
#  [ 4 26  0  0]
#  [ 0  0 23  1]
#  [ 1  0  2 16]]
# Confusion Matrix for Batch = 305 is [[24  0  3  0]
#  [ 0 39  0  1]
#  [ 0  0 18  0]
#  [ 1  0  2 12]]
# Confusion Matrix for Batch = 306 is [[28  0  1  1]
#  [ 1 21  0  0]
#  [ 2  0 25  2]
#  [ 1  0  1 17]]
# Confusion Matrix for Batch = 307 is [[17  0  0  1]
#  [ 0 14  0  0]
#  [ 2  0 23  4]
#  [ 1  0  4 34]]
# Confusion Matrix for Batch = 308 is [[15  0  1  0]
#  [ 2 16  0  1]
#  [ 0  0 29  1]
#  [ 1  0  5 29]]
# Confusion Matrix for Batch = 309 is [[18  0  3  0]
#  [ 1 19  1  0]
#  [ 0  0 17  1]
#  [ 2  0  3 35]]
# Confusion Matrix for Batch = 310 is [[22  0  0  1]
#  [ 1 21  0  0]
#  [ 0  0 26  2]
#  [ 2  1  2 22]]
# Confusion Matrix for Batch = 311 is [[23  0  1  1]
#  [ 0 27  1  0]
#  [ 2  0 21  1]
#  [ 0  0  6 17]]
# Confusion Matrix for Batch = 312 is [[26  0  1  0]
#  [ 2 12  0  0]
#  [ 1  1 17  1]
#  [ 1  0  4 34]]
# Confusion Matrix for Batch = 313 is [[27  0  0  1]
#  [ 1 26  0  0]
#  [ 1  0 16  1]
#  [ 1  0  3 23]]
# Confusion Matrix for Batch = 314 is [[27  1  0  1]
#  [ 0 36  0  1]
#  [ 0  0 11  1]
#  [ 1  0  3 18]]
# Confusion Matrix for Batch = 315 is [[21  0  0  0]
#  [ 2 36  0  0]
#  [ 1  1 19  2]
#  [ 2  0  4 12]]
# Confusion Matrix for Batch = 316 is [[30  0  0  0]
#  [ 2 33  0  1]
#  [ 0  1 11  2]
#  [ 2  1  4 13]]
# Confusion Matrix for Batch = 317 is [[16  0  0  0]
#  [ 2 47  0  0]
#  [ 0  1 17  0]
#  [ 1  1  1 14]]
# Confusion Matrix for Batch = 318 is [[38  0  0  0]
#  [ 2 22  0  0]
#  [ 1  0 11  0]
#  [ 2  1  4 19]]
# Confusion Matrix for Batch = 319 is [[36  0  0  1]
#  [ 4 33  0  0]
#  [ 0  0 11  0]
#  [ 3  1  1 10]]
# Confusion Matrix for Batch = 320 is [[30  0  0  1]
#  [ 3 45  1  0]
#  [ 1  0 10  1]
#  [ 0  0  0  8]]
# Confusion Matrix for Batch = 321 is [[36  0  0  0]
#  [ 1 41  0  0]
#  [ 2  1  9  0]
#  [ 3  0  0  7]]
# Confusion Matrix for Batch = 322 is [[24  0  1  0]
#  [ 1 47  1  0]
#  [ 1  0  9  1]
#  [ 0  0  3 12]]
# Confusion Matrix for Batch = 323 is [[39  0  2  2]
#  [ 3 31  0  1]
#  [ 0  1  7  0]
#  [ 0  0  6  8]]
# Confusion Matrix for Batch = 324 is [[42  1  2  2]
#  [ 1 35  0  0]
#  [ 0  0  8  1]
#  [ 1  0  2  5]]
# Confusion Matrix for Batch = 325 is [[40  0  0  1]
#  [ 2 26  1  0]
#  [ 3  0  8  0]
#  [ 7  1  1 10]]
# Confusion Matrix for Batch = 326 is [[35  0  0  0]
#  [ 4 39  0  0]
#  [ 2  0 10  0]
#  [ 1  0  0  9]]
# Confusion Matrix for Batch = 327 is [[34  0  0  2]
#  [ 1 27  0  0]
#  [ 0  0 13  1]
#  [ 0  0  3 19]]
# Confusion Matrix for Batch = 328 is [[33  0  0  0]
#  [ 0 32  0  0]
#  [ 2  0 17  1]
#  [ 2  0  3 10]]
# Confusion Matrix for Batch = 329 is [[27  0  1  2]
#  [ 1 27  0  0]
#  [ 1  0 20  0]
#  [ 0  0  1 20]]
# Confusion Matrix for Batch = 330 is [[26  0  0  1]
#  [ 2 21  0  0]
#  [ 1  0 23  1]
#  [ 1  0  8 16]]
# Confusion Matrix for Batch = 331 is [[30  0  0  1]
#  [ 0 14  0  0]
#  [ 0  0 26  0]
#  [ 1  2  3 23]]
# Confusion Matrix for Batch = 332 is [[19  0  0  0]
#  [ 1 28  1  0]
#  [ 1  0 22  0]
#  [ 1  1  7 19]]
# Confusion Matrix for Batch = 333 is [[17  0  0  0]
#  [ 1 14  0  0]
#  [ 2  0 25  1]
#  [ 1  0  3 36]]
# Confusion Matrix for Batch = 334 is [[21  0  4  0]
#  [ 1 13  0  0]
#  [ 0  0 31  1]
#  [ 1  1  4 23]]
# Confusion Matrix for Batch = 335 is [[18  0  1  0]
#  [ 1 17  0  0]
#  [ 1  0 20  1]
#  [ 2  1  5 33]]
# Confusion Matrix for Batch = 336 is [[29  0  2  0]
#  [ 0  9  0  0]
#  [ 0  0 23  0]
#  [ 1  0  4 32]]
# Confusion Matrix for Batch = 337 is [[19  0  1  0]
#  [ 1 25  1  0]
#  [ 0  0 22  3]
#  [ 2  0  4 22]]
# Confusion Matrix for Batch = 338 is [[17  1  3  1]
#  [ 1 22  0  0]
#  [ 2  0 22  2]
#  [ 2  0  7 20]]
# Confusion Matrix for Batch = 339 is [[20  0  0  1]
#  [ 1 15  0  0]
#  [ 1  0 12  1]
#  [ 1  0  3 45]]
# Confusion Matrix for Batch = 340 is [[23  1  0  1]
#  [ 1 19  0  0]
#  [ 0  0 21  2]
#  [ 2  0  4 26]]
# Confusion Matrix for Batch = 341 is [[27  0  0  1]
#  [ 1 29  0  0]
#  [ 2  0 16  1]
#  [ 2  0  4 17]]
# Confusion Matrix for Batch = 342 is [[18  0  1  0]
#  [ 2 30  0  0]
#  [ 0  0 25  2]
#  [ 0  1  2 19]]
# Confusion Matrix for Batch = 343 is [[16  1  1  1]
#  [ 0 34  0  0]
#  [ 0  0 15  1]
#  [ 1  0  2 28]]
# Confusion Matrix for Batch = 344 is [[29  0  1  1]
#  [ 0 23  0  0]
#  [ 2  0 23  1]
#  [ 1  0  3 16]]
# Confusion Matrix for Batch = 345 is [[15  0  0  0]
#  [ 1 17  0  1]
#  [ 3  0 12  3]
#  [ 0  0  3 45]]
# Confusion Matrix for Batch = 346 is [[15  0  3  2]
#  [ 2 24  0  0]
#  [ 1  0 27  1]
#  [ 0  0  0 25]]
# Confusion Matrix for Batch = 347 is [[17  0  0  0]
#  [ 0 10  0  1]
#  [ 0  0 22  3]
#  [ 1  0  1 45]]
# Confusion Matrix for Batch = 348 is [[22  0  0  1]
#  [ 1 15  0  0]
#  [ 1  0 21  0]
#  [ 0  0  5 34]]
# Confusion Matrix for Batch = 349 is [[19  0  0  2]
#  [ 0 23  0  0]
#  [ 2  0 24  0]
#  [ 1  0  3 26]]
# Confusion Matrix for Batch = 350 is [[20  0  0  0]
#  [ 0 24  0  1]
#  [ 0  0 15  1]
#  [ 1  0  1 37]]
# Confusion Matrix for Batch = 351 is [[25  0  0  1]
#  [ 1 36  0  0]
#  [ 2  0 10  2]
#  [ 0  0  2 21]]
# Confusion Matrix for Batch = 352 is [[23  0  1  0]
#  [ 2 29  0  1]
#  [ 0  0 22  1]
#  [ 0  0  5 16]]
# Confusion Matrix for Batch = 353 is [[28  0  1  1]
#  [ 2 14  0  0]
#  [ 1  0 29  1]
#  [ 2  1  2 18]]
# Confusion Matrix for Batch = 354 is [[21  0  0  1]
#  [ 0 27  1  1]
#  [ 2  0 18  1]
#  [ 2  1  7 18]]
# Confusion Matrix for Batch = 355 is [[29  0  0  2]
#  [ 0 15  1  0]
#  [ 1  0 24  1]
#  [ 1  0  3 23]]
# Confusion Matrix for Batch = 356 is [[22  1  0  0]
#  [ 2  6  0  0]
#  [ 2  0 37  3]
#  [ 2  0  2 23]]
# Confusion Matrix for Batch = 357 is [[20  0  1  0]
#  [ 0 17  1  1]
#  [ 0  0 37  0]
#  [ 3  0  4 16]]
# Confusion Matrix for Batch = 358 is [[26  0  0  0]
#  [ 2 17  0  0]
#  [ 2  0 23  1]
#  [ 2  0  4 23]]
# Confusion Matrix for Batch = 359 is [[23  0  0  1]
#  [ 2 19  1  0]
#  [ 1  0 27  2]
#  [ 0  0  5 19]]
# Confusion Matrix for Batch = 360 is [[22  0  1  1]
#  [ 0  9  0  0]
#  [ 1  0 33  1]
#  [ 0  0  4 28]]
# Confusion Matrix for Batch = 361 is [[21  0  0  0]
#  [ 0 19  1  1]
#  [ 4  0 26  0]
#  [ 0  0  7 21]]
# Confusion Matrix for Batch = 362 is [[16  1  1  1]
#  [ 0 15  0  0]
#  [ 1  0 19  0]
#  [ 0  0  6 40]]
# Confusion Matrix for Batch = 363 is [[28  0  2  0]
#  [ 1 26  0  0]
#  [ 0  0 13  0]
#  [ 1  0  4 25]]
# Confusion Matrix for Batch = 364 is [[23  0  0  0]
#  [ 2 20  0  1]
#  [ 1  0 13  3]
#  [ 5  0  6 26]]
# Confusion Matrix for Batch = 365 is [[28  0  0  1]
#  [ 1 32  1  0]
#  [ 0  0 17  1]
#  [ 1  0  2 16]]
# Confusion Matrix for Batch = 366 is [[20  0  0  1]
#  [ 0 25  0  0]
#  [ 0  0 28  1]
#  [ 2  1  4 18]]
# Confusion Matrix for Batch = 367 is [[27  0  0  1]
#  [ 1 16  1  0]
#  [ 0  0 20  0]
#  [ 0  0  5 29]]
# Confusion Matrix for Batch = 368 is [[26  0  2  1]
#  [ 1 29  0  0]
#  [ 0  0 16  1]
#  [ 2  0  0 22]]
# Confusion Matrix for Batch = 369 is [[24  0  0  2]
#  [ 1 11  0  0]
#  [ 1  0 27  1]
#  [ 1  1  0 31]]
# Confusion Matrix for Batch = 370 is [[20  0  2  1]
#  [ 1 10  0  0]
#  [ 2  0 32  0]
#  [ 3  0  0 29]]
# Confusion Matrix for Batch = 371 is [[24  0  1  0]
#  [ 0 17  0  0]
#  [ 2  0 24  2]
#  [ 0  1  3 26]]
# Confusion Matrix for Batch = 372 is [[25  0  4  0]
#  [ 0 13  0  0]
#  [ 1  0 18  1]
#  [ 1  0  1 36]]
# Confusion Matrix for Batch = 373 is [[15  0  1  0]
#  [ 2 23  0  0]
#  [ 1  0 22  0]
#  [ 3  0  3 30]]
# Confusion Matrix for Batch = 374 is [[16  1  0  2]
#  [ 1 10  0  0]
#  [ 1  0 20  1]
#  [ 1  0  5 42]]
# Confusion Matrix for Batch = 375 is [[24  1  0  0]
#  [ 0 26  0  0]
#  [ 0  0 14  4]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 376 is [[16  0  0  3]
#  [ 1 16  0  0]
#  [ 3  0 14  3]
#  [ 4  0  3 37]]
# Confusion Matrix for Batch = 377 is [[24  0  2  0]
#  [ 1 27  0  0]
#  [ 3  0 20  1]
#  [ 2  0  3 17]]
# Confusion Matrix for Batch = 378 is [[24  0  0  0]
#  [ 0 26  0  0]
#  [ 1  0 34  2]
#  [ 1  0  1 11]]
# Confusion Matrix for Batch = 379 is [[23  1  1  2]
#  [ 2 26  1  0]
#  [ 0  0 23  1]
#  [ 2  0  1 17]]
# Confusion Matrix for Batch = 380 is [[17  0  1  0]
#  [ 0 36  2  0]
#  [ 1  1 22  0]
#  [ 0  0  4 16]]
# Confusion Matrix for Batch = 381 is [[15  0  1  1]
#  [ 2 20  0  0]
#  [ 2  0 27  1]
#  [ 1  0  3 27]]
# Confusion Matrix for Batch = 382 is [[19  1  0  1]
#  [ 0 14  0  0]
#  [ 1  0 36  4]
#  [ 0  0  4 20]]
# Confusion Matrix for Batch = 383 is [[16  0  2  0]
#  [ 1 14  0  0]
#  [ 0  0 33  2]
#  [ 2  0  2 28]]
# Confusion Matrix for Batch = 384 is [[28  0  1  1]
#  [ 0 19  0  1]
#  [ 1  0 20  0]
#  [ 0  0  3 26]]
# Confusion Matrix for Batch = 385 is [[22  1  0  1]
#  [ 0 25  1  0]
#  [ 2  0 22  1]
#  [ 1  0  2 22]]
# Confusion Matrix for Batch = 386 is [[18  0  3  0]
#  [ 0 17  0  1]
#  [ 2  0 20  0]
#  [ 1  0  5 33]]
# Confusion Matrix for Batch = 387 is [[22  0  0  0]
#  [ 0 26  0  1]
#  [ 1  0  9  1]
#  [ 0  0  3 37]]
# Confusion Matrix for Batch = 388 is [[31  0  0  1]
#  [ 1 23  1  0]
#  [ 2  0 13  0]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 389 is [[25  0  1  2]
#  [ 1 35  0  0]
#  [ 0  0 17  0]
#  [ 3  1  5 10]]
# Confusion Matrix for Batch = 390 is [[27  0  1  0]
#  [ 1 29  0  0]
#  [ 0  0 18  1]
#  [ 2  1  1 19]]
# Confusion Matrix for Batch = 391 is [[24  0  1  0]
#  [ 1 45  0  0]
#  [ 1  0  9  0]
#  [ 0  2  3 14]]
# Confusion Matrix for Batch = 392 is [[27  0  2  0]
#  [ 0 42  0  0]
#  [ 0  0 16  1]
#  [ 2  0  1  9]]
# Confusion Matrix for Batch = 393 is [[31  0  0  0]
#  [ 2 40  0  0]
#  [ 2  0  4  0]
#  [ 2  1  2 16]]
# Confusion Matrix for Batch = 394 is [[34  1  2  1]
#  [ 4 43  0  0]
#  [ 0  0  7  0]
#  [ 0  0  3  5]]
# Confusion Matrix for Batch = 395 is [[29  1  0  2]
#  [ 0 44  0  0]
#  [ 1  0 10  1]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 396 is [[29  0  1  0]
#  [ 2 39  0  0]
#  [ 2  0 12  0]
#  [ 0  0  2 13]]
# Confusion Matrix for Batch = 397 is [[24  0  2  1]
#  [ 0 33  2  0]
#  [ 0  0 16  1]
#  [ 1  1  9 10]]
# Confusion Matrix for Batch = 398 is [[44  0  0  0]
#  [ 4 27  0  1]
#  [ 1  0  6  0]
#  [ 2  1  7  7]]
# Confusion Matrix for Batch = 399 is [[30  0  0  1]
#  [ 3 48  1  0]
#  [ 0  0  7  0]
#  [ 0  0  4  6]]
# Confusion Matrix for Batch = 400 is [[50  0  0  0]
#  [ 2 26  0  0]
#  [ 1  0  8  3]
#  [ 2  0  2  6]]
# Confusion Matrix for Batch = 401 is [[31  0  0  0]
#  [ 1 37  0  0]
#  [ 1  0 17  0]
#  [ 0  0  2 11]]
# Confusion Matrix for Batch = 402 is [[29  1  0  0]
#  [ 2 39  0  0]
#  [ 0  0 12  1]
#  [ 1  0  4 11]]
# Confusion Matrix for Batch = 403 is [[22  0  0  0]
#  [ 3 47  0  0]
#  [ 1  0 14  0]
#  [ 4  0  2  7]]
# Confusion Matrix for Batch = 404 is [[23  0  2  1]
#  [ 2 28  0  3]
#  [ 1  0 19  1]
#  [ 2  0  5 13]]
# Confusion Matrix for Batch = 405 is [[21  0  0  1]
#  [ 2 33  1  1]
#  [ 0  0 18  0]
#  [ 2  0  4 17]]
# Confusion Matrix for Batch = 406 is [[33  0  0  0]
#  [ 0 28  1  0]
#  [ 0  1 20  2]
#  [ 0  1  4 10]]
# Confusion Matrix for Batch = 407 is [[25  0  1  0]
#  [ 0  9  0  0]
#  [ 2  0 24  1]
#  [ 2  1  5 30]]
# Confusion Matrix for Batch = 408 is [[22  1  2  0]
#  [ 0 17  0  0]
#  [ 0  0 27  3]
#  [ 2  0  3 23]]
# Confusion Matrix for Batch = 409 is [[18  0  1  1]
#  [ 0  9  1  0]
#  [ 1  0 23  1]
#  [ 3  0  6 36]]
# Confusion Matrix for Batch = 410 is [[25  0  0  3]
#  [ 3 12  0  0]
#  [ 0  0 24  3]
#  [ 1  1  1 27]]
# Confusion Matrix for Batch = 411 is [[21  1  2  0]
#  [ 0 21  1  0]
#  [ 1  0 22  5]
#  [ 2  0  4 20]]
# Confusion Matrix for Batch = 412 is [[19  1  0  2]
#  [ 0 17  1  1]
#  [ 1  0 16  0]
#  [ 0  0  0 42]]
# Confusion Matrix for Batch = 413 is [[18  2  1  0]
#  [ 0 17  0  0]
#  [ 2  0 29  3]
#  [ 0  1  5 22]]
# Confusion Matrix for Batch = 414 is [[16  0  0  1]
#  [ 3 25  0  0]
#  [ 1  0 22  2]
#  [ 0  2  1 27]]
# Confusion Matrix for Batch = 415 is [[20  0  0  0]
#  [ 0 17  0  0]
#  [ 0  0 17  3]
#  [ 1  0  1 41]]
# Confusion Matrix for Batch = 416 is [[22  0  0  2]
#  [ 0 23  0  1]
#  [ 1  0 10  0]
#  [ 0  0  4 37]]
# Confusion Matrix for Batch = 417 is [[12  1  2  0]
#  [ 0 33  1  1]
#  [ 2  0 22  0]
#  [ 2  0  5 19]]
# Confusion Matrix for Batch = 418 is [[21  1  2  2]
#  [ 0 30  1  0]
#  [ 0  0 25  1]
#  [ 2  0  1 14]]
# Confusion Matrix for Batch = 419 is [[11  3  0  0]
#  [ 1 26  0  0]
#  [ 0  0 29  0]
#  [ 0  1  3 26]]
# Confusion Matrix for Batch = 420 is [[24  1  3  0]
#  [ 0 31  1  0]
#  [ 1  0 22  1]
#  [ 0  0  3 13]]
# Confusion Matrix for Batch = 421 is [[22  0  2  0]
#  [ 1 25  0  0]
#  [ 2  0 23  3]
#  [ 0  0  3 19]]
# Confusion Matrix for Batch = 422 is [[16  0  1  0]
#  [ 0 17  0  0]
#  [ 0  0 22  2]
#  [ 1  1  1 39]]
# Confusion Matrix for Batch = 423 is [[23  1  0  1]
#  [ 1 14  0  4]
#  [ 0  0 24  1]
#  [ 1  0  3 27]]
# Confusion Matrix for Batch = 424 is [[15  0  0  1]
#  [ 1 13  0  0]
#  [ 1  0 42  2]
#  [ 0  0  5 20]]
# Confusion Matrix for Batch = 425 is [[29  0  1  0]
#  [ 1 14  1  1]
#  [ 3  0 17  2]
#  [ 0  0  4 27]]
# Confusion Matrix for Batch = 426 is [[12  0  0  1]
#  [ 0 21  2  0]
#  [ 0  0 30  1]
#  [ 0  1  3 29]]
# Confusion Matrix for Batch = 427 is [[19  0  1  2]
#  [ 2 19  0  1]
#  [ 0  0 18  0]
#  [ 0  1  5 32]]
# Confusion Matrix for Batch = 428 is [[21  0  0  0]
#  [ 1 28  0  0]
#  [ 1  0 14  1]
#  [ 2  0  2 30]]
# Confusion Matrix for Batch = 429 is [[18  0  1  0]
#  [ 0 20  0  1]
#  [ 0  0 23  0]
#  [ 0  0  4 33]]
# Confusion Matrix for Batch = 430 is [[23  0  2  1]
#  [ 1 20  1  1]
#  [ 3  0 12  2]
#  [ 1  0  0 33]]
# Confusion Matrix for Batch = 431 is [[19  0  0  1]
#  [ 3 14  0  1]
#  [ 1  0 20  0]
#  [ 2  1  2 36]]
# Confusion Matrix for Batch = 432 is [[26  0  0  0]
#  [ 0 29  0  0]
#  [ 0  0 30  0]
#  [ 2  0  2 11]]
# Confusion Matrix for Batch = 433 is [[15  0  1  0]
#  [ 2 28  1  0]
#  [ 1  0 25  0]
#  [ 0  0  7 20]]
# Confusion Matrix for Batch = 434 is [[33  0  0  0]
#  [ 0 23  1  1]
#  [ 0  0 25  0]
#  [ 1  0  3 13]]
# Confusion Matrix for Batch = 435 is [[25  0  0  0]
#  [ 0 14  0  0]
#  [ 0  0 35  0]
#  [ 1  1  1 23]]
# Confusion Matrix for Batch = 436 is [[16  0  1  0]
#  [ 0 16  0  1]
#  [ 1  0 19  4]
#  [ 1  0  7 34]]
# Confusion Matrix for Batch = 437 is [[23  0  0  2]
#  [ 1 12  0  0]
#  [ 0  0 27  1]
#  [ 2  0  5 27]]
# Confusion Matrix for Batch = 438 is [[18  1  0  1]
#  [ 2 10  0  1]
#  [ 2  0 33  2]
#  [ 1  0  3 26]]
# Confusion Matrix for Batch = 439 is [[17  0  1  2]
#  [ 0 13  1  3]
#  [ 2  0 22  1]
#  [ 0  0  4 34]]
# Confusion Matrix for Batch = 440 is [[13  0  1  0]
#  [ 0 22  0  2]
#  [ 0  0 21  0]
#  [ 0  1  4 36]]
# Confusion Matrix for Batch = 441 is [[16  1  0  2]
#  [ 0 17  0  0]
#  [ 0  0 30  2]
#  [ 1  0  3 28]]
# Confusion Matrix for Batch = 442 is [[22  0  1  0]
#  [ 1 19  0  0]
#  [ 3  0 27  0]
#  [ 2  0  2 23]]
# Confusion Matrix for Batch = 443 is [[18  0  0  1]
#  [ 1 23  0  0]
#  [ 4  0 18  2]
#  [ 0  1  2 30]]
# Confusion Matrix for Batch = 444 is [[13  1  1  2]
#  [ 0 27  1  0]
#  [ 1  0 21  0]
#  [ 1  0  3 29]]
# Confusion Matrix for Batch = 445 is [[22  1  0  1]
#  [ 3 26  0  0]
#  [ 2  0 22  2]
#  [ 0  0  2 19]]
# Confusion Matrix for Batch = 446 is [[22  0  1  2]
#  [ 0 24  0  0]
#  [ 0  0 30  0]
#  [ 1  0  2 18]]
# Confusion Matrix for Batch = 447 is [[30  0  1  1]
#  [ 0 14  0  0]
#  [ 1  0 32  1]
#  [ 2  0  4 14]]
# Confusion Matrix for Batch = 448 is [[28  0  0  0]
#  [ 0 28  0  1]
#  [ 0  0 22  0]
#  [ 0  0  6 15]]
# Confusion Matrix for Batch = 449 is [[24  2  1  1]
#  [ 0 10  0  0]
#  [ 0  0 28  1]
#  [ 0  0  3 30]]
# Confusion Matrix for Batch = 450 is [[20  0  0  1]
#  [ 1 18  1  1]
#  [ 0  0 27  1]
#  [ 1  0  0 29]]
# Confusion Matrix for Batch = 451 is [[25  1  0  0]
#  [ 1  5  0  0]
#  [ 2  0 31  1]
#  [ 1  0  1 32]]
# Confusion Matrix for Batch = 452 is [[11  0  1  1]
#  [ 1 21  0  0]
#  [ 0  0 28  1]
#  [ 1  0  3 32]]
# Confusion Matrix for Batch = 453 is [[10  0  0  0]
#  [ 0 14  0  0]
#  [ 4  1 28  1]
#  [ 1  0  6 35]]
# Confusion Matrix for Batch = 454 is [[17  1  1  0]
#  [ 1 18  0  0]
#  [ 2  0 18  3]
#  [ 0  0  2 37]]
# Confusion Matrix for Batch = 455 is [[18  0  4  1]
#  [ 0 18  1  1]
#  [ 2  0 24  2]
#  [ 1  0  3 25]]
# Confusion Matrix for Batch = 456 is [[19  0  0  0]
#  [ 1 16  0  1]
#  [ 1  0 21  1]
#  [ 0  0  3 37]]
# Confusion Matrix for Batch = 457 is [[23  1  2  0]
#  [ 0 19  2  0]
#  [ 0  0 13  1]
#  [ 1  1  3 34]]
# Confusion Matrix for Batch = 458 is [[23  0  0  0]
#  [ 1 27  0  0]
#  [ 4  0 21  0]
#  [ 0  0  3 21]]
# Confusion Matrix for Batch = 459 is [[23  0  0  1]
#  [ 2 29  0  0]
#  [ 1  0 18  4]
#  [ 2  1  5 14]]
# Confusion Matrix for Batch = 460 is [[13  0  1  1]
#  [ 0 30  0  0]
#  [ 1  0 25  1]
#  [ 2  0  2 24]]
# Confusion Matrix for Batch = 461 is [[21  1  0  2]
#  [ 0 34  0  0]
#  [ 0  0 22  0]
#  [ 0  1  4 15]]
# Confusion Matrix for Batch = 462 is [[29  0  0  0]
#  [ 1 17  0  0]
#  [ 0  0 17  3]
#  [ 0  0  4 29]]
# Confusion Matrix for Batch = 463 is [[14  0  0  1]
#  [ 0 20  1  0]
#  [ 1  2 22  2]
#  [ 0  0  6 31]]
# Confusion Matrix for Batch = 464 is [[27  0  0  1]
#  [ 1 18  1  0]
#  [ 2  0 29  1]
#  [ 1  0  3 16]]
# Confusion Matrix for Batch = 465 is [[10  0  0  3]
#  [ 0 20  0  0]
#  [ 2  0 13  5]
#  [ 2  1  3 41]]
# Confusion Matrix for Batch = 466 is [[17  0  0  1]
#  [ 2 12  0  0]
#  [ 0  0 31  0]
#  [ 2  0  4 31]]
# Confusion Matrix for Batch = 467 is [[16  0  0  0]
#  [ 1 22  0  0]
#  [ 0  0 30  3]
#  [ 2  0  7 19]]
# Confusion Matrix for Batch = 468 is [[16  0  0  1]
#  [ 0 22  0  1]
#  [ 1  0 28  4]
#  [ 2  0  3 22]]
# Confusion Matrix for Batch = 469 is [[17  0  1  0]
#  [ 0 21  0  0]
#  [ 0  0 26  2]
#  [ 1  0  6 26]]
# Confusion Matrix for Batch = 470 is [[22  0  0  0]
#  [ 1 24  0  0]
#  [ 2  0 23  0]
#  [ 2  0  2 24]]
# Confusion Matrix for Batch = 471 is [[12  0  0  2]
#  [ 0 33  0  1]
#  [ 2  0 16  1]
#  [ 1  0  3 29]]
# Confusion Matrix for Batch = 472 is [[23  0  0  0]
#  [ 2 40  0  0]
#  [ 0  0 19  3]
#  [ 0  0  5  8]]
# Confusion Matrix for Batch = 473 is [[26  0  2  1]
#  [ 0 37  1  1]
#  [ 1  0 18  0]
#  [ 1  0  2 10]]
# Confusion Matrix for Batch = 474 is [[28  0  1  1]
#  [ 1 38  0  1]
#  [ 1  0  8  0]
#  [ 2  1  2 16]]
# Confusion Matrix for Batch = 475 is [[34  0  1  0]
#  [ 1 30  0  1]
#  [ 1  0 10  0]
#  [ 4  0  5 13]]
# Confusion Matrix for Batch = 476 is [[30  0  1  1]
#  [ 1 25  1  1]
#  [ 2  0  8  0]
#  [ 2  0  0 28]]
# Confusion Matrix for Batch = 477 is [[33  0  2  0]
#  [ 1 41  0  1]
#  [ 1  0  9  0]
#  [ 2  0  2  8]]
# Confusion Matrix for Batch = 478 is [[22  1  0  1]
#  [ 2 52  0  0]
#  [ 0  0  9  1]
#  [ 0  0  1 11]]
# Confusion Matrix for Batch = 479 is [[24  0  1  1]
#  [ 2 48  0  1]
#  [ 2  0 11  0]
#  [ 0  0  2  8]]
# Confusion Matrix for Batch = 480 is [[25  0  1  0]
#  [ 0 37  3  1]
#  [ 0  0 14  0]
#  [ 0  1  4 14]]
# Confusion Matrix for Batch = 481 is [[30  0  1  1]
#  [ 1 41  1  2]
#  [ 1  0 11  0]
#  [ 1  1  1  8]]
# Confusion Matrix for Batch = 482 is [[49  0  2  0]
#  [ 2 21  1  0]
#  [ 1  0 10  0]
#  [ 1  0  2 11]]
# Confusion Matrix for Batch = 483 is [[36  0  1  0]
#  [ 3 32  0  1]
#  [ 0  0 13  0]
#  [ 1  0  1 12]]
# Confusion Matrix for Batch = 484 is [[18  0  2  1]
#  [ 3 34  0  0]
#  [ 0  0 17  2]
#  [ 2  1  6 14]]
# Confusion Matrix for Batch = 485 is [[26  0  2  0]
#  [ 4 39  0  1]
#  [ 2  0 11  1]
#  [ 1  1  3  9]]
# Confusion Matrix for Batch = 486 is [[20  0  2  0]
#  [ 0 30  1  0]
#  [ 0  0 25  2]
#  [ 1  2  3 14]]
# Confusion Matrix for Batch = 487 is [[34  0  3  2]
#  [ 0 19  0  0]
#  [ 1  0 20  1]
#  [ 0  1  4 15]]
# Confusion Matrix for Batch = 488 is [[39  1  1  0]
#  [ 0 23  0  0]
#  [ 1  0 13  0]
#  [ 1  0  8 13]]
# Confusion Matrix for Batch = 489 is [[16  0  2  2]
#  [ 1 18  1  1]
#  [ 0  0 16  2]
#  [ 0  0 10 31]]
# Confusion Matrix for Batch = 490 is [[22  0  0  1]
#  [ 0 13  0  1]
#  [ 3  0 23  2]
#  [ 1  0  6 28]]
# Confusion Matrix for Batch = 491 is [[14  0  0  1]
#  [ 0 10  0  1]
#  [ 0  0 25  1]
#  [ 1  0  8 39]]
# Confusion Matrix for Batch = 492 is [[16  0  0  2]
#  [ 0 22  0  0]
#  [ 2  0 24  3]
#  [ 1  0  1 29]]
# Confusion Matrix for Batch = 493 is [[18  0  0  0]
#  [ 0  9  0  0]
#  [ 1  0 25  2]
#  [ 2  0  6 37]]
# Confusion Matrix for Batch = 494 is [[11  0  1  1]
#  [ 1 19  1  0]
#  [ 1  0 32  2]
#  [ 0  0  5 26]]
# Confusion Matrix for Batch = 495 is [[19  0  1  2]
#  [ 0 16  0  0]
#  [ 2  0 21  3]
# ...
#  [ 1 14  0  0]
#  [ 2  0 21  1]
#  [ 0  0  3 31]]
# Confusion Matrix for Batch = 1040 is [[16  0  2  0]
#  [ 0 18  0  1]
#  [ 0  0 24  4]
#  [ 1  0  3 31]]
# Confusion Matrix for Batch = 1041 is [[17  0  0  0]
#  [ 0 19  0  0]
#  [ 1  0 23  1]
#  [ 0  0  1 38]]
# Confusion Matrix for Batch = 1042 is [[10  1  1  0]
#  [ 0 17  0  1]
#  [ 0  0 31  0]
#  [ 0  0  2 37]]
# Confusion Matrix for Batch = 1043 is [[15  0  3  1]
#  [ 0 31  0  0]
#  [ 0  0 19  0]
#  [ 1  0  2 28]]
# Confusion Matrix for Batch = 1044 is [[17  0  2  0]
#  [ 0 17  0  0]
#  [ 3  0 32  1]
#  [ 0  0  0 28]]
# Confusion Matrix for Batch = 1045 is [[27  1  3  1]
#  [ 0 24  0  0]
#  [ 0  0 18  0]
#  [ 0  1  1 24]]
# Confusion Matrix for Batch = 1046 is [[19  1  1  0]
#  [ 1 26  0  0]
#  [ 0  0 17  3]
#  [ 2  0  1 29]]
# Confusion Matrix for Batch = 1047 is [[23  0  1  1]
#  [ 1 23  0  0]
#  [ 1  1 29  0]
#  [ 0  0  3 17]]
# Confusion Matrix for Batch = 1048 is [[28  0  2  1]
#  [ 0 20  0  0]
#  [ 1  0 26  0]
#  [ 0  0  7 15]]
# Confusion Matrix for Batch = 1049 is [[30  0  2  1]
#  [ 0 26  0  0]
#  [ 0  0 18  0]
#  [ 1  0  5 17]]
# Confusion Matrix for Batch = 1050 is [[16  0  3  0]
#  [ 0 15  0  0]
#  [ 1  0 27  2]
#  [ 0  0  2 34]]
# Confusion Matrix for Batch = 1051 is [[18  0  0  1]
#  [ 0 18  0  0]
#  [ 0  0 32  2]
#  [ 2  0  4 23]]
# Confusion Matrix for Batch = 1052 is [[32  0  0  0]
#  [ 0 20  1  0]
#  [ 2  0 25  0]
#  [ 1  1  4 14]]
# Confusion Matrix for Batch = 1053 is [[23  0  1  0]
#  [ 0 22  0  0]
#  [ 1  0 21  1]
#  [ 1  0  1 29]]
# Confusion Matrix for Batch = 1054 is [[11  0  1  1]
#  [ 0 15  0  1]
#  [ 2  0 30  1]
#  [ 0  0  4 34]]
# Confusion Matrix for Batch = 1055 is [[16  0  0  0]
#  [ 1 23  0  1]
#  [ 0  0 29  0]
#  [ 2  0  3 25]]
# Confusion Matrix for Batch = 1056 is [[19  0  3  2]
#  [ 1 17  1  0]
#  [ 0  0 24  0]
#  [ 1  0  4 28]]
# Confusion Matrix for Batch = 1057 is [[16  1  0  2]
#  [ 0 24  0  0]
#  [ 1  0 15  1]
#  [ 1  0  1 38]]
# Confusion Matrix for Batch = 1058 is [[24  0  1  0]
#  [ 0 33  0  0]
#  [ 1  0 19  1]
#  [ 2  0  2 17]]
# Confusion Matrix for Batch = 1059 is [[21  0  0  0]
#  [ 0 28  0  0]
#  [ 0  0 22  1]
#  [ 0  0  4 24]]
# Confusion Matrix for Batch = 1060 is [[17  0  1  0]
#  [ 0 33  0  0]
#  [ 0  0 34  0]
#  [ 3  0  3  9]]
# Confusion Matrix for Batch = 1061 is [[25  0  4  0]
#  [ 0 17  0  0]
#  [ 0  0 33  1]
#  [ 0  0  4 16]]
# Confusion Matrix for Batch = 1062 is [[26  0  1  0]
#  [ 0 17  0  2]
#  [ 0  0 19  2]
#  [ 0  0  3 30]]
# Confusion Matrix for Batch = 1063 is [[16  0  0  0]
#  [ 0 21  0  1]
#  [ 0  0 31  1]
#  [ 2  1  3 24]]
# Confusion Matrix for Batch = 1064 is [[23  0  2  0]
#  [ 1 15  0  0]
#  [ 0  0 16  3]
#  [ 0  1  5 34]]
# Confusion Matrix for Batch = 1065 is [[18  0  1  0]
#  [ 0 22  0  0]
#  [ 0  0 23  0]
#  [ 0  0  6 30]]
# Confusion Matrix for Batch = 1066 is [[28  0  0  3]
#  [ 1 18  0  0]
#  [ 1  0 21  0]
#  [ 0  0  5 23]]
# Confusion Matrix for Batch = 1067 is [[29  0  0  1]
#  [ 0 35  0  0]
#  [ 1  0 16  0]
#  [ 1  0  2 15]]
# Confusion Matrix for Batch = 1068 is [[ 9  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 20  0]
#  [ 0  1  1 48]]
# Confusion Matrix for Batch = 1069 is [[12  0  0  0]
#  [ 1 16  0  2]
#  [ 0  0 18  4]
#  [ 1  0  4 42]]
# Confusion Matrix for Batch = 1070 is [[26  1  2  0]
#  [ 0 28  0  0]
#  [ 1  1 24  0]
#  [ 1  1  0 15]]
# Confusion Matrix for Batch = 1071 is [[27  0  0  0]
#  [ 0 20  0  0]
#  [ 2  0 27  0]
#  [ 1  1  5 17]]
# Confusion Matrix for Batch = 1072 is [[18  0  0  0]
#  [ 0 18  0  0]
#  [ 0  0 16  1]
#  [ 2  0  1 44]]
# Confusion Matrix for Batch = 1073 is [[16  0  1  1]
#  [ 1 26  0  0]
#  [ 0  0 26  1]
#  [ 0  1  4 23]]
# Confusion Matrix for Batch = 1074 is [[22  0  0  0]
#  [ 0 26  0  0]
#  [ 0  0 36  0]
#  [ 0  0  3 13]]
# Confusion Matrix for Batch = 1075 is [[16  0  1  0]
#  [ 0 21  0  0]
#  [ 1  0 24  3]
#  [ 1  0  2 31]]
# Confusion Matrix for Batch = 1076 is [[18  0  0  1]
#  [ 0 22  0  0]
#  [ 0  0 14  2]
#  [ 4  0  2 37]]
# Confusion Matrix for Batch = 1077 is [[18  0  1  0]
#  [ 1 24  1  0]
#  [ 0  0 31  0]
#  [ 1  0  6 17]]
# Confusion Matrix for Batch = 1078 is [[23  0  0  1]
#  [ 0 28  0  0]
#  [ 1  0 24  0]
#  [ 1  0  3 19]]
# Confusion Matrix for Batch = 1079 is [[33  0  0  0]
#  [ 1 32  0  0]
#  [ 2  0 23  0]
#  [ 1  0  5  3]]
# Confusion Matrix for Batch = 1080 is [[21  0  0  0]
#  [ 0 17  0  3]
#  [ 0  0 26  0]
#  [ 1  0  4 28]]
# Confusion Matrix for Batch = 1081 is [[22  0  0  0]
#  [ 0 21  1  0]
#  [ 0  0 32  1]
#  [ 0  0  1 22]]
# Confusion Matrix for Batch = 1082 is [[20  0  0  0]
#  [ 0 17  0  0]
#  [ 0  0 29  4]
#  [ 1  1  4 24]]
# Confusion Matrix for Batch = 1083 is [[18  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 36  1]
#  [ 0  0  4 20]]
# Confusion Matrix for Batch = 1084 is [[19  0  0  0]
#  [ 1 16  0  0]
#  [ 3  0 25  1]
#  [ 0  0  4 31]]
# Confusion Matrix for Batch = 1085 is [[21  0  0  0]
#  [ 0 24  0  0]
#  [ 0  0 21  1]
#  [ 0  0  5 28]]
# Confusion Matrix for Batch = 1086 is [[11  0  1  0]
#  [ 0 29  0  0]
#  [ 0  0 14  1]
#  [ 1  0  3 40]]
# Confusion Matrix for Batch = 1087 is [[21  0  1  0]
#  [ 0 45  1  0]
#  [ 0  0 13  0]
#  [ 0  1  6 12]]
# Confusion Matrix for Batch = 1088 is [[26  0  0  0]
#  [ 0 41  0  0]
#  [ 0  0 17  0]
#  [ 2  0  3 11]]
# Confusion Matrix for Batch = 1089 is [[31  0  1  0]
#  [ 0 32  0  2]
#  [ 2  0 15  0]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 1090 is [[26  0  1  2]
#  [ 0 17  0  0]
#  [ 0  0 12  2]
#  [ 1  1  1 37]]
# Confusion Matrix for Batch = 1091 is [[20  0  0  0]
#  [ 0 25  0  0]
#  [ 0  0 25  1]
#  [ 1  0  7 21]]
# Confusion Matrix for Batch = 1092 is [[27  0  0  0]
#  [ 0 19  0  0]
#  [ 1  0 22  0]
#  [ 0  0  3 28]]
# Confusion Matrix for Batch = 1093 is [[20  0  1  0]
#  [ 0 31  0  0]
#  [ 0  0 11  0]
#  [ 1  0  3 33]]
# Confusion Matrix for Batch = 1094 is [[13  0  0  0]
#  [ 1 28  0  0]
#  [ 1  0 26  0]
#  [ 2  0  4 25]]
# Confusion Matrix for Batch = 1095 is [[18  0  0  0]
#  [ 0 44  0  0]
#  [ 2  0 17  1]
#  [ 2  0  2 14]]
# Confusion Matrix for Batch = 1096 is [[25  0  1  0]
#  [ 0 30  0  0]
#  [ 1  0 24  1]
#  [ 2  0  2 14]]
# Confusion Matrix for Batch = 1097 is [[21  0  1  1]
#  [ 0 30  0  0]
#  [ 1  0 33  0]
#  [ 2  0  1 10]]
# Confusion Matrix for Batch = 1098 is [[22  0  1  1]
#  [ 0 27  0  0]
#  [ 0  0 17  0]
#  [ 2  0  2 28]]
# Confusion Matrix for Batch = 1099 is [[22  0  0  0]
#  [ 0 23  0  0]
#  [ 0  0 24  0]
#  [ 0  0 10 21]]
# Confusion Matrix for Batch = 1100 is [[27  0  1  0]
#  [ 0 23  0  1]
#  [ 0  0 23  0]
#  [ 1  0  1 23]]
# Confusion Matrix for Batch = 1101 is [[20  0  0  0]
#  [ 0 21  0  1]
#  [ 1  0 33  0]
#  [ 1  0  4 19]]
# Confusion Matrix for Batch = 1102 is [[15  0  1  1]
#  [ 0 21  0  1]
#  [ 1  0 17  1]
#  [ 0  0  3 39]]
# Confusion Matrix for Batch = 1103 is [[12  0  0  0]
#  [ 0 22  0  0]
#  [ 2  0 26  1]
#  [ 0  0  1 36]]
# Confusion Matrix for Batch = 1104 is [[16  0  2  0]
#  [ 0 25  1  0]
#  [ 0  0 33  0]
#  [ 1  1  2 19]]
# Confusion Matrix for Batch = 1105 is [[27  0  1  0]
#  [ 2 31  0  0]
#  [ 0  0 14  0]
#  [ 1  0  3 21]]
# Confusion Matrix for Batch = 1106 is [[17  0  2  1]
#  [ 0 31  0  0]
#  [ 0  0 13  1]
#  [ 1  0  2 32]]
# Confusion Matrix for Batch = 1107 is [[17  1  1  1]
#  [ 1 22  0  0]
#  [ 0  0 15  1]
#  [ 2  0  5 34]]
# Confusion Matrix for Batch = 1108 is [[25  0  0  1]
#  [ 0 15  0  0]
#  [ 2  0 27  0]
#  [ 3  0  2 25]]
# Confusion Matrix for Batch = 1109 is [[28  0  1  2]
#  [ 0 13  0  1]
#  [ 0  0 30  0]
#  [ 3  1  6 15]]
# Confusion Matrix for Batch = 1110 is [[22  0  3  0]
#  [ 0 23  0  0]
#  [ 0  0 25  0]
#  [ 0  1  6 20]]
# Confusion Matrix for Batch = 1111 is [[19  0  0  0]
#  [ 0 16  0  0]
#  [ 1  0 39  3]
#  [ 0  0  1 21]]
# Confusion Matrix for Batch = 1112 is [[20  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 32  0]
#  [ 1  0  3 23]]
# Confusion Matrix for Batch = 1113 is [[23  0  0  1]
#  [ 0 17  0  0]
#  [ 0  0 12  4]
#  [ 0  0  1 42]]
# Confusion Matrix for Batch = 1114 is [[17  0  0  2]
#  [ 0 22  0  0]
#  [ 0  0 26  0]
#  [ 0  0  3 30]]
# Confusion Matrix for Batch = 1115 is [[19  0  0  2]
#  [ 0 13  0  1]
#  [ 0  0 23  1]
#  [ 0  0  5 36]]
# Confusion Matrix for Batch = 1116 is [[13  0  0  0]
#  [ 0 23  1  0]
#  [ 0  0 25  2]
#  [ 1  0  3 32]]
# Confusion Matrix for Batch = 1117 is [[22  0  1  0]
#  [ 0 26  0  0]
#  [ 1  0 25  0]
#  [ 3  0  3 19]]
# Confusion Matrix for Batch = 1118 is [[14  0  2  0]
#  [ 0 38  1  0]
#  [ 1  0 29  1]
#  [ 1  0  3 10]]
# Confusion Matrix for Batch = 1119 is [[20  0  1  0]
#  [ 0 28  0  0]
#  [ 2  0 22  1]
#  [ 0  0  3 23]]
# Confusion Matrix for Batch = 1120 is [[21  0  1  0]
#  [ 1 34  0  0]
#  [ 0  0 23  0]
#  [ 2  1  3 14]]
# Confusion Matrix for Batch = 1121 is [[16  0  1  1]
#  [ 0 22  0  0]
#  [ 1  0 17  2]
#  [ 1  0  5 34]]
# Confusion Matrix for Batch = 1122 is [[18  0  1  0]
#  [ 0 16  0  0]
#  [ 0  0 31  0]
#  [ 1  0  2 31]]
# Confusion Matrix for Batch = 1123 is [[23  0  0  0]
#  [ 0 24  0  1]
#  [ 0  0 24  0]
#  [ 0  0  2 26]]
# Confusion Matrix for Batch = 1124 is [[25  0  0  1]
#  [ 0 17  0  1]
#  [ 0  0 24  0]
#  [ 1  1  3 27]]
# Confusion Matrix for Batch = 1125 is [[21  0  2  0]
#  [ 0 28  0  0]
#  [ 0  0 22  0]
#  [ 1  0  6 20]]
# Confusion Matrix for Batch = 1126 is [[26  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 28  0]
#  [ 4  0  4 16]]
# Confusion Matrix for Batch = 1127 is [[14  0  1  2]
#  [ 0 20  0  0]
#  [ 1  0 15  3]
#  [ 1  0  3 40]]
# Confusion Matrix for Batch = 1128 is [[19  0  0  1]
#  [ 0 31  0  0]
#  [ 0  0 25  0]
#  [ 2  0  4 18]]
# Confusion Matrix for Batch = 1129 is [[21  0  1  0]
#  [ 0 34  0  0]
#  [ 1  0 21  1]
#  [ 6  1  2 12]]
# Confusion Matrix for Batch = 1130 is [[32  0  0  0]
#  [ 0 24  0  0]
#  [ 1  0 21  0]
#  [ 2  0  4 16]]
# Confusion Matrix for Batch = 1131 is [[30  0  1  0]
#  [ 0 44  0  0]
#  [ 1  0 12  0]
#  [ 3  0  1  8]]
# Confusion Matrix for Batch = 1132 is [[30  0  0  0]
#  [ 0 48  0  0]
#  [ 0  0  7  0]
#  [ 1  0  4 10]]
# Confusion Matrix for Batch = 1133 is [[32  0  0  1]
#  [ 0 41  0  0]
#  [ 0  1  8  0]
#  [ 3  0  8  6]]
# Confusion Matrix for Batch = 1134 is [[20  0  1  1]
#  [ 2 48  1  0]
#  [ 0  0 12  0]
#  [ 1  0  5  9]]
# Confusion Matrix for Batch = 1135 is [[40  0  0  0]
#  [ 1 40  0  0]
#  [ 0  0  5  0]
#  [ 3  0  3  8]]
# Confusion Matrix for Batch = 1136 is [[45  0  1  0]
#  [ 1 20  0  0]
#  [ 0  0 14  0]
#  [ 2  0  1 16]]
# Confusion Matrix for Batch = 1137 is [[30  0  0  0]
#  [ 0 34  0  0]
#  [ 1  0 10  0]
#  [ 1  0  6 18]]
# Confusion Matrix for Batch = 1138 is [[29  0  0  1]
#  [ 1 36  0  3]
#  [ 1  0 11  0]
#  [ 2  0  1 15]]
# Confusion Matrix for Batch = 1139 is [[25  1  1  0]
#  [ 0 30  0  0]
#  [ 0  0 23  1]
#  [ 1  0  3 15]]
# Confusion Matrix for Batch = 1140 is [[20  0  0  1]
#  [ 1 27  1  0]
#  [ 1  0 15  1]
#  [ 2  0  6 25]]
# Confusion Matrix for Batch = 1141 is [[25  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 22  0]
#  [ 2  0  3 18]]
# Confusion Matrix for Batch = 1142 is [[18  0  0  2]
#  [ 1 21  0  0]
#  [ 1  0 22  2]
#  [ 1  0  2 30]]
# Confusion Matrix for Batch = 1143 is [[18  0  0  0]
#  [ 1 17  0  0]
#  [ 2  0 37  0]
#  [ 1  0  4 20]]
# Confusion Matrix for Batch = 1144 is [[16  0  0  3]
#  [ 0 13  0  0]
#  [ 0  0 33  1]
#  [ 0  0  1 33]]
# Confusion Matrix for Batch = 1145 is [[26  0  0  0]
#  [ 0 15  0  0]
#  [ 1  0 39  0]
#  [ 3  0  3 13]]
# Confusion Matrix for Batch = 1146 is [[21  0  1  1]
#  [ 0 21  0  0]
#  [ 0  0 26  0]
#  [ 0  0  2 28]]
# Confusion Matrix for Batch = 1147 is [[20  0  2  1]
#  [ 0 28  0  0]
#  [ 0  0 18  0]
#  [ 0  0  1 30]]
# Confusion Matrix for Batch = 1148 is [[20  0  2  0]
#  [ 0 27  0  0]
#  [ 0  0 21  0]
#  [ 1  0  1 28]]
# Confusion Matrix for Batch = 1149 is [[11  0  0  0]
#  [ 0 19  0  0]
#  [ 0  0 16  4]
#  [ 0  1  0 49]]
# Confusion Matrix for Batch = 1150 is [[24  0  1  1]
#  [ 0 25  0  0]
#  [ 0  0 29  0]
#  [ 0  0  2 18]]
# Confusion Matrix for Batch = 1151 is [[15  0  3  0]
#  [ 0 31  0  1]
#  [ 1  0 19  0]
#  [ 0  0  4 26]]
# Confusion Matrix for Batch = 1152 is [[27  0  0  0]
#  [ 0 27  0  0]
#  [ 0  0 19  0]
#  [ 0  0  4 23]]
# Confusion Matrix for Batch = 1153 is [[27  0  0  0]
#  [ 0 22  0  0]
#  [ 1  0 23  1]
#  [ 2  0  8 16]]
# Confusion Matrix for Batch = 1154 is [[24  0  2  0]
#  [ 0 16  0  0]
#  [ 0  0 18  1]
#  [ 0  0  5 34]]
# Confusion Matrix for Batch = 1155 is [[24  0  0  1]
#  [ 0  9  0  0]
#  [ 0  0 20  0]
#  [ 3  0  1 42]]
# Confusion Matrix for Batch = 1156 is [[23  0  0  4]
#  [ 0  6  0  0]
#  [ 1  0 34  1]
#  [ 0  0  2 29]]
# Confusion Matrix for Batch = 1157 is [[14  0  0  0]
#  [ 0 15  0  0]
#  [ 2  0 26  0]
#  [ 0  1  4 38]]
# Confusion Matrix for Batch = 1158 is [[19  0  0  2]
#  [ 0 13  0  0]
#  [ 0  0 26  2]
#  [ 1  0  1 36]]
# Confusion Matrix for Batch = 1159 is [[25  0  1  0]
#  [ 0 17  0  0]
#  [ 0  0 18  0]
#  [ 1  0  1 37]]
# Confusion Matrix for Batch = 1160 is [[22  1  0  0]
#  [ 0 34  0  0]
#  [ 0  0 21  0]
#  [ 1  0  1 20]]
# Confusion Matrix for Batch = 1161 is [[24  0  1  0]
#  [ 0 28  0  0]
#  [ 1  0 22  1]
#  [ 0  0  4 19]]
# Confusion Matrix for Batch = 1162 is [[25  0  0  0]
#  [ 0 25  0  0]
#  [ 0  0 16  0]
#  [ 1  1  1 31]]
# Confusion Matrix for Batch = 1163 is [[20  0  1  0]
#  [ 0 32  0  0]
#  [ 2  0 32  0]
#  [ 1  0  2 10]]
# Confusion Matrix for Batch = 1164 is [[29  0  0  0]
#  [ 1 29  0  0]
#  [ 0  0 21  1]
#  [ 1  1  4 13]]
# Confusion Matrix for Batch = 1165 is [[33  0  1  0]
#  [ 1 18  0  0]
#  [ 0  0 28  0]
#  [ 0  0  0 19]]
# Confusion Matrix for Batch = 1166 is [[17  0  0  1]
#  [ 0 10  0  0]
#  [ 1  0 44  0]
#  [ 1  0  3 23]]
# Confusion Matrix for Batch = 1167 is [[21  0  1  0]
#  [ 0 21  0  0]
#  [ 0  0 34  0]
#  [ 0  0  0 23]]
# Confusion Matrix for Batch = 1168 is [[24  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 38  0]
#  [ 0  0  1 16]]
# Confusion Matrix for Batch = 1169 is [[28  0  0  0]
#  [ 2 22  1  0]
#  [ 0  0 25  0]
#  [ 1  0  2 19]]
# Confusion Matrix for Batch = 1170 is [[13  0  0  1]
#  [ 1 17  1  0]
#  [ 0  0 16  4]
#  [ 1  0  1 45]]
# Confusion Matrix for Batch = 1171 is [[12  0  1  1]
#  [ 1 22  0  1]
#  [ 2  0 23  4]
#  [ 0  0  5 28]]
# Confusion Matrix for Batch = 1172 is [[27  0  0  0]
#  [ 1 24  0  1]
#  [ 0  0 18  0]
#  [ 0  0  5 24]]
# Confusion Matrix for Batch = 1173 is [[25  0  0  0]
#  [ 2 30  0  1]
#  [ 0  0 19  2]
#  [ 1  0  2 18]]
# Confusion Matrix for Batch = 1174 is [[10  0  2  0]
#  [ 0 31  0  0]
#  [ 1  0 21  0]
#  [ 1  0  5 29]]
# Confusion Matrix for Batch = 1175 is [[15  0  1  0]
#  [ 0 26  0  1]
#  [ 0  0 25  0]
#  [ 0  0  1 31]]
# Confusion Matrix for Batch = 1176 is [[19  0  2  0]
#  [ 0 35  2  0]
#  [ 0  0 25  0]
#  [ 0  0  6 11]]
# Confusion Matrix for Batch = 1177 is [[30  0  1  0]
#  [ 2 31  0  0]
#  [ 1  0 19  0]
#  [ 1  0  1 14]]
# Confusion Matrix for Batch = 1178 is [[24  0  0  0]
#  [ 0 11  0  0]
#  [ 0  0 33  0]
#  [ 3  0  3 26]]
# Confusion Matrix for Batch = 1179 is [[26  0  0  0]
#  [ 1 20  0  0]
#  [ 0  0 35  0]
#  [ 1  0  1 16]]
# Confusion Matrix for Batch = 1180 is [[18  0  0  1]
#  [ 0 16  0  0]
#  [ 0  0 38  1]
#  [ 0  0  1 25]]
# Confusion Matrix for Batch = 1181 is [[34  0  0  0]
#  [ 0 24  0  0]
#  [ 1  0 30  0]
#  [ 1  0  2  8]]
# Confusion Matrix for Batch = 1182 is [[14  0  0  0]
#  [ 0 22  0  0]
#  [ 0  0 42  0]
#  [ 1  0  3 18]]
# Confusion Matrix for Batch = 1183 is [[ 9  0  0  0]
#  [ 0 38  0  0]
#  [ 0  0 17  1]
#  [ 0  0  4 31]]
# Confusion Matrix for Batch = 1184 is [[25  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0 14  2]
#  [ 3  1  1 33]]
# Confusion Matrix for Batch = 1185 is [[27  0  0  0]
#  [ 0 36  0  0]
#  [ 0  0 20  0]
#  [ 2  0  3 12]]
# Confusion Matrix for Batch = 1186 is [[28  0  0  0]
#  [ 0 30  0  0]
#  [ 0  0 22  0]
#  [ 2  0  3 15]]
# Confusion Matrix for Batch = 1187 is [[17  0  0  0]
#  [ 1 21  0  0]
#  [ 2  0 22  1]
#  [ 0  0  6 30]]
# Confusion Matrix for Batch = 1188 is [[20  0  0  0]
#  [ 0 38  0  0]
#  [ 1  0 25  1]
#  [ 1  0  2 12]]
# Confusion Matrix for Batch = 1189 is [[31  0  0  1]
#  [ 0 13  0  1]
#  [ 0  0 21  0]
#  [ 6  0  1 26]]
# Confusion Matrix for Batch = 1190 is [[21  0  1  1]
#  [ 0  9  1  0]
#  [ 1  0 20  1]
#  [ 2  0  1 42]]
# Confusion Matrix for Batch = 1191 is [[17  0  0  0]
#  [ 1 19  0  0]
#  [ 1  0 26  0]
#  [ 1  0  4 31]]
# Confusion Matrix for Batch = 1192 is [[16  0  0  0]
#  [ 0 20  0  1]
#  [ 2  0 24  0]
#  [ 1  0  4 32]]
# Confusion Matrix for Batch = 1193 is [[10  0  0  1]
#  [ 0 22  0  0]
#  [ 1  0 33  0]
#  [ 1  0  6 26]]
# Confusion Matrix for Batch = 1194 is [[14  0  0  0]
#  [ 0 31  0  0]
#  [ 1  0 28  0]
#  [ 1  0  2 23]]
# Confusion Matrix for Batch = 1195 is [[24  0  1  1]
#  [ 0 30  1  0]
#  [ 0  0 18  1]
#  [ 1  1  3 19]]
# Confusion Matrix for Batch = 1196 is [[29  2  1  0]
#  [ 0 31  0  1]
#  [ 0  0 19  0]
#  [ 2  0  1 14]]
# Confusion Matrix for Batch = 1197 is [[27  0  0  1]
#  [ 0 35  0  0]
#  [ 1  0 18  0]
#  [ 1  0  2 15]]
# Confusion Matrix for Batch = 1198 is [[28  1  0  0]
#  [ 1 32  0  0]
#  [ 0  0 19  1]
#  [ 2  1  4 11]]
# Confusion Matrix for Batch = 1199 is [[31  0  0  2]
#  [ 0 27  0  0]
#  [ 0  0 20  0]
#  [ 2  0  3 15]]
# Training Set Accuracy = 0.9070583333333333	Recall = 0.9070583333333334	Precision = 0.9136482083274072	F1-Score = 0.9067620177278076	Loss = 0.002820103894919157	Confusion Matrix = [[31  0  0  2]
#  [ 0 27  0  0]
#  [ 0  0 20  0]
#  [ 2  0  3 15]]

# %%
batch_size = len(data['Description'])
model.eval()
correct = 0
test_loss = 0
precision = []
f1 = []
recall = []


for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in skip_gram_embeddings):
                batch_embeddings[k-batch_size*i][j] = skip_gram_embeddings['OOV']
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(skip_gram_embeddings[word])

        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = skip_gram_embeddings['OOV']
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()

    pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
    true = y_true.cpu().numpy()
    precision.append(precision_score(pred, true, average='weighted'))
    f1.append(f1_score(pred, true, average='weighted'))
    recall.append(recall_score(pred, true, average='weighted'))
    confusion = confusion_matrix(pred, true)
    print(f"Confusion Matrix for Batch = {i} is {confusion}")

print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Confusion Matrix for Batch = 0 is [[1621   36   99   80]
#  [  83 1791   34   61]
#  [  76   13 1475  124]
#  [ 120   60  292 1635]]
# Testing Set Accuracy = 0.8581578947368421	Recall = 0.8581578947368421	Precision = 0.861314404432133	F1-Score = 0.858353144400639	Loss = 5.600050644716248e-05

# %% [markdown]
# # Context Window = 3 Ends
