# %%
import torch
import numpy as np
import math
import torch.nn as nn
import pandas as pd
import re

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
svd_embeddings = torch.load("svd-word-vectors1.pt")
word_indices = torch.load("svd-word-vectors-indices1.pt")
svd_embeddings, word_indices
# Out:
# (array([[-2.43799097e-28,  5.09476327e-14, -2.13425680e-14, ...,
#          -1.40884866e-27, -1.14366508e-28, -1.07118553e-17],
#         [-1.74929039e-27,  1.92066895e-27, -3.57714299e-14, ...,
#           3.17831752e-13, -2.62299787e-13,  7.95804729e-14],
#         [-8.42817093e-21, -1.05777621e-19, -1.18901570e-32, ...,
#           4.87978694e-21,  1.22386488e-21, -7.59481450e-22],
#         ...,
#         [ 2.94370661e-21,  5.45833022e-21,  1.52278608e-21, ...,
#          -2.92611030e-22, -7.78838574e-23,  3.99039340e-23],
#         [-2.89936386e-20, -5.05551754e-20, -1.54139272e-20, ...,
#           2.83231611e-21,  7.55045559e-22, -3.92232633e-22],
#         [ 4.61246621e-21,  8.15461565e-21,  2.38549478e-21, ...,
#          -4.52367808e-22, -1.14266903e-22,  6.40721615e-23]]),
#  {'Reuters': 0,
#   '-': 1,
#   'Short': 2,
#   'sellers': 3,
#   ',': 4,
#   'Wall': 5,
#   "Street's": 6,
#   'dwindling': 7,
#   'band': 8,
#   'of': 9,
#   'ultra': 10,
#   'cynics': 11,
#   'are': 12,
#   'seeing': 13,
#   'green': 14,
#   'again': 15,
#   '.': 16,
#   'Private': 17,
#   'investment': 18,
#   'firm': 19,
#   'Carlyle': 20,
#   'Group': 21,
#   'which': 22,
#   'has': 23,
#   'a': 24,
#   'reputation': 25,
#   'for': 26,
#   'making': 27,
#   'well': 28,
#   'timed': 29,
#   'and': 30,
#   'occasionally': 31,
#   'controversial': 32,
#   'plays': 33,
#   'in': 34,
#   'the': 35,
#   'defense': 36,
#   'industry': 37,
#   'quietly': 38,
#   'placed': 39,
#   'its': 40,
#   'bets': 41,
#   'on': 42,
#   'another': 43,
#   'part': 44,
#   'market': 45,
#   'Soaring': 46,
#   'crude': 47,
#   'prices': 48,
#   'plus': 49,
#   'worries': 50,
#   'about': 51,
#   'economy': 52,
#   'outlook': 53,
#   'earnings': 54,
#   'expected': 55,
#   'to': 56,
#   'hang': 57,
#   'over': 58,
#   'stock': 59,
#   'next': 60,
#   'week': 61,
#   'during': 62,
#   'depth': 63,
#   'summer': 64,
#   'doldrums': 65,
#   'Authorities': 66,
#   'have': 67,
#   'halted': 68,
#   'oil': 69,
#   'export': 70,
#   'flows': 71,
#   'from': 72,
#   'main': 73,
#   'pipeline': 74,
#   'southern': 75,
#   'Iraq': 76,
#   'after': 77,
#   'intelligence': 78,
#   'showed': 79,
#   'rebel': 80,
#   'militia': 81,
#   'could': 82,
#   'strike': 83,
#   'infrastructure': 84,
#   'an': 85,
#   'official': 86,
#   'said': 87,
#   'Saturday': 88,
#   'AFP': 89,
#   'Tearaway': 90,
#   'world': 91,
#   'toppling': 92,
#   'records': 93,
#   'straining': 94,
#   'wallets': 95,
#   'present': 96,
#   'new': 97,
#   'economic': 98,
#   'menace': 99,
#   'barely': 100,
#   'three': 101,
#   'months': 102,
#   'before': 103,
#   'US': 104,
#   'presidential': 105,
#   'elections': 106,
#   'Stocks': 107,
#   'ended': 108,
#   'slightly': 109,
#   'higher': 110,
#   'Friday': 111,
#   'but': 112,
#   'stayed': 113,
#   'near': 114,
#   'lows': 115,
#   'year': 116,
#   'as': 117,
#   'surged': 118,
#   'past': 119,
#   '36': 120,
#   ';': 121,
#   '46': 122,
#   'barrel': 123,
#   'offsetting': 124,
#   'positive': 125,
#   'computer': 126,
#   'maker': 127,
#   'Dell': 128,
#   'Inc': 129,
#   'DELL': 130,
#   'O': 131,
#   'AP': 132,
#   'Assets': 133,
#   "nation's": 134,
#   'retail': 135,
#   'money': 136,
#   'mutual': 137,
#   'funds': 138,
#   'fell': 139,
#   'by': 140,
#   '1': 141,
#   '17': 142,
#   'billion': 143,
#   'latest': 144,
#   '849': 145,
#   '98': 146,
#   'trillion': 147,
#   'Investment': 148,
#   'Company': 149,
#   'Institute': 150,
#   'Thursday': 151,
#   'USATODAY': 152,
#   'com': 153,
#   'Retail': 154,
#   'sales': 155,
#   'bounced': 156,
#   'back': 157,
#   'bit': 158,
#   'July': 159,
#   'claims': 160,
#   'jobless': 161,
#   'benefits': 162,
#   'last': 163,
#   'government': 164,
#   'indicating': 165,
#   'is': 166,
#   'improving': 167,
#   'midsummer': 168,
#   'slump': 169,
#   'Forbes': 170,
#   'After': 171,
#   'earning': 172,
#   'PH': 173,
#   'D': 174,
#   'Sociology': 175,
#   'Danny': 176,
#   'Bazil': 177,
#   'Riley': 178,
#   'started': 179,
#   'work': 180,
#   'general': 181,
#   'manager': 182,
#   'at': 183,
#   'commercial': 184,
#   'real': 185,
#   'estate': 186,
#   'annual': 187,
#   'base': 188,
#   'salary': 189,
#   '70': 190,
#   '000': 191,
#   'Soon': 192,
#   'financial': 193,
#   'planner': 194,
#   'stopped': 195,
#   'his': 196,
#   'desk': 197,
#   'drop': 198,
#   'off': 199,
#   'brochures': 200,
#   'insurance': 201,
#   'available': 202,
#   'through': 203,
#   'employer': 204,
#   'But': 205,
#   '32': 206,
#   'buying': 207,
#   'was': 208,
#   'furthest': 209,
#   'thing': 210,
#   'my': 211,
#   'mind': 212,
#   'says': 213,
#   'NEW': 214,
#   'YORK': 215,
#   'TEHRAN': 216,
#   'OPEC': 217,
#   'can': 218,
#   'do': 219,
#   'nothing': 220,
#   'douse': 221,
#   'scorching': 222,
#   'when': 223,
#   'markets': 224,
#   'already': 225,
#   'oversupplied': 226,
#   '2': 227,
#   '8': 228,
#   'million': 229,
#   'barrels': 230,
#   'per': 231,
#   'day': 232,
#   'bpd': 233,
#   "Iran's": 234,
#   'governor': 235,
#   'warning': 236,
#   'that': 237,
#   'fall': 238,
#   'sharply': 239,
#   'JAKARTA': 240,
#   'Non': 241,
#   'exporters': 242,
#   'should': 243,
#   'consider': 244,
#   'increasing': 245,
#   'output': 246,
#   'cool': 247,
#   'record': 248,
#   'President': 249,
#   'Purnomo': 250,
#   'Yusgiantoro': 251,
#   'Sunday': 252,
#   'WASHINGTON': 253,
#   'The': 254,
#   'auction': 255,
#   'Google': 256,
#   "'s": 257,
#   'highly': 258,
#   'anticipated': 259,
#   'initial': 260,
#   'public': 261,
#   'offering': 262,
#   'got': 263,
#   'rocky': 264,
#   'start': 265,
#   'Web': 266,
#   'search': 267,
#   'company': 268,
#   'sidestepped': 269,
#   'bullet': 270,
#   'U': 271,
#   'S': 272,
#   'securities': 273,
#   'regulators': 274,
#   'dollar': 275,
#   'tumbled': 276,
#   'broadly': 277,
#   'data': 278,
#   'showing': 279,
#   'trade': 280,
#   'deficit': 281,
#   'June': 282,
#   'cast': 283,
#   'fresh': 284,
#   'doubts': 285,
#   "economy's": 286,
#   'recovery': 287,
#   'ability': 288,
#   'draw': 289,
#   'foreign': 290,
#   'capital': 291,
#   'fund': 292,
#   'growing': 293,
#   'gap': 294,
#   'If': 295,
#   'you': 296,
#   'think': 297,
#   'may': 298,
#   'need': 299,
#   'help': 300,
#   'your': 301,
#   'elderly': 302,
#   'relatives': 303,
#   'with': 304,
#   'their': 305,
#   'finances': 306,
#   "don't": 307,
#   'be': 308,
#   'shy': 309,
#   'having': 310,
#   'talk': 311,
#   'soon': 312,
#   'purchasing': 313,
#   'power': 314,
#   'kids': 315,
#   'big': 316,
#   'why': 317,
#   'school': 318,
#   'season': 319,
#   'become': 320,
#   'such': 321,
#   'huge': 322,
#   'marketing': 323,
#   'phenomenon': 324,
#   'There': 325,
#   'little': 326,
#   'cause': 327,
#   'celebration': 328,
#   'these': 329,
#   'days': 330,
#   'investors': 331,
#   'value': 332,
#   'focused': 333,
#   'reason': 334,
#   'feel': 335,
#   'smug': 336,
#   'if': 337,
#   'only': 338,
#   'because': 339,
#   "they've": 340,
#   'lost': 341,
#   'less': 342,
#   'than': 343,
#   'folks': 344,
#   'who': 345,
#   'stuck': 346,
#   'growth': 347,
#   'exploded': 348,
#   '19': 349,
#   '55': 350,
#   '8bn': 351,
#   'costs': 352,
#   'drove': 353,
#   'imports': 354,
#   'according': 355,
#   'figures': 356,
#   'Oil': 357,
#   'giant': 358,
#   'Shell': 359,
#   'bracing': 360,
#   'itself': 361,
#   'takeover': 362,
#   'attempt': 363,
#   'possibly': 364,
#   'French': 365,
#   'rival': 366,
#   'Total': 367,
#   'press': 368,
#   'report': 369,
#   'bidding': 370,
#   'gets': 371,
#   'underway': 372,
#   "Google's": 373,
#   'despite': 374,
#   'minute': 375,
#   'interview': 376,
#   'bosses': 377,
#   'Playboy': 378,
#   'magazine': 379,
#   'Official': 380,
#   'show': 381,
#   '12': 382,
#   'nation': 383,
#   'eurozone': 384,
#   'continues': 385,
#   'grow': 386,
#   'there': 387,
#   'warnings': 388,
#   'it': 389,
#   'slow': 390,
#   'down': 391,
#   'later': 392,
#   'Economic': 393,
#   'Japan': 394,
#   'slows': 395,
#   'country': 396,
#   'experiences': 397,
#   'domestic': 398,
#   'corporate': 399,
#   'spending': 400,
#   'Interest': 401,
#   'rates': 402,
#   'trimmed': 403,
#   '7': 404,
#   '5': 405,
#   'South': 406,
#   'African': 407,
#   'central': 408,
#   'bank': 409,
#   'lack': 410,
#   'hits': 411,
#   'rand': 412,
#   'surprises': 413,
#   'cost': 414,
#   'both': 415,
#   'second': 416,
#   'hand': 417,
#   'cars': 418,
#   'five': 419,
#   'years': 420,
#   'survey': 421,
#   'found': 422,
#   "Korea's": 423,
#   'cuts': 424,
#   'interest': 425,
#   'quarter': 426,
#   'percentage': 427,
#   'point': 428,
#   '3': 429,
#   'bid': 430,
#   'drive': 431,
#   'An': 432,
#   'shares': 433,
#   'web': 434,
#   'engine': 435,
#   'floated': 436,
#   'much': 437,
#   '36bn': 438,
#   'takes': 439,
#   'place': 440,
#   'Hewlett': 441,
#   'Packard': 442,
#   'disappointing': 443,
#   'third': 444,
#   'profits': 445,
#   'while': 446,
#   'warns': 447,
#   'final': 448,
#   'will': 449,
#   'also': 450,
#   'short': 451,
#   'expectations': 452,
#   'One': 453,
#   'oldest': 454,
#   'textile': 455,
#   'operators': 456,
#   'Indian': 457,
#   'Ocean': 458,
#   'island': 459,
#   'Mauritius': 460,
#   'shut': 461,
#   'seven': 462,
#   'factories': 463,
#   'cut': 464,
#   '900': 465,
#   'jobs': 466,
#   'Chad': 467,
#   'asks': 468,
#   'IMF': 469,
#   'loan': 470,
#   'pay': 471,
#   'looking': 472,
#   'more': 473,
#   '100': 474,
#   'refugees': 475,
#   'conflict': 476,
#   'torn': 477,
#   'Darfur': 478,
#   'western': 479,
#   'Sudan': 480,
#   'running': 481,
#   'Japanese': 482,
#   'nuclear': 483,
#   'plant': 484,
#   'hit': 485,
#   'fatal': 486,
#   'accident': 487,
#   'close': 488,
#   'reactors': 489,
#   'safety': 490,
#   'checks': 491,
#   'Trevor': 492,
#   'Baylis': 493,
#   'veteran': 494,
#   'inventor': 495,
#   'famous': 496,
#   'creating': 497,
#   'Freeplay': 498,
#   'clockwork': 499,
#   'radio': 500,
#   'planning': 501,
#   'float': 502,
#   'Saudi': 503,
#   'Arabia': 504,
#   'ready': 505,
#   'push': 506,
#   'extra': 507,
#   'into': 508,
#   'reverse': 509,
#   'surging': 510,
#   'A': 511,
#   'group': 512,
#   'led': 513,
#   "UAE's": 514,
#   'Etisalat': 515,
#   'plans': 516,
#   'spend': 517,
#   '1bn': 518,
#   '544m': 519,
#   'expansion': 520,
#   'winning': 521,
#   'two': 522,
#   'mobile': 523,
#   'phone': 524,
#   'licences': 525,
#   'Network': 526,
#   'Rail': 527,
#   'flies': 528,
#   'specialist': 529,
#   'engineers': 530,
#   'West': 531,
#   'Coast': 532,
#   'Mainline': 533,
#   'UK': 534,
#   'skills': 535,
#   'shortage': 536,
#   'BEDFORD': 537,
#   'Scientists': 538,
#   'NitroMed': 539,
#   'hope': 540,
#   'experimental': 541,
#   'drugs': 542,
#   'cure': 543,
#   'heart': 544,
#   'disease': 545,
#   'someday': 546,
#   'lately': 547,
#   'focus': 548,
#   'been': 549,
#   'mundane': 550,
#   'matters': 551,
#   "I've": 552,
#   'submitted': 553,
#   'buy': 554,
#   "company's": 555,
#   'style': 556,
#   'That': 557,
#   'turn': 558,
#   'out': 559,
#   'good': 560,
#   'news': 561,
#   'or': 562,
#   'bad': 563,
#   'Massachusetts': 564,
#   'bargain': 565,
#   'hunters': 566,
#   'up': 567,
#   'droves': 568,
#   'shopped': 569,
#   'hard': 570,
#   "yesterday's": 571,
#   'tax': 572,
#   'holiday': 573,
#   'everything': 574,
#   'treadmills': 575,
#   'snow': 576,
#   'blowers': 577,
#   'candles': 578,
#   'chandeliers': 579,
#   'crediting': 580,
#   'percent': 581,
#   'break': 582,
#   'bringing': 583,
#   'them': 584,
#   'stores': 585,
#   'E': 586,
#   'mail': 587,
#   'victim': 588,
#   'own': 589,
#   'success': 590,
#   "That's": 591,
#   'conclusion': 592,
#   'IBM': 593,
#   'Corp': 594,
#   'researchers': 595,
#   'Cambridge': 596,
#   'spent': 597,
#   'nearly': 598,
#   'decade': 599,
#   'conducting': 600,
#   'field': 601,
#   'tests': 602,
#   'other': 603,
#   'companies': 604,
#   'how': 605,
#   'employees': 606,
#   'use': 607,
#   'electronic': 608,
#   "It's": 609,
#   'clear': 610,
#   'e': 611,
#   "Internet's": 612,
#   'killer': 613,
#   'application': 614,
#   'Even': 615,
#   'genius': 616,
#   'mess': 617,
#   'Bill': 618,
#   'Gates': 619,
#   'brilliant': 620,
#   'technologist': 621,
#   'he': 622,
#   'cofounded': 623,
#   'Microsoft': 624,
#   'guided': 625,
#   'greatness': 626,
#   'size': 627,
#   'historical': 628,
#   'consequence': 629,
#   'blundered': 630,
#   'He': 631,
#   'terrorized': 632,
#   'underlings': 633,
#   'temper': 634,
#   'parceled': 635,
#   'praise': 636,
#   'like': 637,
#   'Scrooge': 638,
#   'gave': 639,
#   'charity': 640,
#   'Only': 641,
#   'lash': 642,
#   'inspired': 643,
#   'necessary': 644,
#   'aggressiveness': 645,
#   'beat': 646,
#   'competition': 647,
#   'thought': 648,
#   'Target': 649,
#   'abusers': 650,
#   'legal': 651,
#   'weapons': 652,
#   'We': 653,
#   'all': 654,
#   'share': 655,
#   'outrage': 656,
#   'expressed': 657,
#   'columnist': 658,
#   'Steve': 659,
#   'Bailey': 660,
#   "''Summer": 661,
#   'Sizzler': 662,
#   'quot': 663,
#   'Aug': 664,
#   '11': 665,
#   'killings': 666,
#   "city's": 667,
#   'poor': 668,
#   'neighborhoods': 669,
#   "there's": 670,
#   'no': 671,
#   'ignorance': 672,
#   'argues': 673,
#   'renewal': 674,
#   'so': 675,
#   'called': 676,
#   'assault': 677,
#   'weapon': 678,
#   'ban': 679,
#   'claiming': 680,
#   'otherwise': 681,
#   "''UZIs": 682,
#   'AK': 683,
#   '47s': 684,
#   'flooding': 685,
#   'streets': 686,
#   'His': 687,
#   'Bush': 688,
#   'saying': 689,
#   "''turned": 690,
#   'corner': 691,
#   'Democratic': 692,
#   'candidate': 693,
#   'Senator': 694,
#   'John': 695,
#   'F': 696,
#   'Kerry': 697,
#   'wake': 698,
#   'this': 699,
#   "month's": 700,
#   'quipped': 701,
#   'Marlborough': 702,
#   'based': 703,
#   'technology': 704,
#   'suing': 705,
#   'former': 706,
#   'including': 707,
#   'senior': 708,
#   'managers': 709,
#   'allegedly': 710,
#   'conspiring': 711,
#   'against': 712,
#   'working': 713,
#   'opening': 714,
#   'competing': 715,
#   'business': 716,
#   'Central': 717,
#   'Square': 718,
#   'Lynn': 719,
#   'brighter': 720,
#   'New': 721,
#   'sidewalks': 722,
#   'curbs': 723,
#   'fences': 724,
#   'lights': 725,
#   'landscaping': 726,
#   'road': 727,
#   'improvements': 728,
#   'planned': 729,
#   'Gateway': 730,
#   'Artisan': 731,
#   'Block': 732,
#   'key': 733,
#   'area': 734,
#   'square': 735,
#   '830': 736,
#   'state': 737,
#   'grant': 738,
#   'given': 739,
#   'lawsuit': 740,
#   'Gary': 741,
#   'Winnick': 742,
#   'chief': 743,
#   'Global': 744,
#   'Crossing': 745,
#   'refocuses': 746,
#   'attention': 747,
#   'what': 748,
#   'Mr': 749,
#   'knew': 750,
#   'imploded': 751,
#   'Russia': 752,
#   'emerging': 753,
#   'superpower': 754,
#   'Kevin': 755,
#   'B': 756,
#   'Rollins': 757,
#   'executive': 758,
#   'talks': 759,
#   "Dell's": 760,
#   'transitory': 761,
#   'slip': 762,
#   'customer': 763,
#   'service': 764,
#   'sees': 765,
#   'broader': 766,
#   'taking': 767,
#   'With': 768,
#   'cash': 769,
#   'rich': 770,
#   'people': 771,
#   'dying': 772,
#   'wealth': 773,
#   'Stein': 774,
#   'proposes': 775,
#   'unique': 776,
#   'solution': 777,
#   'sell': 778,
#   'titles': 779,
#   'nobility': 780,
#   'Quality': 781,
#   'Distribution': 782,
#   'hammered': 783,
#   'reporting': 784,
#   'large': 785,
#   'loss': 786,
#   'Hurricane': 787,
#   'Charley': 788,
#   'blows': 789,
#   'house': 790,
#   'make': 791,
#   '?': 792,
#   'results': 793,
#   "it's": 794,
#   'not': 795,
#   'grim': 796,
#   'tech': 797,
#   'Just': 798,
#   "isn't": 799,
#   'tough': 800,
#   "Detroit's": 801,
#   'troubled': 802,
#   'carmaker': 803,
#   'thanks': 804,
#   'maverick': 805,
#   'designer': 806,
#   'car': 807,
#   'dazzling': 808,
#   'hip': 809,
#   'hop': 810,
#   'crowd': 811,
#   'Americans': 812,
#   'tricking': 813,
#   'places': 814,
#   'where': 815,
#   'they': 816,
#   'swim': 817,
#   "Here's": 818,
#   'look': 819,
#   'wave': 820,
#   'accessories': 821,
#   'In': 822,
#   '1993': 823,
#   'six': 824,
#   'geeks': 825,
#   'had': 826,
#   'digital': 827,
#   'nightmare': 828,
#   'changed': 829,
#   'culture': 830,
#   'get': 831,
#   'far': 832,
#   'creepier': 833,
#   'Celebrity': 834,
#   'fashion': 835,
#   'booming': 836,
#   'These': 837,
#   'webpreneurs': 838,
#   'street': 839,
#   'No': 840,
#   'recording': 841,
#   'artist': 842,
#   'channel': 843,
#   'American': 844,
#   'middle': 845,
#   'class': 846,
#   'tastes': 847,
#   'quite': 848,
#   'Chip': 849,
#   'Davis': 850,
#   'best': 851,
#   'selling': 852,
#   'Got': 853,
#   'problem': 854,
#   'Not': 855,
#   'worry': 856,
#   'find': 857,
#   'every': 858,
#   'specialized': 859,
#   "Today's": 860,
#   'customers': 861,
#   'increasingly': 862,
#   'demanding': 863,
#   'Asia': 864,
#   'elsewhere': 865,
#   'Henry': 866,
#   'Astorga': 867,
#   'describes': 868,
#   'complex': 869,
#   'reality': 870,
#   'faced': 871,
#   "today's": 872,
#   'marketers': 873,
#   'includes': 874,
#   'we': 875,
#   'used': 876,
#   'want': 877,
#   'performance': 878,
#   'now': 879,
#   '!': 880,
#   'Well': 881,
#   'election': 882,
#   'time': 883,
#   'Republic': 884,
#   'Philippines': 885,
#   'means': 886,
#   'monkeys': 887,
#   'rolling': 888,
#   'around': 889,
#   'those': 890,
#   'political': 891,
#   'fun': 892,
#   'laughing': 893,
#   'heads': 894,
#   'strange': 895,
#   'goings': 896,
#   'characterize': 897,
#   'democratic': 898,
#   'process': 899,
#   'loosely': 900,
#   'model': 901,
#   'de': 902,
#   'facto': 903,
#   'looks': 904,
#   'Fellini': 905,
#   'movie': 906,
#   'crossed': 907,
#   'Tom': 908,
#   'Jerry': 909,
#   'cartoon': 910,
#   'column': 911,
#   'useful': 912,
#   'glossary': 913,
#   'Why': 914,
#   'General': 915,
#   'Motors': 916,
#   'dropped': 917,
#   'Oldsmobile': 918,
#   'four': 919,
#   'brand': 920,
#   'paradoxes': 921,
#   'GM': 922,
#   'face': 923,
#   'name': 924,
#   'product': 925,
#   'image': 926,
#   're': 927,
#   'positioning': 928,
#   'consumer': 929,
#   'added': 930,
#   'rebranding': 931,
#   'Although': 932,
#   'smattering': 933,
#   'Chinese': 934,
#   'Filipinos': 935,
#   'Indians': 936,
#   'Thais': 937,
#   'others': 938,
#   'crow': 939,
#   'kind': 940,
#   'sitting': 941,
#   'prominent': 942,
#   'positions': 943,
#   'corporations': 944,
#   'organizations': 945,
#   'USA': 946,
#   'accomplishments': 947,
#   'mere': 948,
#   'cultural': 949,
#   'high': 950,
#   'fives': 951,
#   'ritualistic': 952,
#   'chest': 953,
#   'thumping': 954,
#   'goaded': 955,
#   'impishly': 956,
#   'patronized': 957,
#   "'mainstream": 958,
#   "society'": 959,
#   'milder': 960,
#   'gentler': 961,
#   'term': 962,
#   'white': 963,
#   'dominated': 964,
#   'populace': 965,
#   'Blues': 966,
#   'alive': 967,
#   'evidenced': 968,
#   'appreciation': 969,
#   'Pinoy': 970,
#   "'Lampano": 971,
#   "Alley'": 972,
#   'penned': 973,
#   'Clarence': 974,
#   'Henderson': 975,
#   'counterpoint': 976,
#   'usual': 977,
#   'economics': 978,
#   'fare': 979,
#   'Globalization': 980,
#   'does': 981,
#   'things': 982,
#   'life': 983,
#   'Manila': 984,
#   'consultant': 985,
#   'proving': 986,
#   'really': 987,
#   'CAN': 988,
#   'Muddy': 989,
#   'Walters': 990,
#   'bluegrass': 991,
#   'same': 992,
#   'page': 993,
#   'APMF': 994,
#   'Asian': 995,
#   'tourism': 996,
#   'destinations': 997,
#   'just': 998,
#   'kicked': 999,
#   ...})

# %%
class LSTM(nn.Module):
    def __init__(self, hidden_dim, output_dim, embedding_dim = 50, num_layers = 1):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True, bidirectional=False)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)
        
        # Initialize hidden state
        output, (hn, cn) = self.lstm(x, (h0, c0))
        
        # Take the output from the last time step

        output_last = output[:, -1]
        # Pass it through the fully connected layer
        output_fc = self.fc(output_last)
        
        return output_fc

        # output, (_, _) = self.lstm(x)
        # return self.fc(output)

# %%
oov_embeddings = torch.randn(50, dtype = torch.float32)

# %%
data_train = pd.read_csv('train.csv')
length = []
for i in range(len(data_train['Description'])):
    sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][i])
    length.append(len(sentence))
length.sort()
max_len = length[int(0.95*len(length))]
max_len
# Out:
# 59

# %%
data = pd.read_csv('test.csv')
data
# Out:
#       Class Index                                        Description
# 0               3  Unions representing workers at Turner   Newall...
# 1               4  SPACE.com - TORONTO, Canada -- A second\team o...
# 2               4  AP - A company founded by a chemistry research...
# 3               4  AP - It's barely dawn when Mike Fitzpatrick st...
# 4               4  AP - Southern California's smog-fighting agenc...
# ...           ...                                                ...
# 7595            1  Ukrainian presidential candidate Viktor Yushch...
# 7596            2  With the supply of attractive pitching options...
# 7597            2  Like Roger Clemens did almost exactly eight ye...
# 7598            3  SINGAPORE : Doctors in the United States have ...
# 7599            3  EBay plans to buy the apartment and home renta...
#
# [7600 rows x 2 columns]

# %%
hidden_dim = 256
output_dim = data['Class Index'].unique().shape[0]

model = LSTM(hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
model
# Out:
# LSTM(
#   (lstm): LSTM(50, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-batch_size*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.34581666666666666	Loss = 0.013166915625333786
# Epoch = 1	Training Set Accuracy = 0.5025833333333334	Loss = 0.011420639231801033
# Epoch = 2	Training Set Accuracy = 0.5476083333333334	Loss = 0.010677801445126534
# Epoch = 3	Training Set Accuracy = 0.5728333333333333	Loss = 0.010225415229797363
# Epoch = 4	Training Set Accuracy = 0.5912916666666667	Loss = 0.009859870187938213
# Epoch = 5	Training Set Accuracy = 0.605925	Loss = 0.009560181759297848
# Epoch = 6	Training Set Accuracy = 0.6214083333333333	Loss = 0.009255439043045044
# Epoch = 7	Training Set Accuracy = 0.6335083333333333	Loss = 0.009005768224596977
# Epoch = 8	Training Set Accuracy = 0.643925	Loss = 0.008801501244306564
# Epoch = 9	Training Set Accuracy = 0.6517166666666667	Loss = 0.008624986745417118

# %%
batch_size = 100
train_loss = 0
correct = 0
model.eval()
for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in word_indices):
                batch_embeddings[k-batch_size*i][j] = oov_embeddings
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = oov_embeddings
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.Tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)]).to(torch.int64)
    loss = criterion(y_pred, y_true-1)
    train_loss += loss

    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()
print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tLoss = {train_loss/len(data['Description'])}")
# Out:
# Testing Set Accuracy = 0.5853947368421053	Loss = 0.010319176129996777

# %%
from sklearn.metrics import precision_score, f1_score, recall_score, confusion_matrix

# %%
torch.save(model, "svd-classification-model.pt")

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(100*i, 100*i+100):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[100*i:100*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.39574166666666666	Loss = 0.012476691044867039
# Epoch = 1	Training Set Accuracy = 1.0512333333333332	Loss = 0.02108396217226982
# Epoch = 2	Training Set Accuracy = 1.7664	Loss = 0.02847791463136673
# Epoch = 3	Training Set Accuracy = 2.5099	Loss = 0.035228148102760315
# Epoch = 4	Training Set Accuracy = 3.27145	Loss = 0.041528452187776566
# Epoch = 5	Training Set Accuracy = 4.048466666666667	Loss = 0.047477059066295624
# Epoch = 6	Training Set Accuracy = 4.839433333333333	Loss = 0.053097303956747055
# Epoch = 7	Training Set Accuracy = 5.640633333333334	Loss = 0.0584648959338665
# Epoch = 8	Training Set Accuracy = 6.449108333333333	Loss = 0.06365052610635757
# Epoch = 9	Training Set Accuracy = 7.265825	Loss = 0.06865249574184418

# %%
batch_size = 100
model.train()
precision = []
f1 = []
recall = []
correct = 0
train_loss = 0
import warnings
warnings.filterwarnings('ignore')


confusion = None
with torch.no_grad():
    for i in range(int(len(data_train['Description'])/batch_size)):
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()

        pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
        true = y_true.cpu().numpy()
        precision.append(precision_score(pred, true, average='weighted'))
        f1.append(f1_score(pred, true, average='weighted'))
        recall.append(recall_score(pred, true, average='weighted'))
        confusion = confusion_matrix(pred, true)
        print(f"Confusion Matrix for Batch = {i} is {confusion}")

    print(f"Training Set Accuracy = {correct / len(data_train['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {train_loss/len(data_train['Description'])}\tConfusion Matrix = {confusion}")
# Out:
# Confusion Matrix for Batch = 0 is [[ 0  0 17  6]
#  [ 0  0 15  2]
#  [ 0  0 14  3]
#  [ 0  0 32 11]]
# Confusion Matrix for Batch = 1 is [[ 0  0 29]
#  [ 0  0 12]
#  [ 0  0 59]]
# Confusion Matrix for Batch = 2 is [[ 0  0  0 18]
#  [ 0  0  0  9]
#  [ 0  0  0  8]
#  [ 0  0  0 65]]
# Confusion Matrix for Batch = 3 is [[ 0  0  0 16]
#  [ 0  0  0  7]
#  [ 0  0  0  7]
#  [ 0  0  0 70]]
# Confusion Matrix for Batch = 4 is [[ 8  6  0  7]
#  [ 0 31  0  6]
#  [ 0  3  0  1]
#  [ 0  4  0 34]]
# Confusion Matrix for Batch = 5 is [[45  4  1  3]
#  [ 9 11  1  1]
#  [ 4  1  2  0]
#  [ 6  1  2  9]]
# Confusion Matrix for Batch = 6 is [[33  4  5  1]
#  [ 2 35  2  0]
#  [ 0  0  7  0]
#  [ 6  2  1  2]]
# Confusion Matrix for Batch = 7 is [[25  2  7  3]
#  [ 5 20  2  2]
#  [ 7  2  6  1]
#  [ 2  1  4 11]]
# Confusion Matrix for Batch = 8 is [[18  2  4  3]
#  [ 1  5  1  1]
#  [ 2  0 27  4]
#  [ 5  1  3 23]]
# Confusion Matrix for Batch = 9 is [[25  0  1  9]
#  [ 3  3  0  5]
#  [ 2  1 15  3]
#  [ 4  3  5 21]]
# Confusion Matrix for Batch = 10 is [[23  4  2  5]
#  [ 5 14  3  7]
#  [ 1  1 11  4]
#  [ 4  1  1 14]]
# Confusion Matrix for Batch = 11 is [[17  2  0 11]
#  [ 2 17  1  4]
#  [ 1  1 10  5]
#  [ 8  0  0 21]]
# Confusion Matrix for Batch = 12 is [[20  0  4  1]
#  [ 2 21  3  2]
#  [ 2  0 16  5]
#  [ 6  2  6 10]]
# Confusion Matrix for Batch = 13 is [[27  2  2  6]
#  [ 0 12  1  0]
#  [ 3  1 19  2]
#  [ 4  1  2 18]]
# Confusion Matrix for Batch = 14 is [[19  2  4  5]
#  [ 2  3  4  4]
#  [ 4  0 29  3]
#  [ 2  0  4 15]]
# Confusion Matrix for Batch = 15 is [[15  6  1  7]
#  [ 5 14  0  1]
#  [ 3  1  8  4]
#  [ 5  1  3 26]]
# Confusion Matrix for Batch = 16 is [[ 6  5  3  3]
#  [ 4 15  3  0]
#  [ 2  0 25  5]
#  [ 2  1  4 22]]
# Confusion Matrix for Batch = 17 is [[15  5  3  2]
#  [ 3 22  2  1]
#  [ 4  1 13  4]
#  [ 2  3  3 17]]
# Confusion Matrix for Batch = 18 is [[17  5  3  5]
#  [ 2 15  2  3]
#  [ 0  0 12  0]
#  [ 2  2  2 30]]
# Confusion Matrix for Batch = 19 is [[18  2  1  5]
#  [ 1 12  1  1]
#  [ 2  0 17  3]
#  [ 5  2  6 24]]
# Confusion Matrix for Batch = 20 is [[14  7  2  7]
#  [ 3 10  2  1]
#  [ 1  1 18  3]
#  [ 1  4  3 23]]
# Confusion Matrix for Batch = 21 is [[20  2  2  1]
#  [ 8 25  0  1]
#  [ 0  1 18  3]
#  [ 0  4  4 11]]
# Confusion Matrix for Batch = 22 is [[11  3  5  3]
#  [ 1 33  3  1]
#  [ 2  4  9  2]
#  [ 3  6  7  7]]
# Confusion Matrix for Batch = 23 is [[21  6  4  1]
#  [ 3 20  3  1]
#  [ 1  1 17  2]
#  [ 2  3  3 12]]
# Confusion Matrix for Batch = 24 is [[26  8  4  2]
#  [ 2 18  0  2]
#  [ 7  1 16  2]
#  [ 3  3  3  3]]
# Confusion Matrix for Batch = 25 is [[31  4  4  1]
#  [ 2  7  1  2]
#  [ 0  0 16  2]
#  [ 3  4  7 16]]
# Confusion Matrix for Batch = 26 is [[18  1  6  6]
#  [ 2  5  0  1]
#  [ 3  2 24  2]
#  [ 4  3  9 14]]
# Confusion Matrix for Batch = 27 is [[20  4  2  5]
#  [ 4 10  3  0]
#  [ 1  1 21  3]
#  [ 4  2  9 11]]
# Confusion Matrix for Batch = 28 is [[13  6  4  3]
#  [ 1  5  3  2]
#  [ 1  1 24  2]
#  [ 0  3  9 23]]
# Confusion Matrix for Batch = 29 is [[14  6  6  5]
#  [ 3 12  2  2]
#  [ 1  1 14  4]
#  [ 2  5  9 14]]
# Confusion Matrix for Batch = 30 is [[30  6  0  3]
#  [ 2 14  1  2]
#  [ 1  1  6  4]
#  [ 2  0  3 25]]
# Confusion Matrix for Batch = 31 is [[16  3  6  4]
#  [ 3  7  0  2]
#  [ 1  1 20  5]
#  [ 0  2  8 22]]
# Confusion Matrix for Batch = 32 is [[27  3  3  2]
#  [ 0 16  2  2]
#  [ 3  0 11  3]
#  [ 1  3  4 20]]
# Confusion Matrix for Batch = 33 is [[25  4  1  6]
#  [ 1 17  1  3]
#  [ 2  1 14  2]
#  [ 2  1  5 15]]
# Confusion Matrix for Batch = 34 is [[20  4  3  5]
#  [ 4 23  0  0]
#  [ 3  0 18  3]
#  [ 6  1  2  8]]
# Confusion Matrix for Batch = 35 is [[20  5  2  3]
#  [ 4 15  3  0]
#  [ 3  0 25  0]
#  [ 5  4  3  8]]
# Confusion Matrix for Batch = 36 is [[17  7  4  1]
#  [ 3 23  0  2]
#  [ 1  0 20  1]
#  [ 6  2  6  7]]
# Confusion Matrix for Batch = 37 is [[19  7  3  5]
#  [ 2 15  0  3]
#  [ 0  2 10  2]
#  [ 2  2  7 21]]
# Confusion Matrix for Batch = 38 is [[23  7  2  6]
#  [ 2  7  0  0]
#  [ 1  1 23  1]
#  [ 0  4  9 14]]
# Confusion Matrix for Batch = 39 is [[ 6  3  3  5]
#  [ 0  3  4  2]
#  [ 0  3 41  4]
#  [ 2  0 11 13]]
# Confusion Matrix for Batch = 40 is [[17  4  0  5]
#  [ 3  8  0 10]
#  [ 0  2  2  8]
#  [ 3  1  0 37]]
# Confusion Matrix for Batch = 41 is [[20  3  3  2]
#  [ 1  6  3  3]
#  [ 2  1 25  4]
#  [ 2  0  8 17]]
# Confusion Matrix for Batch = 42 is [[12  7  1  7]
#  [ 3 12  0  2]
#  [ 0  0  7 12]
#  [ 2  3  5 27]]
# Confusion Matrix for Batch = 43 is [[12  5  6  8]
#  [ 2 16  0  2]
#  [ 3  0 10  3]
#  [ 0  6  6 21]]
# Confusion Matrix for Batch = 44 is [[10  7  5  3]
#  [ 2 21  3  5]
#  [ 2  0 19  0]
#  [ 1  3  9 10]]
# Confusion Matrix for Batch = 45 is [[11  3  6  2]
#  [ 4 24  0  2]
#  [ 1  0 22  2]
#  [ 2  2  6 13]]
# Confusion Matrix for Batch = 46 is [[17  2  3  1]
#  [ 2 12  2  2]
#  [ 1  3 24  1]
#  [ 3  3 11 13]]
# Confusion Matrix for Batch = 47 is [[22  6  2  0]
#  [ 3 26  2  2]
#  [ 3  0 11  2]
#  [ 1  2  6 12]]
# Confusion Matrix for Batch = 48 is [[31  4  4  4]
#  [ 4 11  1  6]
#  [ 3  1  9  4]
#  [ 3  2  3 10]]
# Confusion Matrix for Batch = 49 is [[17  2  2  2]
#  [ 6 18  1  1]
#  [ 4  2 13  5]
#  [ 2  7  8 10]]
# Confusion Matrix for Batch = 50 is [[18  3  2  3]
#  [ 1  9  2  4]
#  [ 2  2 21  3]
#  [ 5  1  6 18]]
# Confusion Matrix for Batch = 51 is [[19  5  1  7]
#  [ 1 19  0  2]
#  [ 0  0 17  2]
#  [ 4  1  6 16]]
# Confusion Matrix for Batch = 52 is [[19  3  0  4]
#  [ 3 13  3  1]
#  [ 3  1 23  4]
#  [ 1  0  4 18]]
# Confusion Matrix for Batch = 53 is [[22  3  0  5]
#  [ 6 12  1  5]
#  [ 4  2 15  3]
#  [ 0  1  1 20]]
# Confusion Matrix for Batch = 54 is [[19  4  2  1]
#  [ 4 27  6  0]
#  [ 2  2 13  0]
#  [ 3  4  4  9]]
# Confusion Matrix for Batch = 55 is [[27  5  1  4]
#  [ 7 22  0  0]
#  [ 0  1  3  1]
#  [ 6  6  5 12]]
# Confusion Matrix for Batch = 56 is [[19  3  3  6]
#  [ 7 20  1  4]
#  [ 0  0  9  4]
#  [ 0  2  8 14]]
# Confusion Matrix for Batch = 57 is [[29  3  6  5]
#  [ 4 21  5  1]
#  [ 0  1  7  1]
#  [ 3  3  5  6]]
# Confusion Matrix for Batch = 58 is [[34  3  1  0]
#  [ 4 35  2  2]
#  [ 0  3  5  3]
#  [ 0  2  3  3]]
# Confusion Matrix for Batch = 59 is [[29  4  6  0]
#  [ 5 24  3  3]
#  [ 0  0  9  2]
#  [ 2  0  4  9]]
# Confusion Matrix for Batch = 60 is [[22  1  6  1]
#  [ 3 34  2  1]
#  [ 3  1  8  0]
#  [ 5  3  4  6]]
# Confusion Matrix for Batch = 61 is [[14  4  2  1]
#  [ 6 41  4  1]
#  [ 0  1  5  0]
#  [ 1  6  6  8]]
# Confusion Matrix for Batch = 62 is [[20  1  6  3]
#  [ 5 28  5  3]
#  [ 1  1  5  3]
#  [ 3  1  8  7]]
# Confusion Matrix for Batch = 63 is [[24  5  3  0]
#  [ 3 28  4  1]
#  [ 0  3  8  0]
#  [ 4  2  7  8]]
# Confusion Matrix for Batch = 64 is [[30  4  2  1]
#  [ 8 23  2  2]
#  [ 5  2  4  2]
#  [ 4  2  5  4]]
# Confusion Matrix for Batch = 65 is [[23  6  8  2]
#  [ 3 22  0  3]
#  [ 0  1  6  4]
#  [ 3  5  4 10]]
# Confusion Matrix for Batch = 66 is [[29  5  1  3]
#  [ 5 33  3  0]
#  [ 1  2  3  1]
#  [ 6  3  4  1]]
# Confusion Matrix for Batch = 67 is [[18  2  7  3]
#  [ 3 32  0  1]
#  [ 2  4  1  3]
#  [ 6  5  2 11]]
# Confusion Matrix for Batch = 68 is [[19  4  5  1]
#  [ 4 29  2  1]
#  [ 3  2 13  1]
#  [ 5  4  6  1]]
# Confusion Matrix for Batch = 69 is [[13  1  7  1]
#  [ 4 27  1  2]
#  [ 4  2  8  1]
#  [ 2  1 10 16]]
# Confusion Matrix for Batch = 70 is [[17  3  4  3]
#  [ 2 29  3  1]
#  [ 2  0 12  2]
#  [ 4  5  7  6]]
# Confusion Matrix for Batch = 71 is [[16  7  7  3]
#  [ 0 24  7  1]
#  [ 3  2  9  1]
#  [ 1  1 10  8]]
# Confusion Matrix for Batch = 72 is [[15  5  3  3]
#  [ 2 29  1  0]
#  [ 5  3 14  2]
#  [ 2  4  1 11]]
# Confusion Matrix for Batch = 73 is [[17  4  5  1]
#  [ 3 19  1  1]
#  [ 3  1 12  3]
#  [ 2  2 12 14]]
# Confusion Matrix for Batch = 74 is [[16  4  1  1]
#  [ 3 10  4  2]
#  [ 1  1 22  4]
#  [ 7  1  9 14]]
# Confusion Matrix for Batch = 75 is [[14  1  1  1]
#  [ 4  8  3  2]
#  [ 4  1 26  5]
#  [ 2  2  5 21]]
# Confusion Matrix for Batch = 76 is [[20  6  4  3]
#  [ 3 12  2  2]
#  [ 3  1 13  4]
#  [ 5  1  5 16]]
# Confusion Matrix for Batch = 77 is [[14  3  6  2]
#  [ 2 16  2  2]
#  [ 0  2 12  7]
#  [ 4  4  5 19]]
# Confusion Matrix for Batch = 78 is [[15  1  3  6]
#  [ 1 12  4  1]
#  [ 3  1 17  6]
#  [ 2  1  7 20]]
# Confusion Matrix for Batch = 79 is [[12  4  5  5]
#  [ 2  7  2  2]
#  [ 0  1 18  5]
#  [ 3  1  6 27]]
# Confusion Matrix for Batch = 80 is [[13  6  1  4]
#  [ 2 16  3  2]
#  [ 1  1 13  4]
#  [ 4  1  8 21]]
# Confusion Matrix for Batch = 81 is [[14  8  4  0]
#  [ 5 17  2  2]
#  [ 2  1 18  2]
#  [ 5  1  4 15]]
# Confusion Matrix for Batch = 82 is [[14  3  1  1]
#  [ 3 23  3  2]
#  [ 4  2  6  4]
#  [ 7  5 10 12]]
# Confusion Matrix for Batch = 83 is [[11  4  6  0]
#  [ 1 21  5  0]
#  [ 5  1 16  5]
#  [ 1  3 10 11]]
# Confusion Matrix for Batch = 84 is [[17  2 12  1]
#  [ 3 18  1  2]
#  [ 3  1 20  1]
#  [ 1  1  6 11]]
# Confusion Matrix for Batch = 85 is [[18  2  6  1]
#  [ 1 23  2  2]
#  [ 1  3 10  5]
#  [ 0  1 12 13]]
# Confusion Matrix for Batch = 86 is [[22  4  4  1]
#  [ 4 10  0  3]
#  [ 4  0 20  0]
#  [ 4  2  1 21]]
# Confusion Matrix for Batch = 87 is [[13  3  3  1]
#  [ 7 12  1  1]
#  [ 4  0 21  3]
#  [ 1  1  5 24]]
# Confusion Matrix for Batch = 88 is [[19  3  1  4]
#  [ 0 12  2  2]
#  [ 1  2 26  6]
#  [ 1  2  3 16]]
# Confusion Matrix for Batch = 89 is [[ 9  3  3  6]
#  [ 4 15  1  3]
#  [ 1  1 20  6]
#  [ 4  2  3 19]]
# Confusion Matrix for Batch = 90 is [[10  3  4  3]
#  [ 3 10  1  3]
#  [ 2  1 29  7]
#  [ 1  2  5 16]]
# Confusion Matrix for Batch = 91 is [[10  4  3  3]
#  [ 2 14  2  4]
#  [ 0  0 15  8]
#  [ 3  0  9 23]]
# Confusion Matrix for Batch = 92 is [[ 8  5  4  5]
#  [ 2 14  2  3]
#  [ 1  1 22  9]
#  [ 4  1  4 15]]
# Confusion Matrix for Batch = 93 is [[15  3  2  2]
#  [ 8 20  2  2]
#  [ 4  2  2  4]
#  [ 7  1  4 22]]
# Confusion Matrix for Batch = 94 is [[13  1  2  8]
#  [ 2 10  3  6]
#  [ 1  1 17  4]
#  [ 2  2  3 25]]
# Confusion Matrix for Batch = 95 is [[10  5  3  6]
#  [ 3 11  4  6]
#  [ 1  1 10  6]
#  [ 2  2  5 25]]
# Confusion Matrix for Batch = 96 is [[17  2  7  3]
#  [ 7 13  0  5]
#  [ 4  0 10  7]
#  [ 0  2  5 18]]
# Confusion Matrix for Batch = 97 is [[14  6  5  4]
#  [ 4  9  0  5]
#  [ 0  2 16  7]
#  [ 5  0  2 21]]
# Confusion Matrix for Batch = 98 is [[ 7  3  1  4]
#  [ 1  9  3  6]
#  [ 3  0 22  8]
#  [ 2  2  3 26]]
# Confusion Matrix for Batch = 99 is [[13  2  4  8]
#  [ 1 13  2  5]
#  [ 0  0 17  4]
#  [ 2  3  4 22]]
# Confusion Matrix for Batch = 100 is [[14  5  6  8]
#  [ 4 12  2  5]
#  [ 1  0 18  3]
#  [ 2  2  4 14]]
# Confusion Matrix for Batch = 101 is [[21  2  2  6]
#  [ 3 19  3  2]
#  [ 0  1 14  2]
#  [ 2  0  8 15]]
# Confusion Matrix for Batch = 102 is [[17  4  5  3]
#  [ 4 23  2  4]
#  [ 1  0 18  2]
#  [ 1  4  4  8]]
# Confusion Matrix for Batch = 103 is [[19  2  5  1]
#  [ 6 22  1  3]
#  [ 3  0 10  6]
#  [ 6  2  5  9]]
# Confusion Matrix for Batch = 104 is [[23  2  5  1]
#  [ 2 26  3  1]
#  [ 0  0 18  1]
#  [ 3  0  9  6]]
# Confusion Matrix for Batch = 105 is [[19  4  2  3]
#  [ 0  9  2  5]
#  [ 2  1 13  5]
#  [ 0  1  4 30]]
# Confusion Matrix for Batch = 106 is [[10  4  3  3]
#  [ 0 15  2  1]
#  [ 2  0 29  6]
#  [ 2  2  1 20]]
# Confusion Matrix for Batch = 107 is [[19  4  5  7]
#  [ 4  8  3  5]
#  [ 0  1 15  1]
#  [ 5  0  6 17]]
# Confusion Matrix for Batch = 108 is [[13  0  5  2]
#  [ 6 16  2  2]
#  [ 0  1 21  7]
#  [ 2  0  4 19]]
# Confusion Matrix for Batch = 109 is [[14  5  6  8]
#  [ 1  9  3  0]
#  [ 0  1 16  4]
#  [ 3  0  9 21]]
# Confusion Matrix for Batch = 110 is [[15  3  3 13]
#  [ 0  4  2  0]
#  [ 1  0 22  3]
#  [ 2  0  3 29]]
# Confusion Matrix for Batch = 111 is [[18  5  5  4]
#  [ 1 18  3  2]
#  [ 1  2 10  4]
#  [ 2  2  4 19]]
# Confusion Matrix for Batch = 112 is [[18  3  6  2]
#  [ 2 19  1  1]
#  [ 1  3 17  4]
#  [ 4  5  4 10]]
# Confusion Matrix for Batch = 113 is [[14  2  5  8]
#  [ 4 23  4  1]
#  [ 1  1 14  1]
#  [ 2  2  6 12]]
# Confusion Matrix for Batch = 114 is [[15  5  5  3]
#  [ 4 18  5  3]
#  [ 2  2 19  2]
#  [ 1  2  7  7]]
# Confusion Matrix for Batch = 115 is [[16  3  4  6]
#  [ 4 20  4  4]
#  [ 0  3 10  3]
#  [ 3  1  8 11]]
# Confusion Matrix for Batch = 116 is [[20  4  4  5]
#  [ 2 23  3  6]
#  [ 2  2  9  2]
#  [ 5  2  3  8]]
# Confusion Matrix for Batch = 117 is [[11  6  2  3]
#  [ 1 22  4  3]
#  [ 2  3 13  4]
#  [ 1  2  6 17]]
# Confusion Matrix for Batch = 118 is [[21  5  7  4]
#  [ 2  9  1  1]
#  [ 3  1 13  7]
#  [ 2  2  2 20]]
# Confusion Matrix for Batch = 119 is [[ 9  7  4  7]
#  [ 2  9  3  3]
#  [ 2  1 20  4]
#  [ 3  0  4 22]]
# Confusion Matrix for Batch = 120 is [[15  4  9  6]
#  [ 3 12  3  4]
#  [ 1  4 14  5]
#  [ 1  2  4 13]]
# Confusion Matrix for Batch = 121 is [[16  3  3  8]
#  [ 3 14  1  1]
#  [ 2  0 14  5]
#  [ 4  2  4 20]]
# Confusion Matrix for Batch = 122 is [[15 10  5  8]
#  [ 4 13  1  2]
#  [ 1  1 14  3]
#  [ 1  0  4 18]]
# Confusion Matrix for Batch = 123 is [[14  7  2  3]
#  [ 5 16  1  3]
#  [ 4  4 11  8]
#  [ 0  0  2 20]]
# Confusion Matrix for Batch = 124 is [[16  5  3  0]
#  [ 7 14  0  2]
#  [ 2  0 13  6]
#  [ 2  3  1 26]]
# Confusion Matrix for Batch = 125 is [[12  9  3  7]
#  [ 3 17  3  1]
#  [ 0  2 10  5]
#  [ 1  2  4 21]]
# Confusion Matrix for Batch = 126 is [[14  3  7  1]
#  [ 1 25  2  0]
#  [ 2  3 10  3]
#  [ 3  3  2 21]]
# Confusion Matrix for Batch = 127 is [[16  7  5  1]
#  [ 5 29  6  1]
#  [ 3  1  4  1]
#  [ 4  6  3  8]]
# Confusion Matrix for Batch = 128 is [[23 10  4  0]
#  [ 0 30  3  2]
#  [ 0  1  5  2]
#  [ 6  2  1 11]]
# Confusion Matrix for Batch = 129 is [[20  6  2  2]
#  [ 5 28  2  0]
#  [ 3  1  8  0]
#  [ 2  6  6  9]]
# Confusion Matrix for Batch = 130 is [[27  6  1  3]
#  [ 4 25  5  1]
#  [ 1  2  7  3]
#  [ 4  2  2  7]]
# Confusion Matrix for Batch = 131 is [[31  8  2  7]
#  [ 3 23  1  1]
#  [ 4  3  2  1]
#  [ 5  1  4  4]]
# Confusion Matrix for Batch = 132 is [[25 11  3  1]
#  [ 4 34  2  2]
#  [ 1  3  0  1]
#  [ 6  2  1  4]]
# Confusion Matrix for Batch = 133 is [[22 11  4  0]
#  [ 6 30  4  0]
#  [ 1  0  2  0]
#  [ 3  7  4  6]]
# Confusion Matrix for Batch = 134 is [[25  4  1  2]
#  [ 4 40  0  0]
#  [ 1  2  2  1]
#  [ 5  4  2  7]]
# Confusion Matrix for Batch = 135 is [[24  1  2  1]
#  [ 6 21  3  3]
#  [ 2  2  8  1]
#  [ 8  3  4 11]]
# Confusion Matrix for Batch = 136 is [[24  3  4  0]
#  [ 6 28  5  2]
#  [ 1  3  3  1]
#  [ 2  4  8  6]]
# Confusion Matrix for Batch = 137 is [[36  7  1  3]
#  [ 3 16  3  2]
#  [ 4  0  3  3]
#  [ 6  2  5  6]]
# Confusion Matrix for Batch = 138 is [[27  7  5  2]
#  [ 6 28  4  1]
#  [ 2  4  1  1]
#  [ 4  3  1  4]]
# Confusion Matrix for Batch = 139 is [[31  4  4  0]
#  [ 4 28  1  3]
#  [ 3  2  4  2]
#  [ 5  3  0  6]]
# Confusion Matrix for Batch = 140 is [[27  7  2  3]
#  [ 6 36  2  2]
#  [ 2  1  0  4]
#  [ 1  0  2  5]]
# Confusion Matrix for Batch = 141 is [[24  1  4  3]
#  [ 5 24  2  3]
#  [ 1  1 11  2]
#  [ 5  4  6  4]]
# Confusion Matrix for Batch = 142 is [[20  2  4  3]
#  [ 2 25  4  2]
#  [ 3  1  9  2]
#  [ 1  2  7 13]]
# Confusion Matrix for Batch = 143 is [[19  4  4  1]
#  [ 2 28  1  0]
#  [ 3  2  8  3]
#  [ 2  6  8  9]]
# Confusion Matrix for Batch = 144 is [[22  0  4  4]
#  [ 6 19  3  0]
#  [ 4  1  6  4]
#  [ 6  5  8  8]]
# Confusion Matrix for Batch = 145 is [[16  6  4  3]
#  [ 2 15  0  9]
#  [ 1  1 13  0]
#  [ 7  1  8 14]]
# Confusion Matrix for Batch = 146 is [[16  1  4  2]
#  [ 2  6  3  1]
#  [ 6  1 21  3]
#  [ 4  2  3 25]]
# Confusion Matrix for Batch = 147 is [[18  4  5  3]
#  [ 1 10  2  4]
#  [ 5  2 15  2]
#  [ 4  0  6 19]]
# Confusion Matrix for Batch = 148 is [[18  4  2  7]
#  [ 3  5  1  6]
#  [ 5  1 17  5]
#  [ 4  3  5 14]]
# Confusion Matrix for Batch = 149 is [[20  4  4  2]
#  [ 0 17  1  3]
#  [ 2  1 14  3]
#  [ 3  0  9 17]]
# Confusion Matrix for Batch = 150 is [[ 8  2  1 10]
#  [ 3 14  4  3]
#  [ 2  5 13  3]
#  [ 3  1  4 24]]
# Confusion Matrix for Batch = 151 is [[10  0  1  5]
#  [ 2  9  4  4]
#  [ 3  0 10  4]
#  [ 5  0  6 37]]
# Confusion Matrix for Batch = 152 is [[19  2  3  1]
#  [ 4 23  0  2]
#  [ 1  3 18  3]
#  [ 4  2  1 14]]
# Confusion Matrix for Batch = 153 is [[10  3  4  2]
#  [ 1 20  4  4]
#  [ 2  2 15  9]
#  [ 5  0  4 15]]
# Confusion Matrix for Batch = 154 is [[17  2  5  4]
#  [ 5 18  1  2]
#  [ 1  2  9  3]
#  [ 3  2  5 21]]
# Confusion Matrix for Batch = 155 is [[16  2  3  4]
#  [ 4  8  1  4]
#  [ 3  4 26  2]
#  [ 2  1  2 18]]
# Confusion Matrix for Batch = 156 is [[12  2  4  3]
#  [ 3 10  3  6]
#  [ 3  1 15  5]
#  [ 1  1  3 28]]
# Confusion Matrix for Batch = 157 is [[12  2  3  5]
#  [ 4  8  3  3]
#  [ 0  1 23  7]
#  [ 2  2  3 22]]
# Confusion Matrix for Batch = 158 is [[15  6 10  3]
#  [ 5 11  2  2]
#  [ 1  1 15  4]
#  [ 4  1  6 14]]
# Confusion Matrix for Batch = 159 is [[10  2  1  7]
#  [ 1  9  6  4]
#  [ 1  0  7 11]
#  [ 3  1  8 29]]
# Confusion Matrix for Batch = 160 is [[19  5  1  1]
#  [ 4 29  5  4]
#  [ 0  2  6  3]
#  [ 3  2  6 10]]
# Confusion Matrix for Batch = 161 is [[17  6  4  5]
#  [ 1 13  0  8]
#  [ 2  0 14  4]
#  [ 2  1  2 21]]
# Confusion Matrix for Batch = 162 is [[29  1  5  3]
#  [ 5 14  2  3]
#  [ 2  1  9  2]
#  [ 3  3  6 12]]
# Confusion Matrix for Batch = 163 is [[11  3  3  8]
#  [ 2  5  5  2]
#  [ 1  0 18  7]
#  [ 2  0  6 27]]
# Confusion Matrix for Batch = 164 is [[24  5  4  3]
#  [ 2 20  2  2]
#  [ 2  0 20  2]
#  [ 1  1  2 10]]
# Confusion Matrix for Batch = 165 is [[13  1  2  6]
#  [ 0  7  1  5]
#  [ 0  0  6  6]
#  [ 2  2  5 44]]
# Confusion Matrix for Batch = 166 is [[10  1  1  7]
#  [ 3 20  0  8]
#  [ 0  1 14  5]
#  [ 0  0  4 26]]
# Confusion Matrix for Batch = 167 is [[22  4  2  7]
#  [ 4 18  0  6]
#  [ 1  0  6  4]
#  [ 3  1  3 19]]
# Confusion Matrix for Batch = 168 is [[17  4  4  4]
#  [ 3 29  3  1]
#  [ 1  1 15  0]
#  [ 4  0  1 13]]
# Confusion Matrix for Batch = 169 is [[21  4  0  7]
#  [ 2 19  0  4]
#  [ 2  0 13  4]
#  [ 6  6  6  6]]
# Confusion Matrix for Batch = 170 is [[18  2  2  2]
#  [ 2 22  0  4]
#  [ 2  1  5  4]
#  [ 3  2  4 27]]
# Confusion Matrix for Batch = 171 is [[26  2  5  6]
#  [ 4  8  2  0]
#  [ 1  0 20  7]
#  [ 5  0 10  4]]
# Confusion Matrix for Batch = 172 is [[10  4  2  6]
#  [ 5 11  1  3]
#  [ 1  0 13 14]
#  [ 0  0  2 28]]
# Confusion Matrix for Batch = 173 is [[14  4  1  6]
#  [ 2 22  0  2]
#  [ 1  0 15  8]
#  [ 2  0  4 19]]
# Confusion Matrix for Batch = 174 is [[14  3  8  0]
#  [ 3 27  6  1]
#  [ 2  0 16  1]
#  [ 3  5  7  4]]
# Confusion Matrix for Batch = 175 is [[11  1  4 11]
#  [ 1 10  1  6]
#  [ 0  0  8 11]
#  [ 0  0  2 34]]
# Confusion Matrix for Batch = 176 is [[26  1  3  3]
#  [ 1  9  2  2]
#  [ 4  0 16  3]
#  [ 7  0  4 19]]
# Confusion Matrix for Batch = 177 is [[15  5  3  4]
#  [ 1 14  1  3]
#  [ 1  1 20  5]
#  [ 0  0  5 22]]
# Confusion Matrix for Batch = 178 is [[21  2  4  5]
#  [ 3 17  4  4]
#  [ 4  0  9  6]
#  [ 5  0  4 12]]
# Confusion Matrix for Batch = 179 is [[16  0  3  4]
#  [ 3 12  0  6]
#  [ 1  0  5  7]
#  [ 4  2  2 35]]
# Confusion Matrix for Batch = 180 is [[18  3  4  2]
#  [ 3 25  0  5]
#  [ 4  1  9  3]
#  [ 2  2  8 11]]
# Confusion Matrix for Batch = 181 is [[20  6  6  1]
#  [ 6 32  0  4]
#  [ 0  0  8  1]
#  [ 2  1  2 11]]
# Confusion Matrix for Batch = 182 is [[24  3  7  1]
#  [ 8 27  1  2]
#  [ 1  2  9  4]
#  [ 2  1  2  6]]
# Confusion Matrix for Batch = 183 is [[24  6  3  4]
#  [ 3 31  4  6]
#  [ 0  0  4  2]
#  [ 1  4  4  4]]
# Confusion Matrix for Batch = 184 is [[26  1  4  3]
#  [ 5 21  3  1]
#  [ 4  1  8  3]
#  [11  0  2  7]]
# Confusion Matrix for Batch = 185 is [[27  3  3  2]
#  [ 5 36  2  1]
#  [ 2  1  6  1]
#  [ 0  0  1 10]]
# Confusion Matrix for Batch = 186 is [[20  4  4  0]
#  [ 3 32  2  1]
#  [ 0  0 10  0]
#  [ 7  5  8  4]]
# Confusion Matrix for Batch = 187 is [[28  2  3  2]
#  [ 4 22  3  1]
#  [ 3  2  7  2]
#  [ 3  3 11  4]]
# Confusion Matrix for Batch = 188 is [[19  4  2  1]
#  [ 0 48  4  2]
#  [ 1  1  1  1]
#  [ 2  3  7  4]]
# Confusion Matrix for Batch = 189 is [[29  4  7  0]
#  [ 4 19  0  2]
#  [ 1  3  3  7]
#  [ 0  2  8 11]]
# Confusion Matrix for Batch = 190 is [[28  4  7  0]
#  [ 5 21  2  1]
#  [ 4  0  7  1]
#  [ 7  2  3  8]]
# Confusion Matrix for Batch = 191 is [[19  5  3  1]
#  [ 4 30  2  4]
#  [ 3  0 12  4]
#  [ 0  1  4  8]]
# Confusion Matrix for Batch = 192 is [[13  6  1  5]
#  [ 3 31  3  1]
#  [ 3  2 12  5]
#  [ 6  1  4  4]]
# Confusion Matrix for Batch = 193 is [[20  4  3  3]
#  [ 4 33  3  0]
#  [ 1  0  9  0]
#  [ 1  2  6 11]]
# Confusion Matrix for Batch = 194 is [[27  3  2  3]
#  [ 1 22  5  1]
#  [ 2  5  9  0]
#  [ 4  2  5  9]]
# Confusion Matrix for Batch = 195 is [[18  3  4  2]
#  [ 4 19  4  3]
#  [ 4  1 11  1]
#  [ 6  4  3 13]]
# Confusion Matrix for Batch = 196 is [[20  0  2  5]
#  [ 4 12  1  1]
#  [ 1  1 13 10]
#  [ 4  3  7 16]]
# Confusion Matrix for Batch = 197 is [[20  0  7  2]
#  [ 2 16  5  4]
#  [ 2  1 11  1]
#  [ 6  1  7 15]]
# Confusion Matrix for Batch = 198 is [[16  4  5  4]
#  [ 4 17  1  2]
#  [ 1  0 10  3]
#  [ 6  2  3 22]]
# Confusion Matrix for Batch = 199 is [[18  5  5  6]
#  [ 5 23  3  1]
#  [ 4  1  6  2]
#  [ 8  1  2 10]]
# Confusion Matrix for Batch = 200 is [[25  1  4  4]
#  [ 4 29  0  2]
#  [ 1  1  7  1]
#  [ 4  1  6 10]]
# Confusion Matrix for Batch = 201 is [[25  6  2  0]
#  [ 0 26  2  2]
#  [ 3  1 10  5]
#  [ 3  3  2 10]]
# Confusion Matrix for Batch = 202 is [[14  4  2  1]
#  [ 6 31  4  2]
#  [ 3  2  7  1]
#  [ 4  2  8  9]]
# Confusion Matrix for Batch = 203 is [[21  3  2  1]
#  [ 2 22  3  3]
#  [ 2  3 14  1]
#  [ 4  3  4 12]]
# Confusion Matrix for Batch = 204 is [[20  1  5  3]
#  [ 0 23  3  1]
#  [ 3  1 19  2]
#  [ 4  2  5  8]]
# Confusion Matrix for Batch = 205 is [[16  1  1  2]
#  [ 5 10  2  3]
#  [ 3  1 21  5]
#  [ 4  1  4 21]]
# Confusion Matrix for Batch = 206 is [[12  1  1  6]
#  [ 3  9  2  6]
#  [ 0  0 11  6]
#  [ 0  4  3 36]]
# Confusion Matrix for Batch = 207 is [[10  1  1  6]
#  [ 1 14  1  2]
#  [ 2  0 25  3]
#  [ 2  2  3 27]]
# Confusion Matrix for Batch = 208 is [[19  1  3  6]
#  [ 4 10  2  7]
#  [ 3  0  9  9]
#  [ 2  0  3 22]]
# Confusion Matrix for Batch = 209 is [[15  1  5  3]
#  [ 5  6  4  3]
#  [ 1  2 17  6]
#  [ 3  1  5 23]]
# Confusion Matrix for Batch = 210 is [[20  2  1  5]
#  [ 6 17  0  3]
#  [ 3  3 11  5]
#  [ 3  2  2 17]]
# Confusion Matrix for Batch = 211 is [[10  1  3  5]
#  [ 0 17  1 10]
#  [ 2  1  9  2]
#  [ 0  2  2 35]]
# Confusion Matrix for Batch = 212 is [[11  3  4  3]
#  [ 3 25  5  5]
#  [ 3  0 12  7]
#  [ 2  3  5  9]]
# Confusion Matrix for Batch = 213 is [[16  1  5  0]
#  [ 5 16  2  7]
#  [ 1  0 12  5]
#  [ 6  4  4 16]]
# Confusion Matrix for Batch = 214 is [[14  1  4  0]
#  [ 3 14  3  4]
#  [ 1  1 24  5]
#  [ 6  3  3 14]]
# Confusion Matrix for Batch = 215 is [[17  6  3  1]
#  [ 4 17  1  4]
#  [ 2  1 16  5]
#  [ 3  2  1 17]]
# Confusion Matrix for Batch = 216 is [[15  1  4  7]
#  [ 3 18  1  4]
#  [ 1  0 21  6]
#  [ 1  0  2 16]]
# Confusion Matrix for Batch = 217 is [[20  2  3  3]
#  [ 3  9  2  2]
#  [ 3  1 16  6]
#  [ 6  0  7 17]]
# Confusion Matrix for Batch = 218 is [[ 6  2  2  9]
#  [ 2 13  2  7]
#  [ 4  1 11  6]
#  [ 2  1  5 27]]
# Confusion Matrix for Batch = 219 is [[24  2  3  6]
#  [ 1  8  4  4]
#  [ 2  2 17  3]
#  [ 2  1  2 19]]
# Confusion Matrix for Batch = 220 is [[ 8  3  3  7]
#  [ 4 14  1  7]
#  [ 5  2  9  7]
#  [ 3  1  3 23]]
# Confusion Matrix for Batch = 221 is [[13  4  7  6]
#  [ 6 18  1  2]
#  [ 4  2 12  2]
#  [ 5  1  3 14]]
# Confusion Matrix for Batch = 222 is [[11  4  2  6]
#  [ 4 14  3  4]
#  [ 4  0 18  1]
#  [ 2  1  4 22]]
# Confusion Matrix for Batch = 223 is [[23  3  4  3]
#  [ 4 23  1  2]
#  [ 1  3 10  3]
#  [ 1  3  4 12]]
# Confusion Matrix for Batch = 224 is [[20  2  4  7]
#  [ 4 28  2  3]
#  [ 0  0 13  3]
#  [ 1  0  3 10]]
# Confusion Matrix for Batch = 225 is [[17  2  7  2]
#  [ 2 20  4  2]
#  [ 1  2 16  0]
#  [ 3  1  5 16]]
# Confusion Matrix for Batch = 226 is [[13  3  3  5]
#  [ 2 18  1  3]
#  [ 0  0 24  3]
#  [ 2  0  7 16]]
# Confusion Matrix for Batch = 227 is [[23  0  5 14]
#  [ 1  2  0  3]
#  [ 2  0  6  5]
#  [ 3  0  6 30]]
# Confusion Matrix for Batch = 228 is [[15  3  4  5]
#  [ 2 19  3  4]
#  [ 1  1 12  5]
#  [ 6  1  4 15]]
# Confusion Matrix for Batch = 229 is [[16  5  4  8]
#  [ 4 10  4  0]
#  [ 2  1 11  6]
#  [ 4  2  6 17]]
# Confusion Matrix for Batch = 230 is [[14  2  6  9]
#  [ 3 17  2  3]
#  [ 0  1 11  6]
#  [ 4  2  2 18]]
# Confusion Matrix for Batch = 231 is [[24  2  2  7]
#  [ 3 16  1  3]
#  [ 6  1 10  4]
#  [ 4  1  4 12]]
# Confusion Matrix for Batch = 232 is [[ 8  3  1 14]
#  [ 0 17  1  2]
#  [ 3  1 13  4]
#  [ 1  1  1 30]]
# Confusion Matrix for Batch = 233 is [[14  4  2  4]
#  [ 1 24  4  3]
#  [ 4  1 13  2]
#  [ 5  4  5 10]]
# Confusion Matrix for Batch = 234 is [[19  2  4  2]
#  [ 3 24  0  5]
#  [ 1  2  8  4]
#  [ 2  9  7  8]]
# Confusion Matrix for Batch = 235 is [[15  0  5  6]
#  [ 2 18  5  3]
#  [ 2  0 19  3]
#  [ 1  1  3 17]]
# Confusion Matrix for Batch = 236 is [[12  4  3  5]
#  [ 3 17  2  4]
#  [ 3  2 16  4]
#  [ 4  3  2 16]]
# Confusion Matrix for Batch = 237 is [[16  1  2  8]
#  [ 2  9  1  5]
#  [ 0  0 14  4]
#  [ 2  1  9 26]]
# Confusion Matrix for Batch = 238 is [[13  2  3  7]
#  [ 3 22  2  3]
#  [ 1  1 20  2]
#  [ 1  1  4 15]]
# Confusion Matrix for Batch = 239 is [[21  4  2  8]
#  [ 2  5  0  1]
#  [ 2  0 15  2]
#  [ 8  0  6 24]]
# Confusion Matrix for Batch = 240 is [[ 9  4  5 11]
#  [ 1 20  2  2]
#  [ 0  1 12  6]
#  [ 3  0  4 20]]
# Confusion Matrix for Batch = 241 is [[17  5  0  9]
#  [ 3 15  0  1]
#  [ 2  0 15  4]
#  [ 1  0  1 27]]
# Confusion Matrix for Batch = 242 is [[16  7  2  1]
#  [ 2 26  3  3]
#  [ 2  0  8  1]
#  [ 6  3  6 14]]
# Confusion Matrix for Batch = 243 is [[22  4  3  4]
#  [ 5 33  3  3]
#  [ 0  0  6  2]
#  [ 4  3  4  4]]
# Confusion Matrix for Batch = 244 is [[28  7  1  2]
#  [ 5 18  1  1]
#  [ 4  2 12  2]
#  [ 3  2  3  9]]
# Confusion Matrix for Batch = 245 is [[22  6  3  3]
#  [ 3 31  3  0]
#  [ 3  1  6  1]
#  [10  1  0  7]]
# Confusion Matrix for Batch = 246 is [[22  6  2  2]
#  [ 6 26  2  0]
#  [ 1  1 11  0]
#  [ 5  7  3  6]]
# Confusion Matrix for Batch = 247 is [[21  3  4  4]
#  [ 1 33  0  3]
#  [ 1  0  2  0]
#  [ 2  2  6 18]]
# Confusion Matrix for Batch = 248 is [[35  2  6  0]
#  [ 2 27  2  3]
#  [ 4  0  8  0]
#  [ 4  1  4  2]]
# Confusion Matrix for Batch = 249 is [[16  3  2  0]
#  [ 5 48  1  1]
#  [ 0  2  6  1]
#  [ 2  4  4  5]]
# Confusion Matrix for Batch = 250 is [[24  3  1  2]
#  [ 7 30  4  1]
#  [ 3  4  4  0]
#  [ 3  4  5  5]]
# Confusion Matrix for Batch = 251 is [[34  4  3  6]
#  [ 4 20  2  2]
#  [ 3  3  8  1]
#  [ 3  1  0  6]]
# Confusion Matrix for Batch = 252 is [[25  0  4  3]
#  [ 6 27  2  2]
#  [ 2  0  3  3]
#  [ 6  3  1 13]]
# Confusion Matrix for Batch = 253 is [[25  2  1  1]
#  [ 5 35  1  0]
#  [ 2  0 13  0]
#  [ 5  1  6  3]]
# Confusion Matrix for Batch = 254 is [[20  3  4  2]
#  [ 3 26  2  1]
#  [ 3  1 11  2]
#  [ 3  5  2 12]]
# Confusion Matrix for Batch = 255 is [[10  5  3  4]
#  [ 4 15  4  2]
#  [ 1  1 24  1]
#  [ 1  3  9 13]]
# Confusion Matrix for Batch = 256 is [[19  3  0  5]
#  [ 7 15  0  3]
#  [ 5  2  8  3]
#  [12  0  3 15]]
# Confusion Matrix for Batch = 257 is [[13  4  6  2]
#  [ 2 17  5  1]
#  [ 0  1  8  6]
#  [ 2  3  5 25]]
# Confusion Matrix for Batch = 258 is [[31  4  1  2]
#  [ 5  7  4  2]
#  [ 3  0 14  2]
#  [ 7  0  5 13]]
# Confusion Matrix for Batch = 259 is [[ 7  1  5  7]
#  [ 3  9  1  3]
#  [ 1  0 12  7]
#  [ 3  0 11 30]]
# Confusion Matrix for Batch = 260 is [[18  3  1  4]
#  [ 6 12  1  4]
#  [ 1  0 17  4]
#  [ 3  0  7 19]]
# Confusion Matrix for Batch = 261 is [[12  5  4  5]
#  [ 0 13  0  7]
#  [ 3  2 13  1]
#  [ 5  0  2 28]]
# Confusion Matrix for Batch = 262 is [[19  1  0  5]
#  [ 3 15  1  1]
#  [ 5  0 11  5]
#  [ 4  0  4 26]]
# Confusion Matrix for Batch = 263 is [[17  5  4  4]
#  [ 2 13  2  1]
#  [ 4  0 21  3]
#  [ 0  2  4 18]]
# Confusion Matrix for Batch = 264 is [[10  6  2  1]
#  [11 16  2  3]
#  [ 3  2 14  3]
#  [ 4  2  3 18]]
# Confusion Matrix for Batch = 265 is [[20  1  2  1]
#  [ 5 23  4  2]
#  [ 3  1 20  4]
#  [ 2  1  3  8]]
# Confusion Matrix for Batch = 266 is [[16  5  3  1]
#  [ 5 20  4  3]
#  [ 3  1 12  2]
#  [ 6  1 11  7]]
# Confusion Matrix for Batch = 267 is [[21  2  5  2]
#  [ 5 20  1  3]
#  [ 2  0 10  5]
#  [ 3  3  5 13]]
# Confusion Matrix for Batch = 268 is [[16  2  1  7]
#  [ 3  8  3  5]
#  [ 4  0 14  5]
#  [ 5  0  4 23]]
# Confusion Matrix for Batch = 269 is [[ 9  1  3  1]
#  [ 1 13  3  7]
#  [ 1  0 33  4]
#  [ 6  0  5 13]]
# Confusion Matrix for Batch = 270 is [[20  3  4  6]
#  [ 6 12  2  1]
#  [ 2  0 18  4]
#  [ 5  2  3 12]]
# Confusion Matrix for Batch = 271 is [[21  2  4  2]
#  [ 8 10  0  1]
#  [ 1  2 14 11]
#  [ 4  0  2 18]]
# Confusion Matrix for Batch = 272 is [[13  0  2  5]
#  [ 2 17  2  4]
#  [ 2  2 13  5]
#  [ 0  3  7 23]]
# Confusion Matrix for Batch = 273 is [[18  3  1  6]
#  [ 3 13  4  5]
#  [ 2  0 15  0]
#  [ 5  0  7 18]]
# Confusion Matrix for Batch = 274 is [[ 8  3  4  2]
#  [ 3 19  0  4]
#  [ 3  1 15  1]
#  [ 5  1  6 25]]
# Confusion Matrix for Batch = 275 is [[22  5  2  6]
#  [ 4 13  1  5]
#  [ 3  2 13  3]
#  [ 1  2  4 14]]
# Confusion Matrix for Batch = 276 is [[13  2  4  6]
#  [ 4 21  2  5]
#  [ 1  3 10  4]
#  [ 0  2  6 17]]
# Confusion Matrix for Batch = 277 is [[22  3  4  5]
#  [ 6 16  2  1]
#  [ 1  0 20  3]
#  [ 4  0  5  8]]
# Confusion Matrix for Batch = 278 is [[13  3  8  2]
#  [ 2 28  0  1]
#  [ 2  0 16  2]
#  [ 1  1  7 14]]
# Confusion Matrix for Batch = 279 is [[17  1  4  1]
#  [ 4 26  2  0]
#  [ 3  0 18  2]
#  [ 4  4  9  5]]
# Confusion Matrix for Batch = 280 is [[16  3  6  2]
#  [ 1 28  3  4]
#  [ 3  0  8  1]
#  [ 5  3  5 12]]
# Confusion Matrix for Batch = 281 is [[23  2  6  4]
#  [ 2 16  2  2]
#  [ 1  0 19  1]
#  [ 2  0 10 10]]
# Confusion Matrix for Batch = 282 is [[13  5  3  2]
#  [ 1 16  1  2]
#  [ 1  1 22  4]
#  [ 2  1  5 21]]
# Confusion Matrix for Batch = 283 is [[18  2  4  7]
#  [ 2  8  2  2]
#  [ 1  0 21  6]
#  [ 3  1  3 20]]
# Confusion Matrix for Batch = 284 is [[14  2  4  3]
#  [ 2 16  2  3]
#  [ 1  1 23  1]
#  [ 4  0  4 20]]
# Confusion Matrix for Batch = 285 is [[12  2  7  6]
#  [ 2 20  0  2]
#  [ 1  0 23  2]
#  [ 4  3  4 12]]
# Confusion Matrix for Batch = 286 is [[ 6  1  4  3]
#  [ 3 18  2  3]
#  [ 5  0 21  6]
#  [ 3  3  3 19]]
# Confusion Matrix for Batch = 287 is [[20  3  2  6]
#  [ 2 14  1  2]
#  [ 1  1 19  2]
#  [ 5  2  4 16]]
# Confusion Matrix for Batch = 288 is [[14  2  3  9]
#  [ 2 15  4  1]
#  [ 4  0 14  4]
#  [ 1  2  5 20]]
# Confusion Matrix for Batch = 289 is [[20  4  3  4]
#  [ 2 19  2  3]
#  [ 2  0  9  7]
#  [ 2  3  2 18]]
# Confusion Matrix for Batch = 290 is [[13  1  4  1]
#  [ 3 21  4  0]
#  [ 0  0 14  1]
#  [ 0  2  8 28]]
# Confusion Matrix for Batch = 291 is [[19  5  1  2]
#  [ 3 28  5  1]
#  [ 2  1 16  1]
#  [ 4  0  6  6]]
# Confusion Matrix for Batch = 292 is [[17  2  3  2]
#  [10 29  1  2]
#  [ 0  1 18  1]
#  [ 2  1  7  4]]
# Confusion Matrix for Batch = 293 is [[22  5 10  2]
#  [ 2 24  3  4]
#  [ 1  1 11  0]
#  [ 3  2  3  7]]
# Confusion Matrix for Batch = 294 is [[26  1  4  3]
#  [ 3 28  1  1]
#  [ 0  1 10  1]
#  [ 1  2  5 13]]
# Confusion Matrix for Batch = 295 is [[17  2  2  9]
#  [ 1 10  3  3]
#  [ 1  0 18  2]
#  [ 5  1  4 22]]
# Confusion Matrix for Batch = 296 is [[11  1  3  6]
#  [ 4 11  3  3]
#  [ 0  2 26  2]
#  [ 3  2  2 21]]
# Confusion Matrix for Batch = 297 is [[17  3  3  3]
#  [ 4 18  0  1]
#  [ 1  1 17  5]
#  [ 3  2  4 18]]
# Confusion Matrix for Batch = 298 is [[10  1  5  3]
#  [ 2 16  3  5]
#  [ 2  2 17  4]
#  [ 6  1  4 19]]
# Confusion Matrix for Batch = 299 is [[17  1  4  2]
#  [ 0 16  4  4]
#  [ 3  1 12  3]
#  [ 1  1  2 29]]
# Confusion Matrix for Batch = 300 is [[ 6  3  5  7]
#  [ 5 19  1  3]
#  [ 0  0 18  4]
#  [ 3  0  5 21]]
# Confusion Matrix for Batch = 301 is [[15  3  3  7]
#  [ 6 12  1  1]
#  [ 2  3 16  4]
#  [ 2  2  1 22]]
# Confusion Matrix for Batch = 302 is [[25  3  9  7]
#  [ 1 16  2  2]
#  [ 4  0  9  1]
#  [ 4  0  3 14]]
# Confusion Matrix for Batch = 303 is [[20  2  5  3]
#  [ 4 26  1  3]
#  [ 0  0  8  5]
#  [ 2  4  7 10]]
# Confusion Matrix for Batch = 304 is [[16  1  7  4]
#  [ 9 24  4  3]
#  [ 1  0 17  2]
#  [ 1  1  2  8]]
# Confusion Matrix for Batch = 305 is [[13  4  7  0]
#  [ 6 32  3  1]
#  [ 1  1 10  2]
#  [ 5  2  3 10]]
# Confusion Matrix for Batch = 306 is [[24  4  4  3]
#  [ 2 16  1  2]
#  [ 2  0 22  4]
#  [ 4  1  0 11]]
# Confusion Matrix for Batch = 307 is [[17  2  6  8]
#  [ 2 10  2  2]
#  [ 0  1 16  6]
#  [ 1  1  3 23]]
# Confusion Matrix for Batch = 308 is [[14  2  5  3]
#  [ 1 12  3  5]
#  [ 1  1 23  3]
#  [ 2  1  4 20]]
# Confusion Matrix for Batch = 309 is [[10  5  3  5]
#  [ 3 13  3  3]
#  [ 3  0 15  3]
#  [ 5  1  3 25]]
# Confusion Matrix for Batch = 310 is [[16  2  3  4]
#  [ 5 17  1  4]
#  [ 3  3 19  6]
#  [ 1  0  5 11]]
# Confusion Matrix for Batch = 311 is [[20  6  4  4]
#  [ 4 17  3  1]
#  [ 1  1 12  3]
#  [ 0  3 10 11]]
# Confusion Matrix for Batch = 312 is [[19  1  5  4]
#  [ 8 11  3  3]
#  [ 1  1 11  8]
#  [ 2  0  3 20]]
# Confusion Matrix for Batch = 313 is [[21  4  3  5]
#  [ 5 19  1  2]
#  [ 0  0 10  3]
#  [ 4  3  5 15]]
# Confusion Matrix for Batch = 314 is [[19  6  3  2]
#  [ 3 29  1  2]
#  [ 3  0  7  4]
#  [ 3  2  3 13]]
# Confusion Matrix for Batch = 315 is [[19  3  1  5]
#  [ 3 28  3  2]
#  [ 1  1 13  1]
#  [ 3  5  6  6]]
# Confusion Matrix for Batch = 316 is [[29  3  4  2]
#  [ 2 29  1  1]
#  [ 1  2  7  2]
#  [ 2  1  3 11]]
# Confusion Matrix for Batch = 317 is [[16  3  6  5]
#  [ 2 39  2  1]
#  [ 0  2  7  1]
#  [ 1  5  3  7]]
# Confusion Matrix for Batch = 318 is [[27  4  0  3]
#  [ 4 15  3  2]
#  [ 3  0 10  1]
#  [ 9  4  2 13]]
# Confusion Matrix for Batch = 319 is [[26  4  1  3]
#  [ 9 26  1  1]
#  [ 4  0  5  1]
#  [ 4  4  5  6]]
# Confusion Matrix for Batch = 320 is [[25  3  3  3]
#  [ 5 38  1  3]
#  [ 3  1  6  0]
#  [ 1  3  1  4]]
# Confusion Matrix for Batch = 321 is [[28  3  3  0]
#  [ 1 38  1  1]
#  [ 1  1  3  2]
#  [12  0  2  4]]
# Confusion Matrix for Batch = 322 is [[20  3  1  1]
#  [ 3 41  6  0]
#  [ 2  0  4  0]
#  [ 1  3  3 12]]
# Confusion Matrix for Batch = 323 is [[26  3  0  4]
#  [ 7 27 10  1]
#  [ 3  0  1  0]
#  [ 6  2  4  6]]
# Confusion Matrix for Batch = 324 is [[29  6  3  2]
#  [ 7 21  3  3]
#  [ 3  2  3  0]
#  [ 5  7  3  3]]
# Confusion Matrix for Batch = 325 is [[32  5  2  1]
#  [ 7 21  0  3]
#  [ 1  1  6  1]
#  [12  0  2  6]]
# Confusion Matrix for Batch = 326 is [[27  2  2  3]
#  [ 5 33  2  1]
#  [ 3  1  2  3]
#  [ 7  3  4  2]]
# Confusion Matrix for Batch = 327 is [[27  3  4  4]
#  [ 3 23  2  2]
#  [ 3  1  6  4]
#  [ 2  0  4 12]]
# Confusion Matrix for Batch = 328 is [[21  7  1  1]
#  [ 4 22  1  1]
#  [ 3  1 11  2]
#  [ 9  2  7  7]]
# Confusion Matrix for Batch = 329 is [[17  0  2  9]
#  [ 5 24  3  2]
#  [ 2  0 13  1]
#  [ 5  3  4 10]]
# Confusion Matrix for Batch = 330 is [[15  1  5  4]
#  [ 7 19  3  1]
#  [ 2  0 16  4]
#  [ 6  1  7  9]]
# Confusion Matrix for Batch = 331 is [[25  0  7  3]
#  [ 2 14  2  1]
#  [ 1  0 14  7]
#  [ 3  2  6 13]]
# Confusion Matrix for Batch = 332 is [[13  2  3  1]
#  [ 4 24  8  3]
#  [ 4  1  7  1]
#  [ 1  2 12 14]]
# Confusion Matrix for Batch = 333 is [[16  1  3  4]
#  [ 3 11  1  1]
#  [ 1  0 22  7]
#  [ 1  2  2 25]]
# Confusion Matrix for Batch = 334 is [[17  2  3  2]
#  [ 2 10  2  3]
#  [ 3  2 26  4]
#  [ 1  0  8 15]]
# Confusion Matrix for Batch = 335 is [[12  3  0  3]
#  [ 0 14  3  1]
#  [ 6  0 18  2]
#  [ 4  1  5 28]]
# Confusion Matrix for Batch = 336 is [[21  2  2  5]
#  [ 1  6  5  1]
#  [ 2  0 13  6]
#  [ 6  1  9 20]]
# Confusion Matrix for Batch = 337 is [[15  3  1  2]
#  [ 4 18  1  2]
#  [ 1  2 15  4]
#  [ 2  2 11 17]]
# Confusion Matrix for Batch = 338 is [[10  6  4  4]
#  [ 6 15  3  1]
#  [ 2  1 20  6]
#  [ 4  1  5 12]]
# Confusion Matrix for Batch = 339 is [[13  3  3  2]
#  [ 6  9  4  6]
#  [ 1  0  7  9]
#  [ 3  3  1 30]]
# Confusion Matrix for Batch = 340 is [[17  4  1  5]
#  [ 3 15  3  4]
#  [ 2  0 16  3]
#  [ 4  1  5 17]]
# Confusion Matrix for Batch = 341 is [[17  2  2  4]
#  [ 7 26  2  3]
#  [ 3  1  9  2]
#  [ 5  0  7 10]]
# Confusion Matrix for Batch = 342 is [[12  4  6  1]
#  [ 2 25  2  0]
#  [ 1  1 14  2]
#  [ 5  1  6 18]]
# Confusion Matrix for Batch = 343 is [[ 9  2  2  7]
#  [ 4 26  2  0]
#  [ 1  1  8  6]
#  [ 3  6  6 17]]
# Confusion Matrix for Batch = 344 is [[23  2  2  2]
#  [ 3 16  0  0]
#  [ 3  2 20  2]
#  [ 3  3  5 14]]
# Confusion Matrix for Batch = 345 is [[11  3  2  9]
#  [ 2 13  1  4]
#  [ 1  0  6  7]
#  [ 5  1  6 29]]
# Confusion Matrix for Batch = 346 is [[12  6  2  7]
#  [ 3 16  3  2]
#  [ 1  0 20  2]
#  [ 2  2  5 17]]
# Confusion Matrix for Batch = 347 is [[11  0  1  4]
#  [ 3  9  2  2]
#  [ 1  0 16  7]
#  [ 3  1  4 36]]
# Confusion Matrix for Batch = 348 is [[13  4  4  4]
#  [ 5 10  2  1]
#  [ 2  0 14  5]
#  [ 4  1  6 25]]
# Confusion Matrix for Batch = 349 is [[17  5  3  5]
#  [ 1 18  0  4]
#  [ 1  0 16  4]
#  [ 3  0  8 15]]
# Confusion Matrix for Batch = 350 is [[12  1  1  4]
#  [ 1 21  3  4]
#  [ 1  0 10  8]
#  [ 7  2  2 23]]
# Confusion Matrix for Batch = 351 is [[17  9  1  4]
#  [ 5 22  2  1]
#  [ 4  2  8  3]
#  [ 2  3  1 16]]
# Confusion Matrix for Batch = 352 is [[12  3  6  1]
#  [ 5 24  1  6]
#  [ 2  0 15  3]
#  [ 6  2  6  8]]
# Confusion Matrix for Batch = 353 is [[21  2  2  1]
#  [ 5 12  6  2]
#  [ 3  1 21  3]
#  [ 4  0  3 14]]
# Confusion Matrix for Batch = 354 is [[16  2  5  4]
#  [ 2 24  5  4]
#  [ 2  0  8  1]
#  [ 5  2  8 12]]
# Confusion Matrix for Batch = 355 is [[23  1  4  4]
#  [ 4 13  1  2]
#  [ 0  1 20  0]
#  [ 4  0  3 20]]
# Confusion Matrix for Batch = 356 is [[20  2  4  2]
#  [ 2  5  1  3]
#  [ 1  0 28  5]
#  [ 5  0  6 16]]
# Confusion Matrix for Batch = 357 is [[17  3  4  2]
#  [ 2 11  3  2]
#  [ 2  0 31  4]
#  [ 2  3  5  9]]
# Confusion Matrix for Batch = 358 is [[19  2  4  4]
#  [ 6 12  3  1]
#  [ 2  1 15  3]
#  [ 5  2  5 16]]
# Confusion Matrix for Batch = 359 is [[18  3  7  4]
#  [ 4 11  3  1]
#  [ 2  1 19  4]
#  [ 2  4  4 13]]
# Confusion Matrix for Batch = 360 is [[15  3  8  4]
#  [ 4  5  2  3]
#  [ 3  1 25  4]
#  [ 1  0  3 19]]
# Confusion Matrix for Batch = 361 is [[18  2  9  4]
#  [ 2 16  7  4]
#  [ 1  0 16  2]
#  [ 4  1  2 12]]
# Confusion Matrix for Batch = 362 is [[13  2  4  5]
#  [ 1 12  4  5]
#  [ 1  0 10  6]
#  [ 2  2  8 25]]
# Confusion Matrix for Batch = 363 is [[25  3  3  1]
#  [ 2 18  4  7]
#  [ 1  2  8  7]
#  [ 2  3  4 10]]
# Confusion Matrix for Batch = 364 is [[21  2  4  8]
#  [ 2 15  2  5]
#  [ 4  0  6  3]
#  [ 4  3  7 14]]
# Confusion Matrix for Batch = 365 is [[16  2  2  3]
#  [ 5 29  4  1]
#  [ 4  0 11  0]
#  [ 5  1  3 14]]
# Confusion Matrix for Batch = 366 is [[16  2  5  2]
#  [ 5 20  5  1]
#  [ 1  0 19  1]
#  [ 0  4  3 16]]
# Confusion Matrix for Batch = 367 is [[19  1  5  2]
#  [ 2 10  1  5]
#  [ 4  1  5  2]
#  [ 3  4 15 21]]
# Confusion Matrix for Batch = 368 is [[18  2  3  2]
#  [ 6 26  4  2]
#  [ 2  0  9  3]
#  [ 3  1  2 17]]
# Confusion Matrix for Batch = 369 is [[19  4  5  6]
#  [ 5  8  2  3]
#  [ 1  0 16  4]
#  [ 2  0  4 21]]
# Confusion Matrix for Batch = 370 is [[16  3  8  5]
#  [ 4  6  1  5]
#  [ 1  1 20  1]
#  [ 5  0  5 19]]
# Confusion Matrix for Batch = 371 is [[15  6  6  3]
#  [ 4 11  3  4]
#  [ 0  1 15  3]
#  [ 7  0  4 18]]
# Confusion Matrix for Batch = 372 is [[21  5  7  4]
#  [ 2  7  0  5]
#  [ 3  1 13  9]
#  [ 1  0  3 19]]
# Confusion Matrix for Batch = 373 is [[15  3  4  5]
#  [ 2 18  1  2]
#  [ 0  0 18  3]
#  [ 4  2  3 20]]
# Confusion Matrix for Batch = 374 is [[10  6  3 11]
#  [ 1  2  3  2]
#  [ 1  0 14  6]
#  [ 7  3  5 26]]
# Confusion Matrix for Batch = 375 is [[19  4  2  3]
#  [ 1 20  1  1]
#  [ 0  0 12  6]
#  [ 4  3  0 24]]
# Confusion Matrix for Batch = 376 is [[13  1  2  7]
#  [ 5 13  2  7]
#  [ 3  0 10  7]
#  [ 3  2  3 22]]
# Confusion Matrix for Batch = 377 is [[16  6  5  2]
#  [ 2 19  0  3]
#  [ 5  1 13  2]
#  [ 7  1  7 11]]
# Confusion Matrix for Batch = 378 is [[15  5  6  1]
#  [ 3 17  2  1]
#  [ 1  2 20  4]
#  [ 7  2  7  7]]
# Confusion Matrix for Batch = 379 is [[19  4  0  5]
#  [ 3 22  4  2]
#  [ 1  0 14  5]
#  [ 4  1  8  8]]
# Confusion Matrix for Batch = 380 is [[13  1  4  1]
#  [ 1 28  2  3]
#  [ 2  2 18  6]
#  [ 2  6  5  6]]
# Confusion Matrix for Batch = 381 is [[12  3  6  4]
#  [ 4 17  7  6]
#  [ 0  0 12  4]
#  [ 4  0  6 15]]
# Confusion Matrix for Batch = 382 is [[10  1  9  5]
#  [ 4 11  0  1]
#  [ 1  1 26  1]
#  [ 5  2  5 18]]
# Confusion Matrix for Batch = 383 is [[14  5  5  7]
#  [ 3  7  3  3]
#  [ 1  0 23  5]
#  [ 1  2  6 15]]
# Confusion Matrix for Batch = 384 is [[20  6  6  6]
#  [ 3 13  1  2]
#  [ 2  0 14  4]
#  [ 4  0  3 16]]
# Confusion Matrix for Batch = 385 is [[19  5  7  2]
#  [ 3 18  2  1]
#  [ 0  0 13  3]
#  [ 3  3  3 18]]
# Confusion Matrix for Batch = 386 is [[16  5  1  2]
#  [ 1  9  5  4]
#  [ 1  0 14  5]
#  [ 3  3  8 23]]
# Confusion Matrix for Batch = 387 is [[16  6  2  7]
#  [ 3 18  2  4]
#  [ 0  1  5  4]
#  [ 4  1  3 24]]
# Confusion Matrix for Batch = 388 is [[29  8  2  7]
#  [ 2 14  0  0]
#  [ 2  0  7  2]
#  [ 2  1  7 17]]
# Confusion Matrix for Batch = 389 is [[22  4  4  2]
#  [ 1 22  4  2]
#  [ 3  2 10  2]
#  [ 3  8  5  6]]
# Confusion Matrix for Batch = 390 is [[22  3  5  2]
#  [ 1 21  3  2]
#  [ 1  0  8  3]
#  [ 6  6  4 13]]
# Confusion Matrix for Batch = 391 is [[18  6  2  1]
#  [ 5 36  3  5]
#  [ 2  0  7  1]
#  [ 1  5  1  7]]
# Confusion Matrix for Batch = 392 is [[25  6  7  1]
#  [ 2 32  0  2]
#  [ 0  1 10  2]
#  [ 2  3  2  5]]
# Confusion Matrix for Batch = 393 is [[21  3  1  3]
#  [ 8 34  1  0]
#  [ 2  2  4  3]
#  [ 6  2  0 10]]
# Confusion Matrix for Batch = 394 is [[28  2  5  2]
#  [ 5 38  4  0]
#  [ 0  0  1  0]
#  [ 5  4  2  4]]
# Confusion Matrix for Batch = 395 is [[22  5  2  4]
#  [ 4 36  3  1]
#  [ 3  0  4  1]
#  [ 1  4  2  8]]
# Confusion Matrix for Batch = 396 is [[21  5  2  2]
#  [ 6 33  0  1]
#  [ 1  0  9  0]
#  [ 5  1  4 10]]
# Confusion Matrix for Batch = 397 is [[18  2  4  2]
#  [ 4 27  5  0]
#  [ 1  2  9  3]
#  [ 2  3 11  7]]
# Confusion Matrix for Batch = 398 is [[31  2  2  3]
#  [11 22  2  0]
#  [ 3  1  3  0]
#  [ 6  3  6  5]]
# Confusion Matrix for Batch = 399 is [[26  1  5  2]
#  [ 5 43  3  1]
#  [ 0  1  3  0]
#  [ 2  3  1  4]]
# Confusion Matrix for Batch = 400 is [[36  3  4  3]
#  [ 7 21  1  2]
#  [ 3  1  3  1]
#  [ 9  1  2  3]]
# Confusion Matrix for Batch = 401 is [[27  5  5  1]
#  [ 1 29  2  4]
#  [ 1  1 10  2]
#  [ 4  2  2  4]]
# Confusion Matrix for Batch = 402 is [[21  5  1  1]
#  [ 5 32  2  1]
#  [ 3  2  7  1]
#  [ 3  1  6  9]]
# Confusion Matrix for Batch = 403 is [[16  3  1  1]
#  [ 6 39  0  1]
#  [ 1  2 13  0]
#  [ 7  3  2  5]]
# Confusion Matrix for Batch = 404 is [[19  6  4  4]
#  [ 5 19  2  2]
#  [ 1  0 11  4]
#  [ 3  3  9  8]]
# Confusion Matrix for Batch = 405 is [[14  4  3  2]
#  [ 5 26  2  3]
#  [ 2  2 13  3]
#  [ 4  1  5 11]]
# Confusion Matrix for Batch = 406 is [[20  4  5  2]
#  [ 4 23  4  1]
#  [ 5  1  8  2]
#  [ 4  2  8  7]]
# Confusion Matrix for Batch = 407 is [[16  0  3  2]
#  [ 4 10  1  3]
#  [ 7  0 19  2]
#  [ 2  0  7 24]]
# Confusion Matrix for Batch = 408 is [[14  2  2  5]
#  [ 2 12  1  3]
#  [ 3  2 25  4]
#  [ 5  2  4 14]]
# Confusion Matrix for Batch = 409 is [[12  0  2  3]
#  [ 6  8  2  4]
#  [ 3  0 19  7]
#  [ 1  1  8 24]]
# Confusion Matrix for Batch = 410 is [[22  1  2  2]
#  [ 2 11  0  1]
#  [ 3  0 19  7]
#  [ 2  1  4 23]]
# Confusion Matrix for Batch = 411 is [[ 7  1  3  5]
#  [ 8 19  1  1]
#  [ 3  0 19  5]
#  [ 6  2  6 14]]
# Confusion Matrix for Batch = 412 is [[11  1  1  3]
#  [ 3 16  1  5]
#  [ 4  1  9  4]
#  [ 2  0  6 33]]
# Confusion Matrix for Batch = 413 is [[14  0  1  0]
#  [ 2 17  1  4]
#  [ 1  0 26  2]
#  [ 3  3  7 19]]
# Confusion Matrix for Batch = 414 is [[12  4  3  4]
#  [ 4 20  1  2]
#  [ 1  1 18  4]
#  [ 3  2  1 20]]
# Confusion Matrix for Batch = 415 is [[ 9  1  2  3]
#  [ 4 16  0  3]
#  [ 2  0 14  8]
#  [ 6  0  2 30]]
# Confusion Matrix for Batch = 416 is [[12  2  2  6]
#  [ 4 18  3  6]
#  [ 3  0  7  4]
#  [ 4  3  2 24]]
# Confusion Matrix for Batch = 417 is [[12  3  7  1]
#  [ 2 27  3  5]
#  [ 2  1 18  1]
#  [ 0  3  2 13]]
# Confusion Matrix for Batch = 418 is [[17  2  1  1]
#  [ 2 28  4  3]
#  [ 1  0 18  2]
#  [ 3  1  6 11]]
# Confusion Matrix for Batch = 419 is [[ 5  2  2  3]
#  [ 2 23  4  3]
#  [ 1  4 18  1]
#  [ 4  1  8 19]]
# Confusion Matrix for Batch = 420 is [[19  2  4  2]
#  [ 3 25  6  2]
#  [ 2  0 11  1]
#  [ 1  5  8  9]]
# Confusion Matrix for Batch = 421 is [[21  2  3  2]
#  [ 3 20  2  4]
#  [ 1  1 15  4]
#  [ 0  2  8 12]]
# Confusion Matrix for Batch = 422 is [[13  2  2  6]
#  [ 1 15  2  2]
#  [ 2  0 12  7]
#  [ 1  1  8 26]]
# Confusion Matrix for Batch = 423 is [[17  2  5  7]
#  [ 5 13  0  3]
#  [ 0  0 15  1]
#  [ 3  0  7 22]]
# Confusion Matrix for Batch = 424 is [[ 7  1  1  7]
#  [ 2 11  2  1]
#  [ 3  0 39  2]
#  [ 5  1  5 13]]
# Confusion Matrix for Batch = 425 is [[18  5  3  3]
#  [ 7  9  3  3]
#  [ 3  0 14  6]
#  [ 5  0  3 18]]
# Confusion Matrix for Batch = 426 is [[ 9  2  5  3]
#  [ 1 19  0  3]
#  [ 1  0 19  7]
#  [ 1  1 11 18]]
# Confusion Matrix for Batch = 427 is [[ 9  1  3  5]
#  [ 7 18  2  5]
#  [ 1  0 11  4]
#  [ 4  1  8 21]]
# Confusion Matrix for Batch = 428 is [[15  0  1  6]
#  [ 4 24  1  4]
#  [ 3  1 13  2]
#  [ 3  3  1 19]]
# Confusion Matrix for Batch = 429 is [[13  1  3  6]
#  [ 2 15  0  4]
#  [ 2  1 22  2]
#  [ 1  3  3 22]]
# Confusion Matrix for Batch = 430 is [[18  1  2  6]
#  [ 4 19  1  3]
#  [ 2  0 10  0]
#  [ 4  0  2 28]]
# Confusion Matrix for Batch = 431 is [[18  1  2  6]
#  [ 3 12  5  5]
#  [ 2  0 11  5]
#  [ 2  2  4 22]]
# Confusion Matrix for Batch = 432 is [[17  6  7  3]
#  [ 3 20  1  1]
#  [ 1  0 18  4]
#  [ 7  3  6  3]]
# Confusion Matrix for Batch = 433 is [[13  1  9  6]
#  [ 3 26  6  3]
#  [ 1  1 16  3]
#  [ 1  0  3  8]]
# Confusion Matrix for Batch = 434 is [[24  6  4  2]
#  [ 5 13  3  1]
#  [ 1  0 17  1]
#  [ 4  4  5 10]]
# Confusion Matrix for Batch = 435 is [[20  1  6  5]
#  [ 1 12  1  3]
#  [ 1  0 23  0]
#  [ 4  2  6 15]]
# Confusion Matrix for Batch = 436 is [[11  1  5 10]
#  [ 2 14  4  1]
#  [ 1  0 15  8]
#  [ 4  1  3 20]]
# Confusion Matrix for Batch = 437 is [[16  1  3  2]
#  [ 3 10  2  2]
#  [ 2  0 23  6]
#  [ 5  1  4 20]]
# Confusion Matrix for Batch = 438 is [[14  1  7  6]
#  [ 4  8  2  5]
#  [ 3  0 24  7]
#  [ 2  2  3 12]]
# Confusion Matrix for Batch = 439 is [[15  2  2  7]
#  [ 1  9  6  4]
#  [ 2  0 17  5]
#  [ 1  2  3 24]]
# Confusion Matrix for Batch = 440 is [[ 9  3  4  8]
#  [ 1 20  4  3]
#  [ 1  0 16  6]
#  [ 2  0  2 21]]
# Confusion Matrix for Batch = 441 is [[13  2  5  2]
#  [ 3 15  1  3]
#  [ 0  1 20  5]
#  [ 1  0  7 22]]
# Confusion Matrix for Batch = 442 is [[18  2  2  6]
#  [ 6 14  3  3]
#  [ 2  1 23  2]
#  [ 2  2  2 12]]
# Confusion Matrix for Batch = 443 is [[17  5  3  5]
#  [ 4 16  2  5]
#  [ 1  0 10  2]
#  [ 1  3  5 21]]
# Confusion Matrix for Batch = 444 is [[ 9  2  1  5]
#  [ 4 23  3  3]
#  [ 0  0 19  1]
#  [ 2  3  3 22]]
# Confusion Matrix for Batch = 445 is [[16  6  4  7]
#  [ 5 18  3  5]
#  [ 2  0 12  1]
#  [ 4  3  5  9]]
# Confusion Matrix for Batch = 446 is [[19  3  4  4]
#  [ 0 18  3  3]
#  [ 2  1 22  2]
#  [ 2  2  4 11]]
# Confusion Matrix for Batch = 447 is [[24  0  5  5]
#  [ 2 13  3  0]
#  [ 1  0 24  3]
#  [ 6  1  5  8]]
# Confusion Matrix for Batch = 448 is [[24  4  3  6]
#  [ 0 20  1  2]
#  [ 1  0 19  0]
#  [ 3  4  5  8]]
# Confusion Matrix for Batch = 449 is [[13  3  3  5]
#  [ 6  9  4  3]
#  [ 2  0 21  5]
#  [ 3  0  4 19]]
# Confusion Matrix for Batch = 450 is [[17  2  4  7]
#  [ 2 12  0  3]
#  [ 1  0 20  2]
#  [ 2  4  4 20]]
# Confusion Matrix for Batch = 451 is [[18  0  5  8]
#  [ 2  6  3  3]
#  [ 6  0 18  3]
#  [ 3  0  6 19]]
# Confusion Matrix for Batch = 452 is [[ 9  2  3  4]
#  [ 2 18  3  5]
#  [ 1  0 22  7]
#  [ 1  1  4 18]]
# Confusion Matrix for Batch = 453 is [[ 8  2  5  6]
#  [ 1 12  3  5]
#  [ 2  1 20  6]
#  [ 4  0  6 19]]
# Confusion Matrix for Batch = 454 is [[11  3  3  4]
#  [ 4 13  2  5]
#  [ 2  0 15  5]
#  [ 3  3  1 26]]
# Confusion Matrix for Batch = 455 is [[15  1  3  8]
#  [ 0 16  0  1]
#  [ 2  0 24  5]
#  [ 4  1  5 15]]
# Confusion Matrix for Batch = 456 is [[11  0  4  7]
#  [ 5 15  2  4]
#  [ 2  1 14  7]
#  [ 3  0  4 21]]
# Confusion Matrix for Batch = 457 is [[15  3  2  4]
#  [ 5 13  0  1]
#  [ 3  0 15  5]
#  [ 1  5  3 25]]
# Confusion Matrix for Batch = 458 is [[19  2  8  4]
#  [ 4 21  1  0]
#  [ 1  0 10  3]
#  [ 4  4  5 14]]
# Confusion Matrix for Batch = 459 is [[19  3  4  3]
#  [ 3 23  2  2]
#  [ 2  0  9  4]
#  [ 4  4  8 10]]
# Confusion Matrix for Batch = 460 is [[ 5  3  3  3]
#  [ 8 23  1  5]
#  [ 2  2 21  6]
#  [ 1  2  3 12]]
# Confusion Matrix for Batch = 461 is [[16  5  5  2]
#  [ 4 25  5  5]
#  [ 0  0 10  3]
#  [ 1  6  6  7]]
# Confusion Matrix for Batch = 462 is [[26  3  4  3]
#  [ 2 14  3  4]
#  [ 1  0 12  4]
#  [ 1  0  2 21]]
# Confusion Matrix for Batch = 463 is [[10  2  5  4]
#  [ 1 16  1  4]
#  [ 1  1 18  2]
#  [ 3  3  5 24]]
# Confusion Matrix for Batch = 464 is [[24  6  5  1]
#  [ 4 12  1  1]
#  [ 0  0 21  3]
#  [ 3  0  6 13]]
# Confusion Matrix for Batch = 465 is [[10  1  1 11]
#  [ 2 19  0  4]
#  [ 2  1 11  6]
#  [ 0  0  4 28]]
# Confusion Matrix for Batch = 466 is [[16  4  3  6]
#  [ 3  8  4  2]
#  [ 0  0 21  5]
#  [ 2  0  7 19]]
# Confusion Matrix for Batch = 467 is [[13  3  5  4]
#  [ 5 19  6  2]
#  [ 0  0 20  1]
#  [ 1  0  6 15]]
# Confusion Matrix for Batch = 468 is [[14  6  6  5]
#  [ 3 14  1  3]
#  [ 0  0 13  7]
#  [ 2  2 11 13]]
# Confusion Matrix for Batch = 469 is [[12  3  4  7]
#  [ 0 16  6  4]
#  [ 2  0 18  6]
#  [ 4  2  5 11]]
# Confusion Matrix for Batch = 470 is [[16  2  7  2]
#  [ 3 21  2  5]
#  [ 6  0  8  5]
#  [ 2  1  8 12]]
# Confusion Matrix for Batch = 471 is [[11  3  2  8]
#  [ 2 26  3  6]
#  [ 1  0  9  1]
#  [ 1  4  5 18]]
# Confusion Matrix for Batch = 472 is [[19  5  2  2]
#  [ 3 33  6  3]
#  [ 1  1 13  3]
#  [ 2  1  3  3]]
# Confusion Matrix for Batch = 473 is [[22  0  9  1]
#  [ 2 32  0  1]
#  [ 2  0 10  2]
#  [ 2  5  4  8]]
# Confusion Matrix for Batch = 474 is [[24  3  1  8]
#  [ 0 32  4  1]
#  [ 4  1  4  2]
#  [ 4  3  2  7]]
# Confusion Matrix for Batch = 475 is [[29  6  3  3]
#  [ 1 22  0  3]
#  [ 2  1  9  3]
#  [ 8  1  4  5]]
# Confusion Matrix for Batch = 476 is [[28  3  5  5]
#  [ 3 20  1  8]
#  [ 3  0  3  4]
#  [ 1  2  1 13]]
# Confusion Matrix for Batch = 477 is [[30  6  5  1]
#  [ 2 34  1  4]
#  [ 2  0  3  1]
#  [ 3  1  4  3]]
# Confusion Matrix for Batch = 478 is [[18  7  3  5]
#  [ 5 40  0  1]
#  [ 0  3  4  0]
#  [ 1  3  3  7]]
# Confusion Matrix for Batch = 479 is [[17  3  2  3]
#  [ 6 40  2  2]
#  [ 2  1  6  0]
#  [ 3  4  4  5]]
# Confusion Matrix for Batch = 480 is [[16  0  4  4]
#  [ 3 35  6  1]
#  [ 3  1  3  2]
#  [ 3  2  9  8]]
# Confusion Matrix for Batch = 481 is [[22  8  2  2]
#  [ 5 27  5  2]
#  [ 3  3  5  0]
#  [ 3  4  2  7]]
# Confusion Matrix for Batch = 482 is [[36  2  3  1]
#  [ 6 18  3  2]
#  [ 3  0  5  0]
#  [ 8  1  4  8]]
# Confusion Matrix for Batch = 483 is [[28  4  4  3]
#  [ 4 24  0  1]
#  [ 4  2  9  1]
#  [ 4  2  2  8]]
# Confusion Matrix for Batch = 484 is [[13  5  8  2]
#  [ 5 27  3  2]
#  [ 1  1 11  3]
#  [ 4  2  3 10]]
# Confusion Matrix for Batch = 485 is [[17  2  2  3]
#  [ 4 33  4  3]
#  [ 4  1  7  0]
#  [ 8  4  3  5]]
# Confusion Matrix for Batch = 486 is [[11  3  8  4]
#  [ 5 28  4  2]
#  [ 1  0 10  0]
#  [ 4  1  9 10]]
# Confusion Matrix for Batch = 487 is [[17  2  6  1]
#  [ 8 16  3  3]
#  [ 4  0 13  1]
#  [ 6  2  5 13]]
# Confusion Matrix for Batch = 488 is [[27  0  5  1]
#  [ 6 23  3  3]
#  [ 1  0  7  2]
#  [ 7  1  7  7]]
# Confusion Matrix for Batch = 489 is [[ 7  0  2  4]
#  [ 3 13  3  5]
#  [ 1  3 11  4]
#  [ 6  2 13 23]]
# Confusion Matrix for Batch = 490 is [[16  0  2  0]
#  [ 5  9  2  8]
#  [ 4  2 16  5]
#  [ 1  2  9 19]]
# Confusion Matrix for Batch = 491 is [[11  0  4  6]
#  [ 0  9  3  7]
#  [ 1  1 21  4]
#  [ 3  0  5 25]]
# Confusion Matrix for Batch = 492 is [[13  1  3  5]
#  [ 4 17  0  6]
#  [ 1  1 19  6]
#  [ 1  3  3 17]]
# Confusion Matrix for Batch = 493 is [[13  1  2  5]
#  [ 2  5  1  5]
#  [ 3  0 22 11]
#  [ 3  3  6 18]]
# Confusion Matrix for Batch = 494 is [[ 5  2  2  3]
#  [ 2 14  1  4]
#  [ 4  0 24  5]
#  [ 2  3 12 17]]
# Confusion Matrix for Batch = 495 is [[12  1  3  3]
#  [ 4 14  2  6]
#  [ 2  0 19  5]
#  [ 3  1  4 21]]
# ...
#  [ 3 12  3  2]
#  [ 0  0 17  3]
#  [ 4  1  3 26]]
# Confusion Matrix for Batch = 1040 is [[13  2  1  4]
#  [ 1 13  4  4]
#  [ 3  2 17  2]
#  [ 0  1  7 26]]
# Confusion Matrix for Batch = 1041 is [[13  1  3  1]
#  [ 0 17  3  5]
#  [ 3  1 13  5]
#  [ 2  0  5 28]]
# Confusion Matrix for Batch = 1042 is [[ 5  2  3  8]
#  [ 0 13  2  9]
#  [ 5  2 22  3]
#  [ 0  1  7 18]]
# Confusion Matrix for Batch = 1043 is [[12  5  6  3]
#  [ 1 22  3  4]
#  [ 0  1 11  5]
#  [ 3  3  4 17]]
# Confusion Matrix for Batch = 1044 is [[11  1  5  1]
#  [ 3 13  1  4]
#  [ 2  0 23  3]
#  [ 4  3  5 21]]
# Confusion Matrix for Batch = 1045 is [[24  3  5  1]
#  [ 3 21  2  1]
#  [ 0  0 10  2]
#  [ 0  2  5 21]]
# Confusion Matrix for Batch = 1046 is [[11  4  2  5]
#  [ 1 20  4  2]
#  [ 5  1 10  8]
#  [ 5  2  3 17]]
# Confusion Matrix for Batch = 1047 is [[16  3  8  0]
#  [ 5 19  4  2]
#  [ 2  2 14  2]
#  [ 2  0  7 14]]
# Confusion Matrix for Batch = 1048 is [[18  0  4  2]
#  [ 3 16  3  1]
#  [ 1  0 16  3]
#  [ 7  4 12 10]]
# Confusion Matrix for Batch = 1049 is [[22  1  1  2]
#  [ 3 25  4  3]
#  [ 3  0 13  3]
#  [ 3  0  7 10]]
# Confusion Matrix for Batch = 1050 is [[12  1  7  5]
#  [ 2 13  3  2]
#  [ 1  1 17  6]
#  [ 2  0  5 23]]
# Confusion Matrix for Batch = 1051 is [[16  0  5  4]
#  [ 2 18  2  0]
#  [ 2  0 24  2]
#  [ 0  0  5 20]]
# Confusion Matrix for Batch = 1052 is [[27  5  2  4]
#  [ 1 15  1  0]
#  [ 4  0 22  0]
#  [ 3  1  5 10]]
# Confusion Matrix for Batch = 1053 is [[17  4  1  3]
#  [ 3 17  1  1]
#  [ 1  1 17  2]
#  [ 4  0  4 24]]
# Confusion Matrix for Batch = 1054 is [[ 8  3  4  6]
#  [ 1  8  5  2]
#  [ 1  1 20  3]
#  [ 3  3  6 26]]
# Confusion Matrix for Batch = 1055 is [[12  1  5  3]
#  [ 4 20  1  3]
#  [ 2  0 21  5]
#  [ 1  2  5 15]]
# Confusion Matrix for Batch = 1056 is [[18  1  1  2]
#  [ 1 12  6  1]
#  [ 1  0 17  2]
#  [ 1  4  8 25]]
# Confusion Matrix for Batch = 1057 is [[13  3  0  5]
#  [ 0 17  2  4]
#  [ 1  1 12  4]
#  [ 4  4  2 28]]
# Confusion Matrix for Batch = 1058 is [[20  2  3  4]
#  [ 1 29  3  0]
#  [ 3  1 13  4]
#  [ 3  1  3 10]]
# Confusion Matrix for Batch = 1059 is [[16  1  3  7]
#  [ 0 25  3  2]
#  [ 2  1 18  0]
#  [ 3  1  2 16]]
# Confusion Matrix for Batch = 1060 is [[10  4  3  2]
#  [ 5 25  3  0]
#  [ 0  2 21  1]
#  [ 5  2 11  6]]
# Confusion Matrix for Batch = 1061 is [[17  0  4  0]
#  [ 3 14  6  4]
#  [ 4  1 25  5]
#  [ 1  2  6  8]]
# Confusion Matrix for Batch = 1062 is [[19  0  3  6]
#  [ 2 16  0  2]
#  [ 4  0 16  5]
#  [ 1  1  4 21]]
# Confusion Matrix for Batch = 1063 is [[13  2  6  1]
#  [ 1 17  2  4]
#  [ 2  0 23  3]
#  [ 2  3  3 18]]
# Confusion Matrix for Batch = 1064 is [[19  1  3 13]
#  [ 2 13  4  2]
#  [ 0  0 14  2]
#  [ 3  2  2 20]]
# Confusion Matrix for Batch = 1065 is [[13  2  3  3]
#  [ 3 17  2  6]
#  [ 1  0 20  4]
#  [ 1  3  5 17]]
# Confusion Matrix for Batch = 1066 is [[19  1  3  5]
#  [ 3 17  2  4]
#  [ 3  0 19  1]
#  [ 5  0  2 16]]
# Confusion Matrix for Batch = 1067 is [[20  1  3  3]
#  [ 0 32  1  1]
#  [ 3  0  8  2]
#  [ 8  2  6 10]]
# Confusion Matrix for Batch = 1068 is [[ 6  1  1 11]
#  [ 2 18  1  5]
#  [ 0  1 17  3]
#  [ 1  2  2 29]]
# Confusion Matrix for Batch = 1069 is [[ 7  0  3  5]
#  [ 4 13  7  5]
#  [ 2  0  9  7]
#  [ 1  3  3 31]]
# Confusion Matrix for Batch = 1070 is [[20  2  5  1]
#  [ 4 27  2  1]
#  [ 2  0 14  3]
#  [ 2  2  5 10]]
# Confusion Matrix for Batch = 1071 is [[24  2  5  1]
#  [ 3 16  3  4]
#  [ 0  0 20  3]
#  [ 3  3  4  9]]
# Confusion Matrix for Batch = 1072 is [[15  1  5  3]
#  [ 2 15  1  2]
#  [ 0  1  9  1]
#  [ 3  1  2 39]]
# Confusion Matrix for Batch = 1073 is [[11  3  5  3]
#  [ 0 21  2  2]
#  [ 0  0 17  2]
#  [ 6  3  7 18]]
# Confusion Matrix for Batch = 1074 is [[15  1  6  1]
#  [ 5 22  4  1]
#  [ 1  0 21  1]
#  [ 1  3  8 10]]
# Confusion Matrix for Batch = 1075 is [[13  0  4  5]
#  [ 1 12  4  3]
#  [ 2  3 17  6]
#  [ 2  6  2 20]]
# Confusion Matrix for Batch = 1076 is [[13  3  2  5]
#  [ 4 15  1  5]
#  [ 3  0 13  4]
#  [ 2  4  0 26]]
# Confusion Matrix for Batch = 1077 is [[15  1  7  2]
#  [ 0 18  3  3]
#  [ 0  2 25  2]
#  [ 5  3  4 10]]
# Confusion Matrix for Batch = 1078 is [[19  1  5  4]
#  [ 2 24  3  3]
#  [ 3  2 18  2]
#  [ 1  1  1 11]]
# Confusion Matrix for Batch = 1079 is [[29  2  4  0]
#  [ 4 26  3  0]
#  [ 1  1 17  1]
#  [ 3  3  4  2]]
# Confusion Matrix for Batch = 1080 is [[16  3  1  4]
#  [ 3 13  6  0]
#  [ 0  0 17  3]
#  [ 3  1  6 24]]
# Confusion Matrix for Batch = 1081 is [[17  1  5  2]
#  [ 3 19  1  2]
#  [ 1  0 20  1]
#  [ 1  1  8 18]]
# Confusion Matrix for Batch = 1082 is [[16  1  3  0]
#  [ 0 14  4  5]
#  [ 1  2 24  4]
#  [ 4  1  2 19]]
# Confusion Matrix for Batch = 1083 is [[13  1  4  4]
#  [ 2 19  5  0]
#  [ 2  0 22  3]
#  [ 1  1  9 14]]
# Confusion Matrix for Batch = 1084 is [[17  2  3 10]
#  [ 1 12  3  5]
#  [ 2  0 18  5]
#  [ 3  2  5 12]]
# Confusion Matrix for Batch = 1085 is [[19  0  3  2]
#  [ 1 21  3  2]
#  [ 0  1 17  6]
#  [ 1  2  3 19]]
# Confusion Matrix for Batch = 1086 is [[ 9  5  4  2]
#  [ 2 17  3  2]
#  [ 1  1  8  4]
#  [ 0  6  3 33]]
# Confusion Matrix for Batch = 1087 is [[16  7  4  4]
#  [ 1 34  4  1]
#  [ 0  1  6  0]
#  [ 4  4  7  7]]
# Confusion Matrix for Batch = 1088 is [[24  4  2  1]
#  [ 2 32  8  0]
#  [ 0  2  5  0]
#  [ 2  3  5 10]]
# Confusion Matrix for Batch = 1089 is [[26  5  1  4]
#  [ 3 23  0  6]
#  [ 3  1 13  3]
#  [ 1  3  3  5]]
# Confusion Matrix for Batch = 1090 is [[19  4  1  5]
#  [ 3 13  2  2]
#  [ 2  0  7  4]
#  [ 3  1  4 30]]
# Confusion Matrix for Batch = 1091 is [[11  2  4  2]
#  [ 4 21  1  2]
#  [ 1  0 20  3]
#  [ 5  2  7 15]]
# Confusion Matrix for Batch = 1092 is [[19  3  2  4]
#  [ 4 14  1  2]
#  [ 0  0 18  3]
#  [ 5  2  4 19]]
# Confusion Matrix for Batch = 1093 is [[13  3  0  4]
#  [ 3 26  3  3]
#  [ 0  0 10  5]
#  [ 5  2  2 21]]
# Confusion Matrix for Batch = 1094 is [[13  2  3  4]
#  [ 2 25  4  1]
#  [ 1  1 17  6]
#  [ 1  0  6 14]]
# Confusion Matrix for Batch = 1095 is [[14  2  4  4]
#  [ 5 34  3  1]
#  [ 1  1  4  3]
#  [ 2  7  8  7]]
# Confusion Matrix for Batch = 1096 is [[17  2  5  3]
#  [ 2 28  2  1]
#  [ 4  0 18  1]
#  [ 5  0  2 10]]
# Confusion Matrix for Batch = 1097 is [[17  5  6  3]
#  [ 1 22  2  2]
#  [ 4  0 21  0]
#  [ 2  3  6  6]]
# Confusion Matrix for Batch = 1098 is [[17  0  2  2]
#  [ 1 26  2  3]
#  [ 1  0 10  6]
#  [ 5  1  6 18]]
# Confusion Matrix for Batch = 1099 is [[19  2  4  3]
#  [ 1 21  3  3]
#  [ 0  0 21  2]
#  [ 2  0  6 13]]
# Confusion Matrix for Batch = 1100 is [[24  4  1  3]
#  [ 2 18  1  5]
#  [ 0  0 20  3]
#  [ 2  1  3 13]]
# Confusion Matrix for Batch = 1101 is [[15  2  2  1]
#  [ 3 17  4  4]
#  [ 1  0 24  4]
#  [ 3  2  7 11]]
# Confusion Matrix for Batch = 1102 is [[10  2  4  6]
#  [ 0 18  1  4]
#  [ 4  0 12  4]
#  [ 2  1  4 28]]
# Confusion Matrix for Batch = 1103 is [[11  1  3  9]
#  [ 2 19  0  6]
#  [ 1  1 18  2]
#  [ 0  1  6 20]]
# Confusion Matrix for Batch = 1104 is [[12  1  6  0]
#  [ 1 24  4  3]
#  [ 1  1 21  3]
#  [ 3  0  7 13]]
# Confusion Matrix for Batch = 1105 is [[26  3  3  3]
#  [ 1 27  3  2]
#  [ 1  0  9  4]
#  [ 2  1  3 12]]
# Confusion Matrix for Batch = 1106 is [[13  3  3  5]
#  [ 1 26  1  4]
#  [ 2  0 10  2]
#  [ 2  2  3 23]]
# Confusion Matrix for Batch = 1107 is [[15  0  4  7]
#  [ 0 22  5  1]
#  [ 0  0 10  7]
#  [ 5  1  2 21]]
# Confusion Matrix for Batch = 1108 is [[19  0  5 10]
#  [ 2 13  6  0]
#  [ 3  1 13  2]
#  [ 6  1  5 14]]
# Confusion Matrix for Batch = 1109 is [[20  3  5  3]
#  [ 5  8  0  3]
#  [ 5  0 22  1]
#  [ 1  3 10 11]]
# Confusion Matrix for Batch = 1110 is [[16  2  5  2]
#  [ 4 18  3  6]
#  [ 1  0 20  2]
#  [ 1  4  6 10]]
# Confusion Matrix for Batch = 1111 is [[11  1  3  3]
#  [ 0 14  4  3]
#  [ 2  0 29  6]
#  [ 7  1  4 12]]
# Confusion Matrix for Batch = 1112 is [[14  2  5  5]
#  [ 5 15  3  3]
#  [ 0  1 24  4]
#  [ 2  3  3 11]]
# Confusion Matrix for Batch = 1113 is [[17  2  2  8]
#  [ 2 14  0  3]
#  [ 1  1  7  6]
#  [ 3  0  4 30]]
# Confusion Matrix for Batch = 1114 is [[ 8  2  3  2]
#  [ 5 18  1  6]
#  [ 2  0 21  5]
#  [ 2  2  4 19]]
# Confusion Matrix for Batch = 1115 is [[11  1  5  9]
#  [ 2 11  3  8]
#  [ 1  0 15  2]
#  [ 5  1  5 21]]
# Confusion Matrix for Batch = 1116 is [[ 9  3  6  2]
#  [ 2 18  4  3]
#  [ 1  0 17  4]
#  [ 2  2  2 25]]
# Confusion Matrix for Batch = 1117 is [[17  5  4  4]
#  [ 3 18  6  1]
#  [ 2  0 12  2]
#  [ 4  3  7 12]]
# Confusion Matrix for Batch = 1118 is [[11  5  8  3]
#  [ 1 28  4  2]
#  [ 2  3 19  0]
#  [ 2  2  4  6]]
# Confusion Matrix for Batch = 1119 is [[14  2  5  4]
#  [ 4 18  2  1]
#  [ 1  5 17  2]
#  [ 3  3  2 17]]
# Confusion Matrix for Batch = 1120 is [[19  2  6  1]
#  [ 3 31  5  1]
#  [ 0  0  8  2]
#  [ 2  2  8 10]]
# Confusion Matrix for Batch = 1121 is [[11  1  2  7]
#  [ 1 21  2  5]
#  [ 3  0 12  2]
#  [ 3  0  7 23]]
# Confusion Matrix for Batch = 1122 is [[12  0  5  5]
#  [ 4 16  4  3]
#  [ 1  0 21  4]
#  [ 2  0  4 19]]
# Confusion Matrix for Batch = 1123 is [[17  2  7  3]
#  [ 2 20  1  3]
#  [ 1  0 11  3]
#  [ 3  2  7 18]]
# Confusion Matrix for Batch = 1124 is [[20  0  3  4]
#  [ 2 16  0  4]
#  [ 2  1 19  4]
#  [ 2  1  5 17]]
# Confusion Matrix for Batch = 1125 is [[16  4  2  3]
#  [ 3 21  3  0]
#  [ 0  0 17  2]
#  [ 3  3  8 15]]
# Confusion Matrix for Batch = 1126 is [[22  0  4  1]
#  [ 1 20  2  3]
#  [ 1  1 22  3]
#  [ 6  1  4  9]]
# Confusion Matrix for Batch = 1127 is [[12  4  0 12]
#  [ 0 12  0  2]
#  [ 2  0  9  8]
#  [ 2  4 10 23]]
# Confusion Matrix for Batch = 1128 is [[10  6  1  4]
#  [ 0 23  3  0]
#  [ 4  0 14  2]
#  [ 7  2 11 13]]
# Confusion Matrix for Batch = 1129 is [[20  3  5  3]
#  [ 4 26  6  2]
#  [ 2  0  9  1]
#  [ 2  6  4  7]]
# Confusion Matrix for Batch = 1130 is [[24  0  6  1]
#  [ 4 22  2  2]
#  [ 3  1 13  4]
#  [ 4  1  4  9]]
# Confusion Matrix for Batch = 1131 is [[21  3  4  2]
#  [ 5 40  1  2]
#  [ 1  0  5  1]
#  [ 7  1  4  3]]
# Confusion Matrix for Batch = 1132 is [[23  0  2  2]
#  [ 2 42  2  1]
#  [ 1  2  4  2]
#  [ 5  4  3  5]]
# Confusion Matrix for Batch = 1133 is [[24  2  2  1]
#  [ 3 38  1  1]
#  [ 1  1  7  0]
#  [ 7  1  6  5]]
# Confusion Matrix for Batch = 1134 is [[19  2  2  2]
#  [ 2 44  0  1]
#  [ 0  0  9  0]
#  [ 2  2  8  7]]
# Confusion Matrix for Batch = 1135 is [[35  1  2  2]
#  [ 3 37  1  0]
#  [ 1  0  1  0]
#  [ 5  2  4  6]]
# Confusion Matrix for Batch = 1136 is [[38  1  5  1]
#  [ 5 19  1  4]
#  [ 0  0  9  2]
#  [ 5  0  1  9]]
# Confusion Matrix for Batch = 1137 is [[24  3  3  5]
#  [ 5 29  1  4]
#  [ 0  0  7  3]
#  [ 3  2  5  6]]
# Confusion Matrix for Batch = 1138 is [[19  4  1  4]
#  [ 8 29  1  2]
#  [ 2  1  8  1]
#  [ 4  2  2 12]]
# Confusion Matrix for Batch = 1139 is [[21  4  4  2]
#  [ 3 26  0  3]
#  [ 0  0 15  0]
#  [ 2  1  8 11]]
# Confusion Matrix for Batch = 1140 is [[16  3  3  2]
#  [ 1 18  3  4]
#  [ 0  0 11  5]
#  [ 7  6  5 16]]
# Confusion Matrix for Batch = 1141 is [[17  0  4  5]
#  [ 2 27  2  0]
#  [ 4  1 16  3]
#  [ 4  2  3 10]]
# Confusion Matrix for Batch = 1142 is [[10  1  4  2]
#  [ 6 18  0  2]
#  [ 4  1 17  5]
#  [ 1  1  3 25]]
# Confusion Matrix for Batch = 1143 is [[ 9  0  4  3]
#  [ 5 16  2  5]
#  [ 2  0 30  2]
#  [ 6  1  5 10]]
# Confusion Matrix for Batch = 1144 is [[13  1  2  6]
#  [ 1 11  0  2]
#  [ 2  0 26  6]
#  [ 0  1  6 23]]
# Confusion Matrix for Batch = 1145 is [[19  0  6  0]
#  [ 3 13  4  3]
#  [ 4  0 23  3]
#  [ 4  2  9  7]]
# Confusion Matrix for Batch = 1146 is [[14  2  1  2]
#  [ 2 19  5  5]
#  [ 1  0 15  4]
#  [ 4  0  8 18]]
# Confusion Matrix for Batch = 1147 is [[13  2  3  2]
#  [ 1 26  2  3]
#  [ 2  0 15  3]
#  [ 4  0  1 23]]
# Confusion Matrix for Batch = 1148 is [[16  3  2  5]
#  [ 4 23  1  1]
#  [ 1  0 17  3]
#  [ 0  1  4 19]]
# Confusion Matrix for Batch = 1149 is [[ 8  1  0  2]
#  [ 1 19  1  7]
#  [ 0  0 10  7]
#  [ 2  0  5 37]]
# Confusion Matrix for Batch = 1150 is [[14  0  2  1]
#  [ 2 24  5  4]
#  [ 1  0 18  3]
#  [ 7  1  7 11]]
# Confusion Matrix for Batch = 1151 is [[12  0  3  0]
#  [ 2 28  3  4]
#  [ 0  0 17  1]
#  [ 2  3  3 22]]
# Confusion Matrix for Batch = 1152 is [[22  2  2  2]
#  [ 0 22  3  0]
#  [ 2  0 13  5]
#  [ 3  3  5 16]]
# Confusion Matrix for Batch = 1153 is [[22  3  3  0]
#  [ 2 16  2  0]
#  [ 2  1 17  1]
#  [ 4  2  9 16]]
# Confusion Matrix for Batch = 1154 is [[22  0  1  5]
#  [ 2 15  0  3]
#  [ 0  1 16  6]
#  [ 0  0  8 21]]
# Confusion Matrix for Batch = 1155 is [[20  0  0  2]
#  [ 2  9  0  6]
#  [ 1  0 19  2]
#  [ 4  0  2 33]]
# Confusion Matrix for Batch = 1156 is [[15  2  1  2]
#  [ 4  4  2  3]
#  [ 3  0 30  7]
#  [ 2  0  3 22]]
# Confusion Matrix for Batch = 1157 is [[10  3  2  2]
#  [ 0 10  1  3]
#  [ 4  0 17  5]
#  [ 2  3 10 28]]
# Confusion Matrix for Batch = 1158 is [[14  0  1  2]
#  [ 2 11  1  6]
#  [ 2  1 22  2]
#  [ 2  1  3 30]]
# Confusion Matrix for Batch = 1159 is [[13  0  3  7]
#  [ 2 16  1  1]
#  [ 3  0 13  9]
#  [ 8  1  3 20]]
# Confusion Matrix for Batch = 1160 is [[15  4  3  2]
#  [ 4 27  2  2]
#  [ 1  3 14  5]
#  [ 3  1  3 11]]
# Confusion Matrix for Batch = 1161 is [[15  2  1  4]
#  [ 3 23  2  2]
#  [ 4  0 20  3]
#  [ 3  3  4 11]]
# Confusion Matrix for Batch = 1162 is [[18  2  0  3]
#  [ 2 22  1  6]
#  [ 4  0 13  4]
#  [ 2  2  3 18]]
# Confusion Matrix for Batch = 1163 is [[21  1  4  1]
#  [ 1 28  4  3]
#  [ 0  1 22  3]
#  [ 1  2  5  3]]
# Confusion Matrix for Batch = 1164 is [[25  1  4  1]
#  [ 1 25  5  1]
#  [ 3  0  9  3]
#  [ 2  4  7  9]]
# Confusion Matrix for Batch = 1165 is [[26  1  5  1]
#  [ 4 15  0  1]
#  [ 0  0 21  2]
#  [ 4  2  3 15]]
# Confusion Matrix for Batch = 1166 is [[13  1  6  1]
#  [ 1  8  5  1]
#  [ 1  1 25  5]
#  [ 4  0 11 17]]
# Confusion Matrix for Batch = 1167 is [[18  2  5  1]
#  [ 0 13  5  3]
#  [ 2  1 23  1]
#  [ 1  5  2 18]]
# Confusion Matrix for Batch = 1168 is [[17  1  7  2]
#  [ 3 17  2  1]
#  [ 2  1 24  5]
#  [ 2  2  6  8]]
# Confusion Matrix for Batch = 1169 is [[23  2  4  0]
#  [ 3 18  3  3]
#  [ 2  0 16  4]
#  [ 3  2  5 12]]
# Confusion Matrix for Batch = 1170 is [[11  0  3  9]
#  [ 1 15  1  1]
#  [ 2  0  9  6]
#  [ 1  2  5 34]]
# Confusion Matrix for Batch = 1171 is [[15  0  4  3]
#  [ 0 20  1  3]
#  [ 0  1 19  2]
#  [ 0  1  5 26]]
# Confusion Matrix for Batch = 1172 is [[18  1  5  4]
#  [ 4 17  1  2]
#  [ 1  3 14  5]
#  [ 5  3  3 14]]
# Confusion Matrix for Batch = 1173 is [[15  3  5  3]
#  [ 8 26  1  4]
#  [ 1  0  9  1]
#  [ 4  1  6 13]]
# Confusion Matrix for Batch = 1174 is [[ 4  2  1  1]
#  [ 2 25  2  1]
#  [ 1  0 19  6]
#  [ 5  4  6 21]]
# Confusion Matrix for Batch = 1175 is [[10  1  5  1]
#  [ 3 23  0  5]
#  [ 0  1 17  1]
#  [ 2  1  5 25]]
# Confusion Matrix for Batch = 1176 is [[16  2  6  2]
#  [ 2 28  2  2]
#  [ 1  1 16  0]
#  [ 0  4 11  7]]
# Confusion Matrix for Batch = 1177 is [[23  4  4  2]
#  [ 4 23  1  3]
#  [ 2  0 12  2]
#  [ 5  4  4  7]]
# Confusion Matrix for Batch = 1178 is [[18  0  5  4]
#  [ 3  6  2  3]
#  [ 3  2 25  1]
#  [ 3  3  4 18]]
# Confusion Matrix for Batch = 1179 is [[20  2  3  4]
#  [ 1 17  2  0]
#  [ 0  0 27  2]
#  [ 7  1  4 10]]
# Confusion Matrix for Batch = 1180 is [[15  1  2  4]
#  [ 1 13  1  4]
#  [ 1  2 35  1]
#  [ 1  0  1 18]]
# Confusion Matrix for Batch = 1181 is [[22  4  3  0]
#  [ 2 17  2  2]
#  [ 3  2 25  1]
#  [ 9  1  2  5]]
# Confusion Matrix for Batch = 1182 is [[13  1  4  3]
#  [ 1 21  3  1]
#  [ 0  0 31  3]
#  [ 1  0  7 11]]
# Confusion Matrix for Batch = 1183 is [[ 7  5  3  4]
#  [ 2 29  1  3]
#  [ 0  0 13  4]
#  [ 0  4  4 21]]
# Confusion Matrix for Batch = 1184 is [[25  2  3  7]
#  [ 0 20  1  3]
#  [ 0  0 10  4]
#  [ 3  0  1 21]]
# Confusion Matrix for Batch = 1185 is [[23  3  3  0]
#  [ 4 29  3  2]
#  [ 1  1 12  1]
#  [ 1  3  5  9]]
# Confusion Matrix for Batch = 1186 is [[23  2  7  0]
#  [ 2 25  1  1]
#  [ 3  0 16  2]
#  [ 2  3  1 12]]
# Confusion Matrix for Batch = 1187 is [[18  1  3  4]
#  [ 0 16  1  4]
#  [ 2  0 18  3]
#  [ 0  4  6 20]]
# Confusion Matrix for Batch = 1188 is [[19  2  3  1]
#  [ 1 31  4  0]
#  [ 0  0 14  2]
#  [ 2  5  6 10]]
# Confusion Matrix for Batch = 1189 is [[27  3  3  4]
#  [ 4 10  1  2]
#  [ 0  0 17  2]
#  [ 6  0  1 20]]
# Confusion Matrix for Batch = 1190 is [[18  0  2  5]
#  [ 4  8  2  2]
#  [ 0  0 16  4]
#  [ 2  1  3 33]]
# Confusion Matrix for Batch = 1191 is [[14  2  2  3]
#  [ 1 16  1  4]
#  [ 1  0 23  1]
#  [ 4  1  4 23]]
# Confusion Matrix for Batch = 1192 is [[16  4  1  6]
#  [ 1 15  3  2]
#  [ 1  0 18  5]
#  [ 1  1  6 20]]
# Confusion Matrix for Batch = 1193 is [[ 9  2  9  7]
#  [ 1 20  3  3]
#  [ 1  0 21  0]
#  [ 1  0  6 17]]
# Confusion Matrix for Batch = 1194 is [[10  0  3  2]
#  [ 2 30  3  0]
#  [ 3  0 18  5]
#  [ 1  1  6 16]]
# Confusion Matrix for Batch = 1195 is [[20  2  4  2]
#  [ 1 28  1  0]
#  [ 2  0 12  1]
#  [ 2  1  6 18]]
# Confusion Matrix for Batch = 1196 is [[20  3  5  1]
#  [ 4 27  3  4]
#  [ 1  2  9  0]
#  [ 6  1  4 10]]
# Confusion Matrix for Batch = 1197 is [[19  0  4  5]
#  [ 7 28  0  1]
#  [ 2  0 10  0]
#  [ 1  7  6 10]]
# Confusion Matrix for Batch = 1198 is [[24  3  4  2]
#  [ 1 28  4  0]
#  [ 1  0 11  2]
#  [ 5  3  4  8]]
# Confusion Matrix for Batch = 1199 is [[22  2  6  2]
#  [ 7 23  0  2]
#  [ 2  0 12  2]
#  [ 2  2  5 11]]
# Training Set Accuracy = 0.6607333333333333	Recall = 0.6607333333333333	Precision = 0.6795405105338129	F1-Score = 0.6598017809919337	Loss = 0.008467479608952999	Confusion Matrix = [[22  2  6  2]
#  [ 7 23  0  2]
#  [ 2  0 12  2]
#  [ 2  2  5 11]]

# %%
batch_size = len(data['Description'])
model.eval()
correct = 0
test_loss = 0
precision = []
f1 = []
recall = []


for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
            else:
                batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()

    pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
    true = y_true.cpu().numpy()
    precision.append(precision_score(pred, true, average='weighted'))
    f1.append(f1_score(pred, true, average='weighted'))
    recall.append(recall_score(pred, true, average='weighted'))
    confusion = confusion_matrix(pred, true)
    print(f"Confusion Matrix for Batch = {i} is {confusion}")

print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Confusion Matrix for Batch = 0 is [[1111  270  292  321]
#  [ 299 1335  202  261]
#  [ 187   97  991  306]
#  [ 303  198  415 1012]]
# Testing Set Accuracy = 0.5853947368421053	Recall = 0.5853947368421053	Precision = 0.5909096952908587	F1-Score = 0.5866057942402126	Loss = 0.0001357786386506632

# %% [markdown]
# # Context Window = 1 Ends

# %%
svd_embeddings = torch.load("svd-word-vectors2.pt")
word_indices = torch.load("svd-word-vectors-indices2.pt")
svd_embeddings, word_indices
# Out:
# (array([[-5.37797350e-14, -2.01467669e-13, -2.08562156e-13, ...,
#          -1.80462108e-25,  4.79097458e-14, -1.49890269e-14],
#         [ 7.85153626e-28, -2.70133484e-14, -2.53050183e-14, ...,
#           6.69037441e-14,  6.01993382e-13,  4.17369076e-13],
#         [ 3.21973660e-18,  4.81106755e-18,  7.23425447e-31, ...,
#           1.00389790e-19,  1.93548197e-20, -9.27567693e-20],
#         ...,
#         [-4.88779219e-20, -3.50257301e-20,  1.67269785e-20, ...,
#          -1.07853147e-21, -1.95833910e-22,  9.58710434e-22],
#         [ 4.74768916e-20,  3.39468553e-20, -1.62689718e-20, ...,
#           1.06544429e-21,  1.79591432e-22, -9.54902989e-22],
#         [ 2.49496885e-20,  1.81164416e-20, -8.65156902e-21, ...,
#           5.43587200e-22,  9.80088934e-23, -4.76045461e-22]]),
#  {'Reuters': 0,
#   '-': 1,
#   'Short': 2,
#   'sellers': 3,
#   ',': 4,
#   'Wall': 5,
#   "Street's": 6,
#   'dwindling': 7,
#   'band': 8,
#   'of': 9,
#   'ultra': 10,
#   'cynics': 11,
#   'are': 12,
#   'seeing': 13,
#   'green': 14,
#   'again': 15,
#   '.': 16,
#   'Private': 17,
#   'investment': 18,
#   'firm': 19,
#   'Carlyle': 20,
#   'Group': 21,
#   'which': 22,
#   'has': 23,
#   'a': 24,
#   'reputation': 25,
#   'for': 26,
#   'making': 27,
#   'well': 28,
#   'timed': 29,
#   'and': 30,
#   'occasionally': 31,
#   'controversial': 32,
#   'plays': 33,
#   'in': 34,
#   'the': 35,
#   'defense': 36,
#   'industry': 37,
#   'quietly': 38,
#   'placed': 39,
#   'its': 40,
#   'bets': 41,
#   'on': 42,
#   'another': 43,
#   'part': 44,
#   'market': 45,
#   'Soaring': 46,
#   'crude': 47,
#   'prices': 48,
#   'plus': 49,
#   'worries': 50,
#   'about': 51,
#   'economy': 52,
#   'outlook': 53,
#   'earnings': 54,
#   'expected': 55,
#   'to': 56,
#   'hang': 57,
#   'over': 58,
#   'stock': 59,
#   'next': 60,
#   'week': 61,
#   'during': 62,
#   'depth': 63,
#   'summer': 64,
#   'doldrums': 65,
#   'Authorities': 66,
#   'have': 67,
#   'halted': 68,
#   'oil': 69,
#   'export': 70,
#   'flows': 71,
#   'from': 72,
#   'main': 73,
#   'pipeline': 74,
#   'southern': 75,
#   'Iraq': 76,
#   'after': 77,
#   'intelligence': 78,
#   'showed': 79,
#   'rebel': 80,
#   'militia': 81,
#   'could': 82,
#   'strike': 83,
#   'infrastructure': 84,
#   'an': 85,
#   'official': 86,
#   'said': 87,
#   'Saturday': 88,
#   'AFP': 89,
#   'Tearaway': 90,
#   'world': 91,
#   'toppling': 92,
#   'records': 93,
#   'straining': 94,
#   'wallets': 95,
#   'present': 96,
#   'new': 97,
#   'economic': 98,
#   'menace': 99,
#   'barely': 100,
#   'three': 101,
#   'months': 102,
#   'before': 103,
#   'US': 104,
#   'presidential': 105,
#   'elections': 106,
#   'Stocks': 107,
#   'ended': 108,
#   'slightly': 109,
#   'higher': 110,
#   'Friday': 111,
#   'but': 112,
#   'stayed': 113,
#   'near': 114,
#   'lows': 115,
#   'year': 116,
#   'as': 117,
#   'surged': 118,
#   'past': 119,
#   '36': 120,
#   ';': 121,
#   '46': 122,
#   'barrel': 123,
#   'offsetting': 124,
#   'positive': 125,
#   'computer': 126,
#   'maker': 127,
#   'Dell': 128,
#   'Inc': 129,
#   'DELL': 130,
#   'O': 131,
#   'AP': 132,
#   'Assets': 133,
#   "nation's": 134,
#   'retail': 135,
#   'money': 136,
#   'mutual': 137,
#   'funds': 138,
#   'fell': 139,
#   'by': 140,
#   '1': 141,
#   '17': 142,
#   'billion': 143,
#   'latest': 144,
#   '849': 145,
#   '98': 146,
#   'trillion': 147,
#   'Investment': 148,
#   'Company': 149,
#   'Institute': 150,
#   'Thursday': 151,
#   'USATODAY': 152,
#   'com': 153,
#   'Retail': 154,
#   'sales': 155,
#   'bounced': 156,
#   'back': 157,
#   'bit': 158,
#   'July': 159,
#   'claims': 160,
#   'jobless': 161,
#   'benefits': 162,
#   'last': 163,
#   'government': 164,
#   'indicating': 165,
#   'is': 166,
#   'improving': 167,
#   'midsummer': 168,
#   'slump': 169,
#   'Forbes': 170,
#   'After': 171,
#   'earning': 172,
#   'PH': 173,
#   'D': 174,
#   'Sociology': 175,
#   'Danny': 176,
#   'Bazil': 177,
#   'Riley': 178,
#   'started': 179,
#   'work': 180,
#   'general': 181,
#   'manager': 182,
#   'at': 183,
#   'commercial': 184,
#   'real': 185,
#   'estate': 186,
#   'annual': 187,
#   'base': 188,
#   'salary': 189,
#   '70': 190,
#   '000': 191,
#   'Soon': 192,
#   'financial': 193,
#   'planner': 194,
#   'stopped': 195,
#   'his': 196,
#   'desk': 197,
#   'drop': 198,
#   'off': 199,
#   'brochures': 200,
#   'insurance': 201,
#   'available': 202,
#   'through': 203,
#   'employer': 204,
#   'But': 205,
#   '32': 206,
#   'buying': 207,
#   'was': 208,
#   'furthest': 209,
#   'thing': 210,
#   'my': 211,
#   'mind': 212,
#   'says': 213,
#   'NEW': 214,
#   'YORK': 215,
#   'TEHRAN': 216,
#   'OPEC': 217,
#   'can': 218,
#   'do': 219,
#   'nothing': 220,
#   'douse': 221,
#   'scorching': 222,
#   'when': 223,
#   'markets': 224,
#   'already': 225,
#   'oversupplied': 226,
#   '2': 227,
#   '8': 228,
#   'million': 229,
#   'barrels': 230,
#   'per': 231,
#   'day': 232,
#   'bpd': 233,
#   "Iran's": 234,
#   'governor': 235,
#   'warning': 236,
#   'that': 237,
#   'fall': 238,
#   'sharply': 239,
#   'JAKARTA': 240,
#   'Non': 241,
#   'exporters': 242,
#   'should': 243,
#   'consider': 244,
#   'increasing': 245,
#   'output': 246,
#   'cool': 247,
#   'record': 248,
#   'President': 249,
#   'Purnomo': 250,
#   'Yusgiantoro': 251,
#   'Sunday': 252,
#   'WASHINGTON': 253,
#   'The': 254,
#   'auction': 255,
#   'Google': 256,
#   "'s": 257,
#   'highly': 258,
#   'anticipated': 259,
#   'initial': 260,
#   'public': 261,
#   'offering': 262,
#   'got': 263,
#   'rocky': 264,
#   'start': 265,
#   'Web': 266,
#   'search': 267,
#   'company': 268,
#   'sidestepped': 269,
#   'bullet': 270,
#   'U': 271,
#   'S': 272,
#   'securities': 273,
#   'regulators': 274,
#   'dollar': 275,
#   'tumbled': 276,
#   'broadly': 277,
#   'data': 278,
#   'showing': 279,
#   'trade': 280,
#   'deficit': 281,
#   'June': 282,
#   'cast': 283,
#   'fresh': 284,
#   'doubts': 285,
#   "economy's": 286,
#   'recovery': 287,
#   'ability': 288,
#   'draw': 289,
#   'foreign': 290,
#   'capital': 291,
#   'fund': 292,
#   'growing': 293,
#   'gap': 294,
#   'If': 295,
#   'you': 296,
#   'think': 297,
#   'may': 298,
#   'need': 299,
#   'help': 300,
#   'your': 301,
#   'elderly': 302,
#   'relatives': 303,
#   'with': 304,
#   'their': 305,
#   'finances': 306,
#   "don't": 307,
#   'be': 308,
#   'shy': 309,
#   'having': 310,
#   'talk': 311,
#   'soon': 312,
#   'purchasing': 313,
#   'power': 314,
#   'kids': 315,
#   'big': 316,
#   'why': 317,
#   'school': 318,
#   'season': 319,
#   'become': 320,
#   'such': 321,
#   'huge': 322,
#   'marketing': 323,
#   'phenomenon': 324,
#   'There': 325,
#   'little': 326,
#   'cause': 327,
#   'celebration': 328,
#   'these': 329,
#   'days': 330,
#   'investors': 331,
#   'value': 332,
#   'focused': 333,
#   'reason': 334,
#   'feel': 335,
#   'smug': 336,
#   'if': 337,
#   'only': 338,
#   'because': 339,
#   "they've": 340,
#   'lost': 341,
#   'less': 342,
#   'than': 343,
#   'folks': 344,
#   'who': 345,
#   'stuck': 346,
#   'growth': 347,
#   'exploded': 348,
#   '19': 349,
#   '55': 350,
#   '8bn': 351,
#   'costs': 352,
#   'drove': 353,
#   'imports': 354,
#   'according': 355,
#   'figures': 356,
#   'Oil': 357,
#   'giant': 358,
#   'Shell': 359,
#   'bracing': 360,
#   'itself': 361,
#   'takeover': 362,
#   'attempt': 363,
#   'possibly': 364,
#   'French': 365,
#   'rival': 366,
#   'Total': 367,
#   'press': 368,
#   'report': 369,
#   'bidding': 370,
#   'gets': 371,
#   'underway': 372,
#   "Google's": 373,
#   'despite': 374,
#   'minute': 375,
#   'interview': 376,
#   'bosses': 377,
#   'Playboy': 378,
#   'magazine': 379,
#   'Official': 380,
#   'show': 381,
#   '12': 382,
#   'nation': 383,
#   'eurozone': 384,
#   'continues': 385,
#   'grow': 386,
#   'there': 387,
#   'warnings': 388,
#   'it': 389,
#   'slow': 390,
#   'down': 391,
#   'later': 392,
#   'Economic': 393,
#   'Japan': 394,
#   'slows': 395,
#   'country': 396,
#   'experiences': 397,
#   'domestic': 398,
#   'corporate': 399,
#   'spending': 400,
#   'Interest': 401,
#   'rates': 402,
#   'trimmed': 403,
#   '7': 404,
#   '5': 405,
#   'South': 406,
#   'African': 407,
#   'central': 408,
#   'bank': 409,
#   'lack': 410,
#   'hits': 411,
#   'rand': 412,
#   'surprises': 413,
#   'cost': 414,
#   'both': 415,
#   'second': 416,
#   'hand': 417,
#   'cars': 418,
#   'five': 419,
#   'years': 420,
#   'survey': 421,
#   'found': 422,
#   "Korea's": 423,
#   'cuts': 424,
#   'interest': 425,
#   'quarter': 426,
#   'percentage': 427,
#   'point': 428,
#   '3': 429,
#   'bid': 430,
#   'drive': 431,
#   'An': 432,
#   'shares': 433,
#   'web': 434,
#   'engine': 435,
#   'floated': 436,
#   'much': 437,
#   '36bn': 438,
#   'takes': 439,
#   'place': 440,
#   'Hewlett': 441,
#   'Packard': 442,
#   'disappointing': 443,
#   'third': 444,
#   'profits': 445,
#   'while': 446,
#   'warns': 447,
#   'final': 448,
#   'will': 449,
#   'also': 450,
#   'short': 451,
#   'expectations': 452,
#   'One': 453,
#   'oldest': 454,
#   'textile': 455,
#   'operators': 456,
#   'Indian': 457,
#   'Ocean': 458,
#   'island': 459,
#   'Mauritius': 460,
#   'shut': 461,
#   'seven': 462,
#   'factories': 463,
#   'cut': 464,
#   '900': 465,
#   'jobs': 466,
#   'Chad': 467,
#   'asks': 468,
#   'IMF': 469,
#   'loan': 470,
#   'pay': 471,
#   'looking': 472,
#   'more': 473,
#   '100': 474,
#   'refugees': 475,
#   'conflict': 476,
#   'torn': 477,
#   'Darfur': 478,
#   'western': 479,
#   'Sudan': 480,
#   'running': 481,
#   'Japanese': 482,
#   'nuclear': 483,
#   'plant': 484,
#   'hit': 485,
#   'fatal': 486,
#   'accident': 487,
#   'close': 488,
#   'reactors': 489,
#   'safety': 490,
#   'checks': 491,
#   'Trevor': 492,
#   'Baylis': 493,
#   'veteran': 494,
#   'inventor': 495,
#   'famous': 496,
#   'creating': 497,
#   'Freeplay': 498,
#   'clockwork': 499,
#   'radio': 500,
#   'planning': 501,
#   'float': 502,
#   'Saudi': 503,
#   'Arabia': 504,
#   'ready': 505,
#   'push': 506,
#   'extra': 507,
#   'into': 508,
#   'reverse': 509,
#   'surging': 510,
#   'A': 511,
#   'group': 512,
#   'led': 513,
#   "UAE's": 514,
#   'Etisalat': 515,
#   'plans': 516,
#   'spend': 517,
#   '1bn': 518,
#   '544m': 519,
#   'expansion': 520,
#   'winning': 521,
#   'two': 522,
#   'mobile': 523,
#   'phone': 524,
#   'licences': 525,
#   'Network': 526,
#   'Rail': 527,
#   'flies': 528,
#   'specialist': 529,
#   'engineers': 530,
#   'West': 531,
#   'Coast': 532,
#   'Mainline': 533,
#   'UK': 534,
#   'skills': 535,
#   'shortage': 536,
#   'BEDFORD': 537,
#   'Scientists': 538,
#   'NitroMed': 539,
#   'hope': 540,
#   'experimental': 541,
#   'drugs': 542,
#   'cure': 543,
#   'heart': 544,
#   'disease': 545,
#   'someday': 546,
#   'lately': 547,
#   'focus': 548,
#   'been': 549,
#   'mundane': 550,
#   'matters': 551,
#   "I've": 552,
#   'submitted': 553,
#   'buy': 554,
#   "company's": 555,
#   'style': 556,
#   'That': 557,
#   'turn': 558,
#   'out': 559,
#   'good': 560,
#   'news': 561,
#   'or': 562,
#   'bad': 563,
#   'Massachusetts': 564,
#   'bargain': 565,
#   'hunters': 566,
#   'up': 567,
#   'droves': 568,
#   'shopped': 569,
#   'hard': 570,
#   "yesterday's": 571,
#   'tax': 572,
#   'holiday': 573,
#   'everything': 574,
#   'treadmills': 575,
#   'snow': 576,
#   'blowers': 577,
#   'candles': 578,
#   'chandeliers': 579,
#   'crediting': 580,
#   'percent': 581,
#   'break': 582,
#   'bringing': 583,
#   'them': 584,
#   'stores': 585,
#   'E': 586,
#   'mail': 587,
#   'victim': 588,
#   'own': 589,
#   'success': 590,
#   "That's": 591,
#   'conclusion': 592,
#   'IBM': 593,
#   'Corp': 594,
#   'researchers': 595,
#   'Cambridge': 596,
#   'spent': 597,
#   'nearly': 598,
#   'decade': 599,
#   'conducting': 600,
#   'field': 601,
#   'tests': 602,
#   'other': 603,
#   'companies': 604,
#   'how': 605,
#   'employees': 606,
#   'use': 607,
#   'electronic': 608,
#   "It's": 609,
#   'clear': 610,
#   'e': 611,
#   "Internet's": 612,
#   'killer': 613,
#   'application': 614,
#   'Even': 615,
#   'genius': 616,
#   'mess': 617,
#   'Bill': 618,
#   'Gates': 619,
#   'brilliant': 620,
#   'technologist': 621,
#   'he': 622,
#   'cofounded': 623,
#   'Microsoft': 624,
#   'guided': 625,
#   'greatness': 626,
#   'size': 627,
#   'historical': 628,
#   'consequence': 629,
#   'blundered': 630,
#   'He': 631,
#   'terrorized': 632,
#   'underlings': 633,
#   'temper': 634,
#   'parceled': 635,
#   'praise': 636,
#   'like': 637,
#   'Scrooge': 638,
#   'gave': 639,
#   'charity': 640,
#   'Only': 641,
#   'lash': 642,
#   'inspired': 643,
#   'necessary': 644,
#   'aggressiveness': 645,
#   'beat': 646,
#   'competition': 647,
#   'thought': 648,
#   'Target': 649,
#   'abusers': 650,
#   'legal': 651,
#   'weapons': 652,
#   'We': 653,
#   'all': 654,
#   'share': 655,
#   'outrage': 656,
#   'expressed': 657,
#   'columnist': 658,
#   'Steve': 659,
#   'Bailey': 660,
#   "''Summer": 661,
#   'Sizzler': 662,
#   'quot': 663,
#   'Aug': 664,
#   '11': 665,
#   'killings': 666,
#   "city's": 667,
#   'poor': 668,
#   'neighborhoods': 669,
#   "there's": 670,
#   'no': 671,
#   'ignorance': 672,
#   'argues': 673,
#   'renewal': 674,
#   'so': 675,
#   'called': 676,
#   'assault': 677,
#   'weapon': 678,
#   'ban': 679,
#   'claiming': 680,
#   'otherwise': 681,
#   "''UZIs": 682,
#   'AK': 683,
#   '47s': 684,
#   'flooding': 685,
#   'streets': 686,
#   'His': 687,
#   'Bush': 688,
#   'saying': 689,
#   "''turned": 690,
#   'corner': 691,
#   'Democratic': 692,
#   'candidate': 693,
#   'Senator': 694,
#   'John': 695,
#   'F': 696,
#   'Kerry': 697,
#   'wake': 698,
#   'this': 699,
#   "month's": 700,
#   'quipped': 701,
#   'Marlborough': 702,
#   'based': 703,
#   'technology': 704,
#   'suing': 705,
#   'former': 706,
#   'including': 707,
#   'senior': 708,
#   'managers': 709,
#   'allegedly': 710,
#   'conspiring': 711,
#   'against': 712,
#   'working': 713,
#   'opening': 714,
#   'competing': 715,
#   'business': 716,
#   'Central': 717,
#   'Square': 718,
#   'Lynn': 719,
#   'brighter': 720,
#   'New': 721,
#   'sidewalks': 722,
#   'curbs': 723,
#   'fences': 724,
#   'lights': 725,
#   'landscaping': 726,
#   'road': 727,
#   'improvements': 728,
#   'planned': 729,
#   'Gateway': 730,
#   'Artisan': 731,
#   'Block': 732,
#   'key': 733,
#   'area': 734,
#   'square': 735,
#   '830': 736,
#   'state': 737,
#   'grant': 738,
#   'given': 739,
#   'lawsuit': 740,
#   'Gary': 741,
#   'Winnick': 742,
#   'chief': 743,
#   'Global': 744,
#   'Crossing': 745,
#   'refocuses': 746,
#   'attention': 747,
#   'what': 748,
#   'Mr': 749,
#   'knew': 750,
#   'imploded': 751,
#   'Russia': 752,
#   'emerging': 753,
#   'superpower': 754,
#   'Kevin': 755,
#   'B': 756,
#   'Rollins': 757,
#   'executive': 758,
#   'talks': 759,
#   "Dell's": 760,
#   'transitory': 761,
#   'slip': 762,
#   'customer': 763,
#   'service': 764,
#   'sees': 765,
#   'broader': 766,
#   'taking': 767,
#   'With': 768,
#   'cash': 769,
#   'rich': 770,
#   'people': 771,
#   'dying': 772,
#   'wealth': 773,
#   'Stein': 774,
#   'proposes': 775,
#   'unique': 776,
#   'solution': 777,
#   'sell': 778,
#   'titles': 779,
#   'nobility': 780,
#   'Quality': 781,
#   'Distribution': 782,
#   'hammered': 783,
#   'reporting': 784,
#   'large': 785,
#   'loss': 786,
#   'Hurricane': 787,
#   'Charley': 788,
#   'blows': 789,
#   'house': 790,
#   'make': 791,
#   '?': 792,
#   'results': 793,
#   "it's": 794,
#   'not': 795,
#   'grim': 796,
#   'tech': 797,
#   'Just': 798,
#   "isn't": 799,
#   'tough': 800,
#   "Detroit's": 801,
#   'troubled': 802,
#   'carmaker': 803,
#   'thanks': 804,
#   'maverick': 805,
#   'designer': 806,
#   'car': 807,
#   'dazzling': 808,
#   'hip': 809,
#   'hop': 810,
#   'crowd': 811,
#   'Americans': 812,
#   'tricking': 813,
#   'places': 814,
#   'where': 815,
#   'they': 816,
#   'swim': 817,
#   "Here's": 818,
#   'look': 819,
#   'wave': 820,
#   'accessories': 821,
#   'In': 822,
#   '1993': 823,
#   'six': 824,
#   'geeks': 825,
#   'had': 826,
#   'digital': 827,
#   'nightmare': 828,
#   'changed': 829,
#   'culture': 830,
#   'get': 831,
#   'far': 832,
#   'creepier': 833,
#   'Celebrity': 834,
#   'fashion': 835,
#   'booming': 836,
#   'These': 837,
#   'webpreneurs': 838,
#   'street': 839,
#   'No': 840,
#   'recording': 841,
#   'artist': 842,
#   'channel': 843,
#   'American': 844,
#   'middle': 845,
#   'class': 846,
#   'tastes': 847,
#   'quite': 848,
#   'Chip': 849,
#   'Davis': 850,
#   'best': 851,
#   'selling': 852,
#   'Got': 853,
#   'problem': 854,
#   'Not': 855,
#   'worry': 856,
#   'find': 857,
#   'every': 858,
#   'specialized': 859,
#   "Today's": 860,
#   'customers': 861,
#   'increasingly': 862,
#   'demanding': 863,
#   'Asia': 864,
#   'elsewhere': 865,
#   'Henry': 866,
#   'Astorga': 867,
#   'describes': 868,
#   'complex': 869,
#   'reality': 870,
#   'faced': 871,
#   "today's": 872,
#   'marketers': 873,
#   'includes': 874,
#   'we': 875,
#   'used': 876,
#   'want': 877,
#   'performance': 878,
#   'now': 879,
#   '!': 880,
#   'Well': 881,
#   'election': 882,
#   'time': 883,
#   'Republic': 884,
#   'Philippines': 885,
#   'means': 886,
#   'monkeys': 887,
#   'rolling': 888,
#   'around': 889,
#   'those': 890,
#   'political': 891,
#   'fun': 892,
#   'laughing': 893,
#   'heads': 894,
#   'strange': 895,
#   'goings': 896,
#   'characterize': 897,
#   'democratic': 898,
#   'process': 899,
#   'loosely': 900,
#   'model': 901,
#   'de': 902,
#   'facto': 903,
#   'looks': 904,
#   'Fellini': 905,
#   'movie': 906,
#   'crossed': 907,
#   'Tom': 908,
#   'Jerry': 909,
#   'cartoon': 910,
#   'column': 911,
#   'useful': 912,
#   'glossary': 913,
#   'Why': 914,
#   'General': 915,
#   'Motors': 916,
#   'dropped': 917,
#   'Oldsmobile': 918,
#   'four': 919,
#   'brand': 920,
#   'paradoxes': 921,
#   'GM': 922,
#   'face': 923,
#   'name': 924,
#   'product': 925,
#   'image': 926,
#   're': 927,
#   'positioning': 928,
#   'consumer': 929,
#   'added': 930,
#   'rebranding': 931,
#   'Although': 932,
#   'smattering': 933,
#   'Chinese': 934,
#   'Filipinos': 935,
#   'Indians': 936,
#   'Thais': 937,
#   'others': 938,
#   'crow': 939,
#   'kind': 940,
#   'sitting': 941,
#   'prominent': 942,
#   'positions': 943,
#   'corporations': 944,
#   'organizations': 945,
#   'USA': 946,
#   'accomplishments': 947,
#   'mere': 948,
#   'cultural': 949,
#   'high': 950,
#   'fives': 951,
#   'ritualistic': 952,
#   'chest': 953,
#   'thumping': 954,
#   'goaded': 955,
#   'impishly': 956,
#   'patronized': 957,
#   "'mainstream": 958,
#   "society'": 959,
#   'milder': 960,
#   'gentler': 961,
#   'term': 962,
#   'white': 963,
#   'dominated': 964,
#   'populace': 965,
#   'Blues': 966,
#   'alive': 967,
#   'evidenced': 968,
#   'appreciation': 969,
#   'Pinoy': 970,
#   "'Lampano": 971,
#   "Alley'": 972,
#   'penned': 973,
#   'Clarence': 974,
#   'Henderson': 975,
#   'counterpoint': 976,
#   'usual': 977,
#   'economics': 978,
#   'fare': 979,
#   'Globalization': 980,
#   'does': 981,
#   'things': 982,
#   'life': 983,
#   'Manila': 984,
#   'consultant': 985,
#   'proving': 986,
#   'really': 987,
#   'CAN': 988,
#   'Muddy': 989,
#   'Walters': 990,
#   'bluegrass': 991,
#   'same': 992,
#   'page': 993,
#   'APMF': 994,
#   'Asian': 995,
#   'tourism': 996,
#   'destinations': 997,
#   'just': 998,
#   'kicked': 999,
#   ...})

# %%
hidden_dim = 256
output_dim = data['Class Index'].unique().shape[0]

model = LSTM(hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
model
# Out:
# LSTM(
#   (lstm): LSTM(50, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-batch_size*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.3389333333333333	Loss = 0.013237746432423592
# Epoch = 1	Training Set Accuracy = 0.5005666666666667	Loss = 0.011424871161580086
# Epoch = 2	Training Set Accuracy = 0.54575	Loss = 0.010722115635871887
# Epoch = 3	Training Set Accuracy = 0.5711416666666667	Loss = 0.010226264595985413
# Epoch = 4	Training Set Accuracy = 0.5905166666666667	Loss = 0.009858565405011177
# Epoch = 5	Training Set Accuracy = 0.6057166666666667	Loss = 0.009568077512085438
# Epoch = 6	Training Set Accuracy = 0.6154166666666666	Loss = 0.009343933314085007
# Epoch = 7	Training Set Accuracy = 0.6267416666666666	Loss = 0.009124214760959148
# Epoch = 8	Training Set Accuracy = 0.6380333333333333	Loss = 0.00887986458837986
# Epoch = 9	Training Set Accuracy = 0.6489583333333333	Loss = 0.008680996485054493

# %%
batch_size = 100
train_loss = 0
correct = 0
model.eval()
for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in word_indices):
                batch_embeddings[k-batch_size*i][j] = oov_embeddings
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = oov_embeddings
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.Tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)]).to(torch.int64)
    loss = criterion(y_pred, y_true-1)
    train_loss += loss

    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()
print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tLoss = {train_loss/len(data['Description'])}")
# Out:
# Testing Set Accuracy = 0.5727631578947369	Loss = 0.010339873842895031

# %%
batch_size = 100
model.train()
precision = []
f1 = []
recall = []
correct = 0
train_loss = 0
import warnings
warnings.filterwarnings('ignore')


confusion = None
with torch.no_grad():
    for i in range(int(len(data_train['Description'])/batch_size)):
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()

        pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
        true = y_true.cpu().numpy()
        precision.append(precision_score(pred, true, average='weighted'))
        f1.append(f1_score(pred, true, average='weighted'))
        recall.append(recall_score(pred, true, average='weighted'))
        confusion = confusion_matrix(pred, true)
        print(f"Confusion Matrix for Batch = {i} is {confusion}")

    print(f"Training Set Accuracy = {correct / len(data_train['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {train_loss/len(data_train['Description'])}\tConfusion Matrix = {confusion}")
# Out:
# Confusion Matrix for Batch = 0 is [[ 0  0 12  8]
#  [ 0  0 10  1]
#  [ 0  0 18  3]
#  [ 0  0 38 10]]
# Confusion Matrix for Batch = 1 is [[ 0  0  0 23]
#  [ 0  0  0 11]
#  [ 0  0  0  2]
#  [ 0  0  0 64]]
# Confusion Matrix for Batch = 2 is [[ 0  0  0 14]
#  [ 0  0  0  8]
#  [ 0  0  0  6]
#  [ 0  0  0 72]]
# Confusion Matrix for Batch = 3 is [[ 0  0  0 14]
#  [ 0  0  0 12]
#  [ 0  0  0  6]
#  [ 0  0  0 68]]
# Confusion Matrix for Batch = 4 is [[ 8  3  0  5]
#  [ 0 36  0  5]
#  [ 0  2  0  7]
#  [ 0  3  0 31]]
# Confusion Matrix for Batch = 5 is [[49  3  0  4]
#  [10 11  0  0]
#  [ 1  1  2  1]
#  [ 4  2  4  8]]
# Confusion Matrix for Batch = 6 is [[32  4  2  1]
#  [ 3 35  3  1]
#  [ 0  0  9  0]
#  [ 6  2  1  1]]
# Confusion Matrix for Batch = 7 is [[27  3  3  1]
#  [ 6 21  1  1]
#  [ 4  1  9  3]
#  [ 2  0  6 12]]
# Confusion Matrix for Batch = 8 is [[15  3  3  3]
#  [ 3  5  0  3]
#  [ 4  0 29  5]
#  [ 4  0  3 20]]
# Confusion Matrix for Batch = 9 is [[24  0  2  8]
#  [ 3  5  1  7]
#  [ 1  0 12  2]
#  [ 6  2  6 21]]
# Confusion Matrix for Batch = 10 is [[21  3  4  3]
#  [ 4 15  3  4]
#  [ 1  2  9  7]
#  [ 7  0  1 16]]
# Confusion Matrix for Batch = 11 is [[15  4  0  7]
#  [ 5 15  2  2]
#  [ 0  1  9  8]
#  [ 8  0  0 24]]
# Confusion Matrix for Batch = 12 is [[21  1  4  2]
#  [ 2 21  1  2]
#  [ 3  0 15  2]
#  [ 4  1  9 12]]
# Confusion Matrix for Batch = 13 is [[24  1  1  4]
#  [ 2 14  0  0]
#  [ 3  0 22  5]
#  [ 5  1  1 17]]
# Confusion Matrix for Batch = 14 is [[16  2  2  4]
#  [ 5  3  2  2]
#  [ 3  0 30  1]
#  [ 3  0  7 20]]
# Confusion Matrix for Batch = 15 is [[20  5  1 11]
#  [ 4 13  0  2]
#  [ 0  1  6  7]
#  [ 4  3  5 18]]
# Confusion Matrix for Batch = 16 is [[ 9  3  5  5]
#  [ 2 17  1  1]
#  [ 2  0 22  3]
#  [ 1  1  7 21]]
# Confusion Matrix for Batch = 17 is [[15  3  1  2]
#  [ 3 22  1  2]
#  [ 3  0 11  2]
#  [ 3  6  8 18]]
# Confusion Matrix for Batch = 18 is [[12  5  4  5]
#  [ 3 16  2  3]
#  [ 2  0 11  2]
#  [ 4  1  2 28]]
# Confusion Matrix for Batch = 19 is [[15  5  1  5]
#  [ 3 10  1  1]
#  [ 2  0 18  1]
#  [ 6  1  5 26]]
# Confusion Matrix for Batch = 20 is [[13  5  3 10]
#  [ 1 10  1  2]
#  [ 2  1 17  3]
#  [ 3  6  4 19]]
# Confusion Matrix for Batch = 21 is [[19  3  4  1]
#  [ 5 27  0  0]
#  [ 1  0 16  2]
#  [ 3  2  4 13]]
# Confusion Matrix for Batch = 22 is [[14  6  4  6]
#  [ 1 30  1  1]
#  [ 1  3 10  1]
#  [ 1  7  9  5]]
# Confusion Matrix for Batch = 23 is [[21  7  3  2]
#  [ 3 19  3  2]
#  [ 0  0 16  1]
#  [ 3  4  5 11]]
# Confusion Matrix for Batch = 24 is [[27  7  2  1]
#  [ 3 17  0  1]
#  [ 6  1 16  1]
#  [ 2  5  5  6]]
# Confusion Matrix for Batch = 25 is [[26  3  4  3]
#  [ 2  6  2  2]
#  [ 0  1 16  1]
#  [ 8  5  6 15]]
# Confusion Matrix for Batch = 26 is [[16  5  5  4]
#  [ 4  3  1  1]
#  [ 1  1 26  1]
#  [ 6  2  7 17]]
# Confusion Matrix for Batch = 27 is [[23  3  5  1]
#  [ 3  9  3  0]
#  [ 1  1 19  1]
#  [ 2  4  8 17]]
# Confusion Matrix for Batch = 28 is [[12  4  6  4]
#  [ 1  5  0  1]
#  [ 0  2 22  2]
#  [ 2  4 12 23]]
# Confusion Matrix for Batch = 29 is [[16  6  2  7]
#  [ 1 11  0  4]
#  [ 0  4 16  3]
#  [ 3  3 13 11]]
# Confusion Matrix for Batch = 30 is [[31  5  0  3]
#  [ 2 14  1  4]
#  [ 0  1  4  3]
#  [ 2  1  5 24]]
# Confusion Matrix for Batch = 31 is [[12  4  5  6]
#  [ 5  7  0  5]
#  [ 2  2 19  3]
#  [ 1  0 10 19]]
# Confusion Matrix for Batch = 32 is [[24  3  2  4]
#  [ 1 14  1  4]
#  [ 2  1 12  4]
#  [ 4  4  5 15]]
# Confusion Matrix for Batch = 33 is [[21  2  0  8]
#  [ 3 18  0  3]
#  [ 1  1 15  0]
#  [ 5  2  6 15]]
# Confusion Matrix for Batch = 34 is [[22  6  1  5]
#  [ 5 21  1  0]
#  [ 1  0 16  3]
#  [ 5  1  5  8]]
# Confusion Matrix for Batch = 35 is [[19  8  3  2]
#  [ 6 12  2  0]
#  [ 4  0 24  3]
#  [ 3  4  4  6]]
# Confusion Matrix for Batch = 36 is [[18  6  3  3]
#  [ 2 21  1  0]
#  [ 3  2 19  2]
#  [ 4  3  7  6]]
# Confusion Matrix for Batch = 37 is [[19  5  2  2]
#  [ 2 16  0  1]
#  [ 0  0  7  4]
#  [ 2  5 11 24]]
# Confusion Matrix for Batch = 38 is [[21  6  2  3]
#  [ 2 10  1  1]
#  [ 1  0 23  4]
#  [ 2  3  8 13]]
# Confusion Matrix for Batch = 39 is [[ 7  5 11  3]
#  [ 1  4  3  2]
#  [ 0  0 32  7]
#  [ 0  0 13 12]]
# Confusion Matrix for Batch = 40 is [[17  5  0  9]
#  [ 2  9  0  7]
#  [ 1  1  1  3]
#  [ 3  0  1 41]]
# Confusion Matrix for Batch = 41 is [[22  3  7  5]
#  [ 2  6  1  6]
#  [ 0  1 20  2]
#  [ 1  0 11 13]]
# Confusion Matrix for Batch = 42 is [[12  6  1  6]
#  [ 1 11  1  0]
#  [ 1  0  7  7]
#  [ 3  5  4 35]]
# Confusion Matrix for Batch = 43 is [[12  3  5  7]
#  [ 2 17  1  2]
#  [ 3  0  8  2]
#  [ 0  7  8 23]]
# Confusion Matrix for Batch = 44 is [[ 8  8  4  0]
#  [ 2 18  3  3]
#  [ 4  1 17  2]
#  [ 1  4 12 13]]
# Confusion Matrix for Batch = 45 is [[ 8  3  5  0]
#  [ 6 20  3  4]
#  [ 2  2 21  2]
#  [ 2  4  5 13]]
# Confusion Matrix for Batch = 46 is [[17  6  5  1]
#  [ 3 10  2  0]
#  [ 0  0 23  1]
#  [ 3  4 10 15]]
# Confusion Matrix for Batch = 47 is [[23  4  3  0]
#  [ 2 28  0  1]
#  [ 3  0 11  1]
#  [ 1  2  7 14]]
# Confusion Matrix for Batch = 48 is [[28  4  3  2]
#  [ 3 11  1  4]
#  [ 2  1 11  4]
#  [ 8  2  2 14]]
# Confusion Matrix for Batch = 49 is [[17  6  3  2]
#  [ 4 18  1  3]
#  [ 2  3 14  1]
#  [ 6  2  6 12]]
# Confusion Matrix for Batch = 50 is [[20  3  5  5]
#  [ 3 10  2  6]
#  [ 0  0 17  2]
#  [ 3  2  7 15]]
# Confusion Matrix for Batch = 51 is [[12  2  4  6]
#  [ 7 19  1  2]
#  [ 3  0 14  3]
#  [ 2  4  5 16]]
# Confusion Matrix for Batch = 52 is [[17  5  4  4]
#  [ 2 11  3  2]
#  [ 3  0 16  3]
#  [ 4  1  7 18]]
# Confusion Matrix for Batch = 53 is [[25  5  3  5]
#  [ 5 13  0  4]
#  [ 1  0 11  1]
#  [ 1  0  3 23]]
# Confusion Matrix for Batch = 54 is [[19  2  8  0]
#  [ 4 29  2  0]
#  [ 2  2  8  0]
#  [ 3  4  7 10]]
# Confusion Matrix for Batch = 55 is [[28  7  3  4]
#  [ 3 21  1  0]
#  [ 2  1  1  1]
#  [ 7  5  4 12]]
# Confusion Matrix for Batch = 56 is [[17  4  2  5]
#  [ 5 16  1  3]
#  [ 2  3  9  3]
#  [ 2  2  9 17]]
# Confusion Matrix for Batch = 57 is [[25  4  6  2]
#  [ 6 23  4  3]
#  [ 0  0  8  2]
#  [ 5  1  5  6]]
# Confusion Matrix for Batch = 58 is [[27  1  0  0]
#  [ 6 37  4  1]
#  [ 4  2  4  5]
#  [ 1  3  3  2]]
# Confusion Matrix for Batch = 59 is [[29  4  5  1]
#  [ 3 24  2  2]
#  [ 2  0  9  5]
#  [ 2  0  6  6]]
# Confusion Matrix for Batch = 60 is [[27  1  6  1]
#  [ 1 35  2  0]
#  [ 2  2  9  0]
#  [ 3  1  3  7]]
# Confusion Matrix for Batch = 61 is [[ 7  2  1  2]
#  [10 42  4  2]
#  [ 1  2  5  0]
#  [ 3  6  7  6]]
# Confusion Matrix for Batch = 62 is [[23  4  5  5]
#  [ 3 22  6  4]
#  [ 1  2  4  1]
#  [ 2  3  9  6]]
# Confusion Matrix for Batch = 63 is [[27  3  3  1]
#  [ 0 26  4  0]
#  [ 2  4  9  1]
#  [ 2  5  6  7]]
# Confusion Matrix for Batch = 64 is [[27  5  3  1]
#  [12 25  2  1]
#  [ 5  0  4  1]
#  [ 3  1  4  6]]
# Confusion Matrix for Batch = 65 is [[17  6  7  1]
#  [ 5 22  0  4]
#  [ 0  1  7  4]
#  [ 7  5  4 10]]
# Confusion Matrix for Batch = 66 is [[26 10  1  1]
#  [ 6 30  3  0]
#  [ 3  2  4  1]
#  [ 6  1  3  3]]
# Confusion Matrix for Batch = 67 is [[12  2  5  1]
#  [ 5 36  1  3]
#  [ 3  1  2  4]
#  [ 9  4  2 10]]
# Confusion Matrix for Batch = 68 is [[19  7  6  2]
#  [ 4 28  3  0]
#  [ 3  1 13  1]
#  [ 5  3  4  1]]
# Confusion Matrix for Batch = 69 is [[14  3  6  1]
#  [ 4 23  5  2]
#  [ 3  1 10  0]
#  [ 2  4  5 17]]
# Confusion Matrix for Batch = 70 is [[15  4  4  3]
#  [ 2 29  4  2]
#  [ 3  1 13  3]
#  [ 5  3  5  4]]
# Confusion Matrix for Batch = 71 is [[15  9  3  2]
#  [ 2 21  8  2]
#  [ 3  2  8  2]
#  [ 0  2 14  7]]
# Confusion Matrix for Batch = 72 is [[17  4  3  2]
#  [ 2 28  0  0]
#  [ 4  4 13  2]
#  [ 1  5  3 12]]
# Confusion Matrix for Batch = 73 is [[14  4  8  2]
#  [ 2 20  3  3]
#  [ 5  1 14  2]
#  [ 4  1  5 12]]
# Confusion Matrix for Batch = 74 is [[17  2  1  1]
#  [ 5 13  3  2]
#  [ 2  1 26  3]
#  [ 3  0  6 15]]
# Confusion Matrix for Batch = 75 is [[10  3  2  3]
#  [ 4  8  4  0]
#  [ 7  1 24  4]
#  [ 3  0  5 22]]
# Confusion Matrix for Batch = 76 is [[18  6  4  1]
#  [ 5  9  4  1]
#  [ 4  2 15  4]
#  [ 4  3  1 19]]
# Confusion Matrix for Batch = 77 is [[13  5  5  2]
#  [ 3 15  1  5]
#  [ 2  2 15  2]
#  [ 2  3  4 21]]
# Confusion Matrix for Batch = 78 is [[14  1  4  4]
#  [ 2 14  1  0]
#  [ 1  0 14 10]
#  [ 4  0 12 19]]
# Confusion Matrix for Batch = 79 is [[11  2  5  6]
#  [ 2  9  4  3]
#  [ 1  1 17  4]
#  [ 3  1  5 26]]
# Confusion Matrix for Batch = 80 is [[11  7  4  5]
#  [ 2 15  0  0]
#  [ 2  0 16  8]
#  [ 5  2  5 18]]
# Confusion Matrix for Batch = 81 is [[13  2  1  2]
#  [10 23  3  1]
#  [ 2  0 19  1]
#  [ 1  2  5 15]]
# Confusion Matrix for Batch = 82 is [[15  3  3  1]
#  [ 5 25  2  0]
#  [ 3  3  6  5]
#  [ 5  2  9 13]]
# Confusion Matrix for Batch = 83 is [[13  4  4  1]
#  [ 1 21  6  1]
#  [ 1  1 19  3]
#  [ 3  3  8 11]]
# Confusion Matrix for Batch = 84 is [[21  1 11  1]
#  [ 0 19  0  1]
#  [ 1  0 20  4]
#  [ 2  2  8  9]]
# Confusion Matrix for Batch = 85 is [[16  3  4  1]
#  [ 1 24  2  2]
#  [ 1  0 15  5]
#  [ 2  2  9 13]]
# Confusion Matrix for Batch = 86 is [[19  1  2  2]
#  [ 4 14  2  4]
#  [ 5  0 17  0]
#  [ 6  1  4 19]]
# Confusion Matrix for Batch = 87 is [[10  1  4  1]
#  [ 7 15  0  3]
#  [ 2  0 21  2]
#  [ 6  0  5 23]]
# Confusion Matrix for Batch = 88 is [[14  3  1  7]
#  [ 5 13  3  1]
#  [ 1  0 23  3]
#  [ 1  3  5 17]]
# Confusion Matrix for Batch = 89 is [[ 8  3  3  3]
#  [ 4 16  1  4]
#  [ 1  0 18  7]
#  [ 5  2  5 20]]
# Confusion Matrix for Batch = 90 is [[ 9  2  4  5]
#  [ 4 14  1  3]
#  [ 1  0 28  4]
#  [ 2  0  6 17]]
# Confusion Matrix for Batch = 91 is [[10  4  2  3]
#  [ 3 14  1  4]
#  [ 1  0 18  7]
#  [ 1  0  8 24]]
# Confusion Matrix for Batch = 92 is [[12  6  5  7]
#  [ 2 12  1  5]
#  [ 0  1 17  7]
#  [ 1  2  9 13]]
# Confusion Matrix for Batch = 93 is [[14  4  0  2]
#  [12 18  1  3]
#  [ 1  1  5  4]
#  [ 7  3  4 21]]
# Confusion Matrix for Batch = 94 is [[13  1  3  5]
#  [ 3 10  1  4]
#  [ 1  1 20  6]
#  [ 1  2  1 28]]
# Confusion Matrix for Batch = 95 is [[12  3  1  7]
#  [ 2 14  4  3]
#  [ 1  0 10  5]
#  [ 1  2  7 28]]
# Confusion Matrix for Batch = 96 is [[14  7  4  2]
#  [ 5 10  1  3]
#  [ 7  0 13  8]
#  [ 2  0  4 20]]
# Confusion Matrix for Batch = 97 is [[11  4  1  4]
#  [ 7 11  2  5]
#  [ 1  0 17  8]
#  [ 4  2  3 20]]
# Confusion Matrix for Batch = 98 is [[ 5  5  1  2]
#  [ 4  8  3  9]
#  [ 2  0 22  8]
#  [ 2  1  3 25]]
# Confusion Matrix for Batch = 99 is [[11  5  3  1]
#  [ 1 12  2  3]
#  [ 0  1 16  9]
#  [ 4  0  6 26]]
# Confusion Matrix for Batch = 100 is [[13  5  7  3]
#  [ 6 12  2  4]
#  [ 0  0 18  5]
#  [ 2  2  3 18]]
# Confusion Matrix for Batch = 101 is [[17  0  4  4]
#  [ 5 21  2  3]
#  [ 1  1 14  3]
#  [ 3  0  7 15]]
# Confusion Matrix for Batch = 102 is [[16  3  5  2]
#  [ 3 24  2  2]
#  [ 1  0 18  4]
#  [ 3  4  4  9]]
# Confusion Matrix for Batch = 103 is [[20  5  2  2]
#  [ 6 19  4  2]
#  [ 4  1 10  7]
#  [ 4  1  5  8]]
# Confusion Matrix for Batch = 104 is [[20  3  1  1]
#  [ 1 21  3  2]
#  [ 3  1 21  0]
#  [ 4  3 10  6]]
# Confusion Matrix for Batch = 105 is [[17  3  2  7]
#  [ 0 10  2  4]
#  [ 4  1 12  5]
#  [ 0  1  5 27]]
# Confusion Matrix for Batch = 106 is [[ 7  3  3  3]
#  [ 3 16  3  3]
#  [ 2  1 28  3]
#  [ 2  1  1 21]]
# Confusion Matrix for Batch = 107 is [[17  1  5  7]
#  [ 1 10  4  4]
#  [ 3  2 15  0]
#  [ 7  0  5 19]]
# Confusion Matrix for Batch = 108 is [[15  0  4  2]
#  [ 3 15  3  2]
#  [ 1  1 22  5]
#  [ 2  1  3 21]]
# Confusion Matrix for Batch = 109 is [[15  5  5  8]
#  [ 1  8  1  1]
#  [ 0  1 20  8]
#  [ 2  1  8 16]]
# Confusion Matrix for Batch = 110 is [[12  0  3  7]
#  [ 2  6  3  4]
#  [ 2  1 18  6]
#  [ 2  0  6 28]]
# Confusion Matrix for Batch = 111 is [[15  6  3  5]
#  [ 4 17  3  2]
#  [ 1  3 12  4]
#  [ 2  1  4 18]]
# Confusion Matrix for Batch = 112 is [[19  5  3  2]
#  [ 4 20  2  5]
#  [ 0  1 20  4]
#  [ 2  4  3  6]]
# Confusion Matrix for Batch = 113 is [[13  3  4  3]
#  [ 4 22  4  4]
#  [ 0  1 16  5]
#  [ 4  2  5 10]]
# Confusion Matrix for Batch = 114 is [[15  4  9  4]
#  [ 3 18  5  1]
#  [ 3  4 15  3]
#  [ 1  1  7  7]]
# Confusion Matrix for Batch = 115 is [[16  3  3  2]
#  [ 2 22  3  4]
#  [ 3  1 11  6]
#  [ 2  1  9 12]]
# Confusion Matrix for Batch = 116 is [[16  3  3  6]
#  [ 6 23  1  3]
#  [ 1  3 11  4]
#  [ 6  2  4  8]]
# Confusion Matrix for Batch = 117 is [[ 8  6  3  4]
#  [ 3 19  3  1]
#  [ 1  2 12  3]
#  [ 3  6  7 19]]
# Confusion Matrix for Batch = 118 is [[19  2  3  3]
#  [ 1 13  3  1]
#  [ 2  2 14  7]
#  [ 6  0  3 21]]
# Confusion Matrix for Batch = 119 is [[10  4  2  7]
#  [ 2 12  4  3]
#  [ 1  0 22  7]
#  [ 3  1  3 19]]
# Confusion Matrix for Batch = 120 is [[14  5  6  6]
#  [ 3 11  3  4]
#  [ 0  4 15  3]
#  [ 3  2  6 15]]
# Confusion Matrix for Batch = 121 is [[18  2  4  6]
#  [ 3 12  1  3]
#  [ 0  1 11  4]
#  [ 4  4  6 21]]
# Confusion Matrix for Batch = 122 is [[13  7  6  4]
#  [ 5 17  1  4]
#  [ 1  0 10  3]
#  [ 2  0  7 20]]
# Confusion Matrix for Batch = 123 is [[17  3  2  4]
#  [ 5 18  1  1]
#  [ 0  5 11  7]
#  [ 1  1  2 22]]
# Confusion Matrix for Batch = 124 is [[19  3  4  2]
#  [ 4 16  0  0]
#  [ 2  1 12  6]
#  [ 2  2  1 26]]
# Confusion Matrix for Batch = 125 is [[13  8  2  9]
#  [ 3 19  1  1]
#  [ 0  1 13  2]
#  [ 0  2  4 22]]
# Confusion Matrix for Batch = 126 is [[12  2  8  4]
#  [ 1 23  2  3]
#  [ 4  3  9  2]
#  [ 3  6  2 16]]
# Confusion Matrix for Batch = 127 is [[15  5  4  2]
#  [ 5 33  7  1]
#  [ 3  0  3  2]
#  [ 5  5  4  6]]
# Confusion Matrix for Batch = 128 is [[22  4  2  2]
#  [ 2 32  2  2]
#  [ 1  1  6  2]
#  [ 4  6  3  9]]
# Confusion Matrix for Batch = 129 is [[19  8  5  0]
#  [ 4 26  2  1]
#  [ 3  1  7  2]
#  [ 4  6  4  8]]
# Confusion Matrix for Batch = 130 is [[25  6  2  2]
#  [ 4 23  3  1]
#  [ 2  3  8  3]
#  [ 5  3  2  8]]
# Confusion Matrix for Batch = 131 is [[27  4  3  7]
#  [ 8 23  3  1]
#  [ 1  5  2  1]
#  [ 7  3  1  4]]
# Confusion Matrix for Batch = 132 is [[25  8  4  2]
#  [ 3 38  1  0]
#  [ 3  2  0  1]
#  [ 5  2  1  5]]
# Confusion Matrix for Batch = 133 is [[17  8  3  0]
#  [ 9 31  3  0]
#  [ 0  1  2  0]
#  [ 6  8  6  6]]
# Confusion Matrix for Batch = 134 is [[23  6  0  3]
#  [ 6 36  1  2]
#  [ 1  2  2  1]
#  [ 5  6  2  4]]
# Confusion Matrix for Batch = 135 is [[24  2  3  1]
#  [ 8 21  1  1]
#  [ 1  3  9  2]
#  [ 7  1  4 12]]
# Confusion Matrix for Batch = 136 is [[25  4  4  0]
#  [ 4 24  5  0]
#  [ 1  4  2  2]
#  [ 3  6  9  7]]
# Confusion Matrix for Batch = 137 is [[37  5  1  3]
#  [ 3 16  2  2]
#  [ 1  2  4  3]
#  [ 8  2  5  6]]
# Confusion Matrix for Batch = 138 is [[28 10  4  3]
#  [ 5 29  3  0]
#  [ 2  1  2  1]
#  [ 4  2  2  4]]
# Confusion Matrix for Batch = 139 is [[31  7  3  1]
#  [ 5 24  1  1]
#  [ 2  3  5  0]
#  [ 5  3  0  9]]
# Confusion Matrix for Batch = 140 is [[27  6  1  4]
#  [ 6 31  0  2]
#  [ 1  2  4  2]
#  [ 2  5  1  6]]
# Confusion Matrix for Batch = 141 is [[21  2  5  3]
#  [ 7 26  3  3]
#  [ 3  2 12  2]
#  [ 4  0  3  4]]
# Confusion Matrix for Batch = 142 is [[20  4  3  6]
#  [ 4 22  2  0]
#  [ 0  2 11  2]
#  [ 2  2  8 12]]
# Confusion Matrix for Batch = 143 is [[20  2  2  1]
#  [ 3 31  1  0]
#  [ 2  1  9  4]
#  [ 1  6  9  8]]
# Confusion Matrix for Batch = 144 is [[17  0  5  1]
#  [ 8 22  2  2]
#  [ 4  1  7  1]
#  [ 9  2  7 12]]
# Confusion Matrix for Batch = 145 is [[13  4  2  0]
#  [ 3 15  0  8]
#  [ 2  0 15  0]
#  [ 8  4  8 18]]
# Confusion Matrix for Batch = 146 is [[17  0  1  4]
#  [ 2  8  5  1]
#  [ 5  2 23  4]
#  [ 4  0  2 22]]
# Confusion Matrix for Batch = 147 is [[21  3  4  2]
#  [ 1 11  2  3]
#  [ 3  0 14  4]
#  [ 3  2  8 19]]
# Confusion Matrix for Batch = 148 is [[15  2  2  8]
#  [ 6  5  0  5]
#  [ 4  2 20  4]
#  [ 5  4  3 15]]
# Confusion Matrix for Batch = 149 is [[18  1  4  2]
#  [ 3 18  2  2]
#  [ 0  2 14  5]
#  [ 4  1  8 16]]
# Confusion Matrix for Batch = 150 is [[ 8  4  2  8]
#  [ 4 15  1  3]
#  [ 1  1 13  4]
#  [ 3  2  6 25]]
# Confusion Matrix for Batch = 151 is [[ 7  0  1  8]
#  [ 4  8  1  8]
#  [ 2  0 13  3]
#  [ 7  1  6 31]]
# Confusion Matrix for Batch = 152 is [[14  0  1  2]
#  [ 4 24  1  1]
#  [ 1  3 16  5]
#  [ 9  3  4 12]]
# Confusion Matrix for Batch = 153 is [[ 9  4  2  2]
#  [ 4 19  4  2]
#  [ 0  1 13  7]
#  [ 5  1  8 19]]
# Confusion Matrix for Batch = 154 is [[14  2  1  2]
#  [ 6 20  3  3]
#  [ 1  0 14  3]
#  [ 5  2  2 22]]
# Confusion Matrix for Batch = 155 is [[15  0  5  3]
#  [ 5 10  1  5]
#  [ 1  3 25  4]
#  [ 4  2  1 16]]
# Confusion Matrix for Batch = 156 is [[14  1  4  3]
#  [ 1 10  2  5]
#  [ 0  1 17  6]
#  [ 4  2  2 28]]
# Confusion Matrix for Batch = 157 is [[15  1  3  5]
#  [ 0  8  2  4]
#  [ 0  1 22  7]
#  [ 3  3  5 21]]
# Confusion Matrix for Batch = 158 is [[14  3 10  2]
#  [ 2 11  2  1]
#  [ 2  2 12  6]
#  [ 7  3  9 14]]
# Confusion Matrix for Batch = 159 is [[ 6  2  4 11]
#  [ 3  9  7  5]
#  [ 1  0  6  4]
#  [ 5  1  5 31]]
# Confusion Matrix for Batch = 160 is [[15  1  4  3]
#  [ 7 30  3  2]
#  [ 0  2 10  8]
#  [ 4  5  1  5]]
# Confusion Matrix for Batch = 161 is [[13  5  2  4]
#  [ 3 13  0  3]
#  [ 3  0 16  6]
#  [ 3  2  2 25]]
# Confusion Matrix for Batch = 162 is [[25  0  4  4]
#  [ 7 12  2  5]
#  [ 2  2 10  2]
#  [ 5  5  6  9]]
# Confusion Matrix for Batch = 163 is [[11  2  2  6]
#  [ 3  6  1  2]
#  [ 1  0 22  7]
#  [ 1  0  7 29]]
# Confusion Matrix for Batch = 164 is [[21  2  4  1]
#  [ 2 21  2  4]
#  [ 2  0 19  2]
#  [ 4  3  3 10]]
# Confusion Matrix for Batch = 165 is [[12  1  2  9]
#  [ 0  8  1  2]
#  [ 0  0  6  4]
#  [ 3  1  5 46]]
# Confusion Matrix for Batch = 166 is [[ 6  1  1  7]
#  [ 5 18  0  7]
#  [ 1  1 13  6]
#  [ 1  2  5 26]]
# Confusion Matrix for Batch = 167 is [[20  1  1  5]
#  [ 3 20  2  5]
#  [ 3  0  7  2]
#  [ 4  2  1 24]]
# Confusion Matrix for Batch = 168 is [[19  2  5  1]
#  [ 3 29  2  3]
#  [ 1  1 14  3]
#  [ 2  2  2 11]]
# Confusion Matrix for Batch = 169 is [[20  3  1  4]
#  [ 3 21  1  4]
#  [ 2  0 13  3]
#  [ 6  5  4 10]]
# Confusion Matrix for Batch = 170 is [[18  5  2  2]
#  [ 2 19  0  3]
#  [ 1  1  6  6]
#  [ 4  2  3 26]]
# Confusion Matrix for Batch = 171 is [[23  2  5  7]
#  [ 7  6  3  0]
#  [ 3  1 20  4]
#  [ 3  1  9  6]]
# Confusion Matrix for Batch = 172 is [[10  2  0  5]
#  [ 2 12  2  2]
#  [ 1  1 13 11]
#  [ 3  0  3 33]]
# Confusion Matrix for Batch = 173 is [[12  2  3  8]
#  [ 3 24  1  2]
#  [ 2  0 16  6]
#  [ 2  0  0 19]]
# Confusion Matrix for Batch = 174 is [[13  3  7  0]
#  [ 3 23  4  0]
#  [ 2  0 18  0]
#  [ 4  9  8  6]]
# Confusion Matrix for Batch = 175 is [[11  2  4  5]
#  [ 1  8  2  8]
#  [ 0  1  8 14]
#  [ 0  0  1 35]]
# Confusion Matrix for Batch = 176 is [[23  0  2  1]
#  [ 2  9  1  6]
#  [ 3  0 18  2]
#  [10  1  4 18]]
# Confusion Matrix for Batch = 177 is [[12  5  4  5]
#  [ 0 14  0  3]
#  [ 3  1 23  9]
#  [ 2  0  2 17]]
# Confusion Matrix for Batch = 178 is [[21  1  6  5]
#  [ 2 17  3  3]
#  [ 6  0  9  5]
#  [ 4  1  3 14]]
# Confusion Matrix for Batch = 179 is [[18  0  1  4]
#  [ 3 12  0  4]
#  [ 0  1  6 10]
#  [ 3  1  3 34]]
# Confusion Matrix for Batch = 180 is [[20  2  3  3]
#  [ 2 26  2  3]
#  [ 2  0 12  1]
#  [ 3  3  4 14]]
# Confusion Matrix for Batch = 181 is [[19  7  4  1]
#  [ 6 31  2  1]
#  [ 0  0  7  1]
#  [ 3  1  3 14]]
# Confusion Matrix for Batch = 182 is [[29  3  3  1]
#  [ 3 28  0  2]
#  [ 0  1 11  3]
#  [ 3  1  5  7]]
# Confusion Matrix for Batch = 183 is [[24  3  4  5]
#  [ 3 34  6  4]
#  [ 0  0  4  1]
#  [ 1  4  1  6]]
# Confusion Matrix for Batch = 184 is [[36  1  5  3]
#  [ 1 21  2  0]
#  [ 1  0  8  4]
#  [ 8  1  2  7]]
# Confusion Matrix for Batch = 185 is [[26  1  3  3]
#  [ 6 36  2  0]
#  [ 0  3  6  0]
#  [ 2  0  1 11]]
# Confusion Matrix for Batch = 186 is [[18  4  4  0]
#  [ 6 30  3  1]
#  [ 1  0 10  1]
#  [ 5  7  7  3]]
# Confusion Matrix for Batch = 187 is [[27  4  3  1]
#  [ 3 22  4  1]
#  [ 2  1  8  2]
#  [ 6  2  9  5]]
# Confusion Matrix for Batch = 188 is [[17  3  1  2]
#  [ 3 48  4  1]
#  [ 1  1  5  0]
#  [ 1  4  4  5]]
# Confusion Matrix for Batch = 189 is [[29  4  4  0]
#  [ 3 16  0  3]
#  [ 0  3  7  5]
#  [ 2  5  7 12]]
# Confusion Matrix for Batch = 190 is [[27  3  6  0]
#  [ 6 23  1  1]
#  [ 2  0  6  3]
#  [ 9  1  6  6]]
# Confusion Matrix for Batch = 191 is [[16  3  3  2]
#  [ 5 30  2  6]
#  [ 1  1 11  4]
#  [ 4  2  5  5]]
# Confusion Matrix for Batch = 192 is [[13  5  1  4]
#  [ 6 32  3  3]
#  [ 0  2 11  3]
#  [ 6  1  5  5]]
# Confusion Matrix for Batch = 193 is [[20  5  5  2]
#  [ 4 30  3  0]
#  [ 0  2 10  3]
#  [ 2  2  3  9]]
# Confusion Matrix for Batch = 194 is [[23  3  4  1]
#  [ 3 23  6  1]
#  [ 4  4  6  5]
#  [ 4  2  5  6]]
# Confusion Matrix for Batch = 195 is [[22  0  4  3]
#  [ 1 15  4  2]
#  [ 3  5 10  4]
#  [ 6  7  4 10]]
# Confusion Matrix for Batch = 196 is [[19  0  4  9]
#  [ 4 13  1  1]
#  [ 1  0 12  8]
#  [ 5  3  6 14]]
# Confusion Matrix for Batch = 197 is [[21  0  9  2]
#  [ 4 12  2  2]
#  [ 4  3 15  0]
#  [ 1  3  4 18]]
# Confusion Matrix for Batch = 198 is [[17  2  3  6]
#  [ 5 18  1  4]
#  [ 2  2  9  4]
#  [ 3  1  6 17]]
# Confusion Matrix for Batch = 199 is [[25  3  7  2]
#  [ 2 22  1  1]
#  [ 2  1  4  1]
#  [ 6  4  4 15]]
# Confusion Matrix for Batch = 200 is [[21  0  5  2]
#  [ 4 27  1  3]
#  [ 3  1  6  3]
#  [ 6  4  5  9]]
# Confusion Matrix for Batch = 201 is [[24  3  3  4]
#  [ 4 27  3  3]
#  [ 2  3  8  2]
#  [ 1  3  2  8]]
# Confusion Matrix for Batch = 202 is [[14  6  4  2]
#  [ 7 28  3  3]
#  [ 2  3  7  1]
#  [ 4  2  7  7]]
# Confusion Matrix for Batch = 203 is [[20  2  3  0]
#  [ 2 21  3  5]
#  [ 3  5 14  1]
#  [ 4  3  3 11]]
# Confusion Matrix for Batch = 204 is [[18  1  4  5]
#  [ 0 20  6  0]
#  [ 3  1 18  1]
#  [ 6  5  4  8]]
# Confusion Matrix for Batch = 205 is [[16  0  1  2]
#  [ 5  9  3  0]
#  [ 3  1 21  8]
#  [ 4  3  3 21]]
# Confusion Matrix for Batch = 206 is [[10  3  1 11]
#  [ 3  8  2  7]
#  [ 1  1 11  1]
#  [ 1  2  3 35]]
# Confusion Matrix for Batch = 207 is [[ 9  1  0  7]
#  [ 0 13  2  7]
#  [ 2  0 25  2]
#  [ 4  3  3 22]]
# Confusion Matrix for Batch = 208 is [[19  0  2  6]
#  [ 3 11  1  7]
#  [ 3  0  6  7]
#  [ 3  0  8 24]]
# Confusion Matrix for Batch = 209 is [[15  2  6  3]
#  [ 5  5  3  5]
#  [ 0  1 15  7]
#  [ 4  2  7 20]]
# Confusion Matrix for Batch = 210 is [[22  0  1  5]
#  [ 6 18  1  1]
#  [ 1  3 10  6]
#  [ 3  3  2 18]]
# Confusion Matrix for Batch = 211 is [[11  2  3  8]
#  [ 0 14  2  6]
#  [ 1  2  8  8]
#  [ 0  3  2 30]]
# Confusion Matrix for Batch = 212 is [[10  4  4  5]
#  [ 4 23  3  6]
#  [ 2  2 14  6]
#  [ 3  2  5  7]]
# Confusion Matrix for Batch = 213 is [[16  1  3  1]
#  [ 4 17  1  3]
#  [ 4  0 11  5]
#  [ 4  3  8 19]]
# Confusion Matrix for Batch = 214 is [[13  2  4  4]
#  [ 3 15  1  3]
#  [ 3  0 21  4]
#  [ 5  2  8 12]]
# Confusion Matrix for Batch = 215 is [[20  7  3  2]
#  [ 0 15  1  4]
#  [ 3  2 14  4]
#  [ 3  2  3 17]]
# Confusion Matrix for Batch = 216 is [[14  2  1  4]
#  [ 1 15  1  6]
#  [ 2  1 25  7]
#  [ 3  1  1 16]]
# Confusion Matrix for Batch = 217 is [[20  2  1  3]
#  [ 1  8  2  3]
#  [ 7  0 20  6]
#  [ 4  2  5 16]]
# Confusion Matrix for Batch = 218 is [[ 7  2  3  7]
#  [ 1 13  1  7]
#  [ 3  2 13  6]
#  [ 3  0  3 29]]
# Confusion Matrix for Batch = 219 is [[23  3  2  4]
#  [ 1  6  3  5]
#  [ 0  2 16  5]
#  [ 5  2  5 18]]
# Confusion Matrix for Batch = 220 is [[14  1  3  4]
#  [ 2 15  2  4]
#  [ 1  3  8  3]
#  [ 3  1  3 33]]
# Confusion Matrix for Batch = 221 is [[17  2  7  6]
#  [ 6 20  2  2]
#  [ 0  2 12  4]
#  [ 5  1  2 12]]
# Confusion Matrix for Batch = 222 is [[12  3  5  1]
#  [ 6 14  3  4]
#  [ 2  1 16  1]
#  [ 1  1  3 27]]
# Confusion Matrix for Batch = 223 is [[20  4  6  3]
#  [ 3 23  1  1]
#  [ 3  4  9  5]
#  [ 3  1  3 11]]
# Confusion Matrix for Batch = 224 is [[19  5  2  4]
#  [ 2 22  3  2]
#  [ 2  1 13  8]
#  [ 2  2  4  9]]
# Confusion Matrix for Batch = 225 is [[18  2  4  2]
#  [ 2 18  5  3]
#  [ 0  1 16  0]
#  [ 3  4  7 15]]
# Confusion Matrix for Batch = 226 is [[15  1  2  2]
#  [ 0 19  1  4]
#  [ 0  1 25  4]
#  [ 2  0  7 17]]
# Confusion Matrix for Batch = 227 is [[21  0  5 11]
#  [ 1  2  0  7]
#  [ 0  0 10  7]
#  [ 7  0  2 27]]
# Confusion Matrix for Batch = 228 is [[16  2  3  4]
#  [ 4 19  2  5]
#  [ 1  1 12  6]
#  [ 3  2  6 14]]
# Confusion Matrix for Batch = 229 is [[17  3  3  6]
#  [ 4 13  1  1]
#  [ 2  0 15  1]
#  [ 3  2  6 23]]
# Confusion Matrix for Batch = 230 is [[12  0  4  7]
#  [ 2 17  3  1]
#  [ 3  1 12  5]
#  [ 4  4  2 23]]
# Confusion Matrix for Batch = 231 is [[25  2  2  6]
#  [ 6 14  0  5]
#  [ 3  0 10  3]
#  [ 3  4  5 12]]
# Confusion Matrix for Batch = 232 is [[ 6  2  1 15]
#  [ 1 17  2  5]
#  [ 3  1 11  4]
#  [ 2  2  2 26]]
# Confusion Matrix for Batch = 233 is [[15  2  2  3]
#  [ 1 24  4  2]
#  [ 2  0 13  4]
#  [ 6  7  5 10]]
# Confusion Matrix for Batch = 234 is [[17  3  3  3]
#  [ 2 25  0  2]
#  [ 2  3 12  5]
#  [ 4  6  4  9]]
# Confusion Matrix for Batch = 235 is [[15  0  4  5]
#  [ 1 19  3  2]
#  [ 2  0 20  5]
#  [ 2  0  5 17]]
# Confusion Matrix for Batch = 236 is [[11  5  3  6]
#  [ 3 17  3  1]
#  [ 2  2 14  2]
#  [ 6  2  3 20]]
# Confusion Matrix for Batch = 237 is [[13  0  3  5]
#  [ 3 10  4  6]
#  [ 0  1 14  4]
#  [ 4  0  5 28]]
# Confusion Matrix for Batch = 238 is [[10  2  2  4]
#  [ 2 22  3  4]
#  [ 3  0 20  3]
#  [ 3  2  4 16]]
# Confusion Matrix for Batch = 239 is [[17  3  4  6]
#  [ 3  5  0  2]
#  [ 3  0 14  1]
#  [10  1  5 26]]
# Confusion Matrix for Batch = 240 is [[ 8  4  3  9]
#  [ 2 19  3  3]
#  [ 1  2 15 10]
#  [ 2  0  2 17]]
# Confusion Matrix for Batch = 241 is [[18  6  3  6]
#  [ 4 12  0  4]
#  [ 0  2  9  4]
#  [ 1  0  4 27]]
# Confusion Matrix for Batch = 242 is [[14  3  2  1]
#  [ 3 29  3  1]
#  [ 3  2  9  3]
#  [ 6  2  5 14]]
# Confusion Matrix for Batch = 243 is [[22  3  5  2]
#  [ 6 34  2  5]
#  [ 2  0  5  1]
#  [ 1  3  4  5]]
# Confusion Matrix for Batch = 244 is [[32  3  5  3]
#  [ 3 19  3  2]
#  [ 1  1  8  1]
#  [ 4  6  1  8]]
# Confusion Matrix for Batch = 245 is [[23  3  2  2]
#  [ 3 34  1  2]
#  [ 3  0  7  0]
#  [ 9  2  2  7]]
# Confusion Matrix for Batch = 246 is [[19  1  5  2]
#  [ 4 33  3  1]
#  [ 3  3  7  0]
#  [ 8  3  3  5]]
# Confusion Matrix for Batch = 247 is [[15  2  3  3]
#  [ 4 32  1  3]
#  [ 1  1  3  2]
#  [ 5  3  5 17]]
# Confusion Matrix for Batch = 248 is [[36  1  2  0]
#  [ 3 29  4  3]
#  [ 2  0  8  0]
#  [ 4  0  6  2]]
# Confusion Matrix for Batch = 249 is [[17  5  2  0]
#  [ 2 48  2  1]
#  [ 0  1  5  2]
#  [ 4  3  4  4]]
# Confusion Matrix for Batch = 250 is [[24  4  0  1]
#  [ 5 24  3  0]
#  [ 3  5  3  3]
#  [ 5  8  8  4]]
# Confusion Matrix for Batch = 251 is [[35  1  2  5]
#  [ 4 24  1  0]
#  [ 1  1  8  1]
#  [ 4  2  2  9]]
# Confusion Matrix for Batch = 252 is [[22  0  3  3]
#  [ 7 26  1  3]
#  [ 4  0  4  1]
#  [ 6  4  2 14]]
# Confusion Matrix for Batch = 253 is [[23  1  0  2]
#  [ 7 32  1  0]
#  [ 2  2 13  0]
#  [ 5  3  7  2]]
# Confusion Matrix for Batch = 254 is [[20  3  4  3]
#  [ 2 26  3  1]
#  [ 5  2 10  2]
#  [ 2  4  2 11]]
# Confusion Matrix for Batch = 255 is [[ 8  2  3  3]
#  [ 4 20  2  2]
#  [ 2  0 24  1]
#  [ 2  2 11 14]]
# Confusion Matrix for Batch = 256 is [[23  4  0  5]
#  [ 9 14  1  1]
#  [ 5  1  8  3]
#  [ 6  1  2 17]]
# Confusion Matrix for Batch = 257 is [[12  0  7  3]
#  [ 2 19  2  3]
#  [ 1  2 10  6]
#  [ 2  4  5 22]]
# Confusion Matrix for Batch = 258 is [[26  3  3  1]
#  [10  7  1  2]
#  [ 5  1 15  3]
#  [ 5  0  5 13]]
# Confusion Matrix for Batch = 259 is [[ 5  1  5  5]
#  [ 3  9  1  2]
#  [ 2  0 12  7]
#  [ 4  0 11 33]]
# Confusion Matrix for Batch = 260 is [[21  2  1  3]
#  [ 5 11  3  4]
#  [ 0  0 18  5]
#  [ 2  2  4 19]]
# Confusion Matrix for Batch = 261 is [[10  5  2  4]
#  [ 4 10  0  5]
#  [ 3  1 14  1]
#  [ 3  4  3 31]]
# Confusion Matrix for Batch = 262 is [[21  1  2  4]
#  [ 4 13  1  4]
#  [ 4  1 11  4]
#  [ 2  1  2 25]]
# Confusion Matrix for Batch = 263 is [[12  1  2  2]
#  [ 4 18  3  3]
#  [ 4  0 18  7]
#  [ 3  1  8 14]]
# Confusion Matrix for Batch = 264 is [[14  6  3  1]
#  [ 6 17  3  3]
#  [ 3  2 13  0]
#  [ 5  1  2 21]]
# Confusion Matrix for Batch = 265 is [[23  1  1  2]
#  [ 3 23  4  3]
#  [ 1  0 19  3]
#  [ 3  2  5  7]]
# Confusion Matrix for Batch = 266 is [[16  3  4  0]
#  [ 4 22  4  1]
#  [ 2  0 11  3]
#  [ 8  2 11  9]]
# Confusion Matrix for Batch = 267 is [[17  4  1  4]
#  [ 6 16  2  0]
#  [ 3  0  9  4]
#  [ 5  5  9 15]]
# Confusion Matrix for Batch = 268 is [[14  1  1  9]
#  [ 4  8  2  3]
#  [ 4  0 16  6]
#  [ 6  1  3 22]]
# Confusion Matrix for Batch = 269 is [[ 9  1  6  3]
#  [ 3 11  1  7]
#  [ 3  0 31  2]
#  [ 2  2  6 13]]
# Confusion Matrix for Batch = 270 is [[20  0  2  3]
#  [ 2 11  3  2]
#  [ 2  1 17  4]
#  [ 9  5  5 14]]
# Confusion Matrix for Batch = 271 is [[17  2  7  4]
#  [ 8 10  1  5]
#  [ 0  1  9  7]
#  [ 9  1  3 16]]
# Confusion Matrix for Batch = 272 is [[12  1  3  2]
#  [ 2 14  3  1]
#  [ 0  0 11  8]
#  [ 3  7  7 26]]
# Confusion Matrix for Batch = 273 is [[18  4  1  4]
#  [ 5 12  3  4]
#  [ 1  0 15  0]
#  [ 4  0  8 21]]
# Confusion Matrix for Batch = 274 is [[ 7  2  2  2]
#  [ 5 16  0  3]
#  [ 2  2 16  3]
#  [ 5  4  7 24]]
# Confusion Matrix for Batch = 275 is [[18  2  1  7]
#  [ 4 16  3  4]
#  [ 3  0 15  0]
#  [ 5  4  1 17]]
# Confusion Matrix for Batch = 276 is [[ 9  3  3 10]
#  [ 4 23  1  3]
#  [ 1  1 13  3]
#  [ 4  1  5 16]]
# Confusion Matrix for Batch = 277 is [[15  2  2  2]
#  [11 17  4  0]
#  [ 0  0 20  7]
#  [ 7  0  5  8]]
# Confusion Matrix for Batch = 278 is [[11  1  8  3]
#  [ 2 27  3  0]
#  [ 2  0 16  1]
#  [ 3  4  4 15]]
# Confusion Matrix for Batch = 279 is [[14  2  6  1]
#  [ 5 26  1  0]
#  [ 1  1 17  3]
#  [ 8  2  9  4]]
# Confusion Matrix for Batch = 280 is [[12  3  2  2]
#  [ 5 28  6  0]
#  [ 2  0  8  1]
#  [ 6  3  6 16]]
# Confusion Matrix for Batch = 281 is [[23  1  4  2]
#  [ 3 16  3  1]
#  [ 0  0 21  0]
#  [ 2  1  9 14]]
# Confusion Matrix for Batch = 282 is [[13  3  4  1]
#  [ 3 17  1  6]
#  [ 1  1 22  2]
#  [ 0  2  4 20]]
# Confusion Matrix for Batch = 283 is [[15  2  5  7]
#  [ 2  8  1  3]
#  [ 3  0 21  7]
#  [ 4  1  3 18]]
# Confusion Matrix for Batch = 284 is [[15  3  5  2]
#  [ 2 15  3  2]
#  [ 2  0 21  4]
#  [ 2  1  4 19]]
# Confusion Matrix for Batch = 285 is [[14  2  6  5]
#  [ 0 20  3  1]
#  [ 2  0 21  1]
#  [ 3  3  4 15]]
# Confusion Matrix for Batch = 286 is [[10  0  6  6]
#  [ 4 18  2  2]
#  [ 2  2 16  3]
#  [ 1  2  6 20]]
# Confusion Matrix for Batch = 287 is [[18  3  1  9]
#  [ 7 14  0  3]
#  [ 0  0 16  3]
#  [ 3  3  9 11]]
# Confusion Matrix for Batch = 288 is [[14  1  7  6]
#  [ 3 17  2  2]
#  [ 3  0 14  5]
#  [ 1  1  3 21]]
# Confusion Matrix for Batch = 289 is [[19  6  2  5]
#  [ 2 17  1  3]
#  [ 1  1 10  6]
#  [ 4  2  3 18]]
# Confusion Matrix for Batch = 290 is [[11  0  5  0]
#  [ 3 20  6  2]
#  [ 1  1 14  1]
#  [ 1  3  5 27]]
# Confusion Matrix for Batch = 291 is [[13  3  5  1]
#  [ 7 28  2  2]
#  [ 3  1 16  1]
#  [ 5  2  5  6]]
# Confusion Matrix for Batch = 292 is [[17  3  5  0]
#  [ 9 26  1  1]
#  [ 2  1 19  1]
#  [ 1  3  4  7]]
# Confusion Matrix for Batch = 293 is [[20  8  6  3]
#  [ 4 18  2  2]
#  [ 1  5 14  0]
#  [ 3  1  5  8]]
# Confusion Matrix for Batch = 294 is [[22  2  3  2]
#  [ 4 26  1  3]
#  [ 0  2 13  3]
#  [ 4  2  3 10]]
# Confusion Matrix for Batch = 295 is [[17  1  3 10]
#  [ 2 11  4  2]
#  [ 1  0 18  4]
#  [ 4  1  2 20]]
# Confusion Matrix for Batch = 296 is [[13  2  6  1]
#  [ 1 12  2  1]
#  [ 1  1 20  6]
#  [ 3  1  6 24]]
# Confusion Matrix for Batch = 297 is [[17  3  2  4]
#  [ 5 18  2  2]
#  [ 0  1 16  9]
#  [ 3  2  4 12]]
# Confusion Matrix for Batch = 298 is [[11  3  4  3]
#  [ 0 16  4  6]
#  [ 2  1 17  2]
#  [ 7  0  4 20]]
# Confusion Matrix for Batch = 299 is [[14  0  3  1]
#  [ 3 17  1  5]
#  [ 3  0 12  7]
#  [ 1  2  6 25]]
# Confusion Matrix for Batch = 300 is [[ 7  2  5  4]
#  [ 3 19  1  6]
#  [ 1  0 19  8]
#  [ 3  1  4 17]]
# Confusion Matrix for Batch = 301 is [[17  3  5  5]
#  [ 2 14  0  2]
#  [ 2  2 14  4]
#  [ 4  1  2 23]]
# Confusion Matrix for Batch = 302 is [[23  4  2  3]
#  [ 3 14  2  5]
#  [ 2  0 13  3]
#  [ 6  1  6 13]]
# Confusion Matrix for Batch = 303 is [[16  2  4  4]
#  [ 6 28  1  2]
#  [ 0  0  9  2]
#  [ 4  2  7 13]]
# Confusion Matrix for Batch = 304 is [[13  2  6  2]
#  [10 23  1  4]
#  [ 1  1 19  1]
#  [ 3  0  4 10]]
# Confusion Matrix for Batch = 305 is [[18  1  6  1]
#  [ 3 35  4  2]
#  [ 2  2 10  1]
#  [ 2  1  3  9]]
# Confusion Matrix for Batch = 306 is [[21  2  2  2]
#  [ 3 17  2  4]
#  [ 4  2 20  5]
#  [ 4  0  3  9]]
# Confusion Matrix for Batch = 307 is [[15  1  4 10]
#  [ 1 10  1  4]
#  [ 2  2 17  7]
#  [ 2  1  5 18]]
# Confusion Matrix for Batch = 308 is [[13  0  4  2]
#  [ 3 13  1  7]
#  [ 1  1 23  2]
#  [ 1  2  7 20]]
# Confusion Matrix for Batch = 309 is [[13  2  4  4]
#  [ 3 14  4  4]
#  [ 0  2 12  6]
#  [ 5  1  4 22]]
# Confusion Matrix for Batch = 310 is [[15  1  1  5]
#  [ 6 18  3  0]
#  [ 3  2 19  3]
#  [ 1  1  5 17]]
# Confusion Matrix for Batch = 311 is [[19  5  4  3]
#  [ 4 18  3  1]
#  [ 0  1 14  4]
#  [ 2  3  8 11]]
# Confusion Matrix for Batch = 312 is [[16  1  1  4]
#  [ 6 10  3  4]
#  [ 3  0 12  5]
#  [ 5  2  6 22]]
# Confusion Matrix for Batch = 313 is [[21  4  2  7]
#  [ 5 18  2  3]
#  [ 1  1 13  4]
#  [ 3  3  2 11]]
# Confusion Matrix for Batch = 314 is [[18  2  4  2]
#  [ 7 33  0  1]
#  [ 0  2 10  2]
#  [ 3  0  0 16]]
# Confusion Matrix for Batch = 315 is [[20  1  2  6]
#  [ 4 31  3  0]
#  [ 0  2 13  3]
#  [ 2  3  5  5]]
# Confusion Matrix for Batch = 316 is [[28  1  3  2]
#  [ 1 29  1  2]
#  [ 2  3  7  1]
#  [ 3  2  4 11]]
# Confusion Matrix for Batch = 317 is [[14  3  1  2]
#  [ 3 42  2  1]
#  [ 1  2 10  3]
#  [ 1  2  5  8]]
# Confusion Matrix for Batch = 318 is [[32  2  0  3]
#  [ 6 15  2  2]
#  [ 1  1  7  0]
#  [ 4  5  6 14]]
# Confusion Matrix for Batch = 319 is [[27  1  2  1]
#  [ 8 28  0  1]
#  [ 3  1  6  2]
#  [ 5  4  4  7]]
# Confusion Matrix for Batch = 320 is [[18  3  3  2]
#  [ 8 40  2  2]
#  [ 2  1  4  1]
#  [ 6  1  2  5]]
# Confusion Matrix for Batch = 321 is [[28  3  2  1]
#  [ 4 38  2  0]
#  [ 2  0  3  0]
#  [ 8  1  2  6]]
# Confusion Matrix for Batch = 322 is [[18  1  1  1]
#  [ 2 41  4  0]
#  [ 3  0  7  0]
#  [ 3  5  2 12]]
# Confusion Matrix for Batch = 323 is [[21  3  1  2]
#  [11 26  7  1]
#  [ 4  1  3  1]
#  [ 6  2  4  7]]
# Confusion Matrix for Batch = 324 is [[31  4  4  1]
#  [ 6 27  3  2]
#  [ 2  2  3  0]
#  [ 5  3  2  5]]
# Confusion Matrix for Batch = 325 is [[29  3  2  1]
#  [ 8 21  1  2]
#  [ 4  1  4  1]
#  [11  2  3  7]]
# Confusion Matrix for Batch = 326 is [[24  4  3  2]
#  [ 6 32  3  2]
#  [ 5  0  2  3]
#  [ 7  3  2  2]]
# Confusion Matrix for Batch = 327 is [[23  3  2  3]
#  [ 5 23  3  1]
#  [ 3  0  6  8]
#  [ 4  1  5 10]]
# Confusion Matrix for Batch = 328 is [[21  5  3  0]
#  [ 3 26  2  0]
#  [ 3  0 11  3]
#  [10  1  4  8]]
# Confusion Matrix for Batch = 329 is [[13  1  5  6]
#  [ 8 24  2  3]
#  [ 2  1  9  5]
#  [ 6  1  6  8]]
# Confusion Matrix for Batch = 330 is [[18  1  3  5]
#  [ 7 17  4  0]
#  [ 2  2 15  4]
#  [ 3  1  9  9]]
# Confusion Matrix for Batch = 331 is [[24  0  7  5]
#  [ 1 13  1  1]
#  [ 3  1 15  4]
#  [ 3  2  6 14]]
# Confusion Matrix for Batch = 332 is [[18  2  1  1]
#  [ 1 22  4  5]
#  [ 2  1 10  2]
#  [ 1  4 15 11]]
# Confusion Matrix for Batch = 333 is [[13  2  3  8]
#  [ 3 11  2  1]
#  [ 2  0 20  6]
#  [ 3  1  3 22]]
# Confusion Matrix for Batch = 334 is [[13  3  5  3]
#  [ 2 10  2  4]
#  [ 4  1 24  7]
#  [ 4  0  8 10]]
# Confusion Matrix for Batch = 335 is [[11  2  2  6]
#  [ 2 14  2  2]
#  [ 4  0 17  4]
#  [ 5  2  5 22]]
# Confusion Matrix for Batch = 336 is [[24  3  4  2]
#  [ 2  5  3  2]
#  [ 3  0 14  3]
#  [ 1  1  8 25]]
# Confusion Matrix for Batch = 337 is [[15  3  0  1]
#  [ 4 21  2  1]
#  [ 0  0 16  5]
#  [ 3  1 10 18]]
# Confusion Matrix for Batch = 338 is [[11  4  3  2]
#  [ 4 17  2  1]
#  [ 2  0 22  7]
#  [ 5  2  5 13]]
# Confusion Matrix for Batch = 339 is [[12  2  2  4]
#  [ 8 11  2  5]
#  [ 1  0  9  8]
#  [ 2  2  2 30]]
# Confusion Matrix for Batch = 340 is [[17  5  2  3]
#  [ 2 13  0  4]
#  [ 1  0 17  4]
#  [ 6  2  6 18]]
# Confusion Matrix for Batch = 341 is [[18  2  1  3]
#  [ 5 24  3  2]
#  [ 2  1 10  3]
#  [ 7  2  6 11]]
# Confusion Matrix for Batch = 342 is [[11  5  3  1]
#  [ 2 25  3  1]
#  [ 1  1 13  4]
#  [ 6  0  9 15]]
# Confusion Matrix for Batch = 343 is [[ 9  5  1  4]
#  [ 4 25  1  2]
#  [ 1  0  9  7]
#  [ 3  5  7 17]]
# Confusion Matrix for Batch = 344 is [[25  2  2  4]
#  [ 1 19  1  2]
#  [ 4  1 18  1]
#  [ 2  1  6 11]]
# Confusion Matrix for Batch = 345 is [[11  1  1  6]
#  [ 2 14  3  5]
#  [ 1  1  6  6]
#  [ 5  1  5 32]]
# Confusion Matrix for Batch = 346 is [[15  4  2  5]
#  [ 2 19  3  1]
#  [ 0  0 22  2]
#  [ 1  1  3 20]]
# Confusion Matrix for Batch = 347 is [[14  0  1  3]
#  [ 2  7  3  3]
#  [ 0  1 14  7]
#  [ 2  2  5 36]]
# Confusion Matrix for Batch = 348 is [[14  6  4  3]
#  [ 4  7  2  1]
#  [ 3  1 13  4]
#  [ 3  1  7 27]]
# Confusion Matrix for Batch = 349 is [[13  2  5  1]
#  [ 3 21  2  2]
#  [ 2  0 16  2]
#  [ 4  0  4 23]]
# Confusion Matrix for Batch = 350 is [[11  4  1  2]
#  [ 4 19  1  3]
#  [ 0  0 11  7]
#  [ 6  1  3 27]]
# Confusion Matrix for Batch = 351 is [[11  5  0  4]
#  [ 6 25  0  1]
#  [ 5  3  9  2]
#  [ 6  3  3 17]]
# Confusion Matrix for Batch = 352 is [[12  3  6  2]
#  [ 5 22  1  4]
#  [ 1  2 15  3]
#  [ 7  2  6  9]]
# Confusion Matrix for Batch = 353 is [[22  1  3  1]
#  [ 5 12  6  3]
#  [ 2  1 20  2]
#  [ 4  1  3 14]]
# Confusion Matrix for Batch = 354 is [[12  4  2  5]
#  [ 2 19  4  1]
#  [ 4  2 10  3]
#  [ 7  3 10 12]]
# Confusion Matrix for Batch = 355 is [[23  2  5  5]
#  [ 3 11  3  3]
#  [ 0  2 18  2]
#  [ 5  0  2 16]]
# Confusion Matrix for Batch = 356 is [[22  2  4  1]
#  [ 3  3  1  4]
#  [ 3  0 29  3]
#  [ 0  2  5 18]]
# Confusion Matrix for Batch = 357 is [[17  0  2  0]
#  [ 2 16  3  1]
#  [ 4  0 29  4]
#  [ 0  1  9 12]]
# Confusion Matrix for Batch = 358 is [[18  5  8  4]
#  [ 7 10  0  1]
#  [ 2  0 14  2]
#  [ 5  2  5 17]]
# Confusion Matrix for Batch = 359 is [[19  4  6  2]
#  [ 3 14  5  3]
#  [ 1  0 17  2]
#  [ 3  1  5 15]]
# Confusion Matrix for Batch = 360 is [[16  1 11  3]
#  [ 4  7  2  3]
#  [ 1  1 23  4]
#  [ 2  0  2 20]]
# Confusion Matrix for Batch = 361 is [[15  2  7  6]
#  [ 3 15  9  4]
#  [ 2  0 17  3]
#  [ 5  2  1  9]]
# Confusion Matrix for Batch = 362 is [[13  1  4  5]
#  [ 1 14  3  5]
#  [ 0  0 11  3]
#  [ 3  1  8 28]]
# Confusion Matrix for Batch = 363 is [[24  3  2  1]
#  [ 4 21  4  5]
#  [ 1  1  8  6]
#  [ 1  1  5 13]]
# Confusion Matrix for Batch = 364 is [[16  3  3  6]
#  [ 4 14  2  2]
#  [ 3  1  7  5]
#  [ 8  2  7 17]]
# Confusion Matrix for Batch = 365 is [[17  3  5  2]
#  [ 3 28  2  0]
#  [ 0  0 10  4]
#  [10  1  3 12]]
# Confusion Matrix for Batch = 366 is [[17  2  6  1]
#  [ 3 19  3  0]
#  [ 1  1 17  3]
#  [ 1  4  6 16]]
# Confusion Matrix for Batch = 367 is [[20  3  4  2]
#  [ 2 11  4  3]
#  [ 3  1 11  4]
#  [ 3  1  7 21]]
# Confusion Matrix for Batch = 368 is [[20  3  3  1]
#  [ 3 22  5  4]
#  [ 2  0  7  1]
#  [ 4  4  3 18]]
# Confusion Matrix for Batch = 369 is [[21  2  3  3]
#  [ 3  8  2  5]
#  [ 1  0 17  5]
#  [ 2  2  5 21]]
# Confusion Matrix for Batch = 370 is [[14  1  5  2]
#  [ 4  8  0  3]
#  [ 3  0 20  2]
#  [ 5  1  9 23]]
# Confusion Matrix for Batch = 371 is [[15  5  4  4]
#  [ 4 10  3  3]
#  [ 1  0 16  5]
#  [ 6  3  5 16]]
# Confusion Matrix for Batch = 372 is [[21  3  6  4]
#  [ 2  8  1  3]
#  [ 3  1 14  5]
#  [ 1  1  2 25]]
# Confusion Matrix for Batch = 373 is [[14  2  4  8]
#  [ 3 21  0  2]
#  [ 0  0 15  1]
#  [ 4  0  7 19]]
# Confusion Matrix for Batch = 374 is [[ 9  2  1  9]
#  [ 1  5  5  2]
#  [ 3  3 17  3]
#  [ 6  1  2 31]]
# Confusion Matrix for Batch = 375 is [[19  4  2  1]
#  [ 2 19  2  2]
#  [ 1  3 10  7]
#  [ 2  1  1 24]]
# Confusion Matrix for Batch = 376 is [[13  0  2  8]
#  [ 5 12  4  4]
#  [ 3  1  9  6]
#  [ 3  3  2 25]]
# Confusion Matrix for Batch = 377 is [[16  6  3  2]
#  [ 3 19  3  3]
#  [ 4  1 14  3]
#  [ 7  1  5 10]]
# Confusion Matrix for Batch = 378 is [[15  2 10  1]
#  [ 1 21  5  1]
#  [ 2  2 17  2]
#  [ 8  1  3  9]]
# Confusion Matrix for Batch = 379 is [[15  1  2  4]
#  [ 4 23  2  4]
#  [ 1  0 14  4]
#  [ 7  3  8  8]]
# Confusion Matrix for Batch = 380 is [[12  2  3  1]
#  [ 2 29  4  3]
#  [ 2  1 17  3]
#  [ 2  5  5  9]]
# Confusion Matrix for Batch = 381 is [[13  2  3  3]
#  [ 4 17  3  4]
#  [ 1  1 17  3]
#  [ 2  0  8 19]]
# Confusion Matrix for Batch = 382 is [[11  0  6  5]
#  [ 5 13  1  1]
#  [ 1  0 26  1]
#  [ 3  2  7 18]]
# Confusion Matrix for Batch = 383 is [[13  2  5  5]
#  [ 1 10  4  4]
#  [ 2  1 22  5]
#  [ 3  1  6 16]]
# Confusion Matrix for Batch = 384 is [[20  5  2  3]
#  [ 3 14  2  3]
#  [ 2  0 17  2]
#  [ 4  0  3 20]]
# Confusion Matrix for Batch = 385 is [[14  4  9  6]
#  [ 5 21  1  1]
#  [ 0  0 10  2]
#  [ 6  1  5 15]]
# Confusion Matrix for Batch = 386 is [[15  3  5  2]
#  [ 4 11  2  3]
#  [ 0  0 15  1]
#  [ 2  3  6 28]]
# Confusion Matrix for Batch = 387 is [[15  5  2  5]
#  [ 3 18  2  5]
#  [ 0  0  6  5]
#  [ 5  3  2 24]]
# Confusion Matrix for Batch = 388 is [[29  7  0  5]
#  [ 2 16  1  3]
#  [ 2  0  9  1]
#  [ 2  0  6 17]]
# Confusion Matrix for Batch = 389 is [[19  3  5  1]
#  [ 3 27  5  1]
#  [ 3  1  7  2]
#  [ 4  5  6  8]]
# Confusion Matrix for Batch = 390 is [[20  1  3  5]
#  [ 3 23  2  3]
#  [ 1  0 10  1]
#  [ 6  6  5 11]]
# Confusion Matrix for Batch = 391 is [[14  4  1  2]
#  [ 3 38  4  2]
#  [ 2  1  6  1]
#  [ 7  4  2  9]]
# Confusion Matrix for Batch = 392 is [[20  2  7  2]
#  [ 4 36  2  1]
#  [ 1  1  6  2]
#  [ 4  3  4  5]]
# Confusion Matrix for Batch = 393 is [[20  5  2  3]
#  [ 8 30  1  0]
#  [ 4  2  3  1]
#  [ 5  4  0 12]]
# Confusion Matrix for Batch = 394 is [[29  1  2  1]
#  [ 2 40  3  1]
#  [ 3  1  3  0]
#  [ 4  2  4  4]]
# Confusion Matrix for Batch = 395 is [[20  2  1  2]
#  [ 3 40  2  2]
#  [ 3  0  5  1]
#  [ 4  3  3  9]]
# Confusion Matrix for Batch = 396 is [[23  3  4  2]
#  [ 3 36  0  1]
#  [ 0  0  9  0]
#  [ 7  0  2 10]]
# Confusion Matrix for Batch = 397 is [[15  3  3  1]
#  [ 4 23  6  0]
#  [ 3  2  8  2]
#  [ 3  6 12  9]]
# Confusion Matrix for Batch = 398 is [[28  2  2  2]
#  [ 8 23  1  0]
#  [ 5  1  2  0]
#  [10  2  8  6]]
# Confusion Matrix for Batch = 399 is [[24  3  3  1]
#  [ 4 43  3  2]
#  [ 0  1  3  0]
#  [ 5  1  3  4]]
# Confusion Matrix for Batch = 400 is [[35  3  3  5]
#  [10 20  3  0]
#  [ 0  2  2  1]
#  [10  1  2  3]]
# Confusion Matrix for Batch = 401 is [[22  1  2  1]
#  [ 4 32  3  4]
#  [ 2  1 10  1]
#  [ 5  3  4  5]]
# Confusion Matrix for Batch = 402 is [[20  2  1  3]
#  [ 5 35  1  3]
#  [ 2  1  8  1]
#  [ 5  2  6  5]]
# Confusion Matrix for Batch = 403 is [[18  5  1  0]
#  [ 4 36  1  1]
#  [ 1  2 11  3]
#  [ 7  4  3  3]]
# Confusion Matrix for Batch = 404 is [[14  3  6  4]
#  [ 7 22  2  2]
#  [ 2  1 10  4]
#  [ 5  2  8  8]]
# Confusion Matrix for Batch = 405 is [[10  3  2  6]
#  [ 7 28  3  2]
#  [ 2  2 10  1]
#  [ 6  0  8 10]]
# Confusion Matrix for Batch = 406 is [[24  1  1  0]
#  [ 3 25  4  1]
#  [ 3  1 13  2]
#  [ 3  3  7  9]]
# Confusion Matrix for Batch = 407 is [[18  0  2  3]
#  [ 1  8  3  5]
#  [ 4  0 19  2]
#  [ 6  2  6 21]]
# Confusion Matrix for Batch = 408 is [[16  2  5  4]
#  [ 2 11  1  4]
#  [ 2  2 24  5]
#  [ 4  3  2 13]]
# Confusion Matrix for Batch = 409 is [[12  0  1  4]
#  [ 4  7  2  4]
#  [ 2  0 20  3]
#  [ 4  2  8 27]]
# Confusion Matrix for Batch = 410 is [[23  0  1  3]
#  [ 2 11  1  2]
#  [ 4  0 19 11]
#  [ 0  2  4 17]]
# Confusion Matrix for Batch = 411 is [[14  0  2  3]
#  [ 3 20  1  3]
#  [ 3  0 15  4]
#  [ 4  2 11 15]]
# Confusion Matrix for Batch = 412 is [[12  1  1  3]
#  [ 4 15  1  7]
#  [ 2  1 11  8]
#  [ 2  1  4 27]]
# Confusion Matrix for Batch = 413 is [[13  1  3  0]
#  [ 0 16  4  3]
#  [ 3  0 23  6]
#  [ 4  3  5 16]]
# Confusion Matrix for Batch = 414 is [[13  3  1  4]
#  [ 4 20  2  3]
#  [ 0  2 16  7]
#  [ 3  2  4 16]]
# Confusion Matrix for Batch = 415 is [[10  1  3  5]
#  [ 5 15  0  6]
#  [ 0  0 13  7]
#  [ 6  1  2 26]]
# Confusion Matrix for Batch = 416 is [[15  0  1  4]
#  [ 3 21  0  5]
#  [ 1  0 10 10]
#  [ 4  2  3 21]]
# Confusion Matrix for Batch = 417 is [[ 7  1  7  1]
#  [ 4 30  2  4]
#  [ 4  2 16  3]
#  [ 1  1  5 12]]
# Confusion Matrix for Batch = 418 is [[14  3  4  3]
#  [ 2 25  2  1]
#  [ 0  1 19  2]
#  [ 7  2  4 11]]
# Confusion Matrix for Batch = 419 is [[ 4  2  4  2]
#  [ 4 24  4  0]
#  [ 2  1 18  2]
#  [ 2  3  6 22]]
# Confusion Matrix for Batch = 420 is [[17  1  3  1]
#  [ 4 26  3  3]
#  [ 2  1 14  1]
#  [ 2  4  9  9]]
# Confusion Matrix for Batch = 421 is [[15  1  4  3]
#  [ 6 21  2  2]
#  [ 2  0 18  7]
#  [ 2  3  4 10]]
# Confusion Matrix for Batch = 422 is [[13  4  1  4]
#  [ 1 11  0  5]
#  [ 1  1 18  4]
#  [ 2  2  5 28]]
# Confusion Matrix for Batch = 423 is [[16  1  4  8]
#  [ 2 12  2  4]
#  [ 2  0 15  2]
#  [ 5  2  6 19]]
# Confusion Matrix for Batch = 424 is [[ 8  0  3  8]
#  [ 3 11  2  1]
#  [ 2  0 36  2]
#  [ 4  2  6 12]]
# Confusion Matrix for Batch = 425 is [[18  3  1  4]
#  [ 6  8  3  0]
#  [ 1  1 16  4]
#  [ 8  2  3 22]]
# Confusion Matrix for Batch = 426 is [[ 9  2  5  4]
#  [ 1 18  2  2]
#  [ 0  0 21  7]
#  [ 2  2  7 18]]
# Confusion Matrix for Batch = 427 is [[13  1  1  8]
#  [ 5 17  3  4]
#  [ 2  0 12  2]
#  [ 1  2  8 21]]
# Confusion Matrix for Batch = 428 is [[18  0  4  4]
#  [ 4 25  1  3]
#  [ 0  0 11  4]
#  [ 3  3  0 20]]
# Confusion Matrix for Batch = 429 is [[14  0  0  4]
#  [ 0 16  1  4]
#  [ 2  1 21  4]
#  [ 2  3  6 22]]
# Confusion Matrix for Batch = 430 is [[16  1  4  5]
#  [ 3 17  0  2]
#  [ 4  1  9  1]
#  [ 5  1  2 29]]
# Confusion Matrix for Batch = 431 is [[17  1  5  2]
#  [ 3 11  2  5]
#  [ 2  1 12  7]
#  [ 3  2  3 24]]
# Confusion Matrix for Batch = 432 is [[16  4  4  1]
#  [ 3 22  1  2]
#  [ 2  1 20  2]
#  [ 7  2  7  6]]
# Confusion Matrix for Batch = 433 is [[13  2  5  6]
#  [ 2 25  5  4]
#  [ 0  0 16  2]
#  [ 3  1  8  8]]
# Confusion Matrix for Batch = 434 is [[22  5  4  3]
#  [ 6 15  3  5]
#  [ 1  0 20  0]
#  [ 5  3  2  6]]
# Confusion Matrix for Batch = 435 is [[19  0  8  2]
#  [ 1 14  2  2]
#  [ 1  0 21  3]
#  [ 5  1  5 16]]
# Confusion Matrix for Batch = 436 is [[10  1  3 10]
#  [ 4 14  2  2]
#  [ 2  1 17  7]
#  [ 2  0  5 20]]
# Confusion Matrix for Batch = 437 is [[18  0  0  3]
#  [ 4  9  3  4]
#  [ 2  1 23  4]
#  [ 2  2  6 19]]
# Confusion Matrix for Batch = 438 is [[16  3  1  6]
#  [ 3  6  4  6]
#  [ 2  0 28  1]
#  [ 2  2  3 17]]
# Confusion Matrix for Batch = 439 is [[12  3  3  9]
#  [ 3  9  3  4]
#  [ 2  0 19  4]
#  [ 2  1  3 23]]
# Confusion Matrix for Batch = 440 is [[ 9  3  6  6]
#  [ 1 19  2  8]
#  [ 1  0 14  3]
#  [ 2  1  4 21]]
# Confusion Matrix for Batch = 441 is [[13  3  2  3]
#  [ 3 13  1  3]
#  [ 0  0 23  8]
#  [ 1  2  7 18]]
# Confusion Matrix for Batch = 442 is [[17  2  2  3]
#  [ 7 15  1  1]
#  [ 2  0 23  4]
#  [ 2  2  4 15]]
# Confusion Matrix for Batch = 443 is [[12  2  2  3]
#  [ 3 21  3  5]
#  [ 5  0 11  4]
#  [ 3  1  4 21]]
# Confusion Matrix for Batch = 444 is [[10  5  3  4]
#  [ 2 20  2  4]
#  [ 0  1 19  0]
#  [ 3  2  2 23]]
# Confusion Matrix for Batch = 445 is [[16  3  4  3]
#  [ 4 21  2  5]
#  [ 1  0 12  2]
#  [ 6  3  6 12]]
# Confusion Matrix for Batch = 446 is [[18  0  1  4]
#  [ 3 23  3  3]
#  [ 2  1 24  3]
#  [ 0  0  5 10]]
# Confusion Matrix for Batch = 447 is [[23  0  6  6]
#  [ 3 14  4  2]
#  [ 2  0 24  2]
#  [ 5  0  3  6]]
# Confusion Matrix for Batch = 448 is [[24  2  2  6]
#  [ 0 24  2  2]
#  [ 2  0 16  1]
#  [ 2  2  8  7]]
# Confusion Matrix for Batch = 449 is [[18  3  6  4]
#  [ 2  8  3  4]
#  [ 2  0 18  4]
#  [ 2  1  5 20]]
# Confusion Matrix for Batch = 450 is [[16  1  3  7]
#  [ 2 17  1  2]
#  [ 2  0 19  2]
#  [ 2  0  5 21]]
# Confusion Matrix for Batch = 451 is [[21  0  2  7]
#  [ 1  6  5  2]
#  [ 2  0 20  6]
#  [ 5  0  5 18]]
# Confusion Matrix for Batch = 452 is [[ 8  1  2  2]
#  [ 1 19  2  6]
#  [ 2  0 22  5]
#  [ 2  1  6 21]]
# Confusion Matrix for Batch = 453 is [[12  3  6  6]
#  [ 0 10  3  6]
#  [ 0  0 20  5]
#  [ 3  2  5 19]]
# Confusion Matrix for Batch = 454 is [[13  3  3  6]
#  [ 3 13  0  4]
#  [ 1  0 16  5]
#  [ 3  3  2 25]]
# Confusion Matrix for Batch = 455 is [[15  1  4  6]
#  [ 3 14  0  1]
#  [ 1  0 22  5]
#  [ 2  3  6 17]]
# Confusion Matrix for Batch = 456 is [[10  0  4  8]
#  [ 6 14  4  2]
#  [ 0  0 10  9]
#  [ 5  2  6 20]]
# Confusion Matrix for Batch = 457 is [[17  1  4  4]
#  [ 4 18  1  1]
#  [ 1  0 13  3]
#  [ 2  2  2 27]]
# Confusion Matrix for Batch = 458 is [[21  1  6  2]
#  [ 2 23  3  2]
#  [ 2  1 11  1]
#  [ 3  2  4 16]]
# Confusion Matrix for Batch = 459 is [[19  1  3  3]
#  [ 5 26  3  3]
#  [ 1  0 13  3]
#  [ 3  3  4 10]]
# Confusion Matrix for Batch = 460 is [[ 8  1  2  2]
#  [ 5 27  4  3]
#  [ 0  1 16  4]
#  [ 3  1  6 17]]
# Confusion Matrix for Batch = 461 is [[15  4  4  0]
#  [ 3 27  4  2]
#  [ 0  1 14  2]
#  [ 3  4  4 13]]
# Confusion Matrix for Batch = 462 is [[24  1  3  1]
#  [ 2 14  2  6]
#  [ 1  0 12  4]
#  [ 3  2  4 21]]
# Confusion Matrix for Batch = 463 is [[ 8  2  6  4]
#  [ 3 18  0  5]
#  [ 0  1 19  6]
#  [ 4  1  4 19]]
# Confusion Matrix for Batch = 464 is [[17  6  1  4]
#  [ 5 10  2  0]
#  [ 1  0 17  2]
#  [ 8  2 13 12]]
# Confusion Matrix for Batch = 465 is [[ 6  1  3  9]
#  [ 5 19  0  3]
#  [ 2  0  9  4]
#  [ 1  1  4 33]]
# Confusion Matrix for Batch = 466 is [[15  3  5  7]
#  [ 3  8  5  3]
#  [ 1  0 16  2]
#  [ 2  1  9 20]]
# Confusion Matrix for Batch = 467 is [[13  2  4  1]
#  [ 3 15  4  2]
#  [ 1  2 20  2]
#  [ 2  3  9 17]]
# Confusion Matrix for Batch = 468 is [[13  8  4  3]
#  [ 2 13  1  2]
#  [ 0  0 21  4]
#  [ 4  1  5 19]]
# Confusion Matrix for Batch = 469 is [[10  3  5  8]
#  [ 4 18  5  2]
#  [ 0  0 21  5]
#  [ 4  0  2 13]]
# Confusion Matrix for Batch = 470 is [[16  3  4  4]
#  [ 3 17  1  6]
#  [ 0  0 11  2]
#  [ 8  4  9 12]]
# Confusion Matrix for Batch = 471 is [[12  3  4  9]
#  [ 1 25  2  2]
#  [ 0  2 10  1]
#  [ 2  3  3 21]]
# Confusion Matrix for Batch = 472 is [[19  3  3  0]
#  [ 4 36  5  2]
#  [ 1  0 12  2]
#  [ 1  1  4  7]]
# Confusion Matrix for Batch = 473 is [[19  1  6  2]
#  [ 6 32  2  3]
#  [ 1  1 10  2]
#  [ 2  3  5  5]]
# Confusion Matrix for Batch = 474 is [[22  2  3  7]
#  [ 6 30  1  3]
#  [ 2  2  4  2]
#  [ 2  5  3  6]]
# Confusion Matrix for Batch = 475 is [[26  5  3  3]
#  [ 5 23  1  3]
#  [ 1  0  9  1]
#  [ 8  2  3  7]]
# Confusion Matrix for Batch = 476 is [[30  1  3  2]
#  [ 1 24  2  3]
#  [ 1  0  3  4]
#  [ 3  0  2 21]]
# Confusion Matrix for Batch = 477 is [[28  4  3  1]
#  [ 2 35  1  2]
#  [ 2  0  4  0]
#  [ 5  2  5  6]]
# Confusion Matrix for Batch = 478 is [[18  7  0  3]
#  [ 3 43  1  3]
#  [ 1  1  6  0]
#  [ 2  2  3  7]]
# Confusion Matrix for Batch = 479 is [[16  2  1  3]
#  [ 7 40  2  3]
#  [ 2  1  6  1]
#  [ 3  5  5  3]]
# Confusion Matrix for Batch = 480 is [[14  1  2  1]
#  [ 7 34  6  2]
#  [ 1  1  5  2]
#  [ 3  2  9 10]]
# Confusion Matrix for Batch = 481 is [[21  5  2  1]
#  [ 3 33  3  0]
#  [ 2  2  4  3]
#  [ 7  2  5  7]]
# Confusion Matrix for Batch = 482 is [[38  1  1  1]
#  [ 6 19  5  0]
#  [ 2  1  5  1]
#  [ 7  0  4  9]]
# Confusion Matrix for Batch = 483 is [[27  4  5  1]
#  [ 6 23  1  4]
#  [ 1  1  7  1]
#  [ 6  4  2  7]]
# Confusion Matrix for Batch = 484 is [[12  3 11  4]
#  [ 2 31  5  5]
#  [ 2  1  5  2]
#  [ 7  0  4  6]]
# Confusion Matrix for Batch = 485 is [[14  3  2  4]
#  [ 5 30  2  1]
#  [ 2  3  7  0]
#  [12  4  5  6]]
# Confusion Matrix for Batch = 486 is [[12  3  7  1]
#  [ 5 26  0  2]
#  [ 0  2 13  0]
#  [ 4  1 11 13]]
# Confusion Matrix for Batch = 487 is [[16  1  5  0]
#  [ 6 19  3  4]
#  [ 6  0  9  2]
#  [ 7  0 10 12]]
# Confusion Matrix for Batch = 488 is [[23  1  3  3]
#  [ 9 22  5  1]
#  [ 2  0  7  2]
#  [ 7  1  7  7]]
# Confusion Matrix for Batch = 489 is [[ 9  1  3  5]
#  [ 4 14  1  6]
#  [ 1  2 20  4]
#  [ 3  1  5 21]]
# Confusion Matrix for Batch = 490 is [[16  2  4  3]
#  [ 4  6  3  6]
#  [ 3  3 13  8]
#  [ 3  2  9 15]]
# Confusion Matrix for Batch = 491 is [[11  1  1  5]
#  [ 0  8  2  7]
#  [ 0  0 23  4]
#  [ 4  1  7 26]]
# Confusion Matrix for Batch = 492 is [[12  2  2  4]
#  [ 3 15  1  5]
#  [ 1  1 20 10]
#  [ 3  4  2 15]]
# Confusion Matrix for Batch = 493 is [[18  1  4  8]
#  [ 2  4  2  5]
#  [ 0  2 19  5]
#  [ 1  2  6 21]]
# Confusion Matrix for Batch = 494 is [[ 8  1  3  4]
#  [ 1 16  0  6]
#  [ 1  0 25  1]
#  [ 3  2 11 18]]
# Confusion Matrix for Batch = 495 is [[14  0  4  2]
#  [ 4 13  1  2]
#  [ 1  1 19  5]
# ...
#  [ 3 11  2  5]
#  [ 2  0 13  3]
#  [ 2  0  6 22]]
# Confusion Matrix for Batch = 1040 is [[10  3  2  5]
#  [ 2 13  5  2]
#  [ 4  1 12  3]
#  [ 1  1 10 26]]
# Confusion Matrix for Batch = 1041 is [[11  3  1  0]
#  [ 0 15  1  7]
#  [ 2  0 14  8]
#  [ 5  1  8 24]]
# Confusion Matrix for Batch = 1042 is [[ 8  1  5  5]
#  [ 0 16  0  4]
#  [ 0  0 21  6]
#  [ 2  1  8 23]]
# Confusion Matrix for Batch = 1043 is [[10  4  3  2]
#  [ 3 26  0  6]
#  [ 0  0 12  7]
#  [ 3  1  9 14]]
# Confusion Matrix for Batch = 1044 is [[ 8  2  5  1]
#  [ 5 13  3  2]
#  [ 3  0 24  3]
#  [ 4  2  2 23]]
# Confusion Matrix for Batch = 1045 is [[18  4  4  3]
#  [ 5 20  1  2]
#  [ 1  0 12  5]
#  [ 3  2  5 15]]
# Confusion Matrix for Batch = 1046 is [[10  2  1  5]
#  [ 3 21  6  1]
#  [ 5  1  8  3]
#  [ 4  3  4 23]]
# Confusion Matrix for Batch = 1047 is [[15  3  5  1]
#  [ 2 20  4  1]
#  [ 3  0 12  1]
#  [ 5  1 12 15]]
# Confusion Matrix for Batch = 1048 is [[18  1  2  2]
#  [ 4 17  4  2]
#  [ 0  0 15  4]
#  [ 7  2 14  8]]
# Confusion Matrix for Batch = 1049 is [[21  1  0  3]
#  [ 3 25  1  1]
#  [ 3  0 13  4]
#  [ 4  0 11 10]]
# Confusion Matrix for Batch = 1050 is [[11  0  1  6]
#  [ 4 14  5  2]
#  [ 0  0 19  7]
#  [ 2  1  7 21]]
# Confusion Matrix for Batch = 1051 is [[15  1  2  2]
#  [ 3 17  2  1]
#  [ 0  0 24  2]
#  [ 2  0  8 21]]
# Confusion Matrix for Batch = 1052 is [[25  2  3  4]
#  [ 4 18  1  0]
#  [ 2  0 24  3]
#  [ 4  1  2  7]]
# Confusion Matrix for Batch = 1053 is [[16  3  1  5]
#  [ 3 15  1  2]
#  [ 2  0 18  2]
#  [ 4  4  3 21]]
# Confusion Matrix for Batch = 1054 is [[ 8  3  5  7]
#  [ 1  8  3  4]
#  [ 1  0 23  4]
#  [ 3  4  4 22]]
# Confusion Matrix for Batch = 1055 is [[11  1  4  1]
#  [ 3 21  3  3]
#  [ 2  0 22  5]
#  [ 3  1  3 17]]
# Confusion Matrix for Batch = 1056 is [[11  3  0  0]
#  [ 5 10  3  3]
#  [ 1  1 23  2]
#  [ 4  3  6 25]]
# Confusion Matrix for Batch = 1057 is [[13  4  1  5]
#  [ 0 18  3  5]
#  [ 3  1  9  6]
#  [ 2  2  3 25]]
# Confusion Matrix for Batch = 1058 is [[21  3  5  1]
#  [ 2 29  4  0]
#  [ 0  0  8  4]
#  [ 4  1  5 13]]
# Confusion Matrix for Batch = 1059 is [[17  3  3  6]
#  [ 0 20  2  1]
#  [ 2  1 15  2]
#  [ 2  4  6 16]]
# Confusion Matrix for Batch = 1060 is [[10  4  2  2]
#  [ 3 24  5  1]
#  [ 1  2 16  1]
#  [ 6  3 15  5]]
# Confusion Matrix for Batch = 1061 is [[16  1  3  0]
#  [ 2 12  1  1]
#  [ 2  1 25  4]
#  [ 5  3 12 12]]
# Confusion Matrix for Batch = 1062 is [[20  0  3 10]
#  [ 1 14  2  2]
#  [ 2  0 15  4]
#  [ 3  3  3 18]]
# Confusion Matrix for Batch = 1063 is [[12  2  4  2]
#  [ 4 16  4  4]
#  [ 0  0 21  2]
#  [ 2  4  5 18]]
# Confusion Matrix for Batch = 1064 is [[17  0  4  6]
#  [ 4 14  1  2]
#  [ 0  0 15  5]
#  [ 3  2  3 24]]
# Confusion Matrix for Batch = 1065 is [[ 9  3  2  2]
#  [ 3 14  4  4]
#  [ 1  0 19  2]
#  [ 5  5  5 22]]
# Confusion Matrix for Batch = 1066 is [[19  0  3  2]
#  [ 4 17  3  3]
#  [ 3  0 17  2]
#  [ 4  1  3 19]]
# Confusion Matrix for Batch = 1067 is [[18  1  3  3]
#  [ 2 34  1  3]
#  [ 3  0  7  3]
#  [ 8  0  7  7]]
# Confusion Matrix for Batch = 1068 is [[ 6  2  2  9]
#  [ 2 17  3  4]
#  [ 0  1 14  3]
#  [ 1  2  2 32]]
# Confusion Matrix for Batch = 1069 is [[ 7  0  1  6]
#  [ 2 14  4  7]
#  [ 2  1 11  8]
#  [ 3  1  6 27]]
# Confusion Matrix for Batch = 1070 is [[18  2  3  2]
#  [ 1 27  2  2]
#  [ 5  0 15  3]
#  [ 4  2  6  8]]
# Confusion Matrix for Batch = 1071 is [[20  2  4  1]
#  [ 3 17  2  1]
#  [ 3  0 17  2]
#  [ 4  2  9 13]]
# Confusion Matrix for Batch = 1072 is [[16  0  3  3]
#  [ 1 16  3  5]
#  [ 0  0 10  4]
#  [ 3  2  1 33]]
# Confusion Matrix for Batch = 1073 is [[10  2  5  4]
#  [ 0 22  3  3]
#  [ 2  1 15  3]
#  [ 5  2  8 15]]
# Confusion Matrix for Batch = 1074 is [[15  2  4  1]
#  [ 4 22  5  2]
#  [ 1  0 24  3]
#  [ 2  2  6  7]]
# Confusion Matrix for Batch = 1075 is [[10  3  6  6]
#  [ 3 15  3  2]
#  [ 4  1 15  7]
#  [ 1  2  3 19]]
# Confusion Matrix for Batch = 1076 is [[15  1  3  4]
#  [ 3 17  1  5]
#  [ 1  0 10  4]
#  [ 3  4  2 27]]
# Confusion Matrix for Batch = 1077 is [[10  4  2  0]
#  [ 3 15  3  3]
#  [ 1  2 27  2]
#  [ 6  3  7 12]]
# Confusion Matrix for Batch = 1078 is [[22  2  1  2]
#  [ 1 20  2  4]
#  [ 0  2 19  4]
#  [ 2  4  5 10]]
# Confusion Matrix for Batch = 1079 is [[25  2  2  1]
#  [ 5 21  4  0]
#  [ 2  2 13  0]
#  [ 5  7  9  2]]
# Confusion Matrix for Batch = 1080 is [[14  2  4  1]
#  [ 3 13  3  3]
#  [ 3  0 17  5]
#  [ 2  2  6 22]]
# Confusion Matrix for Batch = 1081 is [[16  1  5  1]
#  [ 2 19  3  2]
#  [ 1  0 22  1]
#  [ 3  1  4 19]]
# Confusion Matrix for Batch = 1082 is [[15  2  4  0]
#  [ 0 14  2  5]
#  [ 3  0 22  3]
#  [ 3  2  5 20]]
# Confusion Matrix for Batch = 1083 is [[16  3  5  2]
#  [ 0 15  4  0]
#  [ 0  1 25  3]
#  [ 2  2  6 16]]
# Confusion Matrix for Batch = 1084 is [[14  1  3 10]
#  [ 3 11  3  7]
#  [ 2  0 17  1]
#  [ 4  4  6 14]]
# Confusion Matrix for Batch = 1085 is [[20  2  3  3]
#  [ 0 20  1  4]
#  [ 0  0 20  5]
#  [ 1  2  2 17]]
# Confusion Matrix for Batch = 1086 is [[ 8  4  4  5]
#  [ 1 20  4  1]
#  [ 2  1  6  5]
#  [ 1  4  4 30]]
# Confusion Matrix for Batch = 1087 is [[16  4  1  2]
#  [ 0 37  5  1]
#  [ 2  0  5  2]
#  [ 3  5 10  7]]
# Confusion Matrix for Batch = 1088 is [[23  3  3  1]
#  [ 2 34  4  1]
#  [ 0  1 10  0]
#  [ 3  3  3  9]]
# Confusion Matrix for Batch = 1089 is [[23  6  1  4]
#  [ 5 21  0  4]
#  [ 2  0 13  2]
#  [ 3  5  3  8]]
# Confusion Matrix for Batch = 1090 is [[18  3  1  6]
#  [ 5 14  2  4]
#  [ 1  1  8  2]
#  [ 3  0  3 29]]
# Confusion Matrix for Batch = 1091 is [[14  1  2  2]
#  [ 1 21  3  3]
#  [ 2  0 17  3]
#  [ 4  3 10 14]]
# Confusion Matrix for Batch = 1092 is [[19  4  1  1]
#  [ 4 13  1  1]
#  [ 1  1 18  8]
#  [ 4  1  5 18]]
# Confusion Matrix for Batch = 1093 is [[13  2  0  3]
#  [ 2 25  1  3]
#  [ 1  1 13  2]
#  [ 5  3  1 25]]
# Confusion Matrix for Batch = 1094 is [[11  2  3  3]
#  [ 2 24  5  3]
#  [ 2  0 17  3]
#  [ 2  2  5 16]]
# Confusion Matrix for Batch = 1095 is [[16  1  6  4]
#  [ 3 37  0  1]
#  [ 1  1  7  2]
#  [ 2  5  6  8]]
# Confusion Matrix for Batch = 1096 is [[21  3  2  1]
#  [ 2 26  2  1]
#  [ 1  1 19  2]
#  [ 4  0  4 11]]
# Confusion Matrix for Batch = 1097 is [[20  4  4  1]
#  [ 0 23  5  2]
#  [ 2  0 22  3]
#  [ 2  3  4  5]]
# Confusion Matrix for Batch = 1098 is [[13  3  2  4]
#  [ 1 21  2  4]
#  [ 3  1 14  2]
#  [ 7  2  2 19]]
# Confusion Matrix for Batch = 1099 is [[16  1  4  2]
#  [ 2 22  2  4]
#  [ 2  0 21  4]
#  [ 2  0  7 11]]
# Confusion Matrix for Batch = 1100 is [[24  5  1  1]
#  [ 1 17  1  3]
#  [ 1  0 16  3]
#  [ 2  1  7 17]]
# Confusion Matrix for Batch = 1101 is [[13  4  5  0]
#  [ 3 16  5  3]
#  [ 2  0 22  3]
#  [ 4  1  5 14]]
# Confusion Matrix for Batch = 1102 is [[10  3  4 10]
#  [ 1 15  1  0]
#  [ 4  0  9  6]
#  [ 1  3  7 26]]
# Confusion Matrix for Batch = 1103 is [[10  1  4  9]
#  [ 1 18  0  8]
#  [ 3  1 17  2]
#  [ 0  2  6 18]]
# Confusion Matrix for Batch = 1104 is [[12  1  6  0]
#  [ 3 21  4  4]
#  [ 2  2 23  2]
#  [ 0  2  5 13]]
# Confusion Matrix for Batch = 1105 is [[22  3  4  1]
#  [ 2 26  4  3]
#  [ 3  0  6  4]
#  [ 3  2  4 13]]
# Confusion Matrix for Batch = 1106 is [[11  3  1  4]
#  [ 3 26  1  3]
#  [ 2  0 10  4]
#  [ 2  2  5 23]]
# Confusion Matrix for Batch = 1107 is [[13  1  6  3]
#  [ 0 22  3  6]
#  [ 3  0 11  5]
#  [ 4  0  1 22]]
# Confusion Matrix for Batch = 1108 is [[17  1  7  6]
#  [ 2 11  4  5]
#  [ 3  0 13  3]
#  [ 8  3  5 12]]
# Confusion Matrix for Batch = 1109 is [[23  1  5  3]
#  [ 2 12  1  5]
#  [ 3  0 22  1]
#  [ 3  1  9  9]]
# Confusion Matrix for Batch = 1110 is [[13  1  4  1]
#  [ 3 20  3  4]
#  [ 4  0 21  2]
#  [ 2  3  6 13]]
# Confusion Matrix for Batch = 1111 is [[10  4  2  2]
#  [ 1 11  3  3]
#  [ 1  0 31  4]
#  [ 8  1  4 15]]
# Confusion Matrix for Batch = 1112 is [[12  1  1  4]
#  [ 3 15  2  1]
#  [ 2  1 25  4]
#  [ 4  4  7 14]]
# Confusion Matrix for Batch = 1113 is [[20  2  1  7]
#  [ 1 15  2  1]
#  [ 1  0  8  4]
#  [ 1  0  2 35]]
# Confusion Matrix for Batch = 1114 is [[11  2  2  5]
#  [ 4 18  1  7]
#  [ 1  1 21  2]
#  [ 1  1  5 18]]
# Confusion Matrix for Batch = 1115 is [[ 9  1  1 10]
#  [ 5  7  2  6]
#  [ 1  0 19  2]
#  [ 4  5  6 22]]
# Confusion Matrix for Batch = 1116 is [[ 9  1  2  5]
#  [ 3 20  4  1]
#  [ 0  0 19  2]
#  [ 2  2  4 26]]
# Confusion Matrix for Batch = 1117 is [[14  3  4  3]
#  [ 3 19  6  2]
#  [ 2  1 14  3]
#  [ 7  3  5 11]]
# Confusion Matrix for Batch = 1118 is [[11  6  9  1]
#  [ 1 26  5  2]
#  [ 2  1 12  1]
#  [ 2  5  9  7]]
# Confusion Matrix for Batch = 1119 is [[16  2  4  2]
#  [ 2 19  2  2]
#  [ 2  2 19  1]
#  [ 2  5  1 19]]
# Confusion Matrix for Batch = 1120 is [[16  4  4  2]
#  [ 0 27  5  3]
#  [ 2  0 10  1]
#  [ 6  4  8  8]]
# Confusion Matrix for Batch = 1121 is [[11  3  1  7]
#  [ 2 19  0  4]
#  [ 1  0 17  5]
#  [ 4  0  5 21]]
# Confusion Matrix for Batch = 1122 is [[13  0  6  1]
#  [ 4 16  5  2]
#  [ 1  0 21  3]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 1123 is [[13  3  3  1]
#  [ 5 20  2  2]
#  [ 0  0 17  2]
#  [ 5  1  4 22]]
# Confusion Matrix for Batch = 1124 is [[17  1  4  3]
#  [ 6 14  0  4]
#  [ 0  0 17  4]
#  [ 3  3  6 18]]
# Confusion Matrix for Batch = 1125 is [[18  2  2  1]
#  [ 1 19  2  2]
#  [ 0  2 23  2]
#  [ 3  5  3 15]]
# Confusion Matrix for Batch = 1126 is [[23  2  4  0]
#  [ 3 18  2  2]
#  [ 1  2 20  5]
#  [ 3  0  6  9]]
# Confusion Matrix for Batch = 1127 is [[13  2  1  8]
#  [ 2 14  2  4]
#  [ 0  1  8  3]
#  [ 1  3  8 30]]
# Confusion Matrix for Batch = 1128 is [[13  3  1  5]
#  [ 1 24  4  1]
#  [ 0  1 14  0]
#  [ 7  3 10 13]]
# Confusion Matrix for Batch = 1129 is [[17  3  3  4]
#  [ 6 28  4  2]
#  [ 1  0 10  1]
#  [ 4  4  7  6]]
# Confusion Matrix for Batch = 1130 is [[23  0  4  1]
#  [ 4 21  1  1]
#  [ 3  1 12  1]
#  [ 5  2  8 13]]
# Confusion Matrix for Batch = 1131 is [[24  2  6  0]
#  [ 4 38  0  2]
#  [ 0  1  7  1]
#  [ 6  3  1  5]]
# Confusion Matrix for Batch = 1132 is [[23  2  2  1]
#  [ 6 38  2  0]
#  [ 0  4  5  2]
#  [ 2  4  2  7]]
# Confusion Matrix for Batch = 1133 is [[28  0  1  3]
#  [ 3 40  2  2]
#  [ 0  0  3  0]
#  [ 4  2 10  2]]
# Confusion Matrix for Batch = 1134 is [[20  1  3  0]
#  [ 2 42  1  2]
#  [ 0  1  5  0]
#  [ 1  4 10  8]]
# Confusion Matrix for Batch = 1135 is [[32  4  3  2]
#  [ 7 32  1  1]
#  [ 2  0  1  0]
#  [ 3  4  3  5]]
# Confusion Matrix for Batch = 1136 is [[35  1  0  0]
#  [ 5 19  0  4]
#  [ 2  0 12  4]
#  [ 6  0  4  8]]
# Confusion Matrix for Batch = 1137 is [[22  3  3  4]
#  [ 4 29  3  2]
#  [ 1  1  5  3]
#  [ 5  1  5  9]]
# Confusion Matrix for Batch = 1138 is [[21  2  0  2]
#  [ 6 33  1  1]
#  [ 1  0  9  4]
#  [ 5  1  2 12]]
# Confusion Matrix for Batch = 1139 is [[15  1  4  1]
#  [ 6 25  2  3]
#  [ 1  2 18  1]
#  [ 4  3  3 11]]
# Confusion Matrix for Batch = 1140 is [[13  3  3  4]
#  [ 1 23  3  6]
#  [ 2  0 10  1]
#  [ 8  1  6 16]]
# Confusion Matrix for Batch = 1141 is [[18  1  3  6]
#  [ 2 26  0  0]
#  [ 3  1 18  2]
#  [ 4  2  4 10]]
# Confusion Matrix for Batch = 1142 is [[ 8  0  2  1]
#  [ 4 20  0  3]
#  [ 4  0 18  5]
#  [ 5  1  4 25]]
# Confusion Matrix for Batch = 1143 is [[ 9  1  3  3]
#  [ 5 15  0  5]
#  [ 0  0 31  1]
#  [ 8  1  7 11]]
# Confusion Matrix for Batch = 1144 is [[14  1  4  7]
#  [ 0 11  0  2]
#  [ 2  0 26  4]
#  [ 0  1  4 24]]
# Confusion Matrix for Batch = 1145 is [[23  2  5  1]
#  [ 2 11  0  2]
#  [ 0  1 29  4]
#  [ 5  1  8  6]]
# Confusion Matrix for Batch = 1146 is [[15  1  2  4]
#  [ 3 18  2  3]
#  [ 1  0 14  1]
#  [ 2  2 11 21]]
# Confusion Matrix for Batch = 1147 is [[13  0  1  4]
#  [ 3 26  1  1]
#  [ 0  1 16  3]
#  [ 4  1  3 23]]
# Confusion Matrix for Batch = 1148 is [[16  1  0  1]
#  [ 4 26  1  5]
#  [ 1  0 21  3]
#  [ 0  0  2 19]]
# Confusion Matrix for Batch = 1149 is [[10  2  1  2]
#  [ 1 16  0  7]
#  [ 0  0 10  6]
#  [ 0  2  5 38]]
# Confusion Matrix for Batch = 1150 is [[13  1  6  1]
#  [ 1 23  3  5]
#  [ 4  0 14  2]
#  [ 6  1  9 11]]
# Confusion Matrix for Batch = 1151 is [[ 9  2  5  1]
#  [ 3 29  4  4]
#  [ 1  0 13  0]
#  [ 3  0  4 22]]
# Confusion Matrix for Batch = 1152 is [[20  0  1  3]
#  [ 0 26  4  0]
#  [ 4  0 14  2]
#  [ 3  1  4 18]]
# Confusion Matrix for Batch = 1153 is [[22  1  2  1]
#  [ 5 19  2  0]
#  [ 0  1 18  3]
#  [ 3  1  9 13]]
# Confusion Matrix for Batch = 1154 is [[21  0  4  4]
#  [ 3 14  1  4]
#  [ 0  1 17  9]
#  [ 0  1  3 18]]
# Confusion Matrix for Batch = 1155 is [[18  0  0  3]
#  [ 1  9  0  4]
#  [ 2  0 17  6]
#  [ 6  0  4 30]]
# Confusion Matrix for Batch = 1156 is [[16  2  1  2]
#  [ 2  4  1  3]
#  [ 1  0 30  7]
#  [ 5  0  4 22]]
# Confusion Matrix for Batch = 1157 is [[12  2  0  3]
#  [ 1 11  3  4]
#  [ 1  1 15  5]
#  [ 2  2 12 26]]
# Confusion Matrix for Batch = 1158 is [[14  0  1  4]
#  [ 3 11  1  3]
#  [ 1  0 21  4]
#  [ 2  2  4 29]]
# Confusion Matrix for Batch = 1159 is [[12  0  1  6]
#  [ 3 17  1  1]
#  [ 3  0 14  7]
#  [ 8  0  4 23]]
# Confusion Matrix for Batch = 1160 is [[13  6  1  0]
#  [ 5 25  3  4]
#  [ 1  3 16  6]
#  [ 4  1  2 10]]
# Confusion Matrix for Batch = 1161 is [[19  5  2  3]
#  [ 2 18  2  2]
#  [ 2  0 18  0]
#  [ 2  5  5 15]]
# Confusion Matrix for Batch = 1162 is [[20  0  1  5]
#  [ 1 24  0  6]
#  [ 4  0 11  3]
#  [ 1  2  5 17]]
# Confusion Matrix for Batch = 1163 is [[18  2  3  1]
#  [ 2 28  6  2]
#  [ 0  0 19  2]
#  [ 3  2  7  5]]
# Confusion Matrix for Batch = 1164 is [[26  0  2  1]
#  [ 0 26  2  2]
#  [ 3  0 10  1]
#  [ 2  4 11 10]]
# Confusion Matrix for Batch = 1165 is [[25  0  3  2]
#  [ 1 15  3  2]
#  [ 0  0 21  2]
#  [ 8  3  2 13]]
# Confusion Matrix for Batch = 1166 is [[13  2  4  1]
#  [ 1  7  1  3]
#  [ 1  0 30  4]
#  [ 4  1 12 16]]
# Confusion Matrix for Batch = 1167 is [[17  1  2  3]
#  [ 1 17  4  5]
#  [ 1  2 27  2]
#  [ 2  1  2 13]]
# Confusion Matrix for Batch = 1168 is [[19  4  2  1]
#  [ 2 14  4  3]
#  [ 2  0 20  3]
#  [ 1  3 13  9]]
# Confusion Matrix for Batch = 1169 is [[22  3  2  2]
#  [ 5 16  1  4]
#  [ 1  0 20  5]
#  [ 3  3  5  8]]
# Confusion Matrix for Batch = 1170 is [[10  4  2  7]
#  [ 3 12  0  6]
#  [ 1  1 13  2]
#  [ 1  0  3 35]]
# Confusion Matrix for Batch = 1171 is [[13  0  5  0]
#  [ 1 20  4  6]
#  [ 0  1 17  6]
#  [ 1  1  3 22]]
# Confusion Matrix for Batch = 1172 is [[23  2  2  4]
#  [ 0 19  0  2]
#  [ 1  2 19  4]
#  [ 4  1  2 15]]
# Confusion Matrix for Batch = 1173 is [[15  5  2  4]
#  [ 6 24  1  3]
#  [ 0  1 12  4]
#  [ 7  0  6 10]]
# Confusion Matrix for Batch = 1174 is [[ 5  1  3  4]
#  [ 1 23  1  2]
#  [ 1  0 18  4]
#  [ 5  7  6 19]]
# Confusion Matrix for Batch = 1175 is [[12  1  5  2]
#  [ 2 22  1  2]
#  [ 1  1 18  0]
#  [ 0  2  3 28]]
# Confusion Matrix for Batch = 1176 is [[12  1  6  3]
#  [ 3 30  3  0]
#  [ 1  0 18  0]
#  [ 3  4  8  8]]
# Confusion Matrix for Batch = 1177 is [[20  1  2  2]
#  [ 7 26  3  4]
#  [ 1  1 13  1]
#  [ 6  3  3  7]]
# Confusion Matrix for Batch = 1178 is [[19  2  7  3]
#  [ 5  7  1  4]
#  [ 1  0 27  1]
#  [ 2  2  1 18]]
# Confusion Matrix for Batch = 1179 is [[19  2  1  3]
#  [ 1 16  1  0]
#  [ 0  0 27  1]
#  [ 8  2  7 12]]
# Confusion Matrix for Batch = 1180 is [[14  1  1  3]
#  [ 3 14  0  3]
#  [ 1  0 34  6]
#  [ 0  1  4 15]]
# Confusion Matrix for Batch = 1181 is [[24  3  4  0]
#  [ 1 18  1  4]
#  [ 1  3 22  1]
#  [10  0  5  3]]
# Confusion Matrix for Batch = 1182 is [[ 9  1  3  1]
#  [ 3 20  2  3]
#  [ 0  0 35  2]
#  [ 3  1  5 12]]
# Confusion Matrix for Batch = 1183 is [[ 6  5  1  2]
#  [ 0 28  2  3]
#  [ 0  0 15  3]
#  [ 3  5  3 24]]
# Confusion Matrix for Batch = 1184 is [[22  2  0  3]
#  [ 2 20  1  4]
#  [ 1  0 11  6]
#  [ 3  0  3 22]]
# Confusion Matrix for Batch = 1185 is [[20  2  2  1]
#  [ 4 28  5  2]
#  [ 1  1 14  2]
#  [ 4  5  2  7]]
# Confusion Matrix for Batch = 1186 is [[22  1  7  2]
#  [ 2 26  2  3]
#  [ 1  0 15  2]
#  [ 5  3  1  8]]
# Confusion Matrix for Batch = 1187 is [[15  0  2  5]
#  [ 2 18  2  2]
#  [ 1  0 17  2]
#  [ 2  3  7 22]]
# Confusion Matrix for Batch = 1188 is [[19  1  4  1]
#  [ 2 31  6  2]
#  [ 0  0 12  0]
#  [ 1  6  5 10]]
# Confusion Matrix for Batch = 1189 is [[23  2  2  6]
#  [ 6 11  1  4]
#  [ 1  0 16  4]
#  [ 7  0  3 14]]
# Confusion Matrix for Batch = 1190 is [[17  1  2  8]
#  [ 2  8  1  2]
#  [ 0  0 15  1]
#  [ 5  0  5 33]]
# Confusion Matrix for Batch = 1191 is [[12  3  3  2]
#  [ 3 15  0  3]
#  [ 1  0 22  2]
#  [ 4  1  5 24]]
# Confusion Matrix for Batch = 1192 is [[15  3  3  8]
#  [ 2 16  0  4]
#  [ 1  1 20  3]
#  [ 1  0  5 18]]
# Confusion Matrix for Batch = 1193 is [[ 7  0  3  2]
#  [ 0 19  3  3]
#  [ 2  1 24  0]
#  [ 3  2  9 22]]
# Confusion Matrix for Batch = 1194 is [[12  1  3  2]
#  [ 2 26  3  0]
#  [ 0  2 20  5]
#  [ 2  2  4 16]]
# Confusion Matrix for Batch = 1195 is [[18  2  4  4]
#  [ 2 27  2  2]
#  [ 2  0 11  4]
#  [ 3  2  6 11]]
# Confusion Matrix for Batch = 1196 is [[17  3  2  3]
#  [ 5 28  1  1]
#  [ 5  0 14  0]
#  [ 4  2  4 11]]
# Confusion Matrix for Batch = 1197 is [[17  1  2  2]
#  [ 7 28  2  1]
#  [ 3  1 12  0]
#  [ 2  5  4 13]]
# Confusion Matrix for Batch = 1198 is [[21  0  6  1]
#  [ 5 31  4  1]
#  [ 0  1 11  1]
#  [ 5  2  2  9]]
# Confusion Matrix for Batch = 1199 is [[22  2  8  1]
#  [ 5 23  2  2]
#  [ 2  0  9  2]
#  [ 4  2  4 12]]
# Training Set Accuracy = 0.6593083333333334	Recall = 0.6593083333333333	Precision = 0.6765449766940893	F1-Score = 0.657648546112857	Loss = 0.008505964651703835	Confusion Matrix = [[22  2  8  1]
#  [ 5 23  2  2]
#  [ 2  0  9  2]
#  [ 4  2  4 12]]

# %%
batch_size = len(data['Description'])
model.eval()
correct = 0
test_loss = 0
precision = []
f1 = []
recall = []


for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
            else:
                batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()

    pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
    true = y_true.cpu().numpy()
    precision.append(precision_score(pred, true, average='weighted'))
    f1.append(f1_score(pred, true, average='weighted'))
    recall.append(recall_score(pred, true, average='weighted'))
    confusion = confusion_matrix(pred, true)
    print(f"Confusion Matrix for Batch = {i} is {confusion}")

print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Confusion Matrix for Batch = 0 is [[1044  246  279  281]
#  [ 337 1336  215  283]
#  [ 191  102  945  308]
#  [ 328  216  461 1028]]
# Testing Set Accuracy = 0.5727631578947369	Recall = 0.5727631578947369	Precision = 0.5805228531855956	F1-Score = 0.5744343303162504	Loss = 0.00013605097774416208

# %% [markdown]
# # Context Window = 2 Ends

# %%
svd_embeddings = torch.load("svd-word-vectors3.pt")
word_indices = torch.load("svd-word-vectors-indices3.pt")
svd_embeddings, word_indices
# Out:
# (array([[-9.01066197e-15, -1.71121577e-13, -8.82430860e-14, ...,
#           1.57304066e-13, -4.09256349e-14, -2.39124909e-14],
#         [ 5.80255324e-28,  8.16976304e-15,  2.93527932e-14, ...,
#          -9.44907305e-13, -4.64221078e-13,  5.41019825e-15],
#         [-4.15031838e-18, -5.47289015e-18, -2.32481956e-30, ...,
#           2.13290499e-19,  2.33853486e-20, -1.10237769e-19],
#         ...,
#         [-8.05791672e-20, -1.38983849e-19,  7.40694056e-21, ...,
#           5.20207690e-21,  6.06631818e-22, -2.64448132e-21],
#         [-1.03028247e-19, -1.78149804e-19,  8.99622451e-21, ...,
#           7.13478398e-21,  7.89125644e-22, -3.70537474e-21],
#         [ 3.53817378e-20,  6.15234070e-20, -2.96573923e-21, ...,
#          -2.57094333e-21, -2.84597033e-22,  1.34442118e-21]]),
#  {'Reuters': 0,
#   '-': 1,
#   'Short': 2,
#   'sellers': 3,
#   ',': 4,
#   'Wall': 5,
#   "Street's": 6,
#   'dwindling': 7,
#   'band': 8,
#   'of': 9,
#   'ultra': 10,
#   'cynics': 11,
#   'are': 12,
#   'seeing': 13,
#   'green': 14,
#   'again': 15,
#   '.': 16,
#   'Private': 17,
#   'investment': 18,
#   'firm': 19,
#   'Carlyle': 20,
#   'Group': 21,
#   'which': 22,
#   'has': 23,
#   'a': 24,
#   'reputation': 25,
#   'for': 26,
#   'making': 27,
#   'well': 28,
#   'timed': 29,
#   'and': 30,
#   'occasionally': 31,
#   'controversial': 32,
#   'plays': 33,
#   'in': 34,
#   'the': 35,
#   'defense': 36,
#   'industry': 37,
#   'quietly': 38,
#   'placed': 39,
#   'its': 40,
#   'bets': 41,
#   'on': 42,
#   'another': 43,
#   'part': 44,
#   'market': 45,
#   'Soaring': 46,
#   'crude': 47,
#   'prices': 48,
#   'plus': 49,
#   'worries': 50,
#   'about': 51,
#   'economy': 52,
#   'outlook': 53,
#   'earnings': 54,
#   'expected': 55,
#   'to': 56,
#   'hang': 57,
#   'over': 58,
#   'stock': 59,
#   'next': 60,
#   'week': 61,
#   'during': 62,
#   'depth': 63,
#   'summer': 64,
#   'doldrums': 65,
#   'Authorities': 66,
#   'have': 67,
#   'halted': 68,
#   'oil': 69,
#   'export': 70,
#   'flows': 71,
#   'from': 72,
#   'main': 73,
#   'pipeline': 74,
#   'southern': 75,
#   'Iraq': 76,
#   'after': 77,
#   'intelligence': 78,
#   'showed': 79,
#   'rebel': 80,
#   'militia': 81,
#   'could': 82,
#   'strike': 83,
#   'infrastructure': 84,
#   'an': 85,
#   'official': 86,
#   'said': 87,
#   'Saturday': 88,
#   'AFP': 89,
#   'Tearaway': 90,
#   'world': 91,
#   'toppling': 92,
#   'records': 93,
#   'straining': 94,
#   'wallets': 95,
#   'present': 96,
#   'new': 97,
#   'economic': 98,
#   'menace': 99,
#   'barely': 100,
#   'three': 101,
#   'months': 102,
#   'before': 103,
#   'US': 104,
#   'presidential': 105,
#   'elections': 106,
#   'Stocks': 107,
#   'ended': 108,
#   'slightly': 109,
#   'higher': 110,
#   'Friday': 111,
#   'but': 112,
#   'stayed': 113,
#   'near': 114,
#   'lows': 115,
#   'year': 116,
#   'as': 117,
#   'surged': 118,
#   'past': 119,
#   '36': 120,
#   ';': 121,
#   '46': 122,
#   'barrel': 123,
#   'offsetting': 124,
#   'positive': 125,
#   'computer': 126,
#   'maker': 127,
#   'Dell': 128,
#   'Inc': 129,
#   'DELL': 130,
#   'O': 131,
#   'AP': 132,
#   'Assets': 133,
#   "nation's": 134,
#   'retail': 135,
#   'money': 136,
#   'mutual': 137,
#   'funds': 138,
#   'fell': 139,
#   'by': 140,
#   '1': 141,
#   '17': 142,
#   'billion': 143,
#   'latest': 144,
#   '849': 145,
#   '98': 146,
#   'trillion': 147,
#   'Investment': 148,
#   'Company': 149,
#   'Institute': 150,
#   'Thursday': 151,
#   'USATODAY': 152,
#   'com': 153,
#   'Retail': 154,
#   'sales': 155,
#   'bounced': 156,
#   'back': 157,
#   'bit': 158,
#   'July': 159,
#   'claims': 160,
#   'jobless': 161,
#   'benefits': 162,
#   'last': 163,
#   'government': 164,
#   'indicating': 165,
#   'is': 166,
#   'improving': 167,
#   'midsummer': 168,
#   'slump': 169,
#   'Forbes': 170,
#   'After': 171,
#   'earning': 172,
#   'PH': 173,
#   'D': 174,
#   'Sociology': 175,
#   'Danny': 176,
#   'Bazil': 177,
#   'Riley': 178,
#   'started': 179,
#   'work': 180,
#   'general': 181,
#   'manager': 182,
#   'at': 183,
#   'commercial': 184,
#   'real': 185,
#   'estate': 186,
#   'annual': 187,
#   'base': 188,
#   'salary': 189,
#   '70': 190,
#   '000': 191,
#   'Soon': 192,
#   'financial': 193,
#   'planner': 194,
#   'stopped': 195,
#   'his': 196,
#   'desk': 197,
#   'drop': 198,
#   'off': 199,
#   'brochures': 200,
#   'insurance': 201,
#   'available': 202,
#   'through': 203,
#   'employer': 204,
#   'But': 205,
#   '32': 206,
#   'buying': 207,
#   'was': 208,
#   'furthest': 209,
#   'thing': 210,
#   'my': 211,
#   'mind': 212,
#   'says': 213,
#   'NEW': 214,
#   'YORK': 215,
#   'TEHRAN': 216,
#   'OPEC': 217,
#   'can': 218,
#   'do': 219,
#   'nothing': 220,
#   'douse': 221,
#   'scorching': 222,
#   'when': 223,
#   'markets': 224,
#   'already': 225,
#   'oversupplied': 226,
#   '2': 227,
#   '8': 228,
#   'million': 229,
#   'barrels': 230,
#   'per': 231,
#   'day': 232,
#   'bpd': 233,
#   "Iran's": 234,
#   'governor': 235,
#   'warning': 236,
#   'that': 237,
#   'fall': 238,
#   'sharply': 239,
#   'JAKARTA': 240,
#   'Non': 241,
#   'exporters': 242,
#   'should': 243,
#   'consider': 244,
#   'increasing': 245,
#   'output': 246,
#   'cool': 247,
#   'record': 248,
#   'President': 249,
#   'Purnomo': 250,
#   'Yusgiantoro': 251,
#   'Sunday': 252,
#   'WASHINGTON': 253,
#   'The': 254,
#   'auction': 255,
#   'Google': 256,
#   "'s": 257,
#   'highly': 258,
#   'anticipated': 259,
#   'initial': 260,
#   'public': 261,
#   'offering': 262,
#   'got': 263,
#   'rocky': 264,
#   'start': 265,
#   'Web': 266,
#   'search': 267,
#   'company': 268,
#   'sidestepped': 269,
#   'bullet': 270,
#   'U': 271,
#   'S': 272,
#   'securities': 273,
#   'regulators': 274,
#   'dollar': 275,
#   'tumbled': 276,
#   'broadly': 277,
#   'data': 278,
#   'showing': 279,
#   'trade': 280,
#   'deficit': 281,
#   'June': 282,
#   'cast': 283,
#   'fresh': 284,
#   'doubts': 285,
#   "economy's": 286,
#   'recovery': 287,
#   'ability': 288,
#   'draw': 289,
#   'foreign': 290,
#   'capital': 291,
#   'fund': 292,
#   'growing': 293,
#   'gap': 294,
#   'If': 295,
#   'you': 296,
#   'think': 297,
#   'may': 298,
#   'need': 299,
#   'help': 300,
#   'your': 301,
#   'elderly': 302,
#   'relatives': 303,
#   'with': 304,
#   'their': 305,
#   'finances': 306,
#   "don't": 307,
#   'be': 308,
#   'shy': 309,
#   'having': 310,
#   'talk': 311,
#   'soon': 312,
#   'purchasing': 313,
#   'power': 314,
#   'kids': 315,
#   'big': 316,
#   'why': 317,
#   'school': 318,
#   'season': 319,
#   'become': 320,
#   'such': 321,
#   'huge': 322,
#   'marketing': 323,
#   'phenomenon': 324,
#   'There': 325,
#   'little': 326,
#   'cause': 327,
#   'celebration': 328,
#   'these': 329,
#   'days': 330,
#   'investors': 331,
#   'value': 332,
#   'focused': 333,
#   'reason': 334,
#   'feel': 335,
#   'smug': 336,
#   'if': 337,
#   'only': 338,
#   'because': 339,
#   "they've": 340,
#   'lost': 341,
#   'less': 342,
#   'than': 343,
#   'folks': 344,
#   'who': 345,
#   'stuck': 346,
#   'growth': 347,
#   'exploded': 348,
#   '19': 349,
#   '55': 350,
#   '8bn': 351,
#   'costs': 352,
#   'drove': 353,
#   'imports': 354,
#   'according': 355,
#   'figures': 356,
#   'Oil': 357,
#   'giant': 358,
#   'Shell': 359,
#   'bracing': 360,
#   'itself': 361,
#   'takeover': 362,
#   'attempt': 363,
#   'possibly': 364,
#   'French': 365,
#   'rival': 366,
#   'Total': 367,
#   'press': 368,
#   'report': 369,
#   'bidding': 370,
#   'gets': 371,
#   'underway': 372,
#   "Google's": 373,
#   'despite': 374,
#   'minute': 375,
#   'interview': 376,
#   'bosses': 377,
#   'Playboy': 378,
#   'magazine': 379,
#   'Official': 380,
#   'show': 381,
#   '12': 382,
#   'nation': 383,
#   'eurozone': 384,
#   'continues': 385,
#   'grow': 386,
#   'there': 387,
#   'warnings': 388,
#   'it': 389,
#   'slow': 390,
#   'down': 391,
#   'later': 392,
#   'Economic': 393,
#   'Japan': 394,
#   'slows': 395,
#   'country': 396,
#   'experiences': 397,
#   'domestic': 398,
#   'corporate': 399,
#   'spending': 400,
#   'Interest': 401,
#   'rates': 402,
#   'trimmed': 403,
#   '7': 404,
#   '5': 405,
#   'South': 406,
#   'African': 407,
#   'central': 408,
#   'bank': 409,
#   'lack': 410,
#   'hits': 411,
#   'rand': 412,
#   'surprises': 413,
#   'cost': 414,
#   'both': 415,
#   'second': 416,
#   'hand': 417,
#   'cars': 418,
#   'five': 419,
#   'years': 420,
#   'survey': 421,
#   'found': 422,
#   "Korea's": 423,
#   'cuts': 424,
#   'interest': 425,
#   'quarter': 426,
#   'percentage': 427,
#   'point': 428,
#   '3': 429,
#   'bid': 430,
#   'drive': 431,
#   'An': 432,
#   'shares': 433,
#   'web': 434,
#   'engine': 435,
#   'floated': 436,
#   'much': 437,
#   '36bn': 438,
#   'takes': 439,
#   'place': 440,
#   'Hewlett': 441,
#   'Packard': 442,
#   'disappointing': 443,
#   'third': 444,
#   'profits': 445,
#   'while': 446,
#   'warns': 447,
#   'final': 448,
#   'will': 449,
#   'also': 450,
#   'short': 451,
#   'expectations': 452,
#   'One': 453,
#   'oldest': 454,
#   'textile': 455,
#   'operators': 456,
#   'Indian': 457,
#   'Ocean': 458,
#   'island': 459,
#   'Mauritius': 460,
#   'shut': 461,
#   'seven': 462,
#   'factories': 463,
#   'cut': 464,
#   '900': 465,
#   'jobs': 466,
#   'Chad': 467,
#   'asks': 468,
#   'IMF': 469,
#   'loan': 470,
#   'pay': 471,
#   'looking': 472,
#   'more': 473,
#   '100': 474,
#   'refugees': 475,
#   'conflict': 476,
#   'torn': 477,
#   'Darfur': 478,
#   'western': 479,
#   'Sudan': 480,
#   'running': 481,
#   'Japanese': 482,
#   'nuclear': 483,
#   'plant': 484,
#   'hit': 485,
#   'fatal': 486,
#   'accident': 487,
#   'close': 488,
#   'reactors': 489,
#   'safety': 490,
#   'checks': 491,
#   'Trevor': 492,
#   'Baylis': 493,
#   'veteran': 494,
#   'inventor': 495,
#   'famous': 496,
#   'creating': 497,
#   'Freeplay': 498,
#   'clockwork': 499,
#   'radio': 500,
#   'planning': 501,
#   'float': 502,
#   'Saudi': 503,
#   'Arabia': 504,
#   'ready': 505,
#   'push': 506,
#   'extra': 507,
#   'into': 508,
#   'reverse': 509,
#   'surging': 510,
#   'A': 511,
#   'group': 512,
#   'led': 513,
#   "UAE's": 514,
#   'Etisalat': 515,
#   'plans': 516,
#   'spend': 517,
#   '1bn': 518,
#   '544m': 519,
#   'expansion': 520,
#   'winning': 521,
#   'two': 522,
#   'mobile': 523,
#   'phone': 524,
#   'licences': 525,
#   'Network': 526,
#   'Rail': 527,
#   'flies': 528,
#   'specialist': 529,
#   'engineers': 530,
#   'West': 531,
#   'Coast': 532,
#   'Mainline': 533,
#   'UK': 534,
#   'skills': 535,
#   'shortage': 536,
#   'BEDFORD': 537,
#   'Scientists': 538,
#   'NitroMed': 539,
#   'hope': 540,
#   'experimental': 541,
#   'drugs': 542,
#   'cure': 543,
#   'heart': 544,
#   'disease': 545,
#   'someday': 546,
#   'lately': 547,
#   'focus': 548,
#   'been': 549,
#   'mundane': 550,
#   'matters': 551,
#   "I've": 552,
#   'submitted': 553,
#   'buy': 554,
#   "company's": 555,
#   'style': 556,
#   'That': 557,
#   'turn': 558,
#   'out': 559,
#   'good': 560,
#   'news': 561,
#   'or': 562,
#   'bad': 563,
#   'Massachusetts': 564,
#   'bargain': 565,
#   'hunters': 566,
#   'up': 567,
#   'droves': 568,
#   'shopped': 569,
#   'hard': 570,
#   "yesterday's": 571,
#   'tax': 572,
#   'holiday': 573,
#   'everything': 574,
#   'treadmills': 575,
#   'snow': 576,
#   'blowers': 577,
#   'candles': 578,
#   'chandeliers': 579,
#   'crediting': 580,
#   'percent': 581,
#   'break': 582,
#   'bringing': 583,
#   'them': 584,
#   'stores': 585,
#   'E': 586,
#   'mail': 587,
#   'victim': 588,
#   'own': 589,
#   'success': 590,
#   "That's": 591,
#   'conclusion': 592,
#   'IBM': 593,
#   'Corp': 594,
#   'researchers': 595,
#   'Cambridge': 596,
#   'spent': 597,
#   'nearly': 598,
#   'decade': 599,
#   'conducting': 600,
#   'field': 601,
#   'tests': 602,
#   'other': 603,
#   'companies': 604,
#   'how': 605,
#   'employees': 606,
#   'use': 607,
#   'electronic': 608,
#   "It's": 609,
#   'clear': 610,
#   'e': 611,
#   "Internet's": 612,
#   'killer': 613,
#   'application': 614,
#   'Even': 615,
#   'genius': 616,
#   'mess': 617,
#   'Bill': 618,
#   'Gates': 619,
#   'brilliant': 620,
#   'technologist': 621,
#   'he': 622,
#   'cofounded': 623,
#   'Microsoft': 624,
#   'guided': 625,
#   'greatness': 626,
#   'size': 627,
#   'historical': 628,
#   'consequence': 629,
#   'blundered': 630,
#   'He': 631,
#   'terrorized': 632,
#   'underlings': 633,
#   'temper': 634,
#   'parceled': 635,
#   'praise': 636,
#   'like': 637,
#   'Scrooge': 638,
#   'gave': 639,
#   'charity': 640,
#   'Only': 641,
#   'lash': 642,
#   'inspired': 643,
#   'necessary': 644,
#   'aggressiveness': 645,
#   'beat': 646,
#   'competition': 647,
#   'thought': 648,
#   'Target': 649,
#   'abusers': 650,
#   'legal': 651,
#   'weapons': 652,
#   'We': 653,
#   'all': 654,
#   'share': 655,
#   'outrage': 656,
#   'expressed': 657,
#   'columnist': 658,
#   'Steve': 659,
#   'Bailey': 660,
#   "''Summer": 661,
#   'Sizzler': 662,
#   'quot': 663,
#   'Aug': 664,
#   '11': 665,
#   'killings': 666,
#   "city's": 667,
#   'poor': 668,
#   'neighborhoods': 669,
#   "there's": 670,
#   'no': 671,
#   'ignorance': 672,
#   'argues': 673,
#   'renewal': 674,
#   'so': 675,
#   'called': 676,
#   'assault': 677,
#   'weapon': 678,
#   'ban': 679,
#   'claiming': 680,
#   'otherwise': 681,
#   "''UZIs": 682,
#   'AK': 683,
#   '47s': 684,
#   'flooding': 685,
#   'streets': 686,
#   'His': 687,
#   'Bush': 688,
#   'saying': 689,
#   "''turned": 690,
#   'corner': 691,
#   'Democratic': 692,
#   'candidate': 693,
#   'Senator': 694,
#   'John': 695,
#   'F': 696,
#   'Kerry': 697,
#   'wake': 698,
#   'this': 699,
#   "month's": 700,
#   'quipped': 701,
#   'Marlborough': 702,
#   'based': 703,
#   'technology': 704,
#   'suing': 705,
#   'former': 706,
#   'including': 707,
#   'senior': 708,
#   'managers': 709,
#   'allegedly': 710,
#   'conspiring': 711,
#   'against': 712,
#   'working': 713,
#   'opening': 714,
#   'competing': 715,
#   'business': 716,
#   'Central': 717,
#   'Square': 718,
#   'Lynn': 719,
#   'brighter': 720,
#   'New': 721,
#   'sidewalks': 722,
#   'curbs': 723,
#   'fences': 724,
#   'lights': 725,
#   'landscaping': 726,
#   'road': 727,
#   'improvements': 728,
#   'planned': 729,
#   'Gateway': 730,
#   'Artisan': 731,
#   'Block': 732,
#   'key': 733,
#   'area': 734,
#   'square': 735,
#   '830': 736,
#   'state': 737,
#   'grant': 738,
#   'given': 739,
#   'lawsuit': 740,
#   'Gary': 741,
#   'Winnick': 742,
#   'chief': 743,
#   'Global': 744,
#   'Crossing': 745,
#   'refocuses': 746,
#   'attention': 747,
#   'what': 748,
#   'Mr': 749,
#   'knew': 750,
#   'imploded': 751,
#   'Russia': 752,
#   'emerging': 753,
#   'superpower': 754,
#   'Kevin': 755,
#   'B': 756,
#   'Rollins': 757,
#   'executive': 758,
#   'talks': 759,
#   "Dell's": 760,
#   'transitory': 761,
#   'slip': 762,
#   'customer': 763,
#   'service': 764,
#   'sees': 765,
#   'broader': 766,
#   'taking': 767,
#   'With': 768,
#   'cash': 769,
#   'rich': 770,
#   'people': 771,
#   'dying': 772,
#   'wealth': 773,
#   'Stein': 774,
#   'proposes': 775,
#   'unique': 776,
#   'solution': 777,
#   'sell': 778,
#   'titles': 779,
#   'nobility': 780,
#   'Quality': 781,
#   'Distribution': 782,
#   'hammered': 783,
#   'reporting': 784,
#   'large': 785,
#   'loss': 786,
#   'Hurricane': 787,
#   'Charley': 788,
#   'blows': 789,
#   'house': 790,
#   'make': 791,
#   '?': 792,
#   'results': 793,
#   "it's": 794,
#   'not': 795,
#   'grim': 796,
#   'tech': 797,
#   'Just': 798,
#   "isn't": 799,
#   'tough': 800,
#   "Detroit's": 801,
#   'troubled': 802,
#   'carmaker': 803,
#   'thanks': 804,
#   'maverick': 805,
#   'designer': 806,
#   'car': 807,
#   'dazzling': 808,
#   'hip': 809,
#   'hop': 810,
#   'crowd': 811,
#   'Americans': 812,
#   'tricking': 813,
#   'places': 814,
#   'where': 815,
#   'they': 816,
#   'swim': 817,
#   "Here's": 818,
#   'look': 819,
#   'wave': 820,
#   'accessories': 821,
#   'In': 822,
#   '1993': 823,
#   'six': 824,
#   'geeks': 825,
#   'had': 826,
#   'digital': 827,
#   'nightmare': 828,
#   'changed': 829,
#   'culture': 830,
#   'get': 831,
#   'far': 832,
#   'creepier': 833,
#   'Celebrity': 834,
#   'fashion': 835,
#   'booming': 836,
#   'These': 837,
#   'webpreneurs': 838,
#   'street': 839,
#   'No': 840,
#   'recording': 841,
#   'artist': 842,
#   'channel': 843,
#   'American': 844,
#   'middle': 845,
#   'class': 846,
#   'tastes': 847,
#   'quite': 848,
#   'Chip': 849,
#   'Davis': 850,
#   'best': 851,
#   'selling': 852,
#   'Got': 853,
#   'problem': 854,
#   'Not': 855,
#   'worry': 856,
#   'find': 857,
#   'every': 858,
#   'specialized': 859,
#   "Today's": 860,
#   'customers': 861,
#   'increasingly': 862,
#   'demanding': 863,
#   'Asia': 864,
#   'elsewhere': 865,
#   'Henry': 866,
#   'Astorga': 867,
#   'describes': 868,
#   'complex': 869,
#   'reality': 870,
#   'faced': 871,
#   "today's": 872,
#   'marketers': 873,
#   'includes': 874,
#   'we': 875,
#   'used': 876,
#   'want': 877,
#   'performance': 878,
#   'now': 879,
#   '!': 880,
#   'Well': 881,
#   'election': 882,
#   'time': 883,
#   'Republic': 884,
#   'Philippines': 885,
#   'means': 886,
#   'monkeys': 887,
#   'rolling': 888,
#   'around': 889,
#   'those': 890,
#   'political': 891,
#   'fun': 892,
#   'laughing': 893,
#   'heads': 894,
#   'strange': 895,
#   'goings': 896,
#   'characterize': 897,
#   'democratic': 898,
#   'process': 899,
#   'loosely': 900,
#   'model': 901,
#   'de': 902,
#   'facto': 903,
#   'looks': 904,
#   'Fellini': 905,
#   'movie': 906,
#   'crossed': 907,
#   'Tom': 908,
#   'Jerry': 909,
#   'cartoon': 910,
#   'column': 911,
#   'useful': 912,
#   'glossary': 913,
#   'Why': 914,
#   'General': 915,
#   'Motors': 916,
#   'dropped': 917,
#   'Oldsmobile': 918,
#   'four': 919,
#   'brand': 920,
#   'paradoxes': 921,
#   'GM': 922,
#   'face': 923,
#   'name': 924,
#   'product': 925,
#   'image': 926,
#   're': 927,
#   'positioning': 928,
#   'consumer': 929,
#   'added': 930,
#   'rebranding': 931,
#   'Although': 932,
#   'smattering': 933,
#   'Chinese': 934,
#   'Filipinos': 935,
#   'Indians': 936,
#   'Thais': 937,
#   'others': 938,
#   'crow': 939,
#   'kind': 940,
#   'sitting': 941,
#   'prominent': 942,
#   'positions': 943,
#   'corporations': 944,
#   'organizations': 945,
#   'USA': 946,
#   'accomplishments': 947,
#   'mere': 948,
#   'cultural': 949,
#   'high': 950,
#   'fives': 951,
#   'ritualistic': 952,
#   'chest': 953,
#   'thumping': 954,
#   'goaded': 955,
#   'impishly': 956,
#   'patronized': 957,
#   "'mainstream": 958,
#   "society'": 959,
#   'milder': 960,
#   'gentler': 961,
#   'term': 962,
#   'white': 963,
#   'dominated': 964,
#   'populace': 965,
#   'Blues': 966,
#   'alive': 967,
#   'evidenced': 968,
#   'appreciation': 969,
#   'Pinoy': 970,
#   "'Lampano": 971,
#   "Alley'": 972,
#   'penned': 973,
#   'Clarence': 974,
#   'Henderson': 975,
#   'counterpoint': 976,
#   'usual': 977,
#   'economics': 978,
#   'fare': 979,
#   'Globalization': 980,
#   'does': 981,
#   'things': 982,
#   'life': 983,
#   'Manila': 984,
#   'consultant': 985,
#   'proving': 986,
#   'really': 987,
#   'CAN': 988,
#   'Muddy': 989,
#   'Walters': 990,
#   'bluegrass': 991,
#   'same': 992,
#   'page': 993,
#   'APMF': 994,
#   'Asian': 995,
#   'tourism': 996,
#   'destinations': 997,
#   'just': 998,
#   'kicked': 999,
#   ...})

# %%
hidden_dim = 256
output_dim = data['Class Index'].unique().shape[0]

model = LSTM(hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
model
# Out:
# LSTM(
#   (lstm): LSTM(50, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
batch_size = 100
model.train()
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    train_loss = 0

    for i in range(int(len(data_train['Description'])/batch_size)):
        optimizer.zero_grad()
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-batch_size*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-batch_size*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])

            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-batch_size*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()
        loss.backward()
        optimizer.step()
    print(f"Epoch = {epoch}\tTraining Set Accuracy = {correct / len(data_train['Description'])}\tLoss = {train_loss/len(data_train['Description'])}")
# Out:
# Epoch = 0	Training Set Accuracy = 0.28546666666666665	Loss = 0.013668730854988098
# Epoch = 1	Training Set Accuracy = 0.428575	Loss = 0.012278773821890354
# Epoch = 2	Training Set Accuracy = 0.496325	Loss = 0.011446230113506317
# Epoch = 3	Training Set Accuracy = 0.5346833333333333	Loss = 0.010862610302865505
# Epoch = 4	Training Set Accuracy = 0.5588916666666667	Loss = 0.010430552996695042
# Epoch = 5	Training Set Accuracy = 0.5763583333333333	Loss = 0.010123650543391705
# Epoch = 6	Training Set Accuracy = 0.5918583333333334	Loss = 0.00981556810438633
# Epoch = 7	Training Set Accuracy = 0.60475	Loss = 0.009563560597598553
# Epoch = 8	Training Set Accuracy = 0.618425	Loss = 0.0093050142750144
# Epoch = 9	Training Set Accuracy = 0.6290916666666667	Loss = 0.009086902253329754

# %%
batch_size = 100
train_loss = 0
correct = 0
model.eval()
for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in word_indices):
                batch_embeddings[k-batch_size*i][j] = oov_embeddings
            else:
                batch_embeddings[k-batch_size*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-batch_size*i][j+len(sentence)] = oov_embeddings
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.Tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)]).to(torch.int64)
    loss = criterion(y_pred, y_true-1)
    train_loss += loss

    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()
print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tLoss = {train_loss/len(data['Description'])}")
# Out:
# Testing Set Accuracy = 0.5621052631578948	Loss = 0.010653287172317505

# %%
batch_size = 100
model.train()
precision = []
f1 = []
recall = []
correct = 0
train_loss = 0
import warnings
warnings.filterwarnings('ignore')


confusion = None
with torch.no_grad():
    for i in range(int(len(data_train['Description'])/batch_size)):
        batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

        for k in range(batch_size*i, batch_size*i+batch_size):
            sentence = re.findall(r"[\w']+|[.,!?;'-]", data_train['Description'][k])
            for j, word in enumerate(sentence):
                if (j >= max_len):
                    break
                if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
                else:
                    batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
            for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
                batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
        y_pred = model(batch_embeddings).to(device)

        # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
        y_true = torch.tensor(data_train['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
        loss = criterion(y_pred, y_true-1)
        train_loss += loss

        predicted = torch.argmax(y_pred, dim = 1)
        correct += torch.sum(predicted+1 == y_true).item()

        pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
        true = y_true.cpu().numpy()
        precision.append(precision_score(pred, true, average='weighted'))
        f1.append(f1_score(pred, true, average='weighted'))
        recall.append(recall_score(pred, true, average='weighted'))
        confusion = confusion_matrix(pred, true)
        print(f"Confusion Matrix for Batch = {i} is {confusion}")

    print(f"Training Set Accuracy = {correct / len(data_train['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {train_loss/len(data_train['Description'])}\tConfusion Matrix = {confusion}")
# Out:
# Confusion Matrix for Batch = 0 is [[ 0  0 15  7]
#  [ 0  0 15  1]
#  [ 0  0 17  4]
#  [ 0  0 31 10]]
# Confusion Matrix for Batch = 1 is [[ 0  0  0 26]
#  [ 0  0  0 11]
#  [ 0  0  0  7]
#  [ 0  0  0 56]]
# Confusion Matrix for Batch = 2 is [[ 0  0  0 17]
#  [ 0  0  0 12]
#  [ 0  0  0  9]
#  [ 0  0  0 62]]
# Confusion Matrix for Batch = 3 is [[ 0  0  0 11]
#  [ 0  0  0  7]
#  [ 0  0  0 14]
#  [ 0  0  0 68]]
# Confusion Matrix for Batch = 4 is [[ 7  3  0  5]
#  [ 0 37  0  5]
#  [ 0  0  0  7]
#  [ 1  4  0 31]]
# Confusion Matrix for Batch = 5 is [[44  5  2  4]
#  [ 5  9  0  0]
#  [ 6  1  4  1]
#  [ 9  2  0  8]]
# Confusion Matrix for Batch = 6 is [[26  5  4  1]
#  [ 2 33  2  0]
#  [ 4  0  7  1]
#  [ 9  3  2  1]]
# Confusion Matrix for Batch = 7 is [[30  3  7  0]
#  [ 3 19  1  0]
#  [ 4  1  6  4]
#  [ 2  2  5 13]]
# Confusion Matrix for Batch = 8 is [[20  3  4  3]
#  [ 3  5  1  0]
#  [ 2  0 28  3]
#  [ 1  0  2 25]]
# Confusion Matrix for Batch = 9 is [[24  0  2  8]
#  [ 4  4  1  4]
#  [ 2  0 14  5]
#  [ 4  3  4 21]]
# Confusion Matrix for Batch = 10 is [[22  7  2  3]
#  [ 5 11  0  4]
#  [ 2  1 12  5]
#  [ 4  1  3 18]]
# Confusion Matrix for Batch = 11 is [[15  5  1  9]
#  [ 5 15  1  3]
#  [ 2  0  8  7]
#  [ 6  0  1 22]]
# Confusion Matrix for Batch = 12 is [[20  2  8  3]
#  [ 2 20  0  1]
#  [ 3  0 13  3]
#  [ 5  1  8 11]]
# Confusion Matrix for Batch = 13 is [[25  0  2  5]
#  [ 2 14  0  2]
#  [ 2  1 20  4]
#  [ 5  1  2 15]]
# Confusion Matrix for Batch = 14 is [[18  0  3  3]
#  [ 2  5  2  3]
#  [ 4  0 31  3]
#  [ 3  0  5 18]]
# Confusion Matrix for Batch = 15 is [[16  6  1  7]
#  [ 5 13  0  5]
#  [ 4  1  8 11]
#  [ 3  2  3 15]]
# Confusion Matrix for Batch = 16 is [[ 4  3  6  4]
#  [ 5 16  2  1]
#  [ 3  1 22  7]
#  [ 2  1  5 18]]
# Confusion Matrix for Batch = 17 is [[15  4  0  2]
#  [ 4 21  2  2]
#  [ 3  0 12  5]
#  [ 2  6  7 15]]
# Confusion Matrix for Batch = 18 is [[13  3  1  3]
#  [ 3 16  2  3]
#  [ 3  1 13  3]
#  [ 2  2  3 29]]
# Confusion Matrix for Batch = 19 is [[13  2  1  4]
#  [ 4 12  1  4]
#  [ 3  0 17  4]
#  [ 6  2  6 21]]
# Confusion Matrix for Batch = 20 is [[15  6  2  5]
#  [ 1  9  3  2]
#  [ 2  1 16  3]
#  [ 1  6  4 24]]
# Confusion Matrix for Batch = 21 is [[21  2  3  3]
#  [ 5 25  0  1]
#  [ 0  0 15  3]
#  [ 2  5  6  9]]
# Confusion Matrix for Batch = 22 is [[ 7  0  3  3]
#  [ 1 33  2  0]
#  [ 3  2 10  1]
#  [ 6 11  9  9]]
# Confusion Matrix for Batch = 23 is [[15  6  1  0]
#  [ 4 20  3  1]
#  [ 4  0 17  4]
#  [ 4  4  6 11]]
# Confusion Matrix for Batch = 24 is [[27  5  1  1]
#  [ 2 22  1  1]
#  [ 6  1 17  1]
#  [ 3  2  4  6]]
# Confusion Matrix for Batch = 25 is [[28  2  6  2]
#  [ 0  8  4  5]
#  [ 2  1 16  1]
#  [ 6  4  2 13]]
# Confusion Matrix for Batch = 26 is [[16  6  1  4]
#  [ 3  4  2  2]
#  [ 0  0 27  4]
#  [ 8  1  9 13]]
# Confusion Matrix for Batch = 27 is [[24  5  2  2]
#  [ 1  9  4  1]
#  [ 0  1 21  3]
#  [ 4  2  8 13]]
# Confusion Matrix for Batch = 28 is [[14  5  4  4]
#  [ 1  6  1  3]
#  [ 0  0 24  7]
#  [ 0  4 11 16]]
# Confusion Matrix for Batch = 29 is [[14  6  3  5]
#  [ 4 13  0  2]
#  [ 0  3 15  3]
#  [ 2  2 13 15]]
# Confusion Matrix for Batch = 30 is [[26  3  0  4]
#  [ 3 14  0  2]
#  [ 2  1  7  3]
#  [ 4  3  3 25]]
# Confusion Matrix for Batch = 31 is [[13  5  4  6]
#  [ 4  7  2  2]
#  [ 1  1 20  4]
#  [ 2  0  8 21]]
# Confusion Matrix for Batch = 32 is [[21  5  4  3]
#  [ 3 13  1  3]
#  [ 2  0 12  7]
#  [ 5  4  3 14]]
# Confusion Matrix for Batch = 33 is [[20  2  1  6]
#  [ 1 18  0  3]
#  [ 3  0 15  0]
#  [ 6  3  5 17]]
# Confusion Matrix for Batch = 34 is [[19  3  3  5]
#  [ 4 20  2  0]
#  [ 4  0 17  4]
#  [ 6  5  1  7]]
# Confusion Matrix for Batch = 35 is [[18  5  3  3]
#  [ 7 14  2  0]
#  [ 3  1 23  2]
#  [ 4  4  5  6]]
# Confusion Matrix for Batch = 36 is [[17  5  2  2]
#  [ 6 19  1  2]
#  [ 0  1 19  2]
#  [ 4  7  8  5]]
# Confusion Matrix for Batch = 37 is [[18  7  2  1]
#  [ 2 14  1  3]
#  [ 1  0  8  2]
#  [ 2  5  9 25]]
# Confusion Matrix for Batch = 38 is [[21  3  1  2]
#  [ 2 11  0  0]
#  [ 2  1 26  4]
#  [ 1  4  7 15]]
# Confusion Matrix for Batch = 39 is [[ 6  1  6  3]
#  [ 0  4  1  2]
#  [ 0  2 41  5]
#  [ 2  2 11 14]]
# Confusion Matrix for Batch = 40 is [[16  6  0  8]
#  [ 3  8  0  8]
#  [ 3  1  2  8]
#  [ 1  0  0 36]]
# Confusion Matrix for Batch = 41 is [[18  4  5  5]
#  [ 1  6  1  1]
#  [ 2  0 22  2]
#  [ 4  0 11 18]]
# Confusion Matrix for Batch = 42 is [[11  5  1  5]
#  [ 1 14  1  1]
#  [ 2  1  9 12]
#  [ 3  2  2 30]]
# Confusion Matrix for Batch = 43 is [[12  3  3  6]
#  [ 2 13  0  3]
#  [ 1  2  7  4]
#  [ 2  9 12 21]]
# Confusion Matrix for Batch = 44 is [[ 9  7  3  2]
#  [ 3 17  3  5]
#  [ 2  2 19  0]
#  [ 1  5 11 11]]
# Confusion Matrix for Batch = 45 is [[11  2  5  1]
#  [ 4 22  1  3]
#  [ 2  1 19  4]
#  [ 1  4  9 11]]
# Confusion Matrix for Batch = 46 is [[15  4  4  0]
#  [ 5 14  2  1]
#  [ 1  2 24  1]
#  [ 2  0 10 15]]
# Confusion Matrix for Batch = 47 is [[20  3  2  3]
#  [ 5 26  1  2]
#  [ 1  1 12  0]
#  [ 3  4  6 11]]
# Confusion Matrix for Batch = 48 is [[28  5  3  2]
#  [ 3 11  0  5]
#  [ 5  2 10  2]
#  [ 5  0  4 15]]
# Confusion Matrix for Batch = 49 is [[13  5  3  2]
#  [ 5 17  1  1]
#  [ 1  5 15  3]
#  [10  2  5 12]]
# Confusion Matrix for Batch = 50 is [[18  3  1  3]
#  [ 4  9  3  4]
#  [ 0  1 18  2]
#  [ 4  2  9 19]]
# Confusion Matrix for Batch = 51 is [[15  5  2  4]
#  [ 7 16  0  3]
#  [ 0  1 15  3]
#  [ 2  3  7 17]]
# Confusion Matrix for Batch = 52 is [[15  3  0  4]
#  [ 5 14  3  2]
#  [ 1  0 20  4]
#  [ 5  0  7 17]]
# Confusion Matrix for Batch = 53 is [[22  0  1  5]
#  [ 4 13  1  3]
#  [ 2  0 13  4]
#  [ 4  5  2 21]]
# Confusion Matrix for Batch = 54 is [[18  1  7  0]
#  [ 2 31  2  0]
#  [ 2  3 16  0]
#  [ 6  2  0 10]]
# Confusion Matrix for Batch = 55 is [[29  5  4  4]
#  [ 5 21  0  0]
#  [ 1  1  3  2]
#  [ 5  7  2 11]]
# Confusion Matrix for Batch = 56 is [[17  3  3  4]
#  [ 7 16  3  1]
#  [ 2  3 10  7]
#  [ 0  3  5 16]]
# Confusion Matrix for Batch = 57 is [[21  5  5  4]
#  [ 7 20  5  2]
#  [ 3  1  9  2]
#  [ 5  2  4  5]]
# Confusion Matrix for Batch = 58 is [[29  3  3  0]
#  [ 7 36  3  1]
#  [ 2  1  2  4]
#  [ 0  3  3  3]]
# Confusion Matrix for Batch = 59 is [[29  4  5  3]
#  [ 3 22  3  3]
#  [ 0  1  9  5]
#  [ 4  1  5  3]]
# Confusion Matrix for Batch = 60 is [[26  3  5  2]
#  [ 2 30  2  2]
#  [ 0  2  7  0]
#  [ 5  4  6  4]]
# Confusion Matrix for Batch = 61 is [[14  3  3  1]
#  [ 5 43  4  0]
#  [ 1  1  5  0]
#  [ 1  5  5  9]]
# Confusion Matrix for Batch = 62 is [[20  5  5  3]
#  [ 3 19  4  3]
#  [ 1  4  6  2]
#  [ 5  3  9  8]]
# Confusion Matrix for Batch = 63 is [[20  4  1  1]
#  [ 3 26  5  0]
#  [ 6  4 12  2]
#  [ 2  4  4  6]]
# Confusion Matrix for Batch = 64 is [[26  5  0  2]
#  [11 25  3  2]
#  [ 4  0  7  1]
#  [ 6  1  3  4]]
# Confusion Matrix for Batch = 65 is [[16  5  6  1]
#  [ 8 21  0  4]
#  [ 2  2  8  7]
#  [ 3  6  4  7]]
# Confusion Matrix for Batch = 66 is [[28  8  1  2]
#  [ 6 34  1  0]
#  [ 6  0  6  1]
#  [ 1  1  3  2]]
# Confusion Matrix for Batch = 67 is [[13  5  6  3]
#  [ 8 31  0  0]
#  [ 0  3  2  6]
#  [ 8  4  2  9]]
# Confusion Matrix for Batch = 68 is [[19  3  4  2]
#  [ 4 30  3  1]
#  [ 4  2 11  1]
#  [ 4  4  8  0]]
# Confusion Matrix for Batch = 69 is [[13  3  7  0]
#  [ 3 25  3  3]
#  [ 5  1  7  1]
#  [ 2  2  9 16]]
# Confusion Matrix for Batch = 70 is [[18  2  4  3]
#  [ 1 30  4  2]
#  [ 1  3 14  2]
#  [ 5  2  4  5]]
# Confusion Matrix for Batch = 71 is [[15  9  5  0]
#  [ 0 21  6  1]
#  [ 3  0  9  1]
#  [ 2  4 13 11]]
# Confusion Matrix for Batch = 72 is [[17  2  2  1]
#  [ 2 30  0  1]
#  [ 1  5 11  2]
#  [ 4  4  6 12]]
# Confusion Matrix for Batch = 73 is [[11  6  4  1]
#  [ 4 17  1  2]
#  [ 4  1 15  2]
#  [ 6  2 10 14]]
# Confusion Matrix for Batch = 74 is [[18  3  1  2]
#  [ 2 12  5  5]
#  [ 3  0 23  5]
#  [ 4  1  7  9]]
# Confusion Matrix for Batch = 75 is [[16  0  3  3]
#  [ 2 10  3  2]
#  [ 3  0 27  4]
#  [ 3  2  2 20]]
# Confusion Matrix for Batch = 76 is [[20  6  2  0]
#  [ 5 11  5  1]
#  [ 3  1 14  7]
#  [ 3  2  3 17]]
# Confusion Matrix for Batch = 77 is [[14  4  4  3]
#  [ 3 15  2  3]
#  [ 2  2 18  5]
#  [ 1  4  1 19]]
# Confusion Matrix for Batch = 78 is [[12  0  2  3]
#  [ 3 14  3  1]
#  [ 2  0 17 11]
#  [ 4  1  9 18]]
# Confusion Matrix for Batch = 79 is [[ 9  4  5  6]
#  [ 5  8  3  3]
#  [ 1  0 17  7]
#  [ 2  1  6 23]]
# Confusion Matrix for Batch = 80 is [[10  7  3  4]
#  [ 1 14  1  3]
#  [ 6  2 13  7]
#  [ 3  1  8 17]]
# Confusion Matrix for Batch = 81 is [[12  4  1  2]
#  [ 8 21  3  2]
#  [ 5  0 22  3]
#  [ 1  2  2 12]]
# Confusion Matrix for Batch = 82 is [[14  1  2  1]
#  [ 4 27  4  1]
#  [ 5  2  7  5]
#  [ 5  3  7 12]]
# Confusion Matrix for Batch = 83 is [[ 8  3  5  1]
#  [ 2 21  6  1]
#  [ 5  1 17  4]
#  [ 3  4  9 10]]
# Confusion Matrix for Batch = 84 is [[17  4  8  1]
#  [ 4 16  1  1]
#  [ 0  0 23  2]
#  [ 3  2  7 11]]
# Confusion Matrix for Batch = 85 is [[16  1  6  3]
#  [ 1 22  4  2]
#  [ 1  1 12  7]
#  [ 2  5  8  9]]
# Confusion Matrix for Batch = 86 is [[19  3  2  2]
#  [ 4  9  2  5]
#  [ 5  1 18  3]
#  [ 6  3  3 15]]
# Confusion Matrix for Batch = 87 is [[16  1  6  1]
#  [ 4 12  1  2]
#  [ 3  2 18  2]
#  [ 2  1  5 24]]
# Confusion Matrix for Batch = 88 is [[13  5  3  3]
#  [ 7 12  1  0]
#  [ 1  2 24  2]
#  [ 0  0  4 23]]
# Confusion Matrix for Batch = 89 is [[11  3  1  1]
#  [ 3 14  0  4]
#  [ 2  2 21  5]
#  [ 2  2  5 24]]
# Confusion Matrix for Batch = 90 is [[ 9  6  3  2]
#  [ 2  8  2  4]
#  [ 1  1 26  7]
#  [ 4  1  8 16]]
# Confusion Matrix for Batch = 91 is [[10  6  6  3]
#  [ 2 11  1  4]
#  [ 1  1 13  6]
#  [ 2  0  9 25]]
# Confusion Matrix for Batch = 92 is [[ 9  6  4  8]
#  [ 2 13  1  2]
#  [ 1  2 20  7]
#  [ 3  0  7 15]]
# Confusion Matrix for Batch = 93 is [[18  6  2  2]
#  [ 8 19  1  1]
#  [ 1  0  3  4]
#  [ 7  1  4 23]]
# Confusion Matrix for Batch = 94 is [[10  3  5  9]
#  [ 1  9  3  4]
#  [ 3  1 14  5]
#  [ 4  1  3 25]]
# Confusion Matrix for Batch = 95 is [[14  3  0  8]
#  [ 1 13  3  3]
#  [ 0  0 14  6]
#  [ 1  3  5 26]]
# Confusion Matrix for Batch = 96 is [[14  3  6  5]
#  [ 8 11  1  1]
#  [ 3  1 10  7]
#  [ 3  2  5 20]]
# Confusion Matrix for Batch = 97 is [[ 9  8  3  2]
#  [ 4  8  2  3]
#  [ 4  0 15 11]
#  [ 6  1  3 21]]
# Confusion Matrix for Batch = 98 is [[ 5  4  3  3]
#  [ 3  8  2  6]
#  [ 2  0 20  8]
#  [ 3  2  4 27]]
# Confusion Matrix for Batch = 99 is [[11  5  3  4]
#  [ 3 11  2  4]
#  [ 0  1 16  9]
#  [ 2  1  6 22]]
# Confusion Matrix for Batch = 100 is [[16  6  5  2]
#  [ 4 10  3  5]
#  [ 0  2 16  5]
#  [ 1  1  6 18]]
# Confusion Matrix for Batch = 101 is [[12  3  3  7]
#  [ 6 18  2  1]
#  [ 4  1 15  4]
#  [ 4  0  7 13]]
# Confusion Matrix for Batch = 102 is [[16  1  5  2]
#  [ 3 23  2  2]
#  [ 1  1 18  3]
#  [ 3  6  4 10]]
# Confusion Matrix for Batch = 103 is [[19  5  2  2]
#  [ 8 16  2  0]
#  [ 3  2 11  9]
#  [ 4  3  6  8]]
# Confusion Matrix for Batch = 104 is [[18  2  7  1]
#  [ 2 24  2  1]
#  [ 5  1 20  0]
#  [ 3  1  6  7]]
# Confusion Matrix for Batch = 105 is [[16  3  3  3]
#  [ 2 10  2  3]
#  [ 2  0 13  6]
#  [ 1  2  3 31]]
# Confusion Matrix for Batch = 106 is [[ 7  3  3  3]
#  [ 2 14  1  2]
#  [ 2  2 31  7]
#  [ 3  2  0 18]]
# Confusion Matrix for Batch = 107 is [[17  3  6  6]
#  [ 4  8  1  4]
#  [ 2  1 16  0]
#  [ 5  1  6 20]]
# Confusion Matrix for Batch = 108 is [[12  2  6  3]
#  [ 5 14  0  1]
#  [ 1  0 23  5]
#  [ 3  1  3 21]]
# Confusion Matrix for Batch = 109 is [[13  7  6 10]
#  [ 2  7  0  1]
#  [ 1  0 20  4]
#  [ 2  1  8 18]]
# Confusion Matrix for Batch = 110 is [[11  1  2 12]
#  [ 2  6  3  3]
#  [ 1  0 20  4]
#  [ 4  0  5 26]]
# Confusion Matrix for Batch = 111 is [[15  3  3  6]
#  [ 3 21  2  0]
#  [ 1  2 12  5]
#  [ 3  1  5 18]]
# Confusion Matrix for Batch = 112 is [[15  7  3  3]
#  [ 3 17  1  3]
#  [ 2  1 20  4]
#  [ 5  5  4  7]]
# Confusion Matrix for Batch = 113 is [[14  3  3  4]
#  [ 5 20  4  4]
#  [ 0  2 15  6]
#  [ 2  3  7  8]]
# Confusion Matrix for Batch = 114 is [[13  5  6  3]
#  [ 3 18  6  3]
#  [ 3  3 19  0]
#  [ 3  1  5  9]]
# Confusion Matrix for Batch = 115 is [[15  3  4  6]
#  [ 4 18  2  3]
#  [ 1  1 10  5]
#  [ 3  5 10 10]]
# Confusion Matrix for Batch = 116 is [[17  5  0  5]
#  [ 3 24  2  5]
#  [ 2  1 13  4]
#  [ 7  1  4  7]]
# Confusion Matrix for Batch = 117 is [[11  5  2  5]
#  [ 1 20  4  1]
#  [ 1  3 14  2]
#  [ 2  5  5 19]]
# Confusion Matrix for Batch = 118 is [[18  5  5  3]
#  [ 3 10  1  2]
#  [ 3  2 13  7]
#  [ 4  0  4 20]]
# Confusion Matrix for Batch = 119 is [[ 9  5  3  6]
#  [ 1  9  2  3]
#  [ 2  1 22  6]
#  [ 4  2  4 21]]
# Confusion Matrix for Batch = 120 is [[15  7  6  6]
#  [ 2  9  3  2]
#  [ 0  2 16  5]
#  [ 3  4  5 15]]
# Confusion Matrix for Batch = 121 is [[18  4  2  8]
#  [ 3 11  1  3]
#  [ 1  1 13  4]
#  [ 3  3  6 19]]
# Confusion Matrix for Batch = 122 is [[14  8  6  5]
#  [ 3 13  2  3]
#  [ 2  0 12  2]
#  [ 2  3  4 21]]
# Confusion Matrix for Batch = 123 is [[15  7  1  1]
#  [ 6 14  1  3]
#  [ 1  4 11 10]
#  [ 1  2  3 20]]
# Confusion Matrix for Batch = 124 is [[13  3  4  1]
#  [ 6 14  0  1]
#  [ 2  1 12  8]
#  [ 6  4  1 24]]
# Confusion Matrix for Batch = 125 is [[10  7  2  7]
#  [ 5 21  2  1]
#  [ 0  1  9  8]
#  [ 1  1  7 18]]
# Confusion Matrix for Batch = 126 is [[14  4  6  2]
#  [ 2 22  4  2]
#  [ 2  2  7  3]
#  [ 2  6  4 18]]
# Confusion Matrix for Batch = 127 is [[16  4  3  1]
#  [ 6 32  5  1]
#  [ 3  1  5  3]
#  [ 3  6  5  6]]
# Confusion Matrix for Batch = 128 is [[20  6  3  0]
#  [ 0 30  2  3]
#  [ 6  1  6  4]
#  [ 3  6  2  8]]
# Confusion Matrix for Batch = 129 is [[23  8  4  1]
#  [ 3 25  3  0]
#  [ 0  1  7  2]
#  [ 4  7  4  8]]
# Confusion Matrix for Batch = 130 is [[25  4  1  1]
#  [ 4 23  4  2]
#  [ 3  5  6  4]
#  [ 4  3  4  7]]
# Confusion Matrix for Batch = 131 is [[25  7  3  4]
#  [ 6 21  2  2]
#  [ 2  3  1  1]
#  [10  4  3  6]]
# Confusion Matrix for Batch = 132 is [[20 10  3  1]
#  [ 3 33  1  2]
#  [ 4  5  1  1]
#  [ 9  2  1  4]]
# Confusion Matrix for Batch = 133 is [[23  7  1  1]
#  [ 7 31  4  1]
#  [ 0  4  4  0]
#  [ 2  6  5  4]]
# Confusion Matrix for Batch = 134 is [[26  5  0  1]
#  [ 4 35  2  3]
#  [ 3  5  1  1]
#  [ 2  5  2  5]]
# Confusion Matrix for Batch = 135 is [[25  4  1  2]
#  [ 4 18  2  2]
#  [ 5  4 10  0]
#  [ 6  1  4 12]]
# Confusion Matrix for Batch = 136 is [[15  3  4  0]
#  [ 6 25  7  0]
#  [ 7  3  4  3]
#  [ 5  7  5  6]]
# Confusion Matrix for Batch = 137 is [[32  5  1  3]
#  [ 5 17  2  2]
#  [ 5  0  5  3]
#  [ 7  3  4  6]]
# Confusion Matrix for Batch = 138 is [[27  5  4  1]
#  [ 5 31  3  1]
#  [ 1  3  1  2]
#  [ 6  3  3  4]]
# Confusion Matrix for Batch = 139 is [[30  5  4  0]
#  [ 5 26  0  2]
#  [ 4  2  4  1]
#  [ 4  4  1  8]]
# Confusion Matrix for Batch = 140 is [[25  5  2  4]
#  [ 8 37  1  2]
#  [ 1  0  3  4]
#  [ 2  2  0  4]]
# Confusion Matrix for Batch = 141 is [[20  2  3  4]
#  [ 5 23  5  1]
#  [ 4  2 10  3]
#  [ 6  3  5  4]]
# Confusion Matrix for Batch = 142 is [[16  5  3  3]
#  [ 4 22  3  2]
#  [ 4  3  9  4]
#  [ 2  0  9 11]]
# Confusion Matrix for Batch = 143 is [[16  2  5  1]
#  [ 5 30  0  1]
#  [ 1  2  9  2]
#  [ 4  6  7  9]]
# Confusion Matrix for Batch = 144 is [[19  0  6  1]
#  [ 8 20  4  2]
#  [ 2  1  5  1]
#  [ 9  4  6 12]]
# Confusion Matrix for Batch = 145 is [[17  5  2  2]
#  [ 2 14  3  7]
#  [ 4  0 16  2]
#  [ 3  4  4 15]]
# Confusion Matrix for Batch = 146 is [[19  1  1  2]
#  [ 1  7  3  2]
#  [ 5  1 24  5]
#  [ 3  1  3 22]]
# Confusion Matrix for Batch = 147 is [[17  3  3  2]
#  [ 3  8  4  4]
#  [ 5  2 18  5]
#  [ 3  3  3 17]]
# Confusion Matrix for Batch = 148 is [[15  4  3  6]
#  [ 5  6  0  6]
#  [ 3  2 18  6]
#  [ 7  1  4 14]]
# Confusion Matrix for Batch = 149 is [[16  5  2  3]
#  [ 5 14  3  3]
#  [ 2  1 17  2]
#  [ 2  2  6 17]]
# Confusion Matrix for Batch = 150 is [[ 9  3  3  7]
#  [ 3 15  2  2]
#  [ 0  2 12  9]
#  [ 4  2  5 22]]
# Confusion Matrix for Batch = 151 is [[ 8  0  0  4]
#  [ 3  7  2  3]
#  [ 2  0 13  9]
#  [ 7  2  6 34]]
# Confusion Matrix for Batch = 152 is [[15  2  2  2]
#  [ 5 22  0  0]
#  [ 3  3 15  5]
#  [ 5  3  5 13]]
# Confusion Matrix for Batch = 153 is [[10  3  5  2]
#  [ 2 19  2  3]
#  [ 2  2 17  4]
#  [ 4  1  3 21]]
# Confusion Matrix for Batch = 154 is [[15  3  2  4]
#  [ 5 19  1  3]
#  [ 2  0 11  6]
#  [ 4  2  6 17]]
# Confusion Matrix for Batch = 155 is [[16  1  4  2]
#  [ 4  8  0  6]
#  [ 1  3 23  5]
#  [ 4  3  5 15]]
# Confusion Matrix for Batch = 156 is [[10  3  5  4]
#  [ 2  7  3  3]
#  [ 2  0 14  7]
#  [ 5  4  3 28]]
# Confusion Matrix for Batch = 157 is [[13  2  2  4]
#  [ 3  7  2  5]
#  [ 0  1 25  8]
#  [ 2  3  3 20]]
# Confusion Matrix for Batch = 158 is [[13  4 10  5]
#  [ 5 11  3  1]
#  [ 4  2 13  6]
#  [ 3  2  7 11]]
# Confusion Matrix for Batch = 159 is [[ 9  2  3 10]
#  [ 3  9  4  5]
#  [ 0  0  8  7]
#  [ 3  1  7 29]]
# Confusion Matrix for Batch = 160 is [[22  6  1  4]
#  [ 1 28  4  1]
#  [ 0  0  8  4]
#  [ 3  4  5  9]]
# Confusion Matrix for Batch = 161 is [[16  4  4  4]
#  [ 3 12  0  6]
#  [ 2  1 13  8]
#  [ 1  3  3 20]]
# Confusion Matrix for Batch = 162 is [[25  0  5  4]
#  [ 3 13  1  3]
#  [ 5  1 10  2]
#  [ 6  5  6 11]]
# Confusion Matrix for Batch = 163 is [[11  4  2  6]
#  [ 3  4  5  3]
#  [ 1  0 22  7]
#  [ 1  0  3 28]]
# Confusion Matrix for Batch = 164 is [[22  4  4  3]
#  [ 1 18  1  4]
#  [ 1  0 20  1]
#  [ 5  4  3  9]]
# Confusion Matrix for Batch = 165 is [[10  1  2  8]
#  [ 1  7  1  3]
#  [ 0  0  7 10]
#  [ 4  2  4 40]]
# Confusion Matrix for Batch = 166 is [[ 9  2  1  7]
#  [ 3 19  1  6]
#  [ 0  0 12  4]
#  [ 1  1  5 29]]
# Confusion Matrix for Batch = 167 is [[18  4  1  3]
#  [ 5 18  0  3]
#  [ 2  0  7  8]
#  [ 5  1  3 22]]
# Confusion Matrix for Batch = 168 is [[20  5  5  0]
#  [ 0 25  1  1]
#  [ 0  2 15  3]
#  [ 5  2  2 14]]
# Confusion Matrix for Batch = 169 is [[15  2  0  3]
#  [ 4 22  3  4]
#  [ 3  0 12  4]
#  [ 9  5  4 10]]
# Confusion Matrix for Batch = 170 is [[17  3  2  4]
#  [ 2 22  1  4]
#  [ 3  0  6  4]
#  [ 3  2  2 25]]
# Confusion Matrix for Batch = 171 is [[24  1  4  5]
#  [ 3  8  3  1]
#  [ 4  0 22  4]
#  [ 5  1  8  7]]
# Confusion Matrix for Batch = 172 is [[10  2  0  7]
#  [ 3 10  1  2]
#  [ 2  0 13 15]
#  [ 1  3  4 27]]
# Confusion Matrix for Batch = 173 is [[13  3  2  6]
#  [ 2 21  0  3]
#  [ 1  0 17  7]
#  [ 3  2  1 19]]
# Confusion Matrix for Batch = 174 is [[13  2  7  0]
#  [ 2 23  4  0]
#  [ 2  1 17  0]
#  [ 5  9  9  6]]
# Confusion Matrix for Batch = 175 is [[10  4  3  5]
#  [ 2  7  0  6]
#  [ 0  0  9 14]
#  [ 0  0  3 37]]
# Confusion Matrix for Batch = 176 is [[25  2  3  4]
#  [ 3  7  0  2]
#  [ 3  0 17  5]
#  [ 7  1  5 16]]
# Confusion Matrix for Batch = 177 is [[11  3  3  4]
#  [ 2 13  1  4]
#  [ 1  1 23  4]
#  [ 3  3  2 22]]
# Confusion Matrix for Batch = 178 is [[16  2  2  3]
#  [ 3 15  3  4]
#  [ 8  0 13  6]
#  [ 6  2  3 14]]
# Confusion Matrix for Batch = 179 is [[15  1  1  3]
#  [ 4  8  0  4]
#  [ 1  3  6  6]
#  [ 4  2  3 39]]
# Confusion Matrix for Batch = 180 is [[17  2  4  4]
#  [ 4 25  1  3]
#  [ 1  0  6  1]
#  [ 5  4 10 13]]
# Confusion Matrix for Batch = 181 is [[16  5  1  1]
#  [ 8 32  5  3]
#  [ 1  0  7  3]
#  [ 3  2  3 10]]
# Confusion Matrix for Batch = 182 is [[25  5  4  2]
#  [ 5 26  2  3]
#  [ 1  1  8  3]
#  [ 4  1  5  5]]
# Confusion Matrix for Batch = 183 is [[22  9  3  3]
#  [ 1 28  6  5]
#  [ 2  2  4  2]
#  [ 3  2  2  6]]
# Confusion Matrix for Batch = 184 is [[26  0  3  3]
#  [ 4 18  1  1]
#  [ 7  1 10  4]
#  [ 9  4  3  6]]
# Confusion Matrix for Batch = 185 is [[21  5  2  2]
#  [ 8 31  2  0]
#  [ 2  2  4  0]
#  [ 3  2  4 12]]
# Confusion Matrix for Batch = 186 is [[17  5  2  2]
#  [ 7 30  2  1]
#  [ 1  0 11  0]
#  [ 5  6  9  2]]
# Confusion Matrix for Batch = 187 is [[29  5  2  1]
#  [ 3 18  2  2]
#  [ 2  2 10  2]
#  [ 4  4 10  4]]
# Confusion Matrix for Batch = 188 is [[19  3  1  1]
#  [ 2 44  2  2]
#  [ 0  1  6  1]
#  [ 1  8  5  4]]
# Confusion Matrix for Batch = 189 is [[24  1  4  3]
#  [ 5 20  0  3]
#  [ 2  4 10  2]
#  [ 3  3  4 12]]
# Confusion Matrix for Batch = 190 is [[23  2  7  1]
#  [ 6 18  3  1]
#  [ 4  3  8  0]
#  [11  4  1  8]]
# Confusion Matrix for Batch = 191 is [[15  3  4  3]
#  [ 3 31  1  4]
#  [ 4  1 11  3]
#  [ 4  1  5  7]]
# Confusion Matrix for Batch = 192 is [[14  5  3  5]
#  [ 3 33  2  0]
#  [ 3  1  9  4]
#  [ 5  1  6  6]]
# Confusion Matrix for Batch = 193 is [[19  4  6  2]
#  [ 3 29  3  1]
#  [ 2  1  8  1]
#  [ 2  5  4 10]]
# Confusion Matrix for Batch = 194 is [[28  3  4  2]
#  [ 2 22  4  1]
#  [ 4  3  6  2]
#  [ 0  4  7  8]]
# Confusion Matrix for Batch = 195 is [[20  0  6  2]
#  [ 2 16  4  4]
#  [ 5  4  8  2]
#  [ 5  7  4 11]]
# Confusion Matrix for Batch = 196 is [[20  1  2  9]
#  [ 3 12  2  1]
#  [ 4  2 14  7]
#  [ 2  1  5 15]]
# Confusion Matrix for Batch = 197 is [[21  1  5  2]
#  [ 3 12  7  4]
#  [ 2  2 13  5]
#  [ 4  3  5 11]]
# Confusion Matrix for Batch = 198 is [[18  3  7  6]
#  [ 6 16  0  4]
#  [ 1  3  7  3]
#  [ 2  1  5 18]]
# Confusion Matrix for Batch = 199 is [[17  7  2  6]
#  [ 8 20  2  3]
#  [ 5  1  5  2]
#  [ 5  2  7  8]]
# Confusion Matrix for Batch = 200 is [[23  2  5  1]
#  [ 2 24  0  7]
#  [ 5  2  8  3]
#  [ 4  4  4  6]]
# Confusion Matrix for Batch = 201 is [[24  7  4  3]
#  [ 3 23  1  1]
#  [ 3  3  9  3]
#  [ 1  3  2 10]]
# Confusion Matrix for Batch = 202 is [[13  5  3  4]
#  [ 8 28  3  3]
#  [ 2  4  6  0]
#  [ 4  2  9  6]]
# Confusion Matrix for Batch = 203 is [[22  6  4  1]
#  [ 4 18  2  3]
#  [ 2  4  9  3]
#  [ 1  3  8 10]]
# Confusion Matrix for Batch = 204 is [[20  1  5  3]
#  [ 0 20  6  1]
#  [ 5  3 15  5]
#  [ 2  3  6  5]]
# Confusion Matrix for Batch = 205 is [[16  1  4  2]
#  [ 1  7  2  2]
#  [ 4  3 19  7]
#  [ 7  2  3 20]]
# Confusion Matrix for Batch = 206 is [[10  3  3  1]
#  [ 4  8  1  4]
#  [ 1  2 11 10]
#  [ 0  1  2 39]]
# Confusion Matrix for Batch = 207 is [[ 8  4  4  5]
#  [ 2  8  1  4]
#  [ 1  2 22  3]
#  [ 4  3  3 26]]
# Confusion Matrix for Batch = 208 is [[18  1  4  4]
#  [ 5  9  3  7]
#  [ 4  0  6  7]
#  [ 1  1  4 26]]
# Confusion Matrix for Batch = 209 is [[11  0  8  1]
#  [ 5  7  1  5]
#  [ 3  1 16  7]
#  [ 5  2  6 22]]
# Confusion Matrix for Batch = 210 is [[23  1  1  7]
#  [ 6 17  2  0]
#  [ 2  3  8  7]
#  [ 1  3  3 16]]
# Confusion Matrix for Batch = 211 is [[ 7  3  2  8]
#  [ 2 13  2  7]
#  [ 2  1  7  7]
#  [ 1  4  4 30]]
# Confusion Matrix for Batch = 212 is [[10  2  3  5]
#  [ 4 26  4  3]
#  [ 4  1 13  4]
#  [ 1  2  6 12]]
# Confusion Matrix for Batch = 213 is [[16  1  2  2]
#  [ 6 15  0  4]
#  [ 4  1 10  5]
#  [ 2  4 11 17]]
# Confusion Matrix for Batch = 214 is [[15  2  6  1]
#  [ 4 13  1  4]
#  [ 0  0 20  3]
#  [ 5  4  7 15]]
# Confusion Matrix for Batch = 215 is [[15  6  0  3]
#  [ 7 12  0  3]
#  [ 3  3 17  4]
#  [ 1  5  4 17]]
# Confusion Matrix for Batch = 216 is [[14  1  3  5]
#  [ 3 17  0  7]
#  [ 2  0 22  1]
#  [ 1  1  3 20]]
# Confusion Matrix for Batch = 217 is [[18  1  7  1]
#  [ 4 11  1  2]
#  [ 5  0 13  5]
#  [ 5  0  7 20]]
# Confusion Matrix for Batch = 218 is [[ 7  2  1  7]
#  [ 2 11  1  7]
#  [ 3  4 13  8]
#  [ 2  0  5 27]]
# Confusion Matrix for Batch = 219 is [[15  2  1  6]
#  [ 3  8  2  6]
#  [ 1  1 20  4]
#  [10  2  3 16]]
# Confusion Matrix for Batch = 220 is [[12  3  0  3]
#  [ 3 15  4  6]
#  [ 2  2  7  9]
#  [ 3  0  5 26]]
# Confusion Matrix for Batch = 221 is [[15  2  9  4]
#  [ 5 19  2  3]
#  [ 3  2  9  3]
#  [ 5  2  3 14]]
# Confusion Matrix for Batch = 222 is [[15  3  2  4]
#  [ 1 13  3  2]
#  [ 5  2 18  3]
#  [ 0  1  4 24]]
# Confusion Matrix for Batch = 223 is [[21  1  3  4]
#  [ 3 21  1  2]
#  [ 2  3 11  3]
#  [ 3  7  4 11]]
# Confusion Matrix for Batch = 224 is [[17  5  2  7]
#  [ 3 21  4  2]
#  [ 3  2 12  0]
#  [ 2  2  4 14]]
# Confusion Matrix for Batch = 225 is [[13  4  7  1]
#  [ 3 18  2  2]
#  [ 4  1 15  3]
#  [ 3  2  8 14]]
# Confusion Matrix for Batch = 226 is [[13  1  3  2]
#  [ 1 18  2  5]
#  [ 1  0 20  5]
#  [ 2  2 10 15]]
# Confusion Matrix for Batch = 227 is [[23  0  7 10]
#  [ 0  2  0  6]
#  [ 1  0  7  8]
#  [ 5  0  3 28]]
# Confusion Matrix for Batch = 228 is [[13  3  4  2]
#  [ 4 18  3  3]
#  [ 3  0 12  6]
#  [ 4  3  4 18]]
# Confusion Matrix for Batch = 229 is [[14  2  2  5]
#  [ 7 14  1  1]
#  [ 3  0 13  5]
#  [ 2  2  9 20]]
# Confusion Matrix for Batch = 230 is [[12  1  4  5]
#  [ 4 15  2  6]
#  [ 0  1 10  7]
#  [ 5  5  5 18]]
# Confusion Matrix for Batch = 231 is [[23  2  1  7]
#  [ 4 16  2  3]
#  [ 6  0 12  5]
#  [ 4  2  2 11]]
# Confusion Matrix for Batch = 232 is [[ 9  3  0 16]
#  [ 1 15  2  2]
#  [ 2  1 13 10]
#  [ 0  3  1 22]]
# Confusion Matrix for Batch = 233 is [[14  4  3  0]
#  [ 2 23  1  2]
#  [ 3  0 14  7]
#  [ 5  6  6 10]]
# Confusion Matrix for Batch = 234 is [[17  3  1  1]
#  [ 2 24  2  5]
#  [ 2  3  9  3]
#  [ 4  7  7 10]]
# Confusion Matrix for Batch = 235 is [[14  0  4  5]
#  [ 2 17  6  1]
#  [ 3  0 19  6]
#  [ 1  2  3 17]]
# Confusion Matrix for Batch = 236 is [[11  6  2  4]
#  [ 4 15  1  1]
#  [ 3  2 17  4]
#  [ 4  3  3 20]]
# Confusion Matrix for Batch = 237 is [[10  3  2  4]
#  [ 3  8  3  6]
#  [ 3  0 12  4]
#  [ 4  0  9 29]]
# Confusion Matrix for Batch = 238 is [[13  3  1  5]
#  [ 3 20  2  4]
#  [ 1  2 21  1]
#  [ 1  1  5 17]]
# Confusion Matrix for Batch = 239 is [[15  3  1  6]
#  [ 3  3  1  1]
#  [ 5  1 15  4]
#  [10  2  6 24]]
# Confusion Matrix for Batch = 240 is [[ 6  4  3  8]
#  [ 1 19  1  2]
#  [ 3  1 14  6]
#  [ 3  1  5 23]]
# Confusion Matrix for Batch = 241 is [[16  7  1  8]
#  [ 3 12  0  2]
#  [ 3  0 11  5]
#  [ 1  1  4 26]]
# Confusion Matrix for Batch = 242 is [[11  3  3  1]
#  [ 4 29  1  2]
#  [ 5  2  9  1]
#  [ 6  2  6 15]]
# Confusion Matrix for Batch = 243 is [[17  1  4  1]
#  [ 7 37  4  4]
#  [ 4  0  2  2]
#  [ 3  2  6  6]]
# Confusion Matrix for Batch = 244 is [[25  5  2  3]
#  [ 6 20  4  1]
#  [ 7  1 10  3]
#  [ 2  3  1  7]]
# Confusion Matrix for Batch = 245 is [[20  5  2  2]
#  [ 7 29  1  4]
#  [ 4  1  9  0]
#  [ 7  4  0  5]]
# Confusion Matrix for Batch = 246 is [[19  2  3  2]
#  [ 4 30  1  1]
#  [ 3  1 11  0]
#  [ 8  7  3  5]]
# Confusion Matrix for Batch = 247 is [[21  1  3  3]
#  [ 1 35  1  0]
#  [ 2  1  4  1]
#  [ 1  1  4 21]]
# Confusion Matrix for Batch = 248 is [[35  3  4  1]
#  [ 1 24  0  2]
#  [ 3  1 11  0]
#  [ 6  2  5  2]]
# Confusion Matrix for Batch = 249 is [[14  2  2  1]
#  [ 3 47  2  0]
#  [ 3  4  7  2]
#  [ 3  4  2  4]]
# Confusion Matrix for Batch = 250 is [[23  2  2  0]
#  [ 5 25  1  4]
#  [ 4  2  3  1]
#  [ 5 12  8  3]]
# Confusion Matrix for Batch = 251 is [[28  2  2  3]
#  [ 5 23  2  1]
#  [ 8  2  9  1]
#  [ 3  1  0 10]]
# Confusion Matrix for Batch = 252 is [[22  2  3  2]
#  [ 6 23  0  2]
#  [ 5  0  5  5]
#  [ 6  5  2 12]]
# Confusion Matrix for Batch = 253 is [[22  3  0  2]
#  [ 6 32  1  0]
#  [ 4  0 15  0]
#  [ 5  3  5  2]]
# Confusion Matrix for Batch = 254 is [[21  1  6  4]
#  [ 2 30  2  2]
#  [ 4  0  6  1]
#  [ 2  4  5 10]]
# Confusion Matrix for Batch = 255 is [[11  2  3  2]
#  [ 1 18  4  1]
#  [ 0  1 25  1]
#  [ 4  3  8 16]]
# Confusion Matrix for Batch = 256 is [[23  3  1  4]
#  [ 5 14  0  0]
#  [ 8  2  6  5]
#  [ 7  1  4 17]]
# Confusion Matrix for Batch = 257 is [[11  2  5  3]
#  [ 2 18  4  1]
#  [ 0  3 10  7]
#  [ 4  2  5 23]]
# Confusion Matrix for Batch = 258 is [[25  2  4  3]
#  [ 8  5  1  2]
#  [ 5  1 16  3]
#  [ 8  3  3 11]]
# Confusion Matrix for Batch = 259 is [[ 8  1  2  7]
#  [ 2  6  3  1]
#  [ 1  1 15  7]
#  [ 3  2  9 32]]
# Confusion Matrix for Batch = 260 is [[19  2  2  2]
#  [ 4 13  2  3]
#  [ 3  0 18  3]
#  [ 2  0  4 23]]
# Confusion Matrix for Batch = 261 is [[12  3  4  5]
#  [ 2 13  2  3]
#  [ 2  3  9  1]
#  [ 4  1  4 32]]
# Confusion Matrix for Batch = 262 is [[20  1  2  7]
#  [ 5 15  0  1]
#  [ 5  0 10  5]
#  [ 1  0  4 24]]
# Confusion Matrix for Batch = 263 is [[15  3  2  2]
#  [ 2 14  4  2]
#  [ 4  0 18  3]
#  [ 2  3  7 19]]
# Confusion Matrix for Batch = 264 is [[11  5  1  1]
#  [ 5 14  1  1]
#  [ 5  3 15  5]
#  [ 7  4  4 18]]
# Confusion Matrix for Batch = 265 is [[19  1  2  0]
#  [ 5 22  4  3]
#  [ 2  1 18  4]
#  [ 4  2  5  8]]
# Confusion Matrix for Batch = 266 is [[19  3  3  0]
#  [ 5 18  3  4]
#  [ 3  1 15  2]
#  [ 3  5  9  7]]
# Confusion Matrix for Batch = 267 is [[24  3  1  4]
#  [ 3 18  3  1]
#  [ 2  2  9  7]
#  [ 2  2  8 11]]
# Confusion Matrix for Batch = 268 is [[15  3  1  8]
#  [ 4  6  4  6]
#  [ 2  0 13  7]
#  [ 7  1  4 19]]
# Confusion Matrix for Batch = 269 is [[10  2  6  3]
#  [ 1 11  3  4]
#  [ 2  0 30  5]
#  [ 4  1  5 13]]
# Confusion Matrix for Batch = 270 is [[20  0  2  4]
#  [ 4 13  2  2]
#  [ 2  1 18  4]
#  [ 7  3  5 13]]
# Confusion Matrix for Batch = 271 is [[19  1  2  2]
#  [ 7  9  1  5]
#  [ 4  3 11  9]
#  [ 4  1  6 16]]
# Confusion Matrix for Batch = 272 is [[12  5  3  3]
#  [ 1 12  3  4]
#  [ 2  0 13  5]
#  [ 2  5  5 25]]
# Confusion Matrix for Batch = 273 is [[15  6  0  4]
#  [ 7 10  4  3]
#  [ 1  0 17  3]
#  [ 5  0  6 19]]
# Confusion Matrix for Batch = 274 is [[ 8  3  5  3]
#  [ 4 16  0  2]
#  [ 2  4 15  0]
#  [ 5  1  5 27]]
# Confusion Matrix for Batch = 275 is [[15  3  3  5]
#  [ 4 15  3  3]
#  [ 6  1 12  3]
#  [ 5  3  2 17]]
# Confusion Matrix for Batch = 276 is [[10  2  4  6]
#  [ 5 23  1  3]
#  [ 3  0 10  5]
#  [ 0  3  7 18]]
# Confusion Matrix for Batch = 277 is [[16  1  3  4]
#  [10 17  2  0]
#  [ 0  1 19  4]
#  [ 7  0  7  9]]
# Confusion Matrix for Batch = 278 is [[13  1  6  4]
#  [ 1 26  2  1]
#  [ 2  1 16  1]
#  [ 2  4  7 13]]
# Confusion Matrix for Batch = 279 is [[15  1  4  3]
#  [ 5 25  1  1]
#  [ 3  0 17  1]
#  [ 5  5 11  3]]
# Confusion Matrix for Batch = 280 is [[17  3  3  3]
#  [ 3 25  2  1]
#  [ 2  1 10  3]
#  [ 3  5  7 12]]
# Confusion Matrix for Batch = 281 is [[19  0  6  2]
#  [ 2 15  2  2]
#  [ 3  1 18  2]
#  [ 4  2 11 11]]
# Confusion Matrix for Batch = 282 is [[14  2  7  2]
#  [ 1 18  1  1]
#  [ 1  1 19  5]
#  [ 1  2  4 21]]
# Confusion Matrix for Batch = 283 is [[15  0  8  6]
#  [ 4  9  0  4]
#  [ 3  0 18  4]
#  [ 2  2  4 21]]
# Confusion Matrix for Batch = 284 is [[14  1  1  2]
#  [ 3 15  3  4]
#  [ 2  1 26  8]
#  [ 2  2  3 13]]
# Confusion Matrix for Batch = 285 is [[14  4  3  5]
#  [ 1 17  2  1]
#  [ 1  2 23  3]
#  [ 3  2  6 13]]
# Confusion Matrix for Batch = 286 is [[ 8  2  3  3]
#  [ 3 17  2  4]
#  [ 3  1 19  5]
#  [ 3  2  6 19]]
# Confusion Matrix for Batch = 287 is [[17  8  2  5]
#  [ 5 10  0  2]
#  [ 1  0 17  3]
#  [ 5  2  7 16]]
# Confusion Matrix for Batch = 288 is [[13  2  3  6]
#  [ 4 13  1  1]
#  [ 2  0 16  5]
#  [ 2  4  6 22]]
# Confusion Matrix for Batch = 289 is [[21  6  4  6]
#  [ 4 16  0  4]
#  [ 0  1  8  5]
#  [ 1  3  4 17]]
# Confusion Matrix for Batch = 290 is [[12  2  5  1]
#  [ 3 21  3  2]
#  [ 1  0 15  4]
#  [ 0  1  7 23]]
# Confusion Matrix for Batch = 291 is [[11  4  3  2]
#  [11 28  3  0]
#  [ 2  0 17  0]
#  [ 4  2  5  8]]
# Confusion Matrix for Batch = 292 is [[15  3  7  0]
#  [ 6 26  1  3]
#  [ 1  2 14  2]
#  [ 7  2  7  4]]
# Confusion Matrix for Batch = 293 is [[22  7  7  3]
#  [ 1 19  3  2]
#  [ 2  1 11  2]
#  [ 3  5  6  6]]
# Confusion Matrix for Batch = 294 is [[22  1  1  3]
#  [ 3 26  1  1]
#  [ 1  1 13  1]
#  [ 4  4  5 13]]
# Confusion Matrix for Batch = 295 is [[15  2  3 10]
#  [ 4  7  3  2]
#  [ 3  0 18  4]
#  [ 2  4  3 20]]
# Confusion Matrix for Batch = 296 is [[12  2  4  2]
#  [ 3 11  3  2]
#  [ 0  0 25  3]
#  [ 3  3  2 25]]
# Confusion Matrix for Batch = 297 is [[16  3  2  2]
#  [ 5 19  2  3]
#  [ 3  0 16  9]
#  [ 1  2  4 13]]
# Confusion Matrix for Batch = 298 is [[ 8  2  4  2]
#  [ 1 15  5  5]
#  [ 3  2 16  4]
#  [ 8  1  4 20]]
# Confusion Matrix for Batch = 299 is [[14  1  3  2]
#  [ 1 16  0  5]
#  [ 3  0 12  8]
#  [ 3  2  7 23]]
# Confusion Matrix for Batch = 300 is [[ 6  1  2  5]
#  [ 3 18  1  6]
#  [ 1  1 20  6]
#  [ 4  2  6 18]]
# Confusion Matrix for Batch = 301 is [[15  5  4  5]
#  [ 3 11  0  3]
#  [ 3  2 13  8]
#  [ 4  2  4 18]]
# Confusion Matrix for Batch = 302 is [[22  4  5  5]
#  [ 2 14  1  1]
#  [ 4  0 12  4]
#  [ 6  1  5 14]]
# Confusion Matrix for Batch = 303 is [[18  1  3  5]
#  [ 3 27  0  3]
#  [ 1  0 13  2]
#  [ 4  4  5 11]]
# Confusion Matrix for Batch = 304 is [[16  0  5  3]
#  [ 5 24  1  2]
#  [ 2  0 18  3]
#  [ 4  2  6  9]]
# Confusion Matrix for Batch = 305 is [[16  2  5  1]
#  [ 4 30  2  1]
#  [ 3  2 14  2]
#  [ 2  5  2  9]]
# Confusion Matrix for Batch = 306 is [[21  3  3  3]
#  [ 3 17  2  4]
#  [ 2  0 18  4]
#  [ 6  1  4  9]]
# Confusion Matrix for Batch = 307 is [[13  2  2  8]
#  [ 1 10  1  2]
#  [ 3  1 16  7]
#  [ 3  1  8 22]]
# Confusion Matrix for Batch = 308 is [[13  4  2  1]
#  [ 1 11  1  2]
#  [ 1  0 27  5]
#  [ 3  1  5 23]]
# Confusion Matrix for Batch = 309 is [[13  5  3  4]
#  [ 1 11  2  5]
#  [ 2  2 14  4]
#  [ 5  1  5 23]]
# Confusion Matrix for Batch = 310 is [[17  5  5  5]
#  [ 2 15  0  1]
#  [ 3  1 18  1]
#  [ 3  1  5 18]]
# Confusion Matrix for Batch = 311 is [[18  6  4  2]
#  [ 3 17  2  2]
#  [ 1  1 16  4]
#  [ 3  3  7 11]]
# Confusion Matrix for Batch = 312 is [[19  2  1  4]
#  [ 7  8  2  2]
#  [ 3  1 13  6]
#  [ 1  2  6 23]]
# Confusion Matrix for Batch = 313 is [[19  7  2  4]
#  [ 3 15  0  4]
#  [ 1  2 13  4]
#  [ 7  2  4 13]]
# Confusion Matrix for Batch = 314 is [[14  5  6  4]
#  [ 5 30  1  2]
#  [ 4  0  6  3]
#  [ 5  2  1 12]]
# Confusion Matrix for Batch = 315 is [[15  0  3  4]
#  [ 4 29  2  2]
#  [ 4  2 12  1]
#  [ 3  6  6  7]]
# Confusion Matrix for Batch = 316 is [[24  2  2  3]
#  [ 4 27  1  3]
#  [ 2  3  7  2]
#  [ 4  3  5  8]]
# Confusion Matrix for Batch = 317 is [[11  4  4  2]
#  [ 5 43  3  1]
#  [ 1  0  8  3]
#  [ 2  2  3  8]]
# Confusion Matrix for Batch = 318 is [[31  2  1  5]
#  [ 5 15  1  1]
#  [ 1  0  9  0]
#  [ 6  6  4 13]]
# Confusion Matrix for Batch = 319 is [[25  3  3  3]
#  [ 7 26  0  1]
#  [ 3  1  5  2]
#  [ 8  4  4  5]]
# Confusion Matrix for Batch = 320 is [[18  2  4  1]
#  [ 6 39  1  2]
#  [ 5  0  5  0]
#  [ 5  4  1  7]]
# Confusion Matrix for Batch = 321 is [[28  5  1  1]
#  [ 4 35  1  0]
#  [ 1  0  4  2]
#  [ 9  2  3  4]]
# Confusion Matrix for Batch = 322 is [[16  4  2  0]
#  [ 5 36  4  1]
#  [ 3  1  4  1]
#  [ 2  6  4 11]]
# Confusion Matrix for Batch = 323 is [[19  3  1  2]
#  [12 24  7  0]
#  [ 5  2  3  2]
#  [ 6  3  4  7]]
# Confusion Matrix for Batch = 324 is [[26  1  1  2]
#  [ 6 26  3  2]
#  [ 6  2  4  0]
#  [ 6  7  4  4]]
# Confusion Matrix for Batch = 325 is [[31  6  1  0]
#  [ 7 20  1  2]
#  [ 5  0  5  0]
#  [ 9  1  3  9]]
# Confusion Matrix for Batch = 326 is [[25  1  3  1]
#  [ 5 37  1  1]
#  [ 4  1  2  3]
#  [ 8  0  4  4]]
# Confusion Matrix for Batch = 327 is [[27  2  1  6]
#  [ 4 23  3  1]
#  [ 2  1  8  7]
#  [ 2  1  4  8]]
# Confusion Matrix for Batch = 328 is [[20  4  2  1]
#  [ 6 25  1  2]
#  [ 3  0 10  2]
#  [ 8  3  7  6]]
# Confusion Matrix for Batch = 329 is [[15  1  1  6]
#  [ 6 25  1  3]
#  [ 2  0 11  5]
#  [ 6  1  9  8]]
# Confusion Matrix for Batch = 330 is [[16  1  2  2]
#  [ 3 17  2  1]
#  [ 2  0 14  3]
#  [ 9  3 13 12]]
# Confusion Matrix for Batch = 331 is [[19  1  4  3]
#  [ 5 13  5  1]
#  [ 3  0 13  7]
#  [ 4  2  7 13]]
# Confusion Matrix for Batch = 332 is [[17  1  4  3]
#  [ 2 23  6  3]
#  [ 1  1 12  2]
#  [ 2  4  8 11]]
# Confusion Matrix for Batch = 333 is [[14  2  2 11]
#  [ 4 10  2  1]
#  [ 0  0 21  5]
#  [ 3  2  3 20]]
# Confusion Matrix for Batch = 334 is [[12  3  6  4]
#  [ 2  8  4  1]
#  [ 7  1 22  9]
#  [ 2  2  7 10]]
# Confusion Matrix for Batch = 335 is [[12  3  0  4]
#  [ 2 11  2  3]
#  [ 4  0 18  4]
#  [ 4  4  6 23]]
# Confusion Matrix for Batch = 336 is [[17  2  3  2]
#  [ 4  5  3  4]
#  [ 5  1 17  7]
#  [ 4  1  6 19]]
# Confusion Matrix for Batch = 337 is [[13  4  4  1]
#  [ 5 16  1  3]
#  [ 2  0 15  8]
#  [ 2  5  8 13]]
# Confusion Matrix for Batch = 338 is [[10  7  2  2]
#  [ 4 14  3  1]
#  [ 4  1 20 10]
#  [ 4  1  7 10]]
# Confusion Matrix for Batch = 339 is [[13  2  2  3]
#  [ 5 12  2  6]
#  [ 3  0  7 10]
#  [ 2  1  4 28]]
# Confusion Matrix for Batch = 340 is [[16  3  4  2]
#  [ 2 17  1  4]
#  [ 5  0 19  3]
#  [ 3  0  1 20]]
# Confusion Matrix for Batch = 341 is [[12  1  3  4]
#  [ 5 26  2  1]
#  [ 6  1  8  2]
#  [ 9  1  7 12]]
# Confusion Matrix for Batch = 342 is [[11  5  6  2]
#  [ 2 21  1  0]
#  [ 1  1 14  5]
#  [ 6  4  7 14]]
# Confusion Matrix for Batch = 343 is [[ 9  1  2  3]
#  [ 3 25  5  4]
#  [ 3  3  9  3]
#  [ 2  6  2 20]]
# Confusion Matrix for Batch = 344 is [[22  3  4  2]
#  [ 1 17  1  3]
#  [ 6  1 16  4]
#  [ 3  2  6  9]]
# Confusion Matrix for Batch = 345 is [[11  1  4  8]
#  [ 2 14  3  4]
#  [ 0  0  3  8]
#  [ 6  2  5 29]]
# Confusion Matrix for Batch = 346 is [[ 6  9  3  8]
#  [ 9 15  2  1]
#  [ 2  0 18  1]
#  [ 1  0  7 18]]
# Confusion Matrix for Batch = 347 is [[12  2  0  4]
#  [ 4  5  2  1]
#  [ 0  1 18  6]
#  [ 2  2  3 38]]
# Confusion Matrix for Batch = 348 is [[13  3  2  5]
#  [ 2 10  2  3]
#  [ 6  1 19  6]
#  [ 3  1  3 21]]
# Confusion Matrix for Batch = 349 is [[15  1  3  2]
#  [ 1 21  1  3]
#  [ 3  1 15  5]
#  [ 3  0  8 18]]
# Confusion Matrix for Batch = 350 is [[11  3  1  3]
#  [ 2 19  2  2]
#  [ 3  0 12  9]
#  [ 5  2  1 25]]
# Confusion Matrix for Batch = 351 is [[15  9  3  4]
#  [ 7 21  0  1]
#  [ 3  2  9  4]
#  [ 3  4  0 15]]
# Confusion Matrix for Batch = 352 is [[12  3  8  2]
#  [ 5 23  0  3]
#  [ 3  0 12  4]
#  [ 5  3  8  9]]
# Confusion Matrix for Batch = 353 is [[22  4  1  2]
#  [ 8 10  5  2]
#  [ 2  0 19  2]
#  [ 1  1  7 14]]
# Confusion Matrix for Batch = 354 is [[10  3  3  5]
#  [ 2 21  4  2]
#  [ 5  1 14  5]
#  [ 8  3  5  9]]
# Confusion Matrix for Batch = 355 is [[20  1  4  5]
#  [ 4 12  3  1]
#  [ 3  1 17  2]
#  [ 4  1  4 18]]
# Confusion Matrix for Batch = 356 is [[17  1  2  2]
#  [ 5  3  2  4]
#  [ 0  2 29  5]
#  [ 6  1  6 15]]
# Confusion Matrix for Batch = 357 is [[13  2  7  1]
#  [ 2 13  2  1]
#  [ 5  0 31  4]
#  [ 3  2  3 11]]
# Confusion Matrix for Batch = 358 is [[16  3  6  2]
#  [ 7 10  2  1]
#  [ 5  1 15  6]
#  [ 4  3  4 15]]
# Confusion Matrix for Batch = 359 is [[17  5  8  1]
#  [ 1 12  2  3]
#  [ 2  1 19  5]
#  [ 6  1  4 13]]
# Confusion Matrix for Batch = 360 is [[15  2  8  3]
#  [ 4  5  1  2]
#  [ 3  1 23  6]
#  [ 1  1  6 19]]
# Confusion Matrix for Batch = 361 is [[15  2  6  4]
#  [ 2 14  4  4]
#  [ 5  1 21  1]
#  [ 3  2  3 13]]
# Confusion Matrix for Batch = 362 is [[10  2  5  6]
#  [ 1 12  3  4]
#  [ 3  0 13  7]
#  [ 3  2  5 24]]
# Confusion Matrix for Batch = 363 is [[21  3  4  2]
#  [ 4 19  3  6]
#  [ 2  1  8  4]
#  [ 3  3  4 13]]
# Confusion Matrix for Batch = 364 is [[21  2  2  6]
#  [ 2 14  2  4]
#  [ 4  0  7  3]
#  [ 4  4  8 17]]
# Confusion Matrix for Batch = 365 is [[14  2  5  5]
#  [ 6 27  1  0]
#  [ 1  0 10  1]
#  [ 9  3  4 12]]
# Confusion Matrix for Batch = 366 is [[17  2  6  2]
#  [ 4 17  4  2]
#  [ 0  0 14  3]
#  [ 1  7  8 13]]
# Confusion Matrix for Batch = 367 is [[19  0  7  1]
#  [ 1 10  2  4]
#  [ 3  1  7  3]
#  [ 5  5 10 22]]
# Confusion Matrix for Batch = 368 is [[14  3  5  3]
#  [ 7 25  1  4]
#  [ 3  0  7  2]
#  [ 5  1  5 15]]
# Confusion Matrix for Batch = 369 is [[19  3  2  4]
#  [ 4  6  1  3]
#  [ 0  1 18  3]
#  [ 4  2  6 24]]
# Confusion Matrix for Batch = 370 is [[15  1  9  2]
#  [ 3  7  0  2]
#  [ 4  1 19  3]
#  [ 4  1  6 23]]
# Confusion Matrix for Batch = 371 is [[12  7  4  4]
#  [ 7  9  5  5]
#  [ 0  1 14  4]
#  [ 7  1  5 15]]
# Confusion Matrix for Batch = 372 is [[22  4  3  8]
#  [ 2  8  1  3]
#  [ 3  0 14  6]
#  [ 0  1  5 20]]
# Confusion Matrix for Batch = 373 is [[12  2  3 10]
#  [ 2 20  3  1]
#  [ 1  0 17  2]
#  [ 6  1  3 17]]
# Confusion Matrix for Batch = 374 is [[ 9  2  0 10]
#  [ 1  5  3  2]
#  [ 2  3 16  3]
#  [ 7  1  6 30]]
# Confusion Matrix for Batch = 375 is [[17  2  1  3]
#  [ 3 20  1  2]
#  [ 1  2 13  7]
#  [ 3  3  0 22]]
# Confusion Matrix for Batch = 376 is [[12  1  1  7]
#  [ 5 11  2  4]
#  [ 3  1 10  7]
#  [ 4  3  4 25]]
# Confusion Matrix for Batch = 377 is [[19  5  1  3]
#  [ 3 19  3  4]
#  [ 3  2 11  2]
#  [ 5  1 10  9]]
# Confusion Matrix for Batch = 378 is [[13  4  5  0]
#  [ 1 17  5  2]
#  [ 2  0 18  2]
#  [10  5  7  9]]
# Confusion Matrix for Batch = 379 is [[13  2  2  4]
#  [ 5 24  2  2]
#  [ 3  0 12  4]
#  [ 6  1 10 10]]
# Confusion Matrix for Batch = 380 is [[12  3  5  0]
#  [ 1 28  2  3]
#  [ 3  2 14  4]
#  [ 2  4  8  9]]
# Confusion Matrix for Batch = 381 is [[13  2  5  2]
#  [ 5 16  7  5]
#  [ 1  0 12  4]
#  [ 1  2  7 18]]
# Confusion Matrix for Batch = 382 is [[12  0  7  4]
#  [ 5 12  1  0]
#  [ 1  0 27  3]
#  [ 2  3  5 18]]
# Confusion Matrix for Batch = 383 is [[13  2  5  3]
#  [ 1  7  3  4]
#  [ 2  1 21  4]
#  [ 3  4  8 19]]
# Confusion Matrix for Batch = 384 is [[20  8  6  2]
#  [ 2 11  1  5]
#  [ 4  0 13  6]
#  [ 3  0  4 15]]
# Confusion Matrix for Batch = 385 is [[16  5  8  3]
#  [ 7 18  1  2]
#  [ 0  0 10  3]
#  [ 2  3  6 16]]
# Confusion Matrix for Batch = 386 is [[16  3  3  6]
#  [ 3  9  3  4]
#  [ 0  1 17  6]
#  [ 2  4  5 18]]
# Confusion Matrix for Batch = 387 is [[15  8  1  7]
#  [ 3 18  2  4]
#  [ 0  0  9  7]
#  [ 5  0  0 21]]
# Confusion Matrix for Batch = 388 is [[27  6  1  4]
#  [ 2 15  3  0]
#  [ 2  0  6  2]
#  [ 4  2  6 20]]
# Confusion Matrix for Batch = 389 is [[23  5  7  3]
#  [ 2 22  2  0]
#  [ 1  0 11  1]
#  [ 3  9  3  8]]
# Confusion Matrix for Batch = 390 is [[22  3  6  1]
#  [ 4 21  1  4]
#  [ 1  1  6  5]
#  [ 3  5  7 10]]
# Confusion Matrix for Batch = 391 is [[17  3  2  3]
#  [ 5 41  3  1]
#  [ 1  0  8  0]
#  [ 3  3  0 10]]
# Confusion Matrix for Batch = 392 is [[22  5  5  3]
#  [ 1 32  1  2]
#  [ 6  3  9  1]
#  [ 0  2  4  4]]
# Confusion Matrix for Batch = 393 is [[19  7  2  2]
#  [ 5 31  1  2]
#  [ 4  2  2  1]
#  [ 9  1  1 11]]
# Confusion Matrix for Batch = 394 is [[23  3  3  2]
#  [ 4 34  1  1]
#  [ 3  2  3  0]
#  [ 8  5  5  3]]
# Confusion Matrix for Batch = 395 is [[23  4  2  2]
#  [ 4 35  2  2]
#  [ 0  1  5  2]
#  [ 3  5  2  8]]
# Confusion Matrix for Batch = 396 is [[24  3  4  2]
#  [ 4 34  0  1]
#  [ 1  0  6  1]
#  [ 4  2  5  9]]
# Confusion Matrix for Batch = 397 is [[15  3  2  1]
#  [ 4 27  5  1]
#  [ 3  1  8  1]
#  [ 3  3 14  9]]
# Confusion Matrix for Batch = 398 is [[30  3  1  3]
#  [ 7 20  1  0]
#  [ 6  1  4  1]
#  [ 8  4  7  4]]
# Confusion Matrix for Batch = 399 is [[23  3  1  2]
#  [ 5 44  1  2]
#  [ 2  1  4  0]
#  [ 3  0  6  3]]
# Confusion Matrix for Batch = 400 is [[34  2  3  2]
#  [ 7 22  2  0]
#  [ 3  2  2  2]
#  [11  0  3  5]]
# Confusion Matrix for Batch = 401 is [[26  5  2  1]
#  [ 1 27  2  4]
#  [ 4  1 10  1]
#  [ 2  4  5  5]]
# Confusion Matrix for Batch = 402 is [[17  1  2  2]
#  [ 6 36  1  1]
#  [ 4  0  6  1]
#  [ 5  3  7  8]]
# Confusion Matrix for Batch = 403 is [[14  5  1  0]
#  [ 4 36  0  0]
#  [ 2  1 11  2]
#  [10  5  4  5]]
# Confusion Matrix for Batch = 404 is [[17  4  5  4]
#  [ 4 20  1  3]
#  [ 3  0 13  4]
#  [ 4  4  7  7]]
# Confusion Matrix for Batch = 405 is [[11  7  4  3]
#  [10 24  0  2]
#  [ 2  0 13  3]
#  [ 2  2  6 11]]
# Confusion Matrix for Batch = 406 is [[25  3  2  3]
#  [ 3 19  4  0]
#  [ 1  2 11  2]
#  [ 4  6  8  7]]
# Confusion Matrix for Batch = 407 is [[15  0  3  3]
#  [ 3  9  2  6]
#  [ 4  0 18  3]
#  [ 7  1  7 19]]
# Confusion Matrix for Batch = 408 is [[13  0  3  5]
#  [ 1 17  0  4]
#  [ 4  0 23  2]
#  [ 6  1  6 15]]
# Confusion Matrix for Batch = 409 is [[ 9  0  1  5]
#  [ 5  8  1  5]
#  [ 1  0 22  3]
#  [ 7  1  7 25]]
# Confusion Matrix for Batch = 410 is [[21  0  1  3]
#  [ 4 10  0  2]
#  [ 2  1 21  4]
#  [ 2  2  3 24]]
# Confusion Matrix for Batch = 411 is [[11  2  3  5]
#  [ 3 18  1  1]
#  [ 5  1 16  6]
#  [ 5  1  9 13]]
# Confusion Matrix for Batch = 412 is [[11  2  2  2]
#  [ 4 15  1  5]
#  [ 2  0 11  7]
#  [ 3  1  3 31]]
# Confusion Matrix for Batch = 413 is [[13  1  4  2]
#  [ 2 16  4  4]
#  [ 2  2 24  4]
#  [ 3  1  3 15]]
# Confusion Matrix for Batch = 414 is [[11  6  3  4]
#  [ 3 18  0  2]
#  [ 2  0 16  6]
#  [ 4  3  4 18]]
# Confusion Matrix for Batch = 415 is [[10  1  0  5]
#  [ 4 13  0  4]
#  [ 2  0 15  8]
#  [ 5  3  3 27]]
# Confusion Matrix for Batch = 416 is [[13  2  2  3]
#  [ 2 18  3  7]
#  [ 3  0  8  9]
#  [ 5  3  1 21]]
# Confusion Matrix for Batch = 417 is [[ 9  3  7  1]
#  [ 4 28  2  5]
#  [ 2  1 12  2]
#  [ 1  2  9 12]]
# Confusion Matrix for Batch = 418 is [[16  2  3  3]
#  [ 2 25  3  1]
#  [ 0  0 18  3]
#  [ 5  4  5 10]]
# Confusion Matrix for Batch = 419 is [[ 4  3  2  2]
#  [ 4 25  3  3]
#  [ 2  1 22  1]
#  [ 2  1  5 20]]
# Confusion Matrix for Batch = 420 is [[17  3  5  1]
#  [ 2 26  3  3]
#  [ 1  0 11  1]
#  [ 5  3 10  9]]
# Confusion Matrix for Batch = 421 is [[18  2  1  1]
#  [ 5 17  3  4]
#  [ 2  1 18  5]
#  [ 0  5  6 12]]
# Confusion Matrix for Batch = 422 is [[12  4  2  3]
#  [ 1 11  1  4]
#  [ 2  2 15  6]
#  [ 2  1  6 28]]
# Confusion Matrix for Batch = 423 is [[13  1  4  7]
#  [ 4 13  0  3]
#  [ 4  0 18  1]
#  [ 4  1  5 22]]
# Confusion Matrix for Batch = 424 is [[ 7  1  4  4]
#  [ 2 12  4  2]
#  [ 3  0 35  4]
#  [ 5  0  4 13]]
# Confusion Matrix for Batch = 425 is [[18  4  1  1]
#  [ 6  8  2  2]
#  [ 2  1 14  8]
#  [ 7  1  6 19]]
# Confusion Matrix for Batch = 426 is [[ 8  2  4  3]
#  [ 1 17  2  2]
#  [ 1  0 20  3]
#  [ 2  3  9 23]]
# Confusion Matrix for Batch = 427 is [[16  1  2  4]
#  [ 3 16  2  3]
#  [ 1  2  9  8]
#  [ 1  1 11 20]]
# Confusion Matrix for Batch = 428 is [[17  0  2  3]
#  [ 4 21  2  6]
#  [ 0  0 11  4]
#  [ 4  7  1 18]]
# Confusion Matrix for Batch = 429 is [[15  2  1  4]
#  [ 1 14  1  6]
#  [ 2  1 21  5]
#  [ 0  3  5 19]]
# Confusion Matrix for Batch = 430 is [[21  1  3  4]
#  [ 2 17  1  4]
#  [ 2  0  8  2]
#  [ 3  2  3 27]]
# Confusion Matrix for Batch = 431 is [[19  3  4  7]
#  [ 3 10  0  4]
#  [ 2  0 14  5]
#  [ 1  2  4 22]]
# Confusion Matrix for Batch = 432 is [[15  2  4  0]
#  [ 5 24  0  2]
#  [ 1  1 19  4]
#  [ 7  2  9  5]]
# Confusion Matrix for Batch = 433 is [[11  0  5  3]
#  [ 4 27  7  2]
#  [ 0  1 15  3]
#  [ 3  0  7 12]]
# Confusion Matrix for Batch = 434 is [[22  1  5  4]
#  [ 2 19  4  0]
#  [ 5  1 16  0]
#  [ 5  2  4 10]]
# Confusion Matrix for Batch = 435 is [[19  1  7  6]
#  [ 2 13  1  4]
#  [ 2  0 19  2]
#  [ 3  1  9 11]]
# Confusion Matrix for Batch = 436 is [[ 9  2  3  7]
#  [ 2 12  2  2]
#  [ 5  0 17  8]
#  [ 2  2  5 22]]
# Confusion Matrix for Batch = 437 is [[16  1  2  2]
#  [ 4  9  4  3]
#  [ 3  0 20  7]
#  [ 3  2  6 18]]
# Confusion Matrix for Batch = 438 is [[10  3  5  6]
#  [ 6  7  3  2]
#  [ 3  0 23  3]
#  [ 4  1  5 19]]
# Confusion Matrix for Batch = 439 is [[12  0  7  7]
#  [ 3 11  2  5]
#  [ 3  0 16  5]
#  [ 1  2  3 23]]
# Confusion Matrix for Batch = 440 is [[ 7  3  5  9]
#  [ 2 20  0  3]
#  [ 0  0 18  6]
#  [ 4  0  3 20]]
# Confusion Matrix for Batch = 441 is [[11  2  3  3]
#  [ 4 13  1  2]
#  [ 1  0 17  8]
#  [ 1  3 12 19]]
# Confusion Matrix for Batch = 442 is [[13  4  2  5]
#  [ 8 13  1  3]
#  [ 3  0 20  6]
#  [ 4  2  7  9]]
# Confusion Matrix for Batch = 443 is [[15  3  2  6]
#  [ 3 18  3  2]
#  [ 3  0 13  4]
#  [ 2  3  2 21]]
# Confusion Matrix for Batch = 444 is [[ 9  5  4  2]
#  [ 4 17  3  6]
#  [ 2  1 17  1]
#  [ 0  5  2 22]]
# Confusion Matrix for Batch = 445 is [[16  3  5  2]
#  [ 5 19  3  2]
#  [ 2  0 10  3]
#  [ 4  5  6 15]]
# Confusion Matrix for Batch = 446 is [[18  1  1  5]
#  [ 1 21  2  3]
#  [ 2  0 23  5]
#  [ 2  2  7  7]]
# Confusion Matrix for Batch = 447 is [[23  0  7  5]
#  [ 2 13  0  2]
#  [ 2  0 22  3]
#  [ 6  1  8  6]]
# Confusion Matrix for Batch = 448 is [[24  3  3  6]
#  [ 0 21  2  2]
#  [ 2  1 15  2]
#  [ 2  3  8  6]]
# Confusion Matrix for Batch = 449 is [[13  4  6  3]
#  [ 4  8  3  4]
#  [ 3  0 17  6]
#  [ 4  0  6 19]]
# Confusion Matrix for Batch = 450 is [[15  4  4  3]
#  [ 1 11  2  2]
#  [ 2  0 19  5]
#  [ 4  3  3 22]]
# Confusion Matrix for Batch = 451 is [[19  0  5  7]
#  [ 1  6  4  2]
#  [ 3  0 17  6]
#  [ 6  0  6 18]]
# Confusion Matrix for Batch = 452 is [[10  1  2  3]
#  [ 0 19  3  5]
#  [ 1  0 18  9]
#  [ 2  1  9 17]]
# Confusion Matrix for Batch = 453 is [[ 9  0  7  6]
#  [ 2 13  3  6]
#  [ 2  1 19  5]
#  [ 2  1  5 19]]
# Confusion Matrix for Batch = 454 is [[13  3  2  5]
#  [ 2 12  1  3]
#  [ 2  0 14  6]
#  [ 3  4  4 26]]
# Confusion Matrix for Batch = 455 is [[15  0  4  6]
#  [ 2 17  2  3]
#  [ 2  0 18  6]
#  [ 2  1  8 14]]
# Confusion Matrix for Batch = 456 is [[12  0  5  6]
#  [ 4 14  3  2]
#  [ 3  1 12  9]
#  [ 2  1  4 22]]
# Confusion Matrix for Batch = 457 is [[17  4  3  2]
#  [ 3 14  1  3]
#  [ 1  0 13  4]
#  [ 3  3  3 26]]
# Confusion Matrix for Batch = 458 is [[18  3  5  4]
#  [ 2 19  1  1]
#  [ 4  1 13  2]
#  [ 4  4  5 14]]
# Confusion Matrix for Batch = 459 is [[18  1  3  0]
#  [ 3 25  3  1]
#  [ 2  1 13  4]
#  [ 5  3  4 14]]
# Confusion Matrix for Batch = 460 is [[ 7  4  4  3]
#  [ 7 20  1  5]
#  [ 0  2 16  3]
#  [ 2  4  7 15]]
# Confusion Matrix for Batch = 461 is [[14  4  1  1]
#  [ 4 28  4  2]
#  [ 1  1 15  1]
#  [ 2  3  6 13]]
# Confusion Matrix for Batch = 462 is [[23  1  5  4]
#  [ 3 16  2  3]
#  [ 1  0 12  4]
#  [ 3  0  2 21]]
# Confusion Matrix for Batch = 463 is [[ 5  3  1  8]
#  [ 2 15  3  1]
#  [ 2  1 18  2]
#  [ 6  3  7 23]]
# Confusion Matrix for Batch = 464 is [[19  2  4  2]
#  [ 4 15  4  0]
#  [ 1  0 14  3]
#  [ 7  1 11 13]]
# Confusion Matrix for Batch = 465 is [[ 6  2  3  9]
#  [ 2 17  1  3]
#  [ 2  0  9  8]
#  [ 4  2  3 29]]
# Confusion Matrix for Batch = 466 is [[14  4  7  6]
#  [ 3  8  2  1]
#  [ 2  0 19  5]
#  [ 2  0  7 20]]
# Confusion Matrix for Batch = 467 is [[12  2  5  1]
#  [ 4 18  3  3]
#  [ 1  1 22  2]
#  [ 2  1  7 16]]
# Confusion Matrix for Batch = 468 is [[13  4  2  4]
#  [ 4 16  1  1]
#  [ 0  1 22  5]
#  [ 2  1  6 18]]
# Confusion Matrix for Batch = 469 is [[10  1  3  4]
#  [ 2 16  8  5]
#  [ 1  0 16  5]
#  [ 5  4  6 14]]
# Confusion Matrix for Batch = 470 is [[17  3  5  3]
#  [ 3 20  4  6]
#  [ 3  0  8  6]
#  [ 4  1  8  9]]
# Confusion Matrix for Batch = 471 is [[12  5  5  5]
#  [ 1 23  2  5]
#  [ 0  1  9  1]
#  [ 2  4  3 22]]
# Confusion Matrix for Batch = 472 is [[17  4  4  2]
#  [ 6 34  5  1]
#  [ 0  1 11  1]
#  [ 2  1  4  7]]
# Confusion Matrix for Batch = 473 is [[19  0  6  1]
#  [ 6 31  3  1]
#  [ 2  3  9  2]
#  [ 1  3  5  8]]
# Confusion Matrix for Batch = 474 is [[23  4  1  7]
#  [ 0 29  2  1]
#  [ 3  1  6  1]
#  [ 6  5  2  9]]
# Confusion Matrix for Batch = 475 is [[27  6  2  3]
#  [ 2 22  1  5]
#  [ 1  1  9  2]
#  [10  1  4  4]]
# Confusion Matrix for Batch = 476 is [[29  1  4  4]
#  [ 1 24  1  4]
#  [ 4  0  3  5]
#  [ 1  0  2 17]]
# Confusion Matrix for Batch = 477 is [[27  5  3  0]
#  [ 3 30  2  4]
#  [ 2  1  5  1]
#  [ 5  5  3  4]]
# Confusion Matrix for Batch = 478 is [[17  5  3  4]
#  [ 5 43  0  2]
#  [ 1  0  4  1]
#  [ 1  5  3  6]]
# Confusion Matrix for Batch = 479 is [[17  6  1  1]
#  [ 7 37  3  4]
#  [ 2  1  6  2]
#  [ 2  4  4  3]]
# Confusion Matrix for Batch = 480 is [[15  1  3  3]
#  [ 6 32  4  1]
#  [ 2  2  3  3]
#  [ 2  3 12  8]]
# Confusion Matrix for Batch = 481 is [[22  5  2  1]
#  [ 3 31  4  3]
#  [ 2  2  5  1]
#  [ 6  4  3  6]]
# Confusion Matrix for Batch = 482 is [[39  3  7  0]
#  [ 5 16  1  3]
#  [ 4  0  1  1]
#  [ 5  2  6  7]]
# Confusion Matrix for Batch = 483 is [[23  5  4  0]
#  [ 8 22  1  4]
#  [ 4  1  8  1]
#  [ 5  4  2  8]]
# Confusion Matrix for Batch = 484 is [[13  4  8  4]
#  [ 4 29  4  3]
#  [ 3  1  9  2]
#  [ 3  1  4  8]]
# Confusion Matrix for Batch = 485 is [[16  1  1  5]
#  [ 6 35  4  2]
#  [ 1  1  7  0]
#  [10  3  4  4]]
# Confusion Matrix for Batch = 486 is [[11  5  5  1]
#  [ 4 23  5  0]
#  [ 0  2 12  4]
#  [ 6  2  9 11]]
# Confusion Matrix for Batch = 487 is [[18  1  6  1]
#  [ 6 16  5  2]
#  [ 6  2 15  2]
#  [ 5  1  1 13]]
# Confusion Matrix for Batch = 488 is [[24  1  5  1]
#  [ 8 22  1  2]
#  [ 4  0  7  2]
#  [ 5  1  9  8]]
# Confusion Matrix for Batch = 489 is [[ 6  0  4  2]
#  [ 3 15  3  1]
#  [ 3  0 11  4]
#  [ 5  3 11 29]]
# Confusion Matrix for Batch = 490 is [[10  0  4  2]
#  [ 3  9  3  9]
#  [ 6  3 14  7]
#  [ 7  1  8 14]]
# Confusion Matrix for Batch = 491 is [[ 9  1  4  4]
#  [ 2  9  3  8]
#  [ 0  0 19  4]
#  [ 4  0  7 26]]
# Confusion Matrix for Batch = 492 is [[10  2  1  2]
#  [ 4 16  0  4]
#  [ 2  0 23  8]
#  [ 3  4  1 20]]
# Confusion Matrix for Batch = 493 is [[14  0  2  4]
#  [ 1  4  2  4]
#  [ 3  2 17 12]
#  [ 3  3 10 19]]
# Confusion Matrix for Batch = 494 is [[ 6  0  3  4]
#  [ 5 17  1  4]
#  [ 2  1 28  7]
#  [ 0  1  7 14]]
# Confusion Matrix for Batch = 495 is [[15  0  5  2]
#  [ 0 15  2  4]
#  [ 1  0 15 11]
# ...
#  [ 3 12  2  4]
#  [ 1  0 14  4]
#  [ 2  1  5 20]]
# Confusion Matrix for Batch = 1040 is [[10  4  2  5]
#  [ 3 12  8  4]
#  [ 1  1 13  6]
#  [ 3  1  6 21]]
# Confusion Matrix for Batch = 1041 is [[11  0  2  1]
#  [ 0 17  1  7]
#  [ 4  2 16 10]
#  [ 3  0  5 21]]
# Confusion Matrix for Batch = 1042 is [[ 5  2  7  4]
#  [ 0 12  0  5]
#  [ 2  2 21  7]
#  [ 3  2  6 22]]
# Confusion Matrix for Batch = 1043 is [[ 8  3  2  3]
#  [ 3 23  3  1]
#  [ 1  1 13 10]
#  [ 4  4  6 15]]
# Confusion Matrix for Batch = 1044 is [[10  1  3  2]
#  [ 2 13  2  2]
#  [ 2  2 22  3]
#  [ 6  1  7 22]]
# Confusion Matrix for Batch = 1045 is [[18  3  5  4]
#  [ 5 21  1  1]
#  [ 2  0 12  3]
#  [ 2  2  4 17]]
# Confusion Matrix for Batch = 1046 is [[ 8  2  4  7]
#  [ 1 21  5  5]
#  [ 5  0  8  7]
#  [ 8  4  2 13]]
# Confusion Matrix for Batch = 1047 is [[12  3  7  3]
#  [ 6 21  7  2]
#  [ 4  0 10  0]
#  [ 3  0  9 13]]
# Confusion Matrix for Batch = 1048 is [[15  0  3  2]
#  [ 5 14  3  2]
#  [ 2  1 18  2]
#  [ 7  5 11 10]]
# Confusion Matrix for Batch = 1049 is [[22  2  2  2]
#  [ 3 23  2  1]
#  [ 1  1 14  5]
#  [ 5  0  7 10]]
# Confusion Matrix for Batch = 1050 is [[11  0  2  4]
#  [ 2 14  3  4]
#  [ 1  1 18  8]
#  [ 3  0  9 20]]
# Confusion Matrix for Batch = 1051 is [[13  1  3  1]
#  [ 4 12  2  0]
#  [ 0  0 27  7]
#  [ 3  5  4 18]]
# Confusion Matrix for Batch = 1052 is [[24  3  1  3]
#  [ 2 18  2  0]
#  [ 5  0 23  5]
#  [ 4  0  4  6]]
# Confusion Matrix for Batch = 1053 is [[18  3  1  0]
#  [ 2 17  0  3]
#  [ 3  2 19  3]
#  [ 2  0  3 24]]
# Confusion Matrix for Batch = 1054 is [[ 8  5  4  5]
#  [ 1  7  2  5]
#  [ 2  1 25  5]
#  [ 2  2  4 22]]
# Confusion Matrix for Batch = 1055 is [[12  2  0  2]
#  [ 2 18  3  4]
#  [ 2  0 24  3]
#  [ 3  3  5 17]]
# Confusion Matrix for Batch = 1056 is [[13  1  1  1]
#  [ 5 14  1  2]
#  [ 2  0 23  4]
#  [ 1  2  7 23]]
# Confusion Matrix for Batch = 1057 is [[10  3  1  5]
#  [ 1 20  3  5]
#  [ 2  1 10  5]
#  [ 5  1  2 26]]
# Confusion Matrix for Batch = 1058 is [[20  3  2  2]
#  [ 1 28  2  0]
#  [ 3  0 13  4]
#  [ 3  2  5 12]]
# Confusion Matrix for Batch = 1059 is [[17  2  2  4]
#  [ 0 22  2  3]
#  [ 2  1 19  2]
#  [ 2  3  3 16]]
# Confusion Matrix for Batch = 1060 is [[12  0  4  2]
#  [ 1 26  3  0]
#  [ 2  1 18  1]
#  [ 5  6 13  6]]
# Confusion Matrix for Batch = 1061 is [[15  0  4  0]
#  [ 3 10  3  3]
#  [ 2  1 28  4]
#  [ 5  6  6 10]]
# Confusion Matrix for Batch = 1062 is [[20  2  4  5]
#  [ 1 12  0  1]
#  [ 0  0 14  6]
#  [ 5  3  5 22]]
# Confusion Matrix for Batch = 1063 is [[10  3  6  1]
#  [ 5 16  2  4]
#  [ 1  0 21  1]
#  [ 2  3  5 20]]
# Confusion Matrix for Batch = 1064 is [[16  2  4  7]
#  [ 3 13  1  2]
#  [ 2  0 12  5]
#  [ 3  1  6 23]]
# Confusion Matrix for Batch = 1065 is [[13  2  3  1]
#  [ 1 18  2  3]
#  [ 1  1 19  5]
#  [ 3  1  6 21]]
# Confusion Matrix for Batch = 1066 is [[22  1  7  6]
#  [ 2 16  3  1]
#  [ 1  0 14  0]
#  [ 5  1  2 19]]
# Confusion Matrix for Batch = 1067 is [[23  1  3  2]
#  [ 1 31  4  3]
#  [ 1  0  8  2]
#  [ 6  3  3  9]]
# Confusion Matrix for Batch = 1068 is [[ 6  2  0  7]
#  [ 2 17  2  7]
#  [ 0  0 16  6]
#  [ 1  3  3 28]]
# Confusion Matrix for Batch = 1069 is [[ 6  0  1  6]
#  [ 3 13  6  2]
#  [ 1  1  8  7]
#  [ 4  2  7 33]]
# Confusion Matrix for Batch = 1070 is [[17  2  3  1]
#  [ 3 25  1  1]
#  [ 6  0 16  2]
#  [ 2  4  6 11]]
# Confusion Matrix for Batch = 1071 is [[22  1  3  1]
#  [ 2 19  2  4]
#  [ 4  1 19  2]
#  [ 2  0  8 10]]
# Confusion Matrix for Batch = 1072 is [[15  0  3  3]
#  [ 2 16  2  5]
#  [ 1  1 10  4]
#  [ 2  1  2 33]]
# Confusion Matrix for Batch = 1073 is [[12  2  1  4]
#  [ 0 21  5  4]
#  [ 1  0 16  4]
#  [ 4  4  9 13]]
# Confusion Matrix for Batch = 1074 is [[17  3  5  2]
#  [ 2 19  3  0]
#  [ 1  1 24  4]
#  [ 2  3  7  7]]
# Confusion Matrix for Batch = 1075 is [[13  2  4  2]
#  [ 0 13  3  3]
#  [ 3  1 17  8]
#  [ 2  5  3 21]]
# Confusion Matrix for Batch = 1076 is [[14  2  2  6]
#  [ 4 17  3  3]
#  [ 1  0 11  6]
#  [ 3  3  0 25]]
# Confusion Matrix for Batch = 1077 is [[ 9  3  9  0]
#  [ 4 15  2  1]
#  [ 3  1 21  2]
#  [ 4  5  7 14]]
# Confusion Matrix for Batch = 1078 is [[15  1  3  1]
#  [ 2 21  2  4]
#  [ 5  3 18  4]
#  [ 3  3  4 11]]
# Confusion Matrix for Batch = 1079 is [[26  6  2  0]
#  [ 5 21  4  0]
#  [ 2  0 15  1]
#  [ 4  5  7  2]]
# Confusion Matrix for Batch = 1080 is [[15  0  4  4]
#  [ 2 15  4  0]
#  [ 3  0 19  5]
#  [ 2  2  3 22]]
# Confusion Matrix for Batch = 1081 is [[12  3  5  2]
#  [ 6 15  2  2]
#  [ 3  0 20  1]
#  [ 1  3  7 18]]
# Confusion Matrix for Batch = 1082 is [[14  5  4  0]
#  [ 0 13  3  6]
#  [ 4  0 21  5]
#  [ 3  0  5 17]]
# Confusion Matrix for Batch = 1083 is [[14  4  8  2]
#  [ 2 13  4  1]
#  [ 0  2 21  3]
#  [ 2  2  7 15]]
# Confusion Matrix for Batch = 1084 is [[13  3  3  8]
#  [ 4 11  2  3]
#  [ 3  0 17  3]
#  [ 3  2  7 18]]
# Confusion Matrix for Batch = 1085 is [[18  1  1  2]
#  [ 0 20  1  2]
#  [ 1  0 17  7]
#  [ 2  3  7 18]]
# Confusion Matrix for Batch = 1086 is [[ 7  3  3  3]
#  [ 2 21  3  2]
#  [ 0  3  9  4]
#  [ 3  2  3 32]]
# Confusion Matrix for Batch = 1087 is [[16  6  2  3]
#  [ 0 33  5  1]
#  [ 2  0  7  1]
#  [ 3  7  7  7]]
# Confusion Matrix for Batch = 1088 is [[22  1  2  0]
#  [ 3 34  5  2]
#  [ 2  2  8  0]
#  [ 1  4  5  9]]
# Confusion Matrix for Batch = 1089 is [[25  7  1  3]
#  [ 1 22  0  3]
#  [ 4  0 11  4]
#  [ 3  3  5  8]]
# Confusion Matrix for Batch = 1090 is [[17  3  1  9]
#  [ 5 12  3  1]
#  [ 3  0  7  3]
#  [ 2  3  3 28]]
# Confusion Matrix for Batch = 1091 is [[13  1  6  3]
#  [ 2 22  2  2]
#  [ 1  0 15  2]
#  [ 5  2  9 15]]
# Confusion Matrix for Batch = 1092 is [[16  2  2  3]
#  [ 5 15  1  3]
#  [ 2  2 15  6]
#  [ 5  0  7 16]]
# Confusion Matrix for Batch = 1093 is [[11  2  1  1]
#  [ 2 27  3  2]
#  [ 4  1 11  5]
#  [ 4  1  0 25]]
# Confusion Matrix for Batch = 1094 is [[10  6  4  5]
#  [ 2 19  2  2]
#  [ 2  0 20  3]
#  [ 3  3  4 15]]
# Confusion Matrix for Batch = 1095 is [[16  1  7  3]
#  [ 2 35  1  1]
#  [ 2  1  4  1]
#  [ 2  7  7 10]]
# Confusion Matrix for Batch = 1096 is [[19  3  2  1]
#  [ 2 26  3  0]
#  [ 2  0 16  2]
#  [ 5  1  6 12]]
# Confusion Matrix for Batch = 1097 is [[19  3  4  2]
#  [ 1 23  4  2]
#  [ 3  2 20  2]
#  [ 1  2  7  5]]
# Confusion Matrix for Batch = 1098 is [[17  3  3  4]
#  [ 1 21  1  3]
#  [ 2  0 11  4]
#  [ 4  3  5 18]]
# Confusion Matrix for Batch = 1099 is [[12  3  4  4]
#  [ 2 20  3  2]
#  [ 4  0 15  3]
#  [ 4  0 12 12]]
# Confusion Matrix for Batch = 1100 is [[20  2  2  4]
#  [ 1 19  1  3]
#  [ 4  0 19  4]
#  [ 3  2  3 13]]
# Confusion Matrix for Batch = 1101 is [[13  2  1  1]
#  [ 1 18  3  2]
#  [ 2  0 25  5]
#  [ 6  1  8 12]]
# Confusion Matrix for Batch = 1102 is [[10  6  4  6]
#  [ 0 12  2  1]
#  [ 4  0  8  8]
#  [ 2  3  7 27]]
# Confusion Matrix for Batch = 1103 is [[ 8  3  1  7]
#  [ 1 18  2  6]
#  [ 1  1 17  1]
#  [ 4  0  7 23]]
# Confusion Matrix for Batch = 1104 is [[ 9  1  6  0]
#  [ 2 20  2  1]
#  [ 3  1 20  4]
#  [ 3  4 10 14]]
# Confusion Matrix for Batch = 1105 is [[24  0  7  1]
#  [ 0 27  2  2]
#  [ 3  0  8  3]
#  [ 3  4  1 15]]
# Confusion Matrix for Batch = 1106 is [[13  4  3  2]
#  [ 2 25  1  1]
#  [ 1  0  9  7]
#  [ 2  2  4 24]]
# Confusion Matrix for Batch = 1107 is [[11  2  5  3]
#  [ 0 21  4  3]
#  [ 4  0 11  3]
#  [ 5  0  1 27]]
# Confusion Matrix for Batch = 1108 is [[16  1  7  7]
#  [ 3 14  3  2]
#  [ 2  0 15  3]
#  [ 9  0  4 14]]
# Confusion Matrix for Batch = 1109 is [[20  1  4  3]
#  [ 3 11  1  1]
#  [ 5  1 24  3]
#  [ 3  1  8 11]]
# Confusion Matrix for Batch = 1110 is [[12  1  6  2]
#  [ 2 21  2  2]
#  [ 3  1 21  3]
#  [ 5  1  5 13]]
# Confusion Matrix for Batch = 1111 is [[10  1  3  3]
#  [ 1 13  4  2]
#  [ 3  0 29  8]
#  [ 6  2  4 11]]
# Confusion Matrix for Batch = 1112 is [[14  1  2  2]
#  [ 4 13  4  2]
#  [ 2  3 23  4]
#  [ 1  4  6 15]]
# Confusion Matrix for Batch = 1113 is [[19  2  2  4]
#  [ 1 12  0  3]
#  [ 2  2  5  8]
#  [ 1  1  6 32]]
# Confusion Matrix for Batch = 1114 is [[ 9  2  1  2]
#  [ 3 16  2  2]
#  [ 3  0 19  4]
#  [ 2  4  7 24]]
# Confusion Matrix for Batch = 1115 is [[ 9  2  3  9]
#  [ 3 10  1  7]
#  [ 2  1 20  3]
#  [ 5  0  4 21]]
# Confusion Matrix for Batch = 1116 is [[10  1  2  1]
#  [ 3 20  4  2]
#  [ 0  0 17  4]
#  [ 1  2  6 27]]
# Confusion Matrix for Batch = 1117 is [[16  1  3  3]
#  [ 0 23  6  1]
#  [ 2  0 14  3]
#  [ 8  2  6 12]]
# Confusion Matrix for Batch = 1118 is [[11  3 11  3]
#  [ 2 28  0  2]
#  [ 1  4 16  0]
#  [ 2  3  8  6]]
# Confusion Matrix for Batch = 1119 is [[15  2  7  5]
#  [ 2 21  1  2]
#  [ 2  2 14  3]
#  [ 3  3  4 14]]
# Confusion Matrix for Batch = 1120 is [[19  1  6  2]
#  [ 1 31  4  2]
#  [ 2  0 10  2]
#  [ 2  3  7  8]]
# Confusion Matrix for Batch = 1121 is [[10  1  2  3]
#  [ 3 19  1  5]
#  [ 3  0 15  6]
#  [ 2  2  5 23]]
# Confusion Matrix for Batch = 1122 is [[16  1  6  2]
#  [ 1 13  4  4]
#  [ 1  0 19  6]
#  [ 1  2  5 19]]
# Confusion Matrix for Batch = 1123 is [[17  0  3  2]
#  [ 4 23  0  1]
#  [ 0  1 17  7]
#  [ 2  0  6 17]]
# Confusion Matrix for Batch = 1124 is [[19  1  1  7]
#  [ 4 17  1  2]
#  [ 1  0 20  3]
#  [ 2  0  5 17]]
# Confusion Matrix for Batch = 1125 is [[15  2  2  3]
#  [ 3 22  0  3]
#  [ 0  0 21  4]
#  [ 4  4  7 10]]
# Confusion Matrix for Batch = 1126 is [[18  0  4  0]
#  [ 2 19  3  3]
#  [ 4  2 19  6]
#  [ 6  1  6  7]]
# Confusion Matrix for Batch = 1127 is [[11  1  0  7]
#  [ 1 16  1  4]
#  [ 1  1  8  4]
#  [ 3  2 10 30]]
# Confusion Matrix for Batch = 1128 is [[12  2  3  3]
#  [ 0 24  3  2]
#  [ 2  1 13  1]
#  [ 7  4 10 13]]
# Confusion Matrix for Batch = 1129 is [[18  2  5  3]
#  [ 4 25  2  1]
#  [ 4  2 11  1]
#  [ 2  6  6  8]]
# Confusion Matrix for Batch = 1130 is [[22  0  6  0]
#  [ 4 21  2  2]
#  [ 4  0 12  3]
#  [ 5  3  5 11]]
# Confusion Matrix for Batch = 1131 is [[23  3  4  1]
#  [ 5 38  0  0]
#  [ 1  1  8  2]
#  [ 5  2  2  5]]
# Confusion Matrix for Batch = 1132 is [[23  1  2  1]
#  [ 4 39  3  2]
#  [ 1  3  3  3]
#  [ 3  5  3  4]]
# Confusion Matrix for Batch = 1133 is [[25  1  1  3]
#  [ 3 37  2  0]
#  [ 1  1  7  0]
#  [ 6  3  6  4]]
# Confusion Matrix for Batch = 1134 is [[17  1  2  1]
#  [ 4 41  0  3]
#  [ 0  1  8  0]
#  [ 2  5  9  6]]
# Confusion Matrix for Batch = 1135 is [[32  2  2  1]
#  [ 3 35  2  1]
#  [ 7  2  2  0]
#  [ 2  1  2  6]]
# Confusion Matrix for Batch = 1136 is [[33  1  1  0]
#  [ 5 19  0  2]
#  [ 4  0 10  3]
#  [ 6  0  5 11]]
# Confusion Matrix for Batch = 1137 is [[24  2  8  5]
#  [ 3 29  1  2]
#  [ 1  2  4  5]
#  [ 4  1  3  6]]
# Confusion Matrix for Batch = 1138 is [[22  3  0  4]
#  [ 5 29  1  2]
#  [ 1  0  9  1]
#  [ 5  4  2 12]]
# Confusion Matrix for Batch = 1139 is [[19  1  3  1]
#  [ 4 25  2  2]
#  [ 1  1 14  3]
#  [ 2  4  8 10]]
# Confusion Matrix for Batch = 1140 is [[14  3  1  3]
#  [ 2 22  1  2]
#  [ 1  0 13  3]
#  [ 7  2  7 19]]
# Confusion Matrix for Batch = 1141 is [[15  0  0  2]
#  [ 3 25  0  3]
#  [ 6  1 18  4]
#  [ 3  4  7  9]]
# Confusion Matrix for Batch = 1142 is [[12  1  2  0]
#  [ 2 16  1  7]
#  [ 4  1 18  5]
#  [ 3  3  3 22]]
# Confusion Matrix for Batch = 1143 is [[10  1  4  1]
#  [ 5 13  2  2]
#  [ 3  0 30  3]
#  [ 4  3  5 14]]
# Confusion Matrix for Batch = 1144 is [[14  0  5  4]
#  [ 1 10  1  4]
#  [ 1  0 26  6]
#  [ 0  3  2 23]]
# Confusion Matrix for Batch = 1145 is [[21  1  4  2]
#  [ 3  9  3  0]
#  [ 0  1 27  3]
#  [ 6  4  8  8]]
# Confusion Matrix for Batch = 1146 is [[15  2  0  3]
#  [ 3 18  6  1]
#  [ 2  1 15  4]
#  [ 1  0  8 21]]
# Confusion Matrix for Batch = 1147 is [[13  4  2  5]
#  [ 3 22  0  1]
#  [ 0  0 16  2]
#  [ 4  2  3 23]]
# Confusion Matrix for Batch = 1148 is [[18  3  0  5]
#  [ 2 24  0  1]
#  [ 0  0 19  4]
#  [ 1  0  5 18]]
# Confusion Matrix for Batch = 1149 is [[10  1  0  3]
#  [ 1 17  0  5]
#  [ 0  1 12  8]
#  [ 0  1  4 37]]
# Confusion Matrix for Batch = 1150 is [[14  1  6  2]
#  [ 2 21  3  5]
#  [ 2  0 15  3]
#  [ 6  3  8  9]]
# Confusion Matrix for Batch = 1151 is [[11  1  1  3]
#  [ 1 29  1  6]
#  [ 2  0 14  0]
#  [ 2  1 10 18]]
# Confusion Matrix for Batch = 1152 is [[19  1  3  1]
#  [ 0 24  2  0]
#  [ 3  0 13  7]
#  [ 5  2  5 15]]
# Confusion Matrix for Batch = 1153 is [[22  3  2  1]
#  [ 2 16  3  0]
#  [ 2  0 18  4]
#  [ 4  3  8 12]]
# Confusion Matrix for Batch = 1154 is [[21  1  2  4]
#  [ 2 15  0  2]
#  [ 1  0 18  9]
#  [ 0  0  5 20]]
# Confusion Matrix for Batch = 1155 is [[16  0  1  2]
#  [ 2  8  0  3]
#  [ 3  0 18  4]
#  [ 6  1  2 34]]
# Confusion Matrix for Batch = 1156 is [[13  1  2  4]
#  [ 4  5  0  3]
#  [ 2  0 31  8]
#  [ 5  0  3 19]]
# Confusion Matrix for Batch = 1157 is [[11  2  0  0]
#  [ 0 12  2  4]
#  [ 3  1 20  5]
#  [ 2  1  8 29]]
# Confusion Matrix for Batch = 1158 is [[16  0  1  6]
#  [ 1 10  2  5]
#  [ 1  1 22  4]
#  [ 2  2  2 25]]
# Confusion Matrix for Batch = 1159 is [[16  0  2  5]
#  [ 3 17  0  4]
#  [ 3  0 12  9]
#  [ 4  0  6 19]]
# Confusion Matrix for Batch = 1160 is [[ 8  4  1  2]
#  [ 5 28  2  2]
#  [ 4  1 14  3]
#  [ 6  2  5 13]]
# Confusion Matrix for Batch = 1161 is [[19  4  1  2]
#  [ 1 20  1  3]
#  [ 3  0 19  1]
#  [ 2  4  6 14]]
# Confusion Matrix for Batch = 1162 is [[18  2  0  6]
#  [ 2 22  0  3]
#  [ 4  0 12  5]
#  [ 2  2  5 17]]
# Confusion Matrix for Batch = 1163 is [[19  0  2  1]
#  [ 0 30  5  2]
#  [ 1  0 18  2]
#  [ 3  2 10  5]]
# Confusion Matrix for Batch = 1164 is [[26  5  2  1]
#  [ 0 18  1  2]
#  [ 3  0 13  3]
#  [ 2  7  9  8]]
# Confusion Matrix for Batch = 1165 is [[22  1  1  3]
#  [ 5 12  2  2]
#  [ 2  1 21  3]
#  [ 5  4  5 11]]
# Confusion Matrix for Batch = 1166 is [[14  0  1  3]
#  [ 0  7  4  3]
#  [ 1  1 32  3]
#  [ 4  2 10 15]]
# Confusion Matrix for Batch = 1167 is [[17  0  2  0]
#  [ 1 16  4  5]
#  [ 2  2 23  4]
#  [ 1  3  6 14]]
# Confusion Matrix for Batch = 1168 is [[14  1  4  0]
#  [ 3 15  3  2]
#  [ 4  1 23  3]
#  [ 3  4  9 11]]
# Confusion Matrix for Batch = 1169 is [[24  5  4  0]
#  [ 3 13  1  2]
#  [ 1  2 16  3]
#  [ 3  2  7 14]]
# Confusion Matrix for Batch = 1170 is [[ 9  1  2  8]
#  [ 3 14  3  5]
#  [ 1  0 11  5]
#  [ 2  2  2 32]]
# Confusion Matrix for Batch = 1171 is [[13  2  3  2]
#  [ 1 18  2  3]
#  [ 0  1 18  4]
#  [ 1  1  6 25]]
# Confusion Matrix for Batch = 1172 is [[24  4  2  3]
#  [ 2 17  1  2]
#  [ 0  0 18  7]
#  [ 2  3  2 13]]
# Confusion Matrix for Batch = 1173 is [[16  6  3  1]
#  [ 3 22  2  2]
#  [ 1  1 11  4]
#  [ 8  1  5 14]]
# Confusion Matrix for Batch = 1174 is [[ 6  2  2  5]
#  [ 3 23  1  2]
#  [ 1  0 17  5]
#  [ 2  6  8 17]]
# Confusion Matrix for Batch = 1175 is [[12  2  3  4]
#  [ 0 20  3  3]
#  [ 3  0 17  1]
#  [ 0  4  4 24]]
# Confusion Matrix for Batch = 1176 is [[13  1  7  4]
#  [ 4 28  1  0]
#  [ 1  0 21  0]
#  [ 1  6  6  7]]
# Confusion Matrix for Batch = 1177 is [[20  3  2  2]
#  [ 7 21  2  1]
#  [ 3  1 15  1]
#  [ 4  6  2 10]]
# Confusion Matrix for Batch = 1178 is [[19  1  4  1]
#  [ 3  8  3  2]
#  [ 3  0 27  3]
#  [ 2  2  2 20]]
# Confusion Matrix for Batch = 1179 is [[15  3  4  2]
#  [ 1 15  1  0]
#  [ 2  0 26  0]
#  [10  2  5 14]]
# Confusion Matrix for Batch = 1180 is [[12  1  1  3]
#  [ 2 12  0  2]
#  [ 4  0 34  3]
#  [ 0  3  4 19]]
# Confusion Matrix for Batch = 1181 is [[23  4  3  0]
#  [ 3 18  1  2]
#  [ 2  2 27  1]
#  [ 8  0  1  5]]
# Confusion Matrix for Batch = 1182 is [[ 8  2  2  2]
#  [ 4 18  1  2]
#  [ 0  0 30  3]
#  [ 3  2 12 11]]
# Confusion Matrix for Batch = 1183 is [[ 6  2  2  1]
#  [ 1 28  1  6]
#  [ 0  1 16  6]
#  [ 2  7  2 19]]
# Confusion Matrix for Batch = 1184 is [[24  3  0  5]
#  [ 0 18  0  3]
#  [ 4  0  9  6]
#  [ 0  1  6 21]]
# Confusion Matrix for Batch = 1185 is [[21  3  2  3]
#  [ 3 26  3  1]
#  [ 1  3 15  2]
#  [ 4  4  3  6]]
# Confusion Matrix for Batch = 1186 is [[21  1  3  0]
#  [ 4 26  3  2]
#  [ 3  0 15  3]
#  [ 2  3  4 10]]
# Confusion Matrix for Batch = 1187 is [[14  0  1  8]
#  [ 0 14  2  1]
#  [ 4  2 17  5]
#  [ 2  5  8 17]]
# Confusion Matrix for Batch = 1188 is [[14  2  5  1]
#  [ 3 32  3  0]
#  [ 4  1  9  1]
#  [ 1  3 10 11]]
# Confusion Matrix for Batch = 1189 is [[25  2  0  6]
#  [ 4 10  2  3]
#  [ 2  0 16  2]
#  [ 6  1  4 17]]
# Confusion Matrix for Batch = 1190 is [[14  0  0  4]
#  [ 5  7  4  1]
#  [ 1  1 16  3]
#  [ 4  1  3 36]]
# Confusion Matrix for Batch = 1191 is [[15  1  3  2]
#  [ 1 16  0  1]
#  [ 0  0 26  5]
#  [ 4  2  1 23]]
# Confusion Matrix for Batch = 1192 is [[14  3  1  7]
#  [ 1 16  3  2]
#  [ 0  0 21  4]
#  [ 4  1  3 20]]
# Confusion Matrix for Batch = 1193 is [[ 8  2  2  9]
#  [ 0 17  7  4]
#  [ 2  1 19  2]
#  [ 2  2 11 12]]
# Confusion Matrix for Batch = 1194 is [[11  1  3  1]
#  [ 3 27  2  1]
#  [ 1  0 20  7]
#  [ 1  3  5 14]]
# Confusion Matrix for Batch = 1195 is [[18  4  3  6]
#  [ 1 26  1  1]
#  [ 3  0 13  4]
#  [ 3  1  6 10]]
# Confusion Matrix for Batch = 1196 is [[17  1  1  2]
#  [ 5 27  2  2]
#  [ 2  1 13  1]
#  [ 7  4  5 10]]
# Confusion Matrix for Batch = 1197 is [[17  0  3  3]
#  [ 3 29  0  1]
#  [ 2  1 12  0]
#  [ 7  5  5 12]]
# Confusion Matrix for Batch = 1198 is [[20  1  3  1]
#  [ 4 29  4  1]
#  [ 1  0 10  1]
#  [ 6  4  6  9]]
# Confusion Matrix for Batch = 1199 is [[21  3  4  3]
#  [ 7 23  0  3]
#  [ 3  0 14  3]
#  [ 2  1  5  8]]
# Training Set Accuracy = 0.6429833333333334	Recall = 0.6429833333333332	Precision = 0.6564437601825045	F1-Score = 0.6403924984721228	Loss = 0.008844300173223019	Confusion Matrix = [[21  3  4  3]
#  [ 7 23  0  3]
#  [ 3  0 14  3]
#  [ 2  1  5  8]]

# %%
batch_size = len(data['Description'])
model.eval()
correct = 0
test_loss = 0
precision = []
f1 = []
recall = []


for i in range(int(len(data['Description'])/batch_size)):
    batch_embeddings = torch.zeros(batch_size, max_len, 50, dtype = torch.float32, device = device)

    for k in range(batch_size*i, batch_size*i+batch_size):
        sentence = re.findall(r"[\w']+|[.,!?;'-]", data['Description'][k])
        for j, word in enumerate(sentence):
            if (j >= max_len):
                break
            if (word not in word_indices):
                    batch_embeddings[k-100*i][j] = oov_embeddings
            else:
                batch_embeddings[k-100*i][j] = torch.from_numpy(svd_embeddings[word_indices[word]])
        for j in range(max(0, max_len-len(sentence))):                      # Pad the sentences with the PAD Token or OOV Embeddings
            batch_embeddings[k-100*i][j+len(sentence)] = oov_embeddings
    y_pred = model(batch_embeddings).to(device)

    # y_true = torch.Tensor(data_train['Class Index'][100*i:100*(i+1)]).to(torch.int64)
    y_true = torch.tensor(data['Class Index'].values[batch_size*i:batch_size*(i+1)], dtype=torch.int64, device=device)
    loss = criterion(y_pred, y_true-1)
    test_loss += loss
    predicted = torch.argmax(y_pred, dim = 1)
    correct += torch.sum(predicted+1 == y_true).item()

    pred = (predicted+torch.ones_like(predicted)).cpu().numpy()
    true = y_true.cpu().numpy()
    precision.append(precision_score(pred, true, average='weighted'))
    f1.append(f1_score(pred, true, average='weighted'))
    recall.append(recall_score(pred, true, average='weighted'))
    confusion = confusion_matrix(pred, true)
    print(f"Confusion Matrix for Batch = {i} is {confusion}")

print(f"Testing Set Accuracy = {correct / len(data['Description'])}\tRecall = {np.mean(recall)}\tPrecision = {np.mean(precision)}\tF1-Score = {np.mean(f1)}\tLoss = {test_loss/len(data['Description'])}")
# Out:
# Confusion Matrix for Batch = 0 is [[1010  256  281  286]
#  [ 316 1302  200  247]
#  [ 244  107  939  346]
#  [ 330  235  480 1021]]
# Testing Set Accuracy = 0.5621052631578948	Recall = 0.5621052631578948	Precision = 0.5668663434903047	F1-Score = 0.5632476957910101	Loss = 0.00014017483044881374
